# %%
### 00_top <a id="title_page"></a

### 00_packages

 <a id="title_page"></a

owner=""
###econiomics DASHBOARD
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display, HTML
import Haver
Haver.path(Haver.direct(1))    
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import os
def clear():
    os.system('cls')
# then you can clear the window with:
from matplotlib.dates import date2num
import os
os.chdir('C:/database/dashboard')
#C:\database\dashboard
print(os.getcwd())

import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import matplotlib.ticker as plticker
import matplotlib.dates as mdates
from matplotlib.ticker import MultipleLocator

import seaborn as sns

from matplotlib.colors import LinearSegmentedColormap

import matplotlib.pyplot as pit
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as pit
from PIL import Image
import seaborn as sns
import plotly.graph_objects as go
from matplotlib.colors import LinearSegmentedColormap

parameter1_s=9
parameter2_s=6
parameter3_s=11
parameter4_s=7
parameter5_s=20
parameter3=15
parameter4=15
parameter5=20
s0=1
s1=5
s2=6
s3=7
s4=12
s5=14
s6=15
l0=1.0
l1=1.0
l2=1.5
tail_y=12
tail_0=24
tail_1=60
tail_2=72
tail_4=36
parameter_size1=8
parameter_size2=6
parameter_w_seas=14
parameter_h_seas=13
million = 1000000
horizon_120 = 120
horizon_tb = 24
#DAA0236BLUECHIP

def zscore(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  o = arr.rolling(window = window).std()
  return (x-u)/o

def zscore_avg(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  return (x-u)
    
country_database = "EUDATA"

country_database = "EUDATA"

### 001 EA11-20: EA11-20 HICP by component   <a id="title_page"></a

####### Inflation 
####### Inflation 
horizon_tb = 24
horizon_1 = 24
country_database = "EUDATA"
#P023HOEF@
#Indexes & growth rates updated with the flash release: (2015=100)
print("tickers")
eu_m_tickers = ['p023h', 'p023hoe', 'p023hoeu',
                'p023hoef', 'p023hf', 'p023hpf', 
                'p023huf', 'p023he', 'p023hnig', 'p023hs']
print("getting from api")
hv_tb_eu_001_001_m=Haver.data(eu_m_tickers, "EUDATA", dates=True)
#print(hv_tb_eu_001_001_m)
#print(hv_tb_eu_001_001_m.columns)
for x in range(len(eu_m_tickers)):
    #print(x)
    variable=str(eu_m_tickers[x])
    #print(variable)
    hv_tb_eu_001_001_m[variable] = hv_tb_eu_001_001_m[variable].pct_change(12).multiply(100).round(3)
    #print(hv_tb_eu_001_001_m[variable])

print("renaming")
hv_tb_eu_001_001_m.rename(columns={"p023h": "EA11-20: HICP Overall NSA Y/Y"}, inplace=True)
hv_tb_eu_001_001_m.rename(columns={"p023hoe": "EA11-20: HICP excl Energy NSA Y/Y"}, inplace=True)
hv_tb_eu_001_001_m.rename(columns={"p023hoeu": "EA11-20: HICP excl Energy, Unpr Food NSA Y/Y"}, inplace=True)
hv_tb_eu_001_001_m.rename(columns={"p023hoef": "EA11-20: HICP excl Enrgy, Fd, Alchl NSA Y/Y"}, inplace=True)
hv_tb_eu_001_001_m.rename(columns={"p023hf": "EA11-20: HICP Food & Alcohol NSA Y/Y"}, inplace=True)
hv_tb_eu_001_001_m.rename(columns={"p023hpf": "EA11-20: HICP Processed Food & Alcohol NSA Y/Y"}, inplace=True)
hv_tb_eu_001_001_m.rename(columns={"p023huf": "EA11-20: HICP Unprocessed Food NSA Y/Y"}, inplace=True)
hv_tb_eu_001_001_m.rename(columns={"p023he": "EA11-20: HICP Energy NSA Y/Y"}, inplace=True)
hv_tb_eu_001_001_m.rename(columns={"p023hnig": "EA11-20: HICP Nonenergy goods NSA Y/Y"}, inplace=True)
hv_tb_eu_001_001_m.rename(columns={"p023hs": "EA11-20: HICP Services NSA Y/Y"}, inplace=True)

#h#v_tb_eu_001_001_m_g_001 = hv_tb_eu_001_001_m.copy()
#hv_tb_eu_001_001_m = hv_tb_eu_001_001_m.tail(horizon_tb)
#hv_tb_eu_001_001_m = hv_tb_eu_001_001_m.transpose()
#hv_tb_eu_001_001_m.index.names = ['Variable']
# dashboard.to_clipboard()
#print(hv_tb_eu_001_001_m)
# dashboard.to_clipboard()




#v_tb_uk_002_006_m = hv_tb_uk_002_006_m.tail(horizon_1)
#hv_tb_uk_002_006_m = hv_tb_uk_002_006_m.transpose()
#hv_tb_uk_002_006_m.index.names = ['Variable']
#dashboard.to_clipboard()
#hv_tb_uk_005_001_m=hv_tb_uk_005_001_m.round(0)
hv_tb_eu_001_001_m_g_001 = hv_tb_eu_001_001_m.copy()

hv_tb_eu_001_001_m.index=hv_tb_eu_001_001_m.index.date
hv_tb_eu_001_001_m = hv_tb_eu_001_001_m.tail(horizon_tb)
hv_tb_eu_001_001_t1=hv_tb_eu_001_001_m.tail(horizon_tb)

hv_tb_eu_001_001_m_t = hv_tb_eu_001_001_m.transpose()
hv_tb_eu_001_001_m_t.index.names = ['Variable']

hv_tb_eu_001_001_t1_t = hv_tb_eu_001_001_t1.transpose()
hv_tb_eu_001_001_t1_t.index.names = ['Variable']

print(hv_tb_eu_001_001_t1_t)

### 001 EA11-20: EA11-20 HICP by component table


############################################################
######Table 1

#####here*******
title_table="ea11_20_hicp_component"
df =hv_tb_eu_001_001_t1.copy()
df_transposed = hv_tb_eu_001_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_eu_001_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_eu_001_001_t1.copy()


df.index = pd.to_datetime(df.index)
#df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_eu_001_001_m_t_002.png')






print("step2")

####### Inflation 
####### Inflation 
title_r0 = "EA11-20: HICP"
title_r = title_r0
y_label = "Index %"
x_label = title_r
list_c = ["EA11-20: HICP Overall NSA Y/Y",
          "EA11-20: HICP excl Enrgy, Fd, Alchl NSA Y/Y"]
df1 = hv_tb_eu_001_001_m_g_001[list_c]
df1 = df1.tail(72)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["EA11-20: HICP Overall NSA Y/Y"], 
        color="darkgreen", linewidth=l1, linestyle="-", marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA11-20: HICP excl Enrgy, Fd, Alchl NSA Y/Y"], 
        color="darkblue", linewidth=l1, linestyle="-", marker='D', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_001_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r0="EA11-20: HICP"
title_r=title_r0
y_label="Index %"
x_label=title_r
list_c=["EA11-20: HICP Overall NSA Y/Y",           
        "EA11-20: HICP excl Enrgy, Fd, Alchl NSA Y/Y"]
df1=hv_tb_eu_001_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["EA11-20: HICP Overall NSA Y/Y"], 
        color="darkgreen", linewidth= l1, linestyle='-',
        marker='P', markersize=s2)

g1.plot(kind='line', ax=ax,y=["EA11-20: HICP excl Enrgy, Fd, Alchl NSA Y/Y"], 
        color="darkblue", linewidth= l1, linestyle='-',
        marker="D", markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_001_001_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

####### Inflation 
####### Inflation 

title_r0="EA11-20: HICP"
title_r=title_r0
y_label="Index %"
x_label=title_r
list_c=["EA11-20: HICP Overall NSA Y/Y",  
        "EA11-20: HICP excl Enrgy, Fd, Alchl NSA Y/Y"]
df1=hv_tb_eu_001_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["EA11-20: HICP Overall NSA Y/Y"], 
        color="darkgreen", linewidth= l1, linestyle='-',
        marker='P', markersize=s2)

g1.plot(kind='line', ax=ax,y=["EA11-20: HICP excl Enrgy, Fd, Alchl NSA Y/Y"],
        color="darkblue", linewidth= l1, linestyle='-',
        marker="D", markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_001_001_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r0 = "EA11-20: HICP Food"
title_r = title_r0
y_label = "Index %"
x_label = title_r
list_c = ["EA11-20: HICP Food & Alcohol NSA Y/Y",
          "EA11-20: HICP Processed Food & Alcohol NSA Y/Y",
          "EA11-20: HICP Unprocessed Food NSA Y/Y"]
df1 = hv_tb_eu_001_001_m_g_001[list_c]
df1 = df1.tail(72)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["EA11-20: HICP Food & Alcohol NSA Y/Y"], color="darkgreen", linewidth=l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA11-20: HICP Processed Food & Alcohol NSA Y/Y"], color="darkblue", linewidth=l1, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA11-20: HICP Unprocessed Food NSA Y/Y"], color="darkred", linewidth=l1, linestyle='-',
        marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_001_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r = title_r0
y_label = "Index %"
x_label = title_r
list_c = [
    "EA11-20: HICP Food & Alcohol NSA Y/Y",
    "EA11-20: HICP Processed Food & Alcohol NSA Y/Y",
    "EA11-20: HICP Unprocessed Food NSA Y/Y"
]
df1 = hv_tb_eu_001_001_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["EA11-20: HICP Food & Alcohol NSA Y/Y"], 
        color="darkgreen", linewidth=l1, linestyle="-",
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA11-20: HICP Processed Food & Alcohol NSA Y/Y"], 
        color="darkblue", linewidth=l1, linestyle="-",
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA11-20: HICP Unprocessed Food NSA Y/Y"], 
        color="darkred", linewidth=l1, linestyle="-",
        marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_001_001_m_g_002z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r0="EA11-20: HICP Energy"
title_r=title_r0
y_label="Index %"
x_label=title_r
list_c=["EA11-20: HICP Energy NSA Y/Y"]
df1=hv_tb_eu_001_001_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["EA11-20: HICP Energy NSA Y/Y"], 
        color="darkgreen", linewidth= l1, linestyle='-',
        marker='P',markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle ="dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_001_001_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r = title_r0
y_label = "Index %"
x_label = title_r
list_c = ["EA11-20: HICP Energy NSA Y/Y"]
df1 = hv_tb_eu_001_001_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["EA11-20: HICP Energy NSA Y/Y"], 
        color="darkgreen", linewidth=l1, linestyle='-', marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_001_001_m_g_003z.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r = title_r0
y_label = "Index %"
x_label = title_r
list_c = ["EA11-20: HICP Energy NSA Y/Y"]
df1 = hv_tb_eu_001_001_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["EA11-20: HICP Energy NSA Y/Y"], color="darkgreen",
        linewidth=l1, linestyle='-', marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_001_001_m_g_003z.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r0="EA11-20: HICP Services"
title_r=title_r0
y_label="Index %"
x_label=title_r
list_c=["EA11-20: HICP Services NSA Y/Y"]
df1=hv_tb_eu_001_001_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax, y=["EA11-20: HICP Services NSA Y/Y"], 
        color="darkred", linewidth=l1, linestyle="-", marker="o", markersize=s2)
plt.axhline(0, color="black", lw=1, linestyle="dashed", alpha=0.75)
plt.style.use("default")
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis="both", alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_001_001_m_g_004.png", bbox_inches="tight")
plt.close()
plt.close("all")
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r = title_r0
y_label = "Index %"
x_label = title_r
list_c = ["EA11-20: HICP Services NSA Y/Y"]
df1 = hv_tb_eu_001_001_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["EA11-20: HICP Services NSA Y/Y"], color="darkred", linewidth=l1, linestyle="-",
        marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle="dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_001_001_m_g_004z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

### 001 EA  CPI BY COUNTRY <a id="title_page"></a

####### Inflation 
####### Inflation 
print("tickers")
eu_m_tickers = ['h134h', 'h134hoeu', 'h134hoef', 'h134hoea', 'h134hg', 'h134hs',
                'h132h', 'h132hoeu', 'h132hoef', 'h132hoea', 'h132hg', 'h132hs',
                'h136h', 'h136hoeu', 'h136hoef', 'h136hoea', 'h136hg', 'h136hs',
                'h138h', 'h138hoeu', 'h138hoef', 'h138hoea', 'h138hg', 'h138hs',
                'h184h', 'h184hoeu', 'h184hoef', 'h184hoea', 'h184hg', 'h184hs',
                'h182h', 'h182hoeu', 'h182hoef', 'h182hoea', 'h182hg', 'h182hs',
                'h122h', 'h122hoeu', 'h122hoef', 'h122hoea', 'h122hg', 'h122hs',
                'h124h', 'h124hoeu', 'h124hoef', 'h124hoea', 'h124hg', 'h124hs',
                'h172h', 'h172hoeu', 'h172hoef', 'h172hoea', 'h172hg', 'h172hs',
                'h939h', 'h939hoeu', 'h939hoef', 'h939hoea', 'h939hg', 'h939hs',
                'h946h', 'h946hoeu', 'h946hoef', 'h946hg', 'h946hs']

print("getting from api")
hv_tb_eu_002_001_m = Haver.data(eu_m_tickers, "EUDATA", dates=True)

#print(hv_tb_eu_002_001_m)
#print(hv_tb_eu_002_001_m.columns)

for x in range(len(eu_m_tickers)):
    #print(x)
    variable = str(eu_m_tickers[x])
    #print(variable)
    hv_tb_eu_002_001_m[variable] = hv_tb_eu_002_001_m[variable].pct_change(12).multiply(100).round(3)
    #print(hv_tb_eu_002_001_m[variable])

print("renaming")
hv_tb_eu_002_001_m.rename(columns={"h122h": "EU Austria HICP SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h122hoeu": "Austria CPI excl Energy, Unpr Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h122hoef": "Austria CPI excl Energy, Fd, Alchl SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h122hoea": "Austria CPI excl Energy, Seas Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h122hg": "Austria CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h122hs": "Austria CPI Services SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h124h": "EU Belgium HICP SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h124hoeu": "Belgium CPI excl Energy, Unpr Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h124hoef": "Belgium CPI excl Energy, Fd, Alchl SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h124hoea": "Belgium CPI excl Energy, Seas Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h124hg": "Belgium CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h124hs": "Belgium CPI Services SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h172h": "EU Finland HICP SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h172hoeu": "Finland CPI excl Energy, Unpr Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h172hoef": "Finland CPI excl Energy, Fd, Alchl SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h172hoea": "Finland CPI excl Energy, Seas Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h172hg": "Finland CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h172hs": "Finland CPI Services SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h939h": "EU Estonia HICP SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h939hoeu": "Estonia CPI excl Energy, Unpr Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h939hoef": "Estonia CPI excl Energy, Fd, Alchl SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h939hoea": "Estonia CPI excl Energy, Seas Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h939hg": "Estonia CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h939hs": "Estonia CPI Services SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h946h": "EU Lithuania HICP SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h946hoeu": "Lithuania CPI excl Energy, Unpr Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h946hoef": "Lithuania CPI excl Energy, Fd, Alchl SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h946hoea": "Lithuania CPI excl Energy, Seas Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h946hg": "Lithuania CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h946hs": "Lithuania CPI Services SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h132h": "EU France HICP SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h132hoeu": "France CPI excl Energy, Unpr Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h132hoef": "France CPI excl Energy, Fd, Alchl SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h132hoea": "France CPI excl Energy, Seas Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h132hg": "France CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h132hs": "France CPI Services SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h134h": "EU Germany HICP SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h134hoeu": "Germany CPI excl Energy, Unpr Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h134hoef": "Germany CPI excl Energy, Fd, Alchl SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h134hoea": "Germany CPI excl Energy, Seas Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h134hg": "Germany CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h134hs": "Germany CPI Services SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h136h": "EU Italy HICP SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h136hoeu": "Italy CPI excl Energy, Unpr Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h136hoef": "Italy CPI excl Energy, Fd, Alchl SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h136hoea": "Italy CPI excl Energy, Seas Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h136hg": "Italy CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h136hs": "Italy CPI Services SA Y/Y"}, inplace=True)


hv_tb_eu_002_001_m.rename(columns={"h138h": "EU Netherlands HICP SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h138hoeu": "Netherlands CPI excl Energy, Unpr Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h138hoef": "Netherlands CPI excl Energy, Fd, Alchl SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h138hoea": "Netherlands CPI excl Energy, Seas Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h138hg": "Netherlands CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h138hs": "Netherlands CPI Services SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h184h": "EU Spain HICP SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h184hoeu": "Spain CPI excl Energy, Unpr Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h184hoef": "Spain CPI excl Energy, Fd, Alchl SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h184hoea": "Spain CPI excl Energy, Seas Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h184hg": "Spain CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h184hs": "Spain CPI Services SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h182h": "EU Portugal HICP SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h182hoeu": "Portugal CPI excl Energy, Unpr Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h182hoef": "Portugal CPI excl Energy, Fd, Alchl SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h182hoea": "Portugal CPI excl Energy, Seas Food SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h182hg": "Portugal CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_001_m.rename(columns={"h182hs": "Portugal CPI Services SA Y/Y"}, inplace=True)

hv_tb_eu_002_001_m_g_001 = hv_tb_eu_002_001_m.copy()
hv_tb_eu_002_001_m = hv_tb_eu_002_001_m.tail(horizon_tb)
hv_tb_eu_002_001_m = hv_tb_eu_002_001_m.transpose()
hv_tb_eu_002_001_m.index.names = ['Variable']
# dashboard.to_clipboard()
print("Complete")
print("step2")

### 001 EA  CPI BY COUNTRY  hcpi graph 

print(hv_tb_eu_002_001_m_g_001.columns)
#Austria CPI excl Energy, Fd, Alch SA Y/Y



text_label = " HICP SA Y/Y"
text_label0="EU "
title_r0 = "HICP SA Y/Y"
title_r = title_r0
y_label = "Index %"
x_label = title_r

list_c = [
    (str(text_label0) + "Austria" + str(text_label)),
    (str(text_label0) + "Belgium" + str(text_label)),
    (str(text_label0) + "Finland" + str(text_label)),
    (str(text_label0) + "Estonia" + str(text_label)),
    (str(text_label0) + "Lithuania" + str(text_label)),
    (str(text_label0) + "France" + str(text_label)),
    (str(text_label0) + "Germany" + str(text_label)),
    (str(text_label0) + "Italy" + str(text_label)),
    (str(text_label0) + "Netherlands" + str(text_label)),
    (str(text_label0) + "Spain" + str(text_label)),
    (str(text_label0) + "Portugal" + str(text_label))
]
df1 = hv_tb_eu_002_001_m_g_001[list_c]
df1 = df1.tail(72)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Austria" + str(text_label))], color="orange",
        linewidth=l1, linestyle='-', marker='P', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Belgium" + str(text_label))], color="black",
        linewidth=l1, linestyle='-', marker="x", markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Finland" + str(text_label))], color="black",
        linewidth=l1, linestyle='-', marker="x", markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Estonia" + str(text_label))], color="red",
        linewidth=l1, linestyle='-', marker='D', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Lithuania" + str(text_label))], color="red",
        linewidth=l1, linestyle='-', marker="x", markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "France" + str(text_label))], color="black",
        linewidth=l1, linestyle="-", marker="x",markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Germany" + str(text_label))], color="black",
        linewidth=l1, linestyle='-', marker="", markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Italy" + str(text_label))], color="black",
        linewidth=l1, linestyle='-', marker="", markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Netherlands" + str(text_label))], color="green",
        linewidth=l1, linestyle='-', marker="X", markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Spain" + str(text_label))], color="black",
         linewidth=l1, linestyle='-', marker="X", markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Portugal" + str(text_label))], color="black",
         linewidth=l1, linestyle='-', marker="X", markersize=s1)      

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_002_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

print("cOMPLETE")






# title_r = "title_ro"
# y_label = "Index %"
# x_label = "title_r"
text_label = " HICP SA Y/Y"
text_label0="EU "
title_r0 = "HICP SA Y/Y"
title_r = title_r0
y_label = "Index %"
x_label = title_r

list_c = [
    (str(text_label0) + "Austria" + str(text_label)),
    (str(text_label0) + "Belgium" + str(text_label)),
    (str(text_label0) + "Finland" + str(text_label)),
    (str(text_label0) + "Estonia" + str(text_label)),
    (str(text_label0) + "Lithuania" + str(text_label)),
    (str(text_label0) + "France" + str(text_label)),
    (str(text_label0) + "Germany" + str(text_label)),
    (str(text_label0) + "Italy" + str(text_label)),
    (str(text_label0) + "Netherlands" + str(text_label)),
    (str(text_label0) + "Spain" + str(text_label)),
    (str(text_label0) + "Portugal" + str(text_label))
]
df1 = hv_tb_eu_002_001_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Austria" + str(text_label))], color="orange",
        linewidth=l1, linestyle='-', marker='P', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Belgium" + str(text_label))], color="black",
        linewidth=l1, linestyle='-', marker="x", markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Finland" + str(text_label))], color="black",
        linewidth=l1, linestyle='-', marker="x", markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Estonia" + str(text_label))], color="red",
        linewidth=l1, linestyle='-', marker='D', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Lithuania" + str(text_label))], color="red",
        linewidth=l1, linestyle='-', marker="x", markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "France" + str(text_label))], color="black",
        linewidth=l1, linestyle="-", marker="x",markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Germany" + str(text_label))], color="black",
        linewidth=l1, linestyle='-', marker="", markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Italy" + str(text_label))], color="black",
        linewidth=l1, linestyle='-', marker="", markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Netherlands" + str(text_label))], color="green",
        linewidth=l1, linestyle='-', marker="X", markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Spain" + str(text_label))], color="black",
         linewidth=l1, linestyle='-', marker="X", markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Portugal" + str(text_label))], color="black",
         linewidth=l1, linestyle='-', marker="X", markersize=s1)      

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_002_001_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2





### 001 EA  CPI BY COUNTRY  CPI excl Energy, Fd, Alch SA Y/Y  graph 

#CPI excl Energy, Fd, Alch SA Y/Y

text_label = " CPI excl Energy, Fd, Alchl SA Y/Y"
title_r0 = "CPI excluding Energy, Food and Alcohol SA Y/Y"
title_r = title_r0
y_label = "Index %"
x_label = title_r
list_c = [
    ("Austria" + str(text_label)),
    ("Belgium" + str(text_label)),
    ("Finland" + str(text_label)),
    ("Estonia" + str(text_label)),
    ("Lithuania" + str(text_label)),
     ("France" + str(text_label)),
     ("Germany" + str(text_label)),
    ("Italy" + str(text_label)),
    ("Netherlands" + str(text_label)),
    ("Spain" + str(text_label)),
    ("Portugal" + str(text_label))
]
df1 = hv_tb_eu_002_001_m_g_001[list_c]
df1 = df1.tail(72)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[("Austria" + str(text_label))], color="orange", linewidth=l1, linestyle='', marker='P', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Belgium" + str(text_label))], color="black", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Finland" + str(text_label))], color="black", linewidth=l1, linestyle='-', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Estonia" + str(text_label))], color="red", linewidth=l1, linestyle='-', marker='D', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Lithuania" + str(text_label))], color="red", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("France" + str(text_label))], color="black", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Germany" + str(text_label))], color="black", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Italy" + str(text_label))], color="black", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Netherlands" + str(text_label))], color="green", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Spain" + str(text_label))], color="black", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Portugal" + str(text_label))], color="black", linewidth=l1, linestyle='', marker='', markersize=s1)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_002_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2





title_r=title_r0
y_label="Index %"

x_label=title_r
list_c=[("Austria"+str(text_label)),
        ("Belgium"+str(text_label)),
        ("Finland"+str(text_label)),
        ("Estonia"+str(text_label)),
        ("Lithuania"+str(text_label)),
        ("France"+str(text_label)),
        ("Germany"+str(text_label)),
        ("Italy"+str(text_label)),
        ("Netherlands"+str(text_label)),
        ("Spain"+str(text_label)),
        ("Portugal"+str(text_label))]
df1=hv_tb_eu_002_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax= plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[("Austria" + str(text_label))], color="orange", linewidth=l1, linestyle='', marker='P', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Belgium" + str(text_label))], color="black", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Finland" + str(text_label))], color="black", linewidth=l1, linestyle='-', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Estonia" + str(text_label))], color="red", linewidth=l1, linestyle='-', marker='D', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Lithuania" + str(text_label))], color="red", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("France" + str(text_label))], color="black", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Germany" + str(text_label))], color="black", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Italy" + str(text_label))], color="black", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Netherlands" + str(text_label))], color="green", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Spain" + str(text_label))], color="black", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Portugal" + str(text_label))], color="black", linewidth=l1, linestyle='', marker='', markersize=s1)
plt.axhline(0, color="black", lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_002_001_m_g_002z.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

### 001 EA  CPI BY COUNTRY QQ <a id="title_page"></a

 

#headline CORE Q/Q
print("tickera")

eu_m_tickers = ['h134h', 'h134hoeu', 'h134hoef', 'h134hoea', 'h134hg', 'h134hs',
                                           'h132h', 'h132hoeu', 'h132hoef', 'h132hoea', 'h132hg', 'h132hs',
                'h136h', 'h136hoeu', 'h136hoef', 'h136hoea', 'h136hg', 'h136hs',
                'h138h', 'h138hoeu', 'h138hoef', 'h138hoea', 'h138hg', 'h138hs',
                'h184h', 'h184hoeu', 'h184hoef', 'h184hoea', 'h184hg', 'h184hs',
                'h182h', 'h182hoeu', 'h182hoef', 'h182hoea', 'h182hg', 'h182hs',
                'h122h', 'h122hoeu', 'h122hoef', 'h122hoea', 'h122hg', 'h122hs',
                'h124h', 'h124hoeu', 'h124hoef', 'h124hoea', 'h124hg', 'h124hs',
                'h172h', 'h172hoeu', 'h172hoef', 'h172hoea', 'h172hg', 'h172hs',
                'h939h', 'h939hoeu', 'h939hoef', 'h939hoea', 'h939hg', 'h939hs',
                'h946h', 'h946hoeu', 'h946hoef', 'h946hg', 'h946hs']
print("getting from api")
hv_tb_eu_002_002_m=Haver.data(eu_m_tickers, "EUDATA", dates=True)
#print(hv_tb_eu_002_002_m)
#print(hv_tb_eu_002_002_m.columns)

for x in range(len(eu_m_tickers)):
     variable=str(eu_m_tickers [x])
     hv_tb_eu_002_002_m[variable] = hv_tb_eu_002_002_m[variable].pct_change(4).multiply(100).round(3)
print("renaming")
hv_tb_eu_002_002_m.rename(columns={"h122h": "EU Austria HICP SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h122hoeu": "Austria CPI excl Energy, Unpr Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h122hoef": "Austria CPI excl Energy, Fd, Alchl SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h122hoea": "Austria CPI excl Energy, Seas Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h122hg": "Austria CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h122hs": "Austria CPI Services SA Q/Q"}, inplace=True)

hv_tb_eu_002_002_m.rename(columns={"h124h": "EU Belgium HICP SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h124hoeu": "Belgium CPI excl Energy, Unpr Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h124hoef": "Belgium CPI excl Energy, Fd, Alchl SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h124hoea": "Belgium CPI excl Energy, Seas Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h124hg": "Belgium CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h124hs":"Belgium CPI Services SA Q/Q"}, inplace=True)

hv_tb_eu_002_002_m.rename(columns={"h172h": "EU Finland HICP SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h172hoeu": "Finland CPI excl Energy, Unpr Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h172hoef": "Finland CPI excl Energy, Fd, Alchl SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h172hoea": "Finland CPI excl Energy, Seas Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h172hg": "Finland CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h172hs": "Finland CPI Services SA Q/Q"}, inplace=True)


hv_tb_eu_002_002_m.rename(columns={"h939h": "EU Estonia HICP SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h939hoeu": "Estonia CPI excl Energy, Unpr Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h939hoef": "Estonia CPI excl Energy, Fd, Alchl SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h939hoea": "Estonia CPI excl Energy, Seas Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h939hg": "Estonia CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h939hs": "Estonia CPI Services SA Q/Q"}, inplace=True)

hv_tb_eu_002_002_m.rename(columns={"h946h":"EU Lithuania HICP SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h946hoeu": "Lithuania CPI excl Energy, Unpr Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h946hoef": "Lithuania CPI excl Energy, Fd, Alchl SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h946hoea": "Lithuania CPI excl Energy, Seas Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h946hg":"Lithuania CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h946hs":"Lithuania CPI Services SA Q/Q"}, inplace=True)

hv_tb_eu_002_002_m.rename(columns={"h132h": "EU France HICP SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h132hoeu": "France CPI excl Energy, Unpr Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h132hoef": "France CPI excl Energy, Fd, Alchl SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h132hoea": "France CPI excl Energy, Seas Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h132hg": "France CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h132hs": "France CPI Services SA Q/Q"}, inplace=True)

hv_tb_eu_002_002_m.rename(columns={"h134h": "EU Germany HICP SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h134hoeu": "Germany CPI excl Energy, Unpr Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h134hoef": "Germany CPI excl Energy, Fd, Alchl SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h134hoea": "Germany CPI excl Energy, Seas Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h134hg": "Germany CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h134hs": "Germany CPI Services SA Q/Q"}, inplace=True)

hv_tb_eu_002_002_m.rename(columns={"h136h": "EU Italy HICP SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h136hoeu": "Italy CPI excl Energy, Unpr Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h136hoef": "Italy CPI excl Energy, Fd, Alchl SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h136hoea": "Italy CPI excl Energy, Seas Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h136hg": "Italy CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h136hs": "Italy CPI Services SA Q/Q"}, inplace=True)

hv_tb_eu_002_002_m.rename(columns={"h138h": "EU Netherlands HICP SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h138hoeu": "Netherlands CPI excl Energy, Unpr Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h138hoef": "Netherlands CPI excl Energy, Fd, Alchl SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h138hoea": "Netherlands CPI excl Energy, Seas Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h138hg": "Netherlands CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h138hs": "Netherlands CPI Services SA Q/Q"}, inplace=True)

hv_tb_eu_002_002_m.rename(columns={"h184h": "EU Spain HICP SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h184hoeu": "Spain CPI excl Energy, Unpr Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h184hoef": "Spain CPI excl Energy, Fd, Alchl SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h184hoea": "Spain CPI excl Energy, Seas Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h184hg": "Spain CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h184hs": "Spain CPI Services SA Q/Q"}, inplace=True)

hv_tb_eu_002_002_m.rename(columns={"h182h": "EU Portugal HICP SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h182hoeu": "Portugal CPI excl Energy, Unpr Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h182hoef": "Portugal CPI excl Energy, Fd, Alchl SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h182hoea": "Portugal CPI excl Energy, Seas Food SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h182hg": "Portugal CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_002_m.rename(columns={"h182hs": "Portugal CPI Services SA Q/Q"}, inplace=True)

hv_tb_eu_002_002_m_g_001 = hv_tb_eu_002_002_m.copy()
hv_tb_eu_002_002_m = hv_tb_eu_002_002_m.tail(horizon_tb)
hv_tb_eu_002_002_m = hv_tb_eu_002_002_m.transpose()
hv_tb_eu_002_002_m.index.names = ['Variable']
# dashboard.to_clipboard()

#print(hv_tb_eu_002_002_m)
# dashboard.to_clipboard()
#path_display = tb_eu_002_002_m.csv'
##print(path_display)
#hv_tb_eu_002_002_m.to_csv(path_display, index=True, header=True)







### 001 EA  CPI BY COUNTRY hicp  QQ

print("step2")
#####headlines
text_label=" HICP SA Q/Q"
text_label0="EU "
title_r0="HICP SA Q/Q"
title_r=title_r0
y_label="Index %"
x_label=title_r
list_c = [
    (str(text_label0) + "Austria" + str(text_label)),
    (str(text_label0) + "Belgium" + str(text_label)),
    (str(text_label0) + "Finland" + str(text_label)),
    (str(text_label0) + "Estonia" + str(text_label)),
    (str(text_label0) + "Lithuania" + str(text_label)),
    (str(text_label0) + "France" + str(text_label)),
    (str(text_label0) + "Germany" + str(text_label)),
    (str(text_label0) + "Italy" + str(text_label)),
    (str(text_label0) + "Netherlands" + str(text_label)),
    (str(text_label0) + "Spain" + str(text_label)),
    (str(text_label0) + "Portugal" + str(text_label))
]

df1 = hv_tb_eu_002_002_m_g_001[list_c]
df1 = df1.tail(72)
g1 = df1.copy()

fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Austria" + str(text_label))], color="orange", 
        linewidth=l1, linestyle='', marker='P', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Belgium" + str(text_label))], color="black", 
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Finland" + str(text_label))], color="black", 
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Estonia" + str(text_label))], color="red", 
        linewidth=l1, linestyle='', marker='D', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Lithuania" + str(text_label))], color="red",
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "France" + str(text_label))], color="black", 
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Germany" + str(text_label))], color="black", 
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Italy" + str(text_label))], color="black", 
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Netherlands" + str(text_label))], color="green", 
        linewidth=l1, linestyle='', marker='X', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Spain" + str(text_label))], color="black", 
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Portugal" + str(text_label))], color="black", 
        linewidth=l1, linestyle='', marker='', markersize=s1)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_003_001_m_g_001.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

print("step2")
#####headlines
text_label=" HICP SA Q/Q"
text_label0="EU "
title_r0="HICP SA Q/Q"
title_r=title_r0
y_label="Index %"
x_label=title_r
list_c = [
    (str(text_label0) + "Austria" + str(text_label)),
    (str(text_label0) + "Belgium" + str(text_label)),
    (str(text_label0) + "Finland" + str(text_label)),
    (str(text_label0) + "Estonia" + str(text_label)),
    (str(text_label0) + "Lithuania" + str(text_label)),
    (str(text_label0) + "France" + str(text_label)),
    (str(text_label0) + "Germany" + str(text_label)),
    (str(text_label0) + "Italy" + str(text_label)),
    (str(text_label0) + "Netherlands" + str(text_label)),
    (str(text_label0) + "Spain" + str(text_label)),
    (str(text_label0) + "Portugal" + str(text_label))
]

df1 = hv_tb_eu_002_002_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()

fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Austria" + str(text_label))], color="orange", 
        linewidth=l1, linestyle='', marker='P', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Belgium" + str(text_label))], color="black", 
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Finland" + str(text_label))], color="black", 
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Estonia" + str(text_label))], color="red", 
        linewidth=l1, linestyle='', marker='D', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Lithuania" + str(text_label))], color="red",
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "France" + str(text_label))], color="black", 
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Germany" + str(text_label))], color="black", 
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Italy" + str(text_label))], color="black", 
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Netherlands" + str(text_label))], color="green", 
        linewidth=l1, linestyle='', marker='X', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Spain" + str(text_label))], color="black", 
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Portugal" + str(text_label))], color="black", 
        linewidth=l1, linestyle='', marker='', markersize=s1)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_003_001_m_g_001z.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2


### 001 EA  CPI BY COUNTRY CPI excl Energy, Fd, Alchl SA Y/Y  QQ

text_label = " CPI excl Energy, Fd, Alchl SA Q/Q"
title_r0 = "CPI excluding Energy, Food and Alcohol SA Q/Q"
title_r = title_r0
y_label = "Index %"
x_label = title_r
list_c = [
    ("Austria" + str(text_label)),
    ("Belgium" + str(text_label)),
    ("Finland" + str(text_label)),
    ("Estonia" + str(text_label)),
    ("Lithuania" + str(text_label)),
     ("France" + str(text_label)),
     ("Germany" + str(text_label)),
    ("Italy" + str(text_label)),
    ("Netherlands" + str(text_label)),
    ("Spain" + str(text_label)),
    ("Portugal" + str(text_label))
]
df1 = hv_tb_eu_002_002_m_g_001[list_c]
df1 = df1.tail(72)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[("Austria" + str(text_label))], color="orange", linewidth=l1, linestyle='', marker='P', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Belgium" + str(text_label))], color="black", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Finland" + str(text_label))], color="black", linewidth=l1, linestyle='-', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Estonia" + str(text_label))], color="red", linewidth=l1, linestyle='-', marker='D', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Lithuania" + str(text_label))], color="red", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("France" + str(text_label))], color="black", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Germany" + str(text_label))], color="black", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Italy" + str(text_label))], color="black", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Netherlands" + str(text_label))], color="green", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Spain" + str(text_label))], color="black", linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Portugal" + str(text_label))], color="black", linewidth=l1, linestyle='', marker='', markersize=s1)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_003_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

text_label = " CPI excl Energy, Fd, Alchl SA Q/Q"
title_r0 = "CPI excluding Energy, Food and Alcohol SA Q/Q"
title_r = title_r0
y_label = "Index %"
x_label = title_r
list_c = [
    ("Austria" + str(text_label)),
    ("Belgium" + str(text_label)),
    ("Finland" + str(text_label)),
    ("Estonia" + str(text_label)),
    ("Lithuania" + str(text_label)),
     ("France" + str(text_label)),
     ("Germany" + str(text_label)),
    ("Italy" + str(text_label)),
    ("Netherlands" + str(text_label)),
    ("Spain" + str(text_label)),
    ("Portugal" + str(text_label))
]
df1 = hv_tb_eu_002_002_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[("Austria" + str(text_label))], color="orange", linewidth=l1, linestyle='-', marker='P', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Belgium" + str(text_label))], color="black", linewidth=l1, linestyle='-', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Finland" + str(text_label))], color="black", linewidth=l1, linestyle='-', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Estonia" + str(text_label))], color="red", linewidth=l1, linestyle='-', marker='D', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Lithuania" + str(text_label))], color="red", linewidth=l1, linestyle='-', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("France" + str(text_label))], color="black", linewidth=l1, linestyle='-', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Germany" + str(text_label))], color="black", linewidth=l1, linestyle='-', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Italy" + str(text_label))], color="black", linewidth=l1, linestyle='-', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Netherlands" + str(text_label))], color="green", linewidth=l1, linestyle='-', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Spain" + str(text_label))], color="black", linewidth=l1, linestyle='-', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[("Portugal" + str(text_label))], color="black", linewidth=l1, linestyle='-', marker='', markersize=s1)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_003_001_m_g_002z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2







### 001 EA  CPI services yy <a id="title_page"></a



####### Inflation 
####### Inflation 


print("tickers")
eu_m_tickers = ['h134hs','h132hs',
                'h136hs','h138hs',
                'h184hs',
                'h182hs','h122hs',
                'h124hs','h172hs',
                'h939hs','h946hs']
#print("getting from api")
hv_tb_eu_002_004_m=Haver.data(eu_m_tickers, "EUDATA", dates=True)
#print(hv_tb_eu_002_004_m)
#print(hv_tb_eu_002_004_m.columns)
for x in range(len(eu_m_tickers)):
    variable=str(eu_m_tickers [x])
    hv_tb_eu_002_004_m[variable] = hv_tb_eu_002_004_m[variable].pct_change(12).multiply(100).round(3)

print("renaming")
hv_tb_eu_002_004_m.rename(columns={"h122hs": "Austria CPI Services SA Y/Y"}, inplace=True)
hv_tb_eu_002_004_m.rename(columns={"h124hs": "Belgium CPI Services SA Y/Y"}, inplace=True)
hv_tb_eu_002_004_m.rename(columns={"h172hs": "Finland CPI Services SA Y/Y"}, inplace=True)
hv_tb_eu_002_004_m.rename(columns={"h939hs": "Estonia CPI Services SA Y/Y"}, inplace=True)
hv_tb_eu_002_004_m.rename(columns={"h946hs": "Lithuania CPI Services SA Y/Y"}, inplace=True)
hv_tb_eu_002_004_m.rename(columns={"h132hs": "France CPI Services SA Y/Y"}, inplace=True)
hv_tb_eu_002_004_m.rename(columns={"h134hs": "Germany CPI Services SA Y/Y"}, inplace=True)
hv_tb_eu_002_004_m.rename(columns={"h136hs": "Italy CPI Services SA Y/Y"}, inplace=True)
hv_tb_eu_002_004_m.rename(columns={"h138hs": "Netherlands CPI Services SA Y/Y"}, inplace=True)
hv_tb_eu_002_004_m.rename(columns={"h184hs": "Spain CPI Services SA Y/Y"}, inplace=True)
hv_tb_eu_002_004_m.rename(columns={"h182hs": "Portugal CPI Services SA Y/Y"}, inplace=True)

#hv_tb_eu_002_004_m_g_001=hv_tb_eu_002_004_m.copy()
#hv_tb_eu_002_004_m = hv_tb_eu_002_004_m.tail(horizon_tb)
#hv_tb_eu_002_004_m = hv_tb_eu_002_004_m.transpose()
#hv_tb_eu_002_004_m.index.names = ['Variable']

hv_tb_eu_002_004_m_g = hv_tb_eu_002_004_m.copy()
hv_tb_eu_002_004_m_g_001 = hv_tb_eu_002_004_m.copy()

hv_tb_eu_002_004_m.index=hv_tb_eu_002_004_m.index.date
hv_tb_eu_002_004_m = hv_tb_eu_002_004_m.tail(horizon_tb)
hv_tb_eu_002_004_t1=hv_tb_eu_002_004_m.tail(horizon_tb)

hv_tb_eu_002_004_m_t = hv_tb_eu_002_004_m.transpose()
hv_tb_eu_002_004_m_t.index.names = ['Variable']

hv_tb_eu_002_004_t1_t = hv_tb_eu_002_004_t1.transpose()
hv_tb_eu_002_004_t1_t.index.names = ['Variable']




print("Complete")

### 001 EA  CPI services yy table  <a id="title_page"></a



############################################################
######Table 1

#####here*******
title_table="ea_cpi_services_yy"
df =hv_tb_eu_002_004_t1.copy()
df_transposed = hv_tb_eu_002_004_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_eu_002_004_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_eu_002_004_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_eu_002_004_m_t_002.png')


### 001 EA  CPI services yy  graphs <a id="title_page"></a

#dashboard.to_clipboard()
print("step2")
text_label=" CPI Services SA Y/Y"
title_r0="CPI Services SA Y/Y"
title_r=title_r0
y_label="Index %"
x_label=title_r
list_c=[("Austria"+str(text_label)),
        ("Belgium"+str(text_label)),
        ("Finland"+str(text_label)),
        ("Estonia"+str(text_label)),
        ("Lithuania"+str(text_label)),
        ("France"+str(text_label)),
        ("Germany"+str(text_label)),
        ("Italy"+str(text_label)),
        ("Netherlands"+str(text_label)),
        ("Spain"+str(text_label)),
        ("Portugal"+str(text_label))]
df1=hv_tb_eu_002_004_m_g_001[list_c]
df1=df1.tail(72)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[("Austria"+str(text_label))], color="orange", linewidth= l1, linestyle='-', marker= 'P', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Belgium"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Finland"+str(text_label))], color="black",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Estonia"+str(text_label))], color="red", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Lithuania"+str(text_label))], color="red",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("France"+str(text_label))], color="black",  linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Germany"+str(text_label))], color="black",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Italy"+str(text_label))], color="black",  linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Netherlands"+str(text_label))], color="green",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Spain"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Portugal"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_004_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2
        

text_label=" CPI Services SA Y/Y"
title_r0="CPI Services SA Y/Y"
title_r=title_r0
y_label="Index %"
x_label=title_r
list_c=[("Austria"+str(text_label)),
        ("Belgium"+str(text_label)),
        ("Finland"+str(text_label)),
        ("Estonia"+str(text_label)),
        ("Lithuania"+str(text_label)),
        ("France"+str(text_label)),
        ("Germany"+str(text_label)),
        ("Italy"+str(text_label)),
        ("Netherlands"+str(text_label)),
        ("Spain"+str(text_label)),
        ("Portugal"+str(text_label))]
df1=hv_tb_eu_002_004_m_g_001[list_c]
df1=df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[("Austria"+str(text_label))], color="orange", linewidth= l1, linestyle='-', marker= 'P', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Belgium"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Finland"+str(text_label))], color="black",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Estonia"+str(text_label))], color="red", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Lithuania"+str(text_label))], color="red",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("France"+str(text_label))], color="black",  linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Germany"+str(text_label))], color="black",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Italy"+str(text_label))], color="black",  linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Netherlands"+str(text_label))], color="green",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Spain"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Portugal"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_004_001_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2





### 001 EA  CPI services qq <a id="title_page"></a

print("tickers")
eu_m_tickers = [
    "h134hs",
    "h132hs",
    "h136hs",
    "h138hs",
    "h184hs",
    "h182hs",
    "h122hs",
    "h124hs",
    "h172hs",
    "h939hs", 
    "h946hs"
]

print("getting from api")
hv_tb_eu_002_005_m = Haver.data(eu_m_tickers, "EUDATA", dates=True)
print(hv_tb_eu_002_005_m.columns)

for x in range(len(eu_m_tickers)):
    variable = eu_m_tickers[x]
    hv_tb_eu_002_005_m[variable] = hv_tb_eu_002_005_m[variable].pct_change(4).multiply(100).round(3)
#print(hv_eu_002_005[variable])

print("renaming")
hv_tb_eu_002_005_m.rename(columns={"h122hs": "Austria CPI Services SA Q/Q"}, inplace=True)
hv_tb_eu_002_005_m.rename(columns={"h124hs": "Belgium CPI Services SA Q/Q"}, inplace=True)
hv_tb_eu_002_005_m.rename(columns={"h172hs": "Finland CPI Services SA Q/Q"}, inplace=True) 
hv_tb_eu_002_005_m.rename(columns={"h939hs": "Estonia CPI Services SA Q/Q"}, inplace=True)
hv_tb_eu_002_005_m.rename(columns={"h946hs": "Lithuania CPI Services SA Q/Q"}, inplace=True)
hv_tb_eu_002_005_m.rename(columns={"h132hs": "France CPI Services SA Q/Q"}, inplace=True)
hv_tb_eu_002_005_m.rename(columns={"h134hs": "Germany CPI Services SA Q/Q"}, inplace=True)
hv_tb_eu_002_005_m.rename(columns={"h136hs": "Italy CPI Services SA Q/Q"}, inplace=True)
hv_tb_eu_002_005_m.rename(columns={"h138hs": "Netherlands CPI Services SA Q/Q"}, inplace=True)
hv_tb_eu_002_005_m.rename(columns={"h184hs": "Spain CPI Services SA Q/Q"}, inplace=True)
hv_tb_eu_002_005_m.rename(columns={"h182hs": "Portugal CPI Services SA Q/Q"}, inplace=True)

#hv_tb_eu_002_005_m_g_001 = hv_tb_eu_002_005_m.copy()
#hv_tb_eu_002_005_m_g_001.columns


hv_tb_eu_002_005_m_g = hv_tb_eu_002_005_m.copy()
hv_tb_eu_002_005_m_g_001 = hv_tb_eu_002_005_m.copy()

hv_tb_eu_002_005_m.index=hv_tb_eu_002_005_m.index.date
hv_tb_eu_002_005_m = hv_tb_eu_002_005_m.tail(horizon_tb)
hv_tb_eu_002_005_t1=hv_tb_eu_002_005_m.tail(horizon_tb)

hv_tb_eu_002_005_m_t = hv_tb_eu_002_005_m.transpose()
hv_tb_eu_002_005_m_t.index.names = ['Variable']

hv_tb_eu_002_005_t1_t = hv_tb_eu_002_005_t1.transpose()
hv_tb_eu_002_005_t1_t.index.names = ['Variable']


### 001 EA  CPI services qq  table <a id="title_page"></a



############################################################
######Table 1

#####here*******
title_table="uk_services_table"
df =hv_tb_eu_002_005_t1.copy()
df_transposed = hv_tb_eu_002_005_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_eu_002_005_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_eu_002_005_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_eu_002_005_m_t_002.png')


### 001 EA  CPI services qq graph  <a id="title_page"></a

text_label = " CPI Services SA Q/Q"
title_r0 = "CPI Services SA Q/Q"
title_r = title_r0
y_label = "Index %"
x_label = title_r


list_c=[("Austria"+str(text_label)),
        ("Belgium"+str(text_label)),
        ("Finland"+str(text_label)),
        ("Estonia"+str(text_label)),
        ("Lithuania"+str(text_label)),
        ("France"+str(text_label)),
        ("Germany"+str(text_label)),
        ("Italy"+str(text_label)),
        ("Netherlands"+str(text_label)),
        ("Spain"+str(text_label)),
        ("Portugal"+str(text_label))]
df1=hv_tb_eu_002_005_m_g_001[list_c]
df1=df1.tail(72)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[("Austria"+str(text_label))], color="orange", linewidth= l1, linestyle='-', marker= 'P', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Belgium"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Finland"+str(text_label))], color="black",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Estonia"+str(text_label))], color="red", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Lithuania"+str(text_label))], color="red",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("France"+str(text_label))], color="black",  linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Germany"+str(text_label))], color="black",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Italy"+str(text_label))], color="black",  linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Netherlands"+str(text_label))], color="green",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Spain"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Portugal"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_004_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

text_label = " CPI Services SA Q/Q"
title_r0 = "CPI Services SA Q/Q"
title_r = title_r0
y_label = "Index %"
x_label = title_r


list_c=[("Austria"+str(text_label)),
        ("Belgium"+str(text_label)),
        ("Finland"+str(text_label)),
        ("Estonia"+str(text_label)),
        ("Lithuania"+str(text_label)),
        ("France"+str(text_label)),
        ("Germany"+str(text_label)),
        ("Italy"+str(text_label)),
        ("Netherlands"+str(text_label)),
        ("Spain"+str(text_label)),
        ("Portugal"+str(text_label))]
df1=hv_tb_eu_002_005_m_g_001[list_c]
df1=df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[("Austria"+str(text_label))], color="orange", linewidth= l1, linestyle='-', marker= 'P', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Belgium"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Finland"+str(text_label))], color="black",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Estonia"+str(text_label))], color="red", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Lithuania"+str(text_label))], color="red",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("France"+str(text_label))], color="black",  linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Germany"+str(text_label))], color="black",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Italy"+str(text_label))], color="black",  linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Netherlands"+str(text_label))], color="green",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Spain"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Portugal"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_004_002_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2



### 001 EA  CPI goods yy <a id="title_page"></a

print("tickera")

eu_m_tickers = ['h134hg',
                'h132hg',
                'h136hg',
                'h138hg',
                'h184hg',
                'h182hg',
                'h122hg',
                'h124hg',
                'h172hg',
                'h939hg',
                'h946hg']

print("getting from api")
hv_tb_eu_002_006_m=Haver.data(eu_m_tickers, "EUDATA", dates=True)
print(hv_tb_eu_002_006_m)
print(hv_tb_eu_002_006_m.columns)
for x in range(len(eu_m_tickers)):
#    print(x)
    variable=str(eu_m_tickers[x])
#    print(variable)
    hv_tb_eu_002_006_m[variable]= hv_tb_eu_002_006_m[variable].pct_change(periods=12, fill_method='bfill').multiply(100).round(3)
#    print(hv_tb_eu_002_006_m[variable])

print("renaming")
hv_tb_eu_002_006_m.rename(columns={"h122hg":"Austria CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_006_m.rename(columns={"h124hg": "Belgium CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_006_m.rename(columns={"h172hg": "Finland CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_006_m.rename(columns={"h939hg": "Estonia CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_006_m.rename(columns={"h946hg": "Lithuania CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_006_m.rename(columns={"h132hg": "France CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_006_m.rename(columns={"h134hg": "Germany CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_006_m.rename(columns={"h136hg": "Italy CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_006_m.rename(columns={"h138hg": "Netherlands CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_006_m.rename(columns={"h184hg": "Spain CPI Goods SA Y/Y"}, inplace=True)
hv_tb_eu_002_006_m.rename(columns={"h182hg": "Portugal CPI Goods SA Y/Y"}, inplace=True)
#hv_tb_eu_002_006_m_g_001=hv_tb_eu_002_006_m.copy()

hv_tb_eu_002_006_m_g = hv_tb_eu_002_006_m.copy()
hv_tb_eu_002_006_m_g_001 = hv_tb_eu_002_006_m.copy()

hv_tb_eu_002_006_m.index=hv_tb_eu_002_006_m.index.date
hv_tb_eu_002_006_m = hv_tb_eu_002_006_m.tail(horizon_tb)
hv_tb_eu_002_006_t1=hv_tb_eu_002_006_m.tail(horizon_tb)

hv_tb_eu_002_006_m_t = hv_tb_eu_002_006_m.transpose()
hv_tb_eu_002_006_m_t.index.names = ['Variable']

hv_tb_eu_002_006_t1_t = hv_tb_eu_002_006_t1.transpose()
hv_tb_eu_002_006_t1_t.index.names = ['Variable']

### 001 EA  CPI goods yy table <a id="title_page"></a



############################################################
######Table 1

#####here*******
title_table="uk_goods_table"
df =hv_tb_eu_002_006_t1.copy()
df_transposed = hv_tb_eu_002_006_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_eu_002_006_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_eu_002_006_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_eu_002_006_m_t_002.png')




### 001 EA  CPI goods yy graphs  <a id="title_page"></a

print("step2")
text_label=" CPI Goods SA Y/Y"
title_r0="CPI Goods SA Y/Y"
title_r=title_r0
y_label="Index %"
x_label=title_r
list_c=[("Austria"+str(text_label)),
        ("Belgium"+str(text_label)),
        ("Finland"+str(text_label)),
        ("Estonia"+str(text_label)),
        ("Lithuania"+str(text_label)),
        ("France"+str(text_label)),
        ("Germany"+str(text_label)),
        ("Italy"+str(text_label)),
        ("Netherlands"+str(text_label)),
        ("Spain"+str(text_label)),
        ("Portugal"+str(text_label))]
df1=hv_tb_eu_002_006_m_g_001[list_c]
df1=df1.tail(72)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[("Austria"+str(text_label))], color="orange", linewidth= l1, linestyle='-', marker= 'P', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Belgium"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Finland"+str(text_label))], color="black",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Estonia"+str(text_label))], color="red", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Lithuania"+str(text_label))], color="red",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("France"+str(text_label))], color="black",  linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Germany"+str(text_label))], color="black",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Italy"+str(text_label))], color="black",  linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Netherlands"+str(text_label))], color="green",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Spain"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Portugal"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_002_006_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

text_label=" CPI Goods SA Y/Y"
title_r0="CPI Goods SA Y/Y"
title_r=title_r0
y_label="Index %"
x_label=title_r
list_c=[("Austria"+str(text_label)),
        ("Belgium"+str(text_label)),
        ("Finland"+str(text_label)),
        ("Estonia"+str(text_label)),
        ("Lithuania"+str(text_label)),
        ("France"+str(text_label)),
        ("Germany"+str(text_label)),
        ("Italy"+str(text_label)),
        ("Netherlands"+str(text_label)),
        ("Spain"+str(text_label)),
        ("Portugal"+str(text_label))]
df1=hv_tb_eu_002_006_m_g_001[list_c]
df1=df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[("Austria"+str(text_label))], color="orange", linewidth= l1, linestyle='-', marker= 'P', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Belgium"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Finland"+str(text_label))], color="black",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Estonia"+str(text_label))], color="red", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Lithuania"+str(text_label))], color="red",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("France"+str(text_label))], color="black",  linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Germany"+str(text_label))], color="black",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Italy"+str(text_label))], color="black",  linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Netherlands"+str(text_label))], color="green",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Spain"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Portugal"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_002_006_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2







### 001 EA  CPI goods qq <a id="title_page"></a

### TIME SERIES ###

print('tickers:')
eu_m_tickers = [
    "h134hg",
    "h132hg",
    "h136hg",
    "h138hg",
    "h184hg",
    "h182hg",
    "h122hg",
    "h124hg",
    "h172hg",
    "h939hg",
    "h946hg",
    ]

#print(eu_m_tickers)
print('getting from api:')
hv_tb_eu_002_007_m = Haver.data(eu_m_tickers, 'EUDATA', dates=True ) 
#print(hv_to_eu_m_002_007.columns)
#print(hv_to_eu_m_002_007)

for x in range(len(eu_m_tickers)):
    variable=str(eu_m_tickers[x])
    hv_tb_eu_002_007_m[variable] = hv_tb_eu_002_007_m[variable].pct_change(4).multiply(100).round(3)
    #print(hv_to_eu_m_002_007[variable])

print('renaming:')
hv_tb_eu_002_007_m.rename(columns={"h122hg": "Austria CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_007_m.rename(columns={"h124hg": "Belgium CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_007_m.rename(columns={"h172hg": "Estonia CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_007_m.rename(columns={"h939hg": "Finland CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_007_m.rename(columns={"h946hg": "France CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_007_m.rename(columns={"h132hg": "Germany CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_007_m.rename(columns={"h134hg": "Lithuania CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_007_m.rename(columns={"h136hg": "Italy CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_007_m.rename(columns={"h138hg": "Netherlands CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_007_m.rename(columns={"h184hg": "Spain CPI Goods SA Q/Q"}, inplace=True)
hv_tb_eu_002_007_m.rename(columns={"h182hg": "Portugal CPI Goods SA Q/Q"}, inplace=True)
#hv_tb_eu_002_007_m_g_001=hv_tb_eu_002_007_m.copy()

hv_tb_eu_002_007_m_g = hv_tb_eu_002_007_m.copy()
hv_tb_eu_002_007_m_g_001 = hv_tb_eu_002_007_m.copy()

hv_tb_eu_002_007_m.index=hv_tb_eu_002_007_m.index.date
hv_tb_eu_002_007_m = hv_tb_eu_002_007_m.tail(horizon_tb)
hv_tb_eu_002_007_t1=hv_tb_eu_002_007_m.tail(horizon_tb)

hv_tb_eu_002_007_m_t = hv_tb_eu_002_007_m.transpose()
hv_tb_eu_002_007_m_t.index.names = ['Variable']

hv_tb_eu_002_007_t1_t = hv_tb_eu_002_007_t1.transpose()
hv_tb_eu_002_007_t1_t.index.names = ['Variable']



### 001 EA  CPI goods qq  table <a id="title_page"></a



############################################################
######Table 1

#####here*******
title_table="ea_cpi_goods_qq"
df =hv_tb_eu_002_007_t1.copy()
df_transposed = hv_tb_eu_002_007_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_eu_002_007_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_eu_002_007_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_eu_002_007_m_t_002.png')


### 001 EA  CPI goods qq graphs  <a id="title_page"></a 

print("step2")
text_label=" CPI Goods SA Q/Q"
title_r0="CPI Goods SA Q/Q"
title_r=title_r0
y_label="Index %"
x_label=title_r
list_c=[("Austria"+str(text_label)),
        ("Belgium"+str(text_label)),
        ("Finland"+str(text_label)),
        ("Estonia"+str(text_label)),
        ("Lithuania"+str(text_label)),
        ("France"+str(text_label)),
        ("Germany"+str(text_label)),
        ("Italy"+str(text_label)),
        ("Netherlands"+str(text_label)),
        ("Spain"+str(text_label)),
        ("Portugal"+str(text_label))]
df1=hv_tb_eu_002_007_m_g_001[list_c]
df1=df1.tail(72)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[("Austria"+str(text_label))], color="orange", linewidth= l1, linestyle='-', marker= 'P', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Belgium"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Finland"+str(text_label))], color="black",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Estonia"+str(text_label))], color="red", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Lithuania"+str(text_label))], color="red",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("France"+str(text_label))], color="black",  linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Germany"+str(text_label))], color="black",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Italy"+str(text_label))], color="black",  linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Netherlands"+str(text_label))], color="green",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Spain"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Portugal"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_002_007_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

text_label=" CPI Goods SA Q/Q"
title_r0="CPI Goods SA Q/Q"
title_r=title_r0
y_label="Index %"
x_label=title_r
list_c=[("Austria"+str(text_label)),
        ("Belgium"+str(text_label)),
        ("Finland"+str(text_label)),
        ("Estonia"+str(text_label)),
        ("Lithuania"+str(text_label)),
        ("France"+str(text_label)),
        ("Germany"+str(text_label)),
        ("Italy"+str(text_label)),
        ("Netherlands"+str(text_label)),
        ("Spain"+str(text_label)),
        ("Portugal"+str(text_label))]
df1=hv_tb_eu_002_007_m_g_001[list_c]
df1=df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[("Austria"+str(text_label))], color="orange", linewidth= l1, linestyle='-', marker= 'P', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Belgium"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Finland"+str(text_label))], color="black",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Estonia"+str(text_label))], color="red", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Lithuania"+str(text_label))], color="red",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("France"+str(text_label))], color="black",  linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Germany"+str(text_label))], color="black",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Italy"+str(text_label))], color="black",  linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Netherlands"+str(text_label))], color="green",linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Spain"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)
g1.plot(kind='line', ax=ax,y=[("Portugal"+str(text_label))], color="black", linewidth= l1, linestyle='-',  marker='', markersize=s1)

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_002_007_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2



### 001 EA  PMI Composite <a id="title_page"></a



print("tickers")
eu_m_tickers = ['m023tg',
                'm132tg',
                'm134tg',
                'm023m',
                'm132m',
                'm134m',
                'm023s',
                'm132s',
                'm134s']
print("getting from api")
hv_tb_eu_003_001_m=Haver.data(eu_m_tickers, "MKTPMI", dates=True)
print(hv_tb_eu_003_001_m)


#print(hv_tb_eu_003_001_m[variable])
print("renaming")
hv_tb_eu_003_001_m.rename(columns={"m023tg": "Euro Area S&P PMI Composite SA"}, inplace=True)
hv_tb_eu_003_001_m.rename(columns={"m132tg": "France S&P PMI Composite SA"}, inplace=True)
hv_tb_eu_003_001_m.rename(columns={"m134tg": "Germany S&P PMI Composite SA"}, inplace=True)
hv_tb_eu_003_001_m.rename(columns={"m023m":"Euro Area S&P PMI Manufacturing SA"}, inplace=True)
hv_tb_eu_003_001_m.rename(columns={"m132m": "France S&P PMI Manufacturing SA"}, inplace=True)
hv_tb_eu_003_001_m.rename(columns={"m134m": "Germany S&P PMI Manufacturing SA"}, inplace=True)
hv_tb_eu_003_001_m.rename(columns={"m023s": "Euro Area S&P PMI Services SA"}, inplace=True)
hv_tb_eu_003_001_m.rename(columns={"m132s": "France S&P PMI Services SA"}, inplace=True)
hv_tb_eu_003_001_m.rename(columns={"m134s": "Germany S&P PMI Services SA"}, inplace=True)
hv_tb_eu_003_001_m_g_001=hv_tb_eu_003_001_m.copy()
hv_tb_eu_003_001_mz=hv_tb_eu_003_001_m.tail(6)
hv_tb_eu_003_001_m=hv_tb_eu_003_001_m.tail(horizon_tb)
hv_tb_eu_003_001_m =hv_tb_eu_003_001_m.transpose()
hv_tb_eu_003_001_m.index.names = ['Variable']
#dashboard.to_clipboard()
print(hv_tb_eu_003_001_m)


print("step2")
###
text_label=" S&P PMI Composite SA"
title_r=text_label
y_label="Index %"
x_label=title_r
list_c=[("Euro Area"+str(text_label)),
        ("France"+str(text_label)),
        ("Germany"+str(text_label))]

df1=hv_tb_eu_003_001_m_g_001[list_c]                
df1=df1.tail(60)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[("Euro Area"+str(text_label))], 
        color="darkgreen", linewidth= l1, linestyle='-',
        marker="P", markersize=s2)
g1.plot(kind='line', ax=ax,y=[("France"+str(text_label))], 
        color="darkblue", linewidth= l1, linestyle-'-',
        marker='D',markersize=s2)
g1.plot(kind='line', ax=ax,y=[("Germany"+str(text_label))],
        color="darkred", linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
#plt.axhline (0, color="black", Lw=1, Linestyle dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_003_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

text_label=" S&P PMI Composite SA"
title_r=text_label
y_label="Index %"
x_label=title_r
list_c=[("Euro Area"+str(text_label)),
        ("France"+str(text_label)),
        ("Germany"+str(text_label))]
df1=hv_tb_eu_003_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[("Euro Area"+str(text_label))], 
        color="darkgreen", linewidth= 11, linestyle='-',
        marker= 'P', markersize=s2)
g1.plot(kind='line', ax=ax,y=[("France"+str(text_label))], 
        color="darkblue", linewidth= 11, linestyle='-',
        marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=[("Germany"+str(text_label))], 
        color="darkred", linewidth= 11, linestyle='-',
        marker='o', markersize=s2)
#plt.axhline(0, color="black", Lw=1, Linestyle 'dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_003_001_m_g_001z.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

### 001 EA  PMI Composite  S&P PMI Manufacturing SA"


text_label=" S&P PMI Manufacturing SA"
title_r=text_label

y_label="Index %"
x_label=title_r

list_c=[("Euro Area"+str(text_label)),
        ("France"+str(text_label)),
        ("Germany"+str(text_label))]
df1=hv_tb_eu_003_001_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax,y=[("Euro Area"+str(text_label))],
        color="darkgreen", linewidth= l1, linestyle='-',
        marker='P',markersize=s2)
g1.plot(kind='line', ax=ax,y=[("France"+str(text_label))], 
        color="darkblue", linewidth= l1, linestyle='-',
        marker='D',markersize=s2)
g1.plot(kind='line', ax=ax,y=[("Germany"+str(text_label))],
        color="darkred", linewidth= l1, linestyle="-",
        marker='o',markersize=s2)
#plt.axhline(8, color="black", (w=1, Linestyle = 'dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_003_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig

del ax
del ax2

text_label=" S&P PMI Manufacturing SA"
title_r=text_label

y_label="Index %"
x_label=title_r

list_c=[("Euro Area"+str(text_label)),
        ("France"+str(text_label)),
        ("Germany"+str(text_label))]
df1=hv_tb_eu_003_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax,y=[("Euro Area"+str(text_label))],
        color="darkgreen", linewidth= l1, linestyle='-',
        marker='P',markersize=s2)
g1.plot(kind='line', ax=ax,y=[("France"+str(text_label))], 
        color="darkblue", linewidth= l1, linestyle='-',
        marker='D',markersize=s2)
g1.plot(kind='line', ax=ax,y=[("Germany"+str(text_label))],
        color="darkred", linewidth= l1, linestyle="-",
        marker='o',markersize=s2)
#plt.axhline(8, color="black", (w=1, Linestyle = 'dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_003_001_m_g_002z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig

del ax
del ax2

text_label=" S&P PMI Services SA"
title_r=text_label

y_label="Index %"
x_label=title_r

list_c=[("Euro Area"+str(text_label)),
        ("France"+str(text_label)),
        ("Germany"+str(text_label))]
df1=hv_tb_eu_003_001_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax,y=[("Euro Area"+str(text_label))],
        color="darkgreen", linewidth= l1, linestyle='-',
        marker='P',markersize=s2)
g1.plot(kind='line', ax=ax,y=[("France"+str(text_label))], 
        color="darkblue", linewidth= l1, linestyle='-',
        marker='D',markersize=s2)
g1.plot(kind='line', ax=ax,y=[("Germany"+str(text_label))],
        color="darkred", linewidth= l1, linestyle="-",
        marker='o',markersize=s2)
#plt.axhline(8, color="black", (w=1, Linestyle = 'dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_003_001_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig

del ax
del ax2

text_label=" S&P PMI Services SA"
title_r=text_label

y_label="Index %"
x_label=title_r

list_c=[("Euro Area"+str(text_label)),
        ("France"+str(text_label)),
        ("Germany"+str(text_label))]
df1=hv_tb_eu_003_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax,y=[("Euro Area"+str(text_label))],
        color="darkgreen", linewidth= l1, linestyle='-',
        marker='P',markersize=s2)
g1.plot(kind='line', ax=ax,y=[("France"+str(text_label))], 
        color="darkblue", linewidth= l1, linestyle='-',
        marker='D',markersize=s2)
g1.plot(kind='line', ax=ax,y=[("Germany"+str(text_label))],
        color="darkred", linewidth= l1, linestyle="-",
        marker='o',markersize=s2)
#plt.axhline(8, color="black", (w=1, Linestyle = 'dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_003_001_m_g_003z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig

del ax
del ax2

### 001 EA  PMI Composite  S&P PMI Manufacturing SA"  hv_tb_eu_003_002_m

rolling0=120
tail0=7

print("tickers")
eu_m_tickers = ['m023tg',
                'm023to',
                'm023te',
                'm023tp',
                'm023tx',
                'm023tpo',
                'm023tb']

print("getting from api")
hv_tb_eu_003_002_m=Haver.data(eu_m_tickers, "MKTPMI", dates=True)
#print(hv_tb_eu_003_002_m)
print("renaming")
hv_tb_eu_003_002_m.rename(columns={"m023tg": "Euro Area S&P PMI Composite SA"}, inplace=True)
hv_tb_eu_003_002_m.rename(columns={"m023to": "Euro Area New Orders SA"}, inplace=True)
hv_tb_eu_003_002_m.rename(columns={"m023te": "Euro Area Employment SA"}, inplace=True)
hv_tb_eu_003_002_m.rename(columns={"m023tp": "Euro Area Input Prices SA"}, inplace=True)
hv_tb_eu_003_002_m.rename(columns={"m023tx": "Euro Area New Export Orders SA"}, inplace=True)
hv_tb_eu_003_002_m.rename(columns={"m023tpo": "Euro Area Output Prices SA"}, inplace=True)
hv_tb_eu_003_002_m.rename(columns={"m023tb": "Euro Area Backlogs of work SA"}, inplace=True)
hv_tb_eu_003_002_m=hv_tb_eu_003_002_m.bfill()
#hv_tb_eu_003_002_m.to_clipboard()

title_r="Euro Area S&P PMI Composite SA"
y_label="Index %"
x_label=title_r
list_c=["Euro Area S&P PMI Composite SA",
        "Euro Area New Orders SA",
        "Euro Area Employment SA",
        "Euro Area Input Prices SA", 
        "Euro Area New Export Orders SA",
        "Euro Area Output prices SA", 
        "Euro Area Backlogs of work SA"]

df1=hv_tb_eu_003_002_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig,ax plt.subplots(figsize= (parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["Euro Area Employment SA"], 
        color="darkred", linewidth= l1, linestyle='-',markers,markersize=s2)
g1.plot(kind='line',ax=ax, y=["Euro Area Input Prices SA"], 
        color="darkblue", linewidth= l1, linestyle'',marker="P", markersize=s2)
g1.plot(kind='line', ax=ax, y=["Euro Area Output prices SA"], 
        color="darkgreen", linewidth= l1, linestyle'-',marker="D', markersize=s2)
#pit.axhiine(0, color="black", Lw=1, Linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 ax.twinx()
ax2.set_ylim(ax.get_vlim())
plt.savefig("hv_tb_eu_003_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list c
del fig
del ax
del ax2

title_r="Euro Area S&P PMI Composite SA"
y_label="Index %"
x_label=title_r
list_c=["Euro Area S&P PMI Composite SA",
        "Euro Area New Orders SA",
        "Euro Area Employment SA",
        "Euro Area Input Prices SA", 
        "Euro Area New Export Orders SA",
        "Euro Area Output prices SA", 
        "Euro Area Backlogs of work SA"]

df1=hv_tb_eu_003_002_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax plt.subplots(figsize= (parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["Euro Area Employment SA"], 
        color="darkred", linewidth= l1, linestyle='-',markers,markersize=s2)
g1.plot(kind='line',ax=ax, y=["Euro Area Input Prices SA"], 
        color="darkblue", linewidth= l1, linestyle'',marker="P", markersize=s2)
g1.plot(kind='line', ax=ax, y=["Euro Area Output prices SA"], 
        color="darkgreen", linewidth= l1, linestyle'-',marker="D', markersize=s2)
#pit.axhiine(0, color="black", Lw=1, Linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 ax.twinx()
ax2.set_ylim(ax.get_vlim())
plt.savefig("hv_tb_eu_003_002_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list c
del fig
del ax
del ax2

hv_tb_eu_003_002_m.to_clipboard()
eu_m_tickers = hv_tb_eu_003_002_m.columns.tolist()

rolling = 12

for x in range(len(eu_m_tickers)):
    variable = str(eu_m_tickers[x])

    print(variable)
    hv_tb_eu_003_002_m[str(variable) + "_diff"] = hv_tb_eu_003_002_m[variable].diff()

    hv_tb_eu_003_002_m[str(variable) + "_mean"] = hv_tb_eu_003_002_m[variable].rolling(window=rolling).mean()
    hv_tb_eu_003_002_m[str(variable) + "_std"] = hv_tb_eu_003_002_m[variable].rolling(rolling).std()

    hv_tb_eu_003_002_m[str(variable) + "_z"] = ((hv_tb_eu_003_002_m[str(variable)] - hv_tb_eu_003_002_m[str(variable) + "_mean"]) / hv_tb_eu_003_002_m[str(variable) + "_mean"])

 print(hv_tb_eu_003_002_m_a_001[variable])
 hv_tb_eu_003_002_mg_001.to_clipboard()

hv_tb_eu_003_002_m.to_clipboard()
 hv_tb_eu_003_002_m.rename(columns={"m023to": "Euro Area New Orders SA"}, inplace=True)
 hv_tb_eu_003_002_m.rename(columns={"m023te": "Euro Area Employment SA"}, inplace=True)

 hv_tb_eu_003_002_m.rename(columns={"m023tp": "Euro Area Input Prices SA"}, inplace=True)
 hv_tb_eu_003_002_m.rename(columns={"m023tx": "Euro Area New Export Orders SA"}, inplace=True)

 hv_tb_eu_003_002_m.rename(columns={"m023tpo": "Euro Area Output Prices SA"}, inplace=True)
 hv_tb_eu_003_002_m.rename(columns={"m023tb": "Euro Area Backlogs of work SA"}, inplace=True)

df1 = hv_tb_eu_003_002_m.copy()
df1_list = df1.columns.tolist()

df1.index = df1.index.date
g1 = df1.copy()

g1 = g1.tail(tail_e)
fig, ax = plt.subplots(figsize=(7, 7))

title_r = "Euro Area PMI"

y_label = "Monthly Change"
x_label = "Z score"

plt.scatter(g1["Euro Area S&P PMI Composite SA_z"], g1["Euro Area S&P PMI Composite SA_diff"], cmap="brg", zorder=2)
plt.scatter(g1["Euro Area Employment SA_z"], g1["Euro Area Employment SA_diff"], cmap="brg", zorder=2)



#hv_tb_eu_003_002_m.rename(columns={"m023to": "Euro Area New Orders SA"}, inplace=True)
#hv_tb_eu_003_002_m.rename(columns={"m023te": "Euro Area Employment SA"}, inplace=True)

#hv_tb_eu_003_002_m.rename(columns={"m023tp": "Euro Area Input Prices SA"}, inplace=True)
#hv_tb_eu_003_002_m.rename(columns={"m023tx": "Euro Area New Export Orders SA"}, inplace=True)

#hv_tb_eu_003_002_m.rename(columns={"m023tpo": "Euro Area Output Prices SA"}, inplace=True)
#hv_tb_eu_003_002_m.rename(columns={"m023tb": "Euro Area Backlogs of work SA"}, inplace=True)

df1=hv_tb_eu_003_002_m.copy()
df1_list=df1.columns.tolist()

df1.index= df1.index.date
g1=df1.copy()

g1=g1.tail(tail0)
fig,ax plt.subplots(figsize=(7,7))

title_r="Euro Area PMI"
#x = 91["Canada Policy Rate EOP"]

#yg1["Canada UR SA"]
#t= 91["Canada Policy Rate EOP"]

y_label="Monthly Change"
x_label="Z score"

plt.scatter(g1 ["Euro Area S&P PMI Composite SA_z"],g1 ["Euro Area S&P PMI Composite SA_diff"], cmap="brg", zorder=2)
plt.scatter(g1["Euro Area Employment SA_z"], g1 ["Euro Area Employment SA_diff"], cmap="brg", zorder=2)

plt.scatter(g1["Euro Area New Orders SA_z"],g1["Euro Area New Orders SA_diff"], cmap="brg", zorder=2)
plt.scatter(g1 "Euro Area Input Prices SA_z"], g1 [ "Euro Area Input Prices SA_diff"], cmap="brg", zorder=2)

plt.scatter(g1 "Euro Area Output Prices SA_z"], g1 ["Euro Area Output Prices SA_diff"], cmap="brg", zorder=2)
#plt.scatter(g1["France Productivity_yy%"],g1 ["France Productivity_mavg4"], cmap="brg", zorder=2)

#plt.scatter(g1["Germany Productivity_yy%"],91["Germany Productivity_mavg4"],
стар="brg", zorder=2)

for line in range(0, g1.shape[0], 1):                                                                  plt.annotate(

                                                             g1.index [line],
                                                             (g1 ["Euro Area S&P PMI Composite SA_z"].iloc[line], gl["Euro Area S&P PMI Composite SA_diff"].iloc[line])

                                                             va='top',
                                                             textcoords="offset points", #how to position the text

                                                             xytext=(-5,10), # distance from text to points (x,y)
                                                             ha='center',
                                                             size = 4)



for line in range(0, g1.shape[0], 1):
    plt.annotate(
        g1.index[line],
        (g1["Euro Area S&P PMI Composite SA_z"].iloc[line], g1["Euro Area S&P PMI Composite SA_diff"].iloc[line]),
        va='top',
        textcoords="offset points",  # how to position the text
        xytext=(-5, 10),  # distance from text to points (x,y)
        ha='center',
        size=4
    )

for line in range(0, g1.shape[0], 1):
    plt.annotate(
        g1.index[line],
        (g1["Euro Area Employment SA_z"].iloc[line], g1["Euro Area Employment SA_diff"].iloc[line]),
        va='top',
        textcoords="offset points",  # how to position the text
        xytext=(-5, 10),  # distance from text to points (x,y)
        ha='center',
        size=4
    )

for line in range(0, g1.shape[0], 1):
    plt.annotate(
        g1.index[line],
        (g1["Euro Area New Orders SA_z"].iloc[line], g1["Euro Area New Orders SA_diff"].iloc[line]),
        va='top',
        textcoords="offset points",  # how to position the text
        xytext=(-5, 10),  # distance from text to points (x,y)
        ha='center',
        size=4
    )

for line in range(0, g1.shape[0], 1):
    plt.annotate(
        g1.index[line],
        (g1["Euro Area Input Prices SA_z"].iloc[line], g1["Euro Area Input Prices SA_diff"].iloc[line]),
        va='top',
        textcoords="offset points",  # how to position the text
        xytext=(-5, 10),  # distance from text to points (x,y)
        ha='center',
        size=4
    )

for line in range(0, g1.shape[0], 1):
    plt.annotate(
        g1.index[line],
        (g1["Euro Area Output Prices SA_z"].iloc[line], g1["Euro Area Output Prices SA_diff"].iloc[line]),
        va='top',
        textcoords="offset points",  # how to position the text
        xytext=(-5, 10),  # distance from text to points (x,y)
        ha='center',
        size=4
    )

plt.plot(g1["Euro Area S&P PMI Composite SA_z"], g1["Euro Area S&P PMI Composite SA_diff"], zorder=1)
plt.plot(g1["Euro Area Employment SA_z"], g1["Euro Area Employment SA_diff"], zorder=1)
plt.plot(g1["Euro Area New Orders SA_z"], g1["Euro Area New Orders SA_diff"], zorder=1)
plt.plot(g1["Euro Area Input Prices SA_z"], g1["Euro Area Input Prices SA_diff"], zorder=1)
plt.plot(g1["Euro Area Output Prices SA_z"], g1["Euro Area Output Prices SA_diff"], zorder=1)

plt.annotate("(Composite now)", xy=(g1["Euro Area S&P PMI Composite SA_z"][-1], g1["Euro Area S&P PMI Composite SA_diff"][-1]),
             xytext=(-25, 25), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.annotate("(Employment now)", xy=(g1["Euro Area Employment SA_z"][-1], g1["Euro Area Employment SA_diff"][-1]),
             xytext=(-25, 25), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.annotate("(New Orders now)", xy=(g1["Euro Area New Orders SA_z"][-1], g1["Euro Area New Orders SA_diff"][-1]),
             xytext=(-25, 25), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.annotate("(Input Prices now)", xy=(g1["Euro Area Input Prices SA_z"][-1], g1["Euro Area Input Prices SA_diff"][-1]),
             xytext=(-25, 25), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.annotate("(Output Prices now)", xy=(g1["Euro Area Output Prices SA_z"][-1], g1["Euro Area Output Prices SA_diff"][-1]),
             xytext=(-25, 25), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))

### 001 EA  ces ifnlation expefctation

#132 France
#134 Germany
#136 Italy
#184 Spain
#138 Netherlands

print("tickers")
eu_m_tickers = ['c025i2tt', 'm025i2tt', 'c025i4tt', 'm025i4tt', 'c025i7tt', 'm025i7tt', 
                'c134i2tt', 'm134i2tt', 'c134i4tt', 'm134i4tt', 'c134i7tt', 'm134i7tt',
                'c132i2tt', 'm132i2tt', 'c132i4tt', 'm132i4tt', 'c132i7tt', 'm132i7tt',
                'c136i2tt', 'm136i2tt', 'c136i4tt', 'm136i4tt', 'c136i7tt', 'm136i7tt',
                'c184i2tt', 'm184i2tt', 'c184i4tt', 'm184i4tt', 'c184i7tt', 'm184i7tt',
                'c138i2tt', 'm138i2tt', 'c138i4tt', 'm138i4tt', 'c138i7tt', 'm138i7tt']

print("getting from api")
hv_tb_eu_004_001_m = Haver.data(eu_m_tickers, "EUSRVYS", dates=True)
print(hv_tb_eu_004_001_m)
#print(hv_tb_eu_004_001_m.columns)
#for x in range(len(us_m_tickers)):
#    print(x)
#   variable=str(us_m_tickers[x])
# #   print(variable) 
#    hv_tb_usa_005_001_m[variable]= hv_tb_usa_005_001_m[variable].pct_change(1).multiply(100).round(3)
#    print(hv_tb_usa_005_001_m[variable])

print("renaming")
hv_tb_eu_004_001_m.rename(columns={"c025i2tt":"CES Inflation perception prev 12m% Mean"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c025i4tt":"CES Inflation perception next 12m% Mean"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c025i7tt":"CES Inflation perception next 3y% Mean"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"m025i2tt":"CES Inflation perception prev 12m% Median"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"m025i4tt":"CES Inflation perception next 12m% Median"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"m025i7tt":"CES Inflation perception next 3y% Median"}, inplace=True)

hv_tb_eu_004_001_m.rename(columns={"c134i2tt": "Germany Inflation perception prev 12m% Mean"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c134i4tt": "Germany Inflation perception next 12m% Mean"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c134i7tt": "Germany Inflation perception next 3y% Mean"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"m134i2tt": "Germany Inflation perception prev 12m% Median"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"m134i4tt": "Germany Inflation perception next 12m% Median"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"m134i7tt": "Germany Inflation perception next 3y% Median"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c132i2tt": "France Inflation perception prev 12m% Mean"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c132i4tt": "France Inflation perception next 12m% Mean"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c132i7tt": "France Inflation perception next 3y% Mean"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"m132i2tt": "France Inflation perception prev 12m% Median"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"m132i4tt": "France Inflation perception next 12m% Median"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"m132i7tt": "France Inflation perception next 3y% Median"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c136i2tt": "Italy Inflation perception prev 12m% Mean"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c136i4tt": "Italy Inflation perception next 12m% Mean"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c136i7tt": "Italy Inflation perception next 3y% Mean"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"m136i2tt": "Italy Inflation perception prev 12m% Median"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"m136i4tt": "Italy Inflation perception next 12m% Median"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"m136i7tt": "Italy Inflation perception next 3y% Median"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c184i2tt": "Spain Inflation perception prev 12m% Mean"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c184i4tt": "Spain Inflation perception next 12m% Mean"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c184i7tt": "Spain Inflation perception next 3y% Mean"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"m184i2tt": "Spain Inflation perception prev 12m% Median"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"m184i4tt": "Spain Inflation perception next 12m% Median"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"m184i7tt": "Spain Inflation perception next 3y% Median"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c138i2tt": "Netherlands Inflation perception prev 12m% Mean"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c138i4tt": "Netherlands Inflation perception next 12m% Mean"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c138i7tt": "Netherlands Inflation perception next 3y% Mean"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"m138i2tt": "Netherlands Inflation perception prev 12m% Median"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"m138i4tt": "Netherlands Inflation perception next 12m% Median"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"m138i7tt": "Netherlands Inflation perception next 3y% Median"}, inplace=True)


#hv_tb_eu_004_001_m_g_001 = hv_tb_eu_004_001_m.copy()
#hv_tb_eu_004_001_m = hv_tb_eu_004_001_m.tail(horizon_tb)
#hv_tb_eu_004_001_m = hv_tb_eu_004_001_m.transpose()
#hv_tb_eu_004_001_m.index.names = ['Variable']
## dashboard.to_clipboard()
#prit(hv_tb_eu_004_001_m)


hv_tb_eu_004_001_m_g = hv_tb_eu_004_001_m.copy()
hv_tb_eu_004_001_m_g_001 = hv_tb_eu_004_001_m.copy()

hv_tb_eu_004_001_m.index=hv_tb_eu_004_001_m.index.date
hv_tb_eu_004_001_m = hv_tb_eu_004_001_m.tail(horizon_tb)
hv_tb_eu_004_001_t1=hv_tb_eu_004_001_m.tail(horizon_tb)

hv_tb_eu_004_001_m_t = hv_tb_eu_004_001_m.transpose()
hv_tb_eu_004_001_m_t.index.names = ['Variable']

hv_tb_eu_004_001_t1_t = hv_tb_eu_004_001_t1.transpose()
hv_tb_eu_004_001_t1_t.index.names = ['Variable']

### 001 EA  ces ifnlation expefctation table



############################################################
######Table 1

#####here*******
title_table="ea_ces_inflation_expectation"
df =hv_tb_eu_004_001_t1.copy()
df_transposed = hv_tb_eu_004_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_eu_004_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_eu_004_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_eu_004_001_m_t_002.png')


### 001 EA  ces ifnlation expefctation graphs

title_r="Inflation perception next 12m% Median"
y_label="Index %"

list_c=["CES Inflation perception next 12m% Median",
        "Germany Inflation perception next 12m% Median",
        "France Inflation perception next 12m% Median",
        "Italy Inflation perception next 12m% Median",
        "Spain Inflation perception next 12m% Median",
        "Netherlands Inflation perception next 12m% Median"]
df1=hv_tb_eu_004_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["CES Inflation perception next 12m% Median"], color="black",
        linewidth= l1,  linestyle='-',marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Germany Inflation perception next 12m% Median"], color="darkred",
        linewidth= l1, linestyle='-',marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["France Inflation perception next 12m% Median"], color="darkgreen",
        linewidth= l1, linestyle='-',marker='>', markersize=s2)
g1.plot(kind='line', ax=ax,y=["Italy Inflation perception next 12m% Median"], color="darkorange",
        linewidth= l1, linestyle='-',marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Spain Inflation perception next 12m% Median"], color="magenta",
        linewidth= l1, linestyle='-',marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,y=["Netherlands Inflation perception next 12m% Median"], color="yellow",
        linewidth= l1, linestyle='-',marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_004_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2


            

title_r="Inflation perception next 3y% Median"
y_label="Index %"
x_label=""

list_c=["CES Inflation perception next 3y% Median",
        "Germany Inflation perception next 3y% Median",
        "France Inflation perception next 3y% Median",
        "Italy Inflation perception next 3y% Median",
        "Spain Inflation perception next 3y% Median",
        "Netherlands Inflation perception next 3y% Median"]
df1=hv_tb_eu_004_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()

fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))

g1.plot(kind='line', ax=ax, y=["CES Inflation perception next 3y% Median"], color="black",
        linewidth= l1,  linestyle='-',marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Germany Inflation perception next 3y% Median"], color="darkred",
        linewidth= l1, linestyle='-',marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["France Inflation perception next 3y% Median"], color="darkgreen",
        linewidth= l1, linestyle='-',marker='>', markersize=s2)
g1.plot(kind='line', ax=ax,y=["Italy Inflation perception next 3y% Median"], color="darkorange",
        linewidth= l1, linestyle='-',marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Spain Inflation perception next 3y% Median"], color="magenta",
        linewidth= l1, linestyle='-',marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,y=["Netherlands Inflation perception next 3y% Median"], color="yellow",
        linewidth= l1, linestyle='-',marker='o', markersize=s2)
plt.axhline(0, color ='black', lw=1,linestyle= 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_004_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2




         



### 001 EA  sentix <a id="title_page"></a

print("tickers")
eu_m_tickers = ['n023vsgx', 'n023vsh6', 'n023vsi6', 'n023vsp6', 'n023vsh0', 'n023vsi0', 'n023vsp0']

print("getting from api")
hv_tb_eu_005_001_m = Haver.data(eu_m_tickers, country_database, dates=True)
print(hv_tb_eu_005_001_m.columns)
#for x in range(Len(us_m_tickers)):

print("renaming")
hv_tb_eu_005_001_m.rename(columns={"n023vsgx":"EA Sentix Overall Economic Index NSA"}, inplace=True)
hv_tb_eu_005_001_m.rename(columns={"n023vsh6": "EA Economic Expectations NSA"}, inplace=True)
hv_tb_eu_005_001_m.rename(columns={"n023vsi6": "EA Inst Inv Eco Expectations NSA"}, inplace=True)
hv_tb_eu_005_001_m.rename(columns={"n023vsp6": "EA Priv Inv Eco Expectations NSA"}, inplace=True)
hv_tb_eu_005_001_m.rename(columns={"n023vsh0": "EA Economic Index Current Situation NSA"}, inplace=True)
hv_tb_eu_005_001_m.rename(columns={"n023vsi0": "EA Inst Inv Current situation NSA"}, inplace=True)
hv_tb_eu_005_001_m.rename(columns={"n023vsp0":"EA Priv Inv Current situation NSA"}, inplace=True)
#hv_tb_eu_005_001_m_g_001=hv_tb_eu_005_001_m.copy()
#hv_tb_eu_005_001_m=hv_tb_eu_005_001_m.tail(horizon_tb)
#hv_tb_eu_005_001_m=hv_tb_eu_005_001_m.transpose()
#hv_tb_eu_005_001_m.index.names ['Variable']
#dashboard.to_clipboard()
#print(hv_tb_eu_005_001_m)
##dashboard.to_clipboard()

#hv_tb_eu_005_001_m.to_csv (path_display, index=True, header=True)
#print(hv_tb_eu_005_001_m)
#print("step2")
hv_tb_eu_005_001_m_g = hv_tb_eu_005_001_m.copy()
hv_tb_eu_005_001_m_g_001 = hv_tb_eu_005_001_m.copy()

hv_tb_eu_005_001_m.index=hv_tb_eu_005_001_m.index.date
hv_tb_eu_005_001_m = hv_tb_eu_005_001_m.tail(horizon_tb)
hv_tb_eu_005_001_t1=hv_tb_eu_005_001_m.tail(horizon_tb)

hv_tb_eu_005_001_m_t = hv_tb_eu_005_001_m.transpose()
hv_tb_eu_005_001_m_t.index.names = ['Variable']

hv_tb_eu_005_001_t1_t = hv_tb_eu_005_001_t1.transpose()
hv_tb_eu_005_001_t1_t.index.names = ['Variable']



### 001 EA  sentix table <a id="title_page"></a


############################################################
######Table 1

#####here*******
title_table="ea_sentix"
df =hv_tb_eu_005_001_t1.copy()
df_transposed = hv_tb_eu_005_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_eu_005_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_eu_005_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_eu_005_001_m_t_002.png')


### 001 EA  sentix graphs <a id="title_page"></a

title_r="EA Sentix Overall Economic Index NSA"
y_label="Index %"
x_label=title_r
list_c=[title_r]
df1=hv_tb_eu_005_001_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig,ax =plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[title_r], color="blue",  linewidth=l1, linestyle='-', marker="P", markersize=s2)
#pit.axhline(0, color 'black', Lw-1, Linestyle 'dashed', alpha-0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_005_001_m_g_001.png", bbox_inches ='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()

title_r="EA Economic Expectations NSA"
y_label="Index %"
x_label=title_r
list_c=[title_r]
df1=hv_tb_eu_005_001_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig,ax =plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[title_r], color="blue",  linewidth=l1, linestyle='-', marker="P", markersize=s2)
#plt.axhline(0, color="black", Lw=1, linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_005_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()


### 001 EA  Consuemr confidee <a id="title_page"></a

print("tickers")
eu_m_tickers = ["e025cf", "e025es", "e025i", "e025s", "e025c", "e025t", "e025r", "e025eei"]
print("getting from api")
hv_tb_eu_005_002_m = Haver.data(eu_m_tickers, "EUDATA", dates=True)
print(hv_tb_eu_005_002_m)
print(hv_tb_eu_005_002_m.columns)
hv_tb_eu_005_002_m.rename(columns={"e025cf": "EA20 Consumer Confidence Flash SA"}, inplace=True)
hv_tb_eu_005_002_m.rename(columns={"e025es": "EA20 Economic Sentiment Indicator SA"}, inplace=True)
hv_tb_eu_005_002_m.rename(columns={"e025i": "EA20 Industrial Confidence SA"}, inplace=True)
hv_tb_eu_005_002_m.rename(columns={"e025s": "EA20 Service Confidence SA"}, inplace=True)
hv_tb_eu_005_002_m.rename(columns={"e025c": "EA20 Consumer Confidence SA"}, inplace=True)
hv_tb_eu_005_002_m.rename(columns={"e025t": "EA20 Construction Confidence SA"}, inplace=True)
hv_tb_eu_005_002_m.rename(columns={"e025r": "EA20 Retail Trade Confidence SA"}, inplace=True)
hv_tb_eu_005_002_m.rename(columns={"e025eei": "EA20 Employment Expectation SA"}, inplace=True)
#hv_tb_eu_005_002_m_g_001 = hv_tb_eu_005_002_m.copy()
#hv_tb_eu_005_002_m = hv_tb_eu_005_002_m.tail(horizon_tb)
#hv_tb_eu_005_002_m = hv_tb_eu_005_002_m.transpose()
#hv_tb_eu_005_002_m.index.names = ['Variable']
## dashboard.to_clipboard()
#print(hv_tb_eu_005_002_m)
# dashboard.to_clipboard()

#hv_tb_eu_005_002_m.to_csv(path_display, index=True, header=True)
#print(hv_tb_eu_005_002_m)
#print("step2")


hv_tb_eu_005_002_m_g = hv_tb_eu_005_002_m.copy()
hv_tb_eu_005_002_m_g_001 = hv_tb_eu_005_002_m.copy()

hv_tb_eu_005_002_m.index=hv_tb_eu_005_002_m.index.date
hv_tb_eu_005_002_m = hv_tb_eu_005_002_m.tail(horizon_tb)
hv_tb_eu_005_002_t1=hv_tb_eu_005_002_m.tail(horizon_tb)

hv_tb_eu_005_002_m_t = hv_tb_eu_005_002_m.transpose()
hv_tb_eu_005_002_m_t.index.names = ['Variable']

hv_tb_eu_005_002_t1_t = hv_tb_eu_005_002_t1.transpose()
hv_tb_eu_005_002_t1_t.index.names = ['Variable']


### 001 EA  Consumer table <a id="title_page"></a


############################################################
######Table 1

#####here*******
title_table="eu_consumer_confidence"
df =hv_tb_eu_005_002_t1.copy()
df_transposed = hv_tb_eu_005_002_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_eu_005_002_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_eu_005_002_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_eu_005_002_m_t_002.png')




### 001 EA  Consumer graphs <a id="title_page"></a



title_r="EA20 Consumer Confidence Flash SA"
y_label="Index %"
x_label=title_r
list_c=[title_r]
df1=hv_tb_eu_005_002_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig,ax = plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[title_r], color="green",linewidth= l1, linestyle="-", marker='P', markersize=s2)
#plt.axhline (0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_005_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r = "EA20 Economic Sentiment Indicator SA"
y_label = "Index"
x_label = "X"
list_c = [title_r]
df1 = hv_tb_eu_005_002_m_g_001[list_c]
df1 = df1.tail(60)
gl = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
gl.plot(kind='line', ax=ax, y=[title_r], color="green",
                                   linewidth=l1, linestyle='-',
                                   marker='o', markersize=s2)
# plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_005_002_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close("all")
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2

title_r = "EA20 Industrial Confidence SA"
y_label = "Index"
x_label = "X"
list_c = [title_r]
df1 = hv_tb_eu_005_002_m_g_001[list_c]
df1 = df1.tail(60)
gl = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
gl.plot(kind='line', ax=ax, y=[title_r], color="green",
                                   linewidth=l1, linestyle='-',
                                   marker='o', markersize=s2)
# plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_005_002_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close("all")
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2

title_r = "EA20 Service Confidence SA"
y_label = "Index"
x_label = "X"
list_c = [title_r]
df1 = hv_tb_eu_005_002_m_g_001[list_c]
df1 = df1.tail(60)
gl = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
gl.plot(kind='line', ax=ax, y=[title_r], color="green",
                                   linewidth=l1, linestyle='-',
                                   marker='o', markersize=s2)
# plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_005_002_m_g_004.png", bbox_inches='tight')
plt.close()
plt.close("all")
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2

title_r = "EA20 Consumer Confidence SA"
y_label = "Index"
x_label = "X"
list_c = [title_r]
df1 = hv_tb_eu_005_002_m_g_001[list_c]
df1 = df1.tail(60)
gl = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
gl.plot(kind='line', ax=ax, y=[title_r], color="green",
                                   linewidth=l1, linestyle='-',
                                   marker='o', markersize=s2)
# plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_005_002_m_g_005.png", bbox_inches='tight')
plt.close()
plt.close("all")
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2

title_r = "EA20 Construction Confidence SA"
y_label = "Index"
x_label = "X"
list_c = [title_r]
df1 = hv_tb_eu_005_002_m_g_001[list_c]
df1 = df1.tail(60)
gl = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
gl.plot(kind='line', ax=ax, y=[title_r], color="green",
                                   linewidth=l1, linestyle='-',
                                   marker='o', markersize=s2)
# plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_005_002_m_g_006.png", bbox_inches='tight')
plt.close()
plt.close("all")
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2

title_r = "EA20 Retail Trade Confidence SA"
y_label = "Index"
x_label = "X"
list_c = [title_r]
df1 = hv_tb_eu_005_002_m_g_001[list_c]
df1 = df1.tail(60)
gl = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
gl.plot(kind='line', ax=ax, y=[title_r], color="green",
                                   linewidth=l1, linestyle='-',
                                   marker='o', markersize=s2)
# plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_005_002_m_g_007.png", bbox_inches='tight')
plt.close()
plt.close("all")
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2

title_r = "EA20 Employment Expectation SA"
y_label = "Index"
x_label = "X"
list_c = [title_r]
df1 = hv_tb_eu_005_002_m_g_001[list_c]
df1 = df1.tail(60)
gl = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
gl.plot(kind='line', ax=ax, y=[title_r], color="green",
                                   linewidth=l1, linestyle='-',
                                   marker='o', markersize=s2)
# plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_005_002_m_g_008.png", bbox_inches='tight')
plt.close()
plt.close("all")
plt.clf()
plt.cla()
del df1
del list_c
del fig
del ax
del ax2

### 001 EA  Retail Trade value volume <a id="title_page"></a

eu_m_tickers = ['s997r47', 's025r47', 's134r47', 's132r47', 's136r47', 's184r47', 's138r47', 
                's997d47', 's025d47', 's134d47', 's132d47', 's136d47', 's184d47', 's138d47']

print("getting from api")
hv_tb_eu_006_001_m=Haver.data(eu_m_tickers, country_database, dates=True)
#print(hv_tb_eu_006_001_m)
#print(hv_tb_eu_006_001_m.columns)

for x in range(len(eu_m_tickers)):
    variable=str(eu_m_tickers [x])
    hv_tb_eu_006_001_m[variable] = hv_tb_eu_006_001_m[variable].pct_change(12).multiply(100).round(3)


hv_tb_eu_006_001_m.rename(columns={"s997r47": "EU27 Retail Trade excl Auto Value SA Y/Y"}, inplace=True)
hv_tb_eu_006_001_m.rename(columns={"s025r47": "EA20 Retail Trade excl Auto Value SA Y/Y"}, inplace=True)
hv_tb_eu_006_001_m.rename(columns={"s134r47": "Germany Retail Trade excl Auto Value SA Y/Y"}, inplace=True)
hv_tb_eu_006_001_m.rename(columns={"s132r47": "France Retail Trade excl Auto Value SA Y/Y"}, inplace=True)
hv_tb_eu_006_001_m.rename(columns={"s136r47": "Italy Retail Trade excl Auto Value SA Y/Y"}, inplace=True)
hv_tb_eu_006_001_m.rename(columns={"s184r47": "Spain Retail Trade excl Auto Value SA Y/Y"}, inplace=True)
hv_tb_eu_006_001_m.rename(columns={"s138r47": "Netherlands Retail Trade excl Auto Value SA Y/Y"}, inplace=True)

hv_tb_eu_006_001_m.rename(columns={"s997d47": "EU27 Retail Trade excl Auto Volume SA Y/Y"}, inplace=True)
hv_tb_eu_006_001_m.rename(columns={"s025d47": "EA20 Retail Trade excl Auto Volume SA Y/Y"}, inplace=True)
hv_tb_eu_006_001_m.rename(columns={"s134d47": "Germany Retail Trade excl Auto Volume SA Y/Y"}, inplace=True)
hv_tb_eu_006_001_m.rename(columns={"s132d47": "France Retail Trade excl Auto Volume SA Y/Y"}, inplace=True)
hv_tb_eu_006_001_m.rename(columns={"s136d47": "Italy Retail Trade excl Auto Volume SA Y/Y"}, inplace=True)
hv_tb_eu_006_001_m.rename(columns={"s184d47": "Spain Retail Trade excl Auto Volume SA Y/Y"}, inplace=True)
hv_tb_eu_006_001_m.rename(columns={"s138d47": "Netherlands Retail Trade excl Auto Volume SA Y/Y"}, inplace=True)

#hv_tb_eu_006_001_m_g_001=hv_tb_eu_006_001_m.copy()
#hv_tb_eu_006_001_m=hv_tb_eu_006_001_m.tail(horizon_tb)
#hv_tb_eu_006_001_m = hv_tb_eu_006_001_m.transpose()
#hv_tb_eu_006_001_m.index.names = ['Variable']
##dashboard.to_clipboard()#
#print(hv_tb_eu_006_001_m)
##dashboard.to_clipboard()

#print("step2")
print("Complete")

hv_tb_eu_006_001_m_g = hv_tb_eu_006_001_m.copy()
hv_tb_eu_006_001_m_g_001 = hv_tb_eu_006_001_m.copy()

hv_tb_eu_006_001_m.index=hv_tb_eu_006_001_m.index.date
hv_tb_eu_006_001_m = hv_tb_eu_006_001_m.tail(horizon_tb)
hv_tb_eu_006_001_t1=hv_tb_eu_006_001_m.tail(horizon_tb)

hv_tb_eu_006_001_m_t = hv_tb_eu_006_001_m.transpose()
hv_tb_eu_006_001_m_t.index.names = ['Variable']

hv_tb_eu_006_001_t1_t = hv_tb_eu_006_001_t1.transpose()
hv_tb_eu_006_001_t1_t.index.names = ['Variable']

### 001 EA  Retail Trade table <a id="title_page"></a



############################################################
######Table 1

#####here*******
title_table="eu_retail_trade"
df =hv_tb_eu_006_001_t1.copy()
df_transposed = hv_tb_eu_006_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_eu_006_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_eu_006_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_eu_006_001_m_t_002.png')




### 001 EA  Retail Trade graph  <a id="title_page"></a

title_r = "Europe Whole Sale Retail Trade"
y_label = "Index %"
list_c = ["EU27 Retail Trade excl Auto Volume SA Y/Y",
          "EA20 Retail Trade excl Auto Volume SA Y/Y"]
df1 = hv_tb_eu_006_001_m_g_001[list_c]
df1 = df1.tail(72)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=['EU27 Retail Trade excl Auto Volume SA Y/Y'], color='black', linestyle='-', linewidth=l1, marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=['EA20 Retail Trade excl Auto Volume SA Y/Y'], color='black', linestyle='-', linewidth=l1, marker='P', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_006_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close("all")
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r = "Europe Whole Sale Retail Trade"
y_label = "Index %"
list_c = ["EU27 Retail Trade excl Auto Volume SA Y/Y",
          "EA20 Retail Trade excl Auto Volume SA Y/Y"]
df1 = hv_tb_eu_006_001_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=['EU27 Retail Trade excl Auto Volume SA Y/Y'], color='black', linestyle='-', linewidth=l1, marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=['EA20 Retail Trade excl Auto Volume SA Y/Y'], color='black', linestyle='-', linewidth=l1, marker='P', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_006_001_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close("all")
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

list_c=["Germany Retail Trade excl Auto Volume SA Y/Y",
       "France Retail Trade excl Auto Volume SA Y/Y",
       "Italy Retail Trade excl Auto Volume SA Y/Y",
       "Spain Retail Trade excl Auto Volume SA Y/Y",
       "Netherlands Retail Trade excl Auto Volume SA Y/Y"]
df1=hv_tb_eu_006_001_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["Germany Retail Trade excl Auto Volume SA Y/Y"], color="darkred",linewidth= l1, linestyle='-',marker='s',markersize=s2)
g1.plot(kind='line', ax=ax,y=["France Retail Trade excl Auto Volume SA Y/Y"], color="darkgreen",linewidth= l1, linestyle='-',marker='s',markersize=s2)
g1.plot(kind='line', ax=ax,y=["Italy Retail Trade excl Auto Volume SA Y/Y"], color="darkorange",linewidth= l1, linestyle='-',marker='s',markersize=s2)
g1.plot(kind='line', ax=ax, y=["Spain Retail Trade excl Auto Volume SA Y/Y"], color="magenta",linewidth= l1, linestyle='-',marker='o', markersize=s2)
g1.plot(kind='line',ax=ax,y=["Netherlands Retail Trade excl Auto Volume SA Y/Y"], color="yellow",linewidth= l1, linestyle='-',marker='s',markersize=s2)
plt.axhline(0, color='black', lw=1,linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_006_001_m_g_002.png", bbox_inches="tight")
plt.close()
plt.close("all")
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

list_c=["Germany Retail Trade excl Auto Volume SA Y/Y",
       "France Retail Trade excl Auto Volume SA Y/Y",
       "Italy Retail Trade excl Auto Volume SA Y/Y",
       "Spain Retail Trade excl Auto Volume SA Y/Y",
       "Netherlands Retail Trade excl Auto Volume SA Y/Y"]
df1=hv_tb_eu_006_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["Germany Retail Trade excl Auto Volume SA Y/Y"], color="darkred",linewidth= l1, linestyle='-',marker='s',markersize=s2)
g1.plot(kind='line', ax=ax,y=["France Retail Trade excl Auto Volume SA Y/Y"], color="darkgreen",linewidth= l1, linestyle='-',marker='s',markersize=s2)
g1.plot(kind='line', ax=ax,y=["Italy Retail Trade excl Auto Volume SA Y/Y"], color="darkorange",linewidth= l1, linestyle='-',marker='s',markersize=s2)
g1.plot(kind='line', ax=ax, y=["Spain Retail Trade excl Auto Volume SA Y/Y"], color="magenta",linewidth= l1, linestyle='-',marker='o', markersize=s2)
g1.plot(kind='line',ax=ax,y=["Netherlands Retail Trade excl Auto Volume SA Y/Y"], color="yellow",linewidth= l1, linestyle='-',marker='s',markersize=s2)
plt.axhline(0, color='black', lw=1,linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_006_001_m_g_002z.png", bbox_inches="tight")
plt.close()
plt.close("all")
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r="Europe Whole Sale Retail Trade"
y_label="Index %"
x_label=title_r
list_c=["EU27 Retail Trade excl Auto Volume SA Y/Y",
        "EA20 Retail Trade excl Auto Volume SA Y/Y"]
df1=hv_tb_eu_006_001_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig,ax =plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["EU27 Retail Trade excl Auto Volume SA Y/Y"], color="black",linewidth=l1, linestyle='-',marker="P",markersize=s2)
g1.plot(kind='line', ax=ax,y=["EA20 Retail Trade excl Auto Volume SA Y/Y"], color="darkblue",linewidth= l1, linestyle='-', marker="D",markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis="both", alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_006_001_m_g_003.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

title_r="Europe Whole Sale Retail Trade"
y_label="Index %"
x_label=title_r
list_c=["EU27 Retail Trade excl Auto Volume SA Y/Y",
        "EA20 Retail Trade excl Auto Volume SA Y/Y"]
df1=hv_tb_eu_006_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax =plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["EU27 Retail Trade excl Auto Volume SA Y/Y"], color="black",linewidth=l1, linestyle='-',marker="P",markersize=s2)
g1.plot(kind='line', ax=ax,y=["EA20 Retail Trade excl Auto Volume SA Y/Y"], color="darkblue",linewidth= l1, linestyle='-', marker="D",markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis="both", alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_006_001_m_g_003z.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

title_r="Europe Whole Sale Retail Trade"
y_label="Index %"

x_label=title_r
list_c=["Germany Retail Trade excl Auto Volume SA Y/Y",
        "France Retail Trade excl Auto Volume SA Y/Y",
        "Italy Retail Trade excl Auto Volume SA Y/Y",
        "Spain Retail Trade excl Auto Volume SA Y/Y",
        "Netherlands Retail Trade excl Auto Volume SA Y/Y"]
df1=hv_tb_eu_006_001_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig,ax= plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["Germany Retail Trade excl Auto Volume SA Y/Y"], color="darkred",linewidth= l1, linestyle='-',marker='s',markersize=s2)
g1.plot(kind='line', ax=ax,y=["France Retail Trade excl Auto Volume SA Y/Y"], color="darkgreen",linewidth= l1, linestyle='-',marker='>',markersize=s2)
g1.plot(kind='line', ax=ax,y=["Italy Retail Trade excl Auto Volume SA Y/Y"], color="darkorange",linewidth= l1, linestyle='-',marker='.',markersize=s2)
g1.plot(kind='line', ax=ax,y=["Spain Retail Trade excl Auto Volume SA Y/Y"], color="magenta",linewidth= l1, linestyle='-',marker='o',markersize=s2)
g1.plot(kind='line', ax=ax,y=["Netherlands Retail Trade excl Auto Volume SA Y/Y"], color="yellow",linewidth= l1, linestyle='-',marker='*',markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis="both", alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_006_001_m_g_004.png", bbox_inches='tight')
plt.close()
plt.close('all')

title_r="Europe Whole Sale Retail Trade"
y_label="Index %"

x_label=title_r
list_c=["Germany Retail Trade excl Auto Volume SA Y/Y",
        "France Retail Trade excl Auto Volume SA Y/Y",
        "Italy Retail Trade excl Auto Volume SA Y/Y",
        "Spain Retail Trade excl Auto Volume SA Y/Y",
        "Netherlands Retail Trade excl Auto Volume SA Y/Y"]
df1=hv_tb_eu_006_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax= plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["Germany Retail Trade excl Auto Volume SA Y/Y"], color="darkred",linewidth= l1, linestyle='-',marker='s',markersize=s2)
g1.plot(kind='line', ax=ax,y=["France Retail Trade excl Auto Volume SA Y/Y"], color="darkgreen",linewidth= l1, linestyle='-',marker='>',markersize=s2)
g1.plot(kind='line', ax=ax,y=["Italy Retail Trade excl Auto Volume SA Y/Y"], color="darkorange",linewidth= l1, linestyle='-',marker='.',markersize=s2)
g1.plot(kind='line', ax=ax,y=["Spain Retail Trade excl Auto Volume SA Y/Y"], color="magenta",linewidth= l1, linestyle='-',marker='o',markersize=s2)
g1.plot(kind='line', ax=ax,y=["Netherlands Retail Trade excl Auto Volume SA Y/Y"], color="yellow",linewidth= l1, linestyle='-',marker='*',markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis="both", alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_006_001_m_g_004z.png", bbox_inches='tight')
plt.close()
plt.close('all')




### 001 EA  Retail Trade MM  <a id="title_page"></a

print("tickers")
eu_m_tickers = ['s997r47', 's025r47', 's134r47', 's132r47', 's136r47', 's184r47', 's138r47',
                's997d47', 's025d47', 's134d47', 's132d47', 's136d47', 's184d47', 's138d47']
print("getting from api")
hv_tb_eu_006_002_m = Haver.data(eu_m_tickers, country_database, dates=True)
print(hv_tb_eu_006_002_m)
print(hv_tb_eu_006_002_m.columns)
for x in range(len(eu_m_tickers)):
    #print(x)
    variable=str(eu_m_tickers[x])
    #print(variable)
    hv_tb_eu_006_002_m[variable] = hv_tb_eu_006_002_m[variable].pct_change(1).multiply(100).round(3)
    #print(hv_tb_eu_006_002_m[variable])

hv_tb_eu_006_002_m.rename(columns={'s997r47': "EU27 Retail Trade excl Auto - Volume SA M/M"}, inplace=True)
hv_tb_eu_006_002_m.rename(columns={'s025r47': "EA20 Retail Trade excl Auto - Volume SA M/M"}, inplace=True)
hv_tb_eu_006_002_m.rename(columns={'s134r47': "Germany Retail Trade excl Auto - Volume SA M/M"}, inplace=True)
hv_tb_eu_006_002_m.rename(columns={'s132r47': "France Retail Trade excl Auto - Volume SA M/M"}, inplace=True)
hv_tb_eu_006_002_m.rename(columns={'s136r47': "Italy Retail Trade excl Auto - Volume SA M/M"}, inplace=True)
hv_tb_eu_006_002_m.rename(columns={'s184r47': "Spain Retail Trade excl Auto - Volume SA M/M"}, inplace=True)
hv_tb_eu_006_002_m.rename(columns={'s138r47': "Netherlands Retail Trade excl Auto - Volume SA M/M"}, inplace=True)

hv_tb_eu_006_002_m.rename(columns={'s997d47': "EU27 Retail Trade excl Auto - Volume SA M/M"}, inplace=True)
hv_tb_eu_006_002_m.rename(columns={'s025d47': "EA20 Retail Trade excl Auto - Volume SA M/M"}, inplace=True)
hv_tb_eu_006_002_m.rename(columns={'s134d47': "Germany Retail Trade excl Auto - Volume SA M/M"}, inplace=True)
hv_tb_eu_006_002_m.rename(columns={'s132d47': "France Retail Trade excl Auto - Volume SA M/M"}, inplace=True)
hv_tb_eu_006_002_m.rename(columns={'s136d47': "Italy Retail Trade excl Auto - Volume SA M/M"}, inplace=True)
hv_tb_eu_006_002_m.rename(columns={'s184d47': "Spain Retail Trade excl Auto - Volume SA M/M"}, inplace=True)
hv_tb_eu_006_002_m.rename(columns={'s138d47': "Netherlands Retail Trade excl Auto - Volume SA M/M"}, inplace=True)
hv_tb_eu_006_002_m_g_001=hv_tb_eu_006_002_m.copy()
hv_tb_eu_006_002_m=hv_tb_eu_006_002_m.tail(horizon_tb)
hv_tb_eu_006_002_m = hv_tb_eu_006_002_m.transpose()
#hv_tb_eu_006_002_m.index.names = ['Variable']
#dashboard.to_clipboard()
#print(hv_tb_eu_006_002_m)
#dashboard.to_clipboard()
#path_display = tb_eu_006_002_m.csv'
#print(path_display)
#hv_tb_eu_006_002_m.to_csv(path_display, index=True, header=True)
#print(hv_tb_eu_006_002_m)
#print("sten2")

### 001 EA  Retail Trade MM  TABLE <a id="title_page"></a





### 001 EA  Retail Trade MM GRAPH <a id="title_page"></a

title_r="Europe Whole Sale Retail Trade M/M"
y_label="Index %"
x_label="Date"
list_c=["EU27 Retail Trade excl Auto - Volume SA M/M",
        "EA20 Retail Trade excl Auto - Volume SA M/M"]
df1=hv_tb_eu_006_002_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["EU27 Retail Trade excl Auto - Volume SA M/M"], color="black",
                                                 linewidth= l1, linestyle="-",
                                                 marker="P", markersize=s2)
g1.plot(kind='line',ax=ax,y=["EA20 Retail Trade excl Auto - Volume SA M/M"], color="darkblue",
                                                 linewidth= l1, linestyle="-",
                                                 marker="D", markersize=s2)
plt.axhline(0, color="black", lw=1, linestyle="dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_006_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r="Europe Whole Sale Retail Trade M/M"
y_label="Index %"
x_label="Date"
list_c=["EU27 Retail Trade excl Auto - Volume SA M/M",
        "EA20 Retail Trade excl Auto - Volume SA M/M"]
df1=hv_tb_eu_006_002_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["EU27 Retail Trade excl Auto - Volume SA M/M"], color="black",
                                                 linewidth= l1, linestyle="-",
                                                 marker="P", markersize=s2)
g1.plot(kind='line',ax=ax,y=["EA20 Retail Trade excl Auto - Volume SA M/M"], color="darkblue",
                                                 linewidth= l1, linestyle="-",
                                                 marker="D", markersize=s2)
plt.axhline(0, color="black", lw=1, linestyle="dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_006_002_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r="Europe Whole Sale Retail Trade M/M"
y_label="Index %"
x_label=title_r
list_c=["Germany Retail Trade excl Auto - Volume SA M/M",
        "France Retail Trade excl Auto - Volume SA M/M",
        "Italy Retail Trade excl Auto - Volume SA M/M",
        "Spain Retail Trade excl Auto - Volume SA M/M",
        "Netherlands Retail Trade excl Auto - Volume SA M/M"]
df1=hv_tb_eu_006_002_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["Germany Retail Trade excl Auto - Volume SA M/M"], color="darkred",
        linewidth= l1, linestyle='',
        marker='s', markersize=s2)
g1.plot(kind='line', ax=ax,y=["France Retail Trade excl Auto - Volume SA M/M"], color="darkgreen",
        linewidth= l1, linestyle="-",
        marker='>',markersize=s2)
g1.plot(kind='line', ax=ax,y=["Italy Retail Trade excl Auto - Volume SA M/M"], color="darkorange",
        linewidth= l1, linestyle='',
        marker='*', markersize=s2)
g1.plot(kind='line', ax=ax,y=["Spain Retail Trade excl Auto - Volume SA M/M"], color="magenta",
        linewidth= l1, linestyle='',
        marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,y=["Netherlands Retail Trade excl Auto - Volume SA M/M"], color="yellow",
        linewidth= l1, linestyle='-',
        marker='.',markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_006_002_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()

title_r="Europe Whole Sale Retail Trade M/M"
y_label="Index %"
x_label=title_r
list_c=["Germany Retail Trade excl Auto - Volume SA M/M",
        "France Retail Trade excl Auto - Volume SA M/M",
        "Italy Retail Trade excl Auto - Volume SA M/M",
        "Spain Retail Trade excl Auto - Volume SA M/M",
        "Netherlands Retail Trade excl Auto - Volume SA M/M"]
df1=hv_tb_eu_006_002_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["Germany Retail Trade excl Auto - Volume SA M/M"], color="darkred",
        linewidth= l1, linestyle='',
        marker='s', markersize=s2)
g1.plot(kind='line', ax=ax,y=["France Retail Trade excl Auto - Volume SA M/M"], color="darkgreen",
        linewidth= l1, linestyle="-",
        marker='>',markersize=s2)
g1.plot(kind='line', ax=ax,y=["Italy Retail Trade excl Auto - Volume SA M/M"], color="darkorange",
        linewidth= l1, linestyle='',
        marker='*', markersize=s2)
g1.plot(kind='line', ax=ax,y=["Spain Retail Trade excl Auto - Volume SA M/M"], color="magenta",
        linewidth= l1, linestyle='',
        marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,y=["Netherlands Retail Trade excl Auto - Volume SA M/M"], color="yellow",
        linewidth= l1, linestyle='-',
        marker='.',markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_006_002_m_g_002z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()

title_r = "Europe Whole Sale Retail Trade N/N"
y_label = "Index %"

list_c = ["EU27 Retail Trade excl Auto - Volume SA M/M",
          "EA20 Retail Trade excl Auto - Volume SA M/M"]

df1 = hv_tb_eu_006_002_m_g_001[list_c]
df1 = df1.tail(72)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["EU27 Retail Trade excl Auto - Volume SA M/M"], color="black",
                                                   linewidth= l1, linestyle='-',
                                                   marker="P", markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA20 Retail Trade excl Auto - Volume SA M/M"], color="darkblue",
                                                   linewidth= l1, linestyle='-',
                                                   marker="D", markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_006_002_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax2

title_r = "Europe Whole Sale Retail Trade N/N"
y_label = "Index %"

list_c = ["EU27 Retail Trade excl Auto - Volume SA M/M",
          "EA20 Retail Trade excl Auto - Volume SA M/M"]

df1 = hv_tb_eu_006_002_m_g_001[list_c]
df1 = df1.tail(24)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["EU27 Retail Trade excl Auto - Volume SA M/M"], color="black",
                                                   linewidth= l1, linestyle='-',
                                                   marker="P", markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA20 Retail Trade excl Auto - Volume SA M/M"], color="darkblue",
                                                   linewidth= l1, linestyle='-',
                                                   marker="D", markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_006_002_m_g_003z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax2

title_r="Europe Whole Sale Retail Trade M/M"
y_label="Index %"
x_label=title_r

list_c=["Germany Retail Trade excl Auto - Volume SA M/M",
        "France Retail Trade excl Auto - Volume SA M/M",
        "Italy Retail Trade excl Auto - Volume SA M/M",
        "Spain Retail Trade excl Auto - Volume SA M/M",
        "Netherlands Retail Trade excl Auto - Volume SA M/M"]
df1=hv_tb_eu_006_002_m_g_001[list_c]
df1=df1.tail(72)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line',ax=ax, y=["Germany Retail Trade excl Auto - Volume SA M/M"], color="darkred",
        linewidth= l1, linestyle='-',
        marker='s',markersize=s2)
g1.plot(kind='line', ax=ax, y=["France Retail Trade excl Auto - Volume SA M/M"], color="darkgreen",
        linewidth= l1, linestyle='-',
        marker='>', markersize=s2)
g1.plot(kind='line', ax=ax,y=["Italy Retail Trade excl Auto - Volume SA M/M"], color="darkorange",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Spain Retail Trade excl Auto - Volume SA M/M"], color="magenta",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Netherlands Retail Trade excl Auto - Volume SA M/M"], color="yellow",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1,linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_006_002_m_g_004.png", bbox_inches='tight')
plt.close()
plt.close('all')

title_r="Europe Whole Sale Retail Trade M/M"
y_label="Index %"
x_label=title_r

list_c=["Germany Retail Trade excl Auto - Volume SA M/M",
        "France Retail Trade excl Auto - Volume SA M/M",
        "Italy Retail Trade excl Auto - Volume SA M/M",
        "Spain Retail Trade excl Auto - Volume SA M/M",
        "Netherlands Retail Trade excl Auto - Volume SA M/M"]
df1=hv_tb_eu_006_002_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line',ax=ax, y=["Germany Retail Trade excl Auto - Volume SA M/M"], color="darkred",
        linewidth= l1, linestyle='-',
        marker='s',markersize=s2)
g1.plot(kind='line', ax=ax, y=["France Retail Trade excl Auto - Volume SA M/M"], color="darkgreen",
        linewidth= l1, linestyle='-',
        marker='>', markersize=s2)
g1.plot(kind='line', ax=ax,y=["Italy Retail Trade excl Auto - Volume SA M/M"], color="darkorange",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Spain Retail Trade excl Auto - Volume SA M/M"], color="magenta",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Netherlands Retail Trade excl Auto - Volume SA M/M"], color="yellow",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1,linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_006_002_m_g_004z.png", bbox_inches='tight')
plt.close()
plt.close('all')

### retail trade seasonality



parameter_w_seas=14
parameter_h_seas=13


##### COmplete seasonality analysis 
### first nsa then sa

list_color = ["green", "brown","yellow", "orange", "blue", "black"]
sei_m_tickers = ['w025d47', 's025d47', ]

hv_tb_se_001_001_m = Haver.data(sei_m_tickers, country_database, dates=True)
print(hv_tb_se_001_001_m)
print(hv_tb_se_001_001_m.columns)
for x in range(len(sei_m_tickers)):
    variable = str(sei_m_tickers[x])
    hv_tb_se_001_001_m[variable] = hv_tb_se_001_001_m[variable].diff()

hv_tb_se_001_001_m.rename(columns={"w025d47": "ea20_retail_trade_wda"}, inplace=True)
hv_tb_se_001_001_m.rename(columns={"s025d47": "ea20_retail_trade_swda"}, inplace=True)
list_names = hv_tb_se_001_001_m.columns.tolist()
hv_tb_se_001_001_m['date']=hv_tb_se_001_001_m.index

#hv_tb_uk_008_001_m_g_001 = hv_tb_uk_008_001_m.copy()
#hv_tb_uk_008_001_m = hv_tb_uk_008_001_m.tail(horizon_1)
#hv_tb_uk_008_001_m = hv_tb_uk_008_001_m.transpose()
#hv_tb_uk_008_001_m.index.names = ['Variable']




df = hv_tb_se_001_001_m.copy()
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
# Filter last 5 years
last_5_years = df[df['date'] >= pd.Timestamp.now() - pd.DateOffset(years=5)]

# Get the last year in the dataset
last_year = last_5_years['year'].max()
years = sorted(last_5_years['year'].unique())
year_colors = {year: list_color[i % len(list_color)] for i, year in enumerate(years)}

# Define function to plot lines by year with the last year's line wider and a dot marker
def plot_by_year(data, value_col, title, ylabel, ax):
    for year, group in data.groupby('year'):
        line_width = 4.0 if year == last_year else 1.5  # Make the last year's line wider
        marker = 'o' if year == last_year else None    # Add dot marker for the last year's line
        ax.plot(group['month'], group[value_col], label=str(year), linewidth=line_width, 
                marker=marker, color=year_colors[year])  # Apply custom colors
    ax.set_title(title,fontsize=16)
    ax.set_xlabel('Month',fontsize=14)
    ax.set_ylabel(ylabel,fontsize=14)
    ax.legend(title='Year', loc='upper right', fontsize='small')
    #ax.grid(True, axis='x')  # Enable grid on x-axis
    ax.grid(True)  # Enable grid on x-axis
    ax.set_xticks(range(1, 13))  # Ensure all months (1 to 12) are shown on the x-axis
    ax.set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])


# Prepare the figure
fig, axs = plt.subplots(3, 2, figsize=(parameter_w_seas, parameter_h_seas))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
# Graph A: Retail Sales NSA by Year
plot_by_year(last_5_years, list_names[0], list_names[0],  'Index Value', axs[0, 0])
# Graph B: Retail Sales SA by Year
plot_by_year(last_5_years, list_names[1],  list_names[1],  'Index Value', axs[0, 1])
# Calculate MoM Returns
last_5_years['mom_return_nsa'] = last_5_years[list_names[0]].pct_change()
last_5_years['mom_return_sa'] = last_5_years[list_names[1]].pct_change()
# Graph C: MoM Returns NSA
plot_by_year(last_5_years.dropna(), 'mom_return_nsa', 
             'MoM Returns - NSA', 'MoM Return', axs[1, 0])
# Graph D: MoM Returns SA
plot_by_year(last_5_years.dropna(), 'mom_return_sa',
             'MoM Returns - SA', 'MoM Return', axs[1, 1])
# Calculate YoY Returns
last_5_years['yoy_return_nsa'] = last_5_years[list_names[0]].pct_change(12)
last_5_years['yoy_return_sa'] = last_5_years[list_names[1]].pct_change(12)
# Graph E: YoY Returns NSA
plot_by_year(last_5_years.dropna(), 'yoy_return_nsa',
             'YoY Returns - NSA', 'YoY Return', axs[2, 0])
# Graph F: YoY Returns SA
plot_by_year(last_5_years.dropna(), 'yoy_return_sa', 
             'YoY Returns - SA', 'YoY Return', axs[2, 1])
# Save the figure
plt.tight_layout()
plt.savefig('hv_tb_eu_006_003_m_g_001.png')








### 001 EA  IP <a id="title_page"></a

print("tickers")
eu_m_tickers = ['s997qbcd',
                's025qbcd',
                's134qbcd', 
                's132qbcd',
                's136qbcd',
                's184qbcd', 
                's138qbcd']
print("getting from api")
hv_tb_eu_007_001_m=Haver.data(eu_m_tickers, country_database, dates=True)
#print(hv_tb_eu_007_001_m)

hv_tb_eu_007_001_m.rename(columns={"s997qbcd": "EU27 Industrial Production excl Constr SA"}, inplace=True)
hv_tb_eu_007_001_m.rename(columns={"s025qbcd":"EA20 Industrial Production excl Constr SA"}, inplace=True)
hv_tb_eu_007_001_m.rename(columns={"s134qbcd": "Germany IP SA"}, inplace=True)
hv_tb_eu_007_001_m.rename(columns={"s132qbcd": "France IP SA"}, inplace=True)
hv_tb_eu_007_001_m.rename(columns={"s136qbcd": "Italy IP SA"}, inplace=True)
hv_tb_eu_007_001_m.rename(columns={"s184qbcd": "Spain IP SA"}, inplace=True)
hv_tb_eu_007_001_m.rename(columns={"s138qbcd": "Netherlands IP SA"}, inplace=True)
#hv_tb_eu_007_001_m_g_001=hv_tb_eu_007_001_m.copy()
#hv_tb_eu_007_001_m=hv_tb_eu_007_001_m.tail(horizon_tb)
#hv_tb_eu_007_001_m = hv_tb_eu_007_001_m.transpose()
#hv_tb_eu_007_001_m.index.names = ['Variable']
#dashboard.to_clipboard()
#print(hv_tb_eu_007_001_m)
#dashboard.to_clipboard()
print("Complete")


hv_tb_eu_007_001_m_g = hv_tb_eu_007_001_m.copy()
hv_tb_eu_007_001_m_g_001 = hv_tb_eu_007_001_m.copy()

hv_tb_eu_007_001_m.index=hv_tb_eu_007_001_m.index.date
hv_tb_eu_007_001_m = hv_tb_eu_007_001_m.tail(horizon_tb)
hv_tb_eu_007_001_t1=hv_tb_eu_007_001_m.tail(horizon_tb)

hv_tb_eu_007_001_m_t = hv_tb_eu_007_001_m.transpose()
hv_tb_eu_007_001_m_t.index.names = ['Variable']

hv_tb_eu_007_001_t1_t = hv_tb_eu_007_001_t1.transpose()
hv_tb_eu_007_001_t1_t.index.names = ['Variable']

### 001 EA ip table


############################################################
######Table 1

#####here*******
title_table="eu_ip"
df =hv_tb_eu_007_001_t1.copy()
df_transposed = hv_tb_eu_007_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_eu_007_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_eu_007_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_eu_007_001_m_t_002.png')




### 001 EA ip graphs

####IP

title_r = "Europe Industrial Production"
y_label = "Index %"
list_c = ["EU27 Industrial Production excl Constr SA",
          "EA20 Industrial Production excl Constr SA"]
df1 = hv_tb_eu_007_001_m_g_001[list_c]
df1 = df1.tail(60)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["EU27 Industrial Production excl Constr SA"],
        color="black",
        linewidth=l1,
        linestyle='-',
        marker="P", 
        markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA20 Industrial Production excl Constr SA"],
        color="darkblue",
        linewidth=l1,
        linestyle='-',
        marker="D", 
        markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_007_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

####IP


title_r="Europe Industrial Production"
y_label="Index %"
x_label=title_r
list_c=["EU27 Industrial Production excl Constr SA",
        "EA20 Industrial Production excl Constr SA"]
df1=hv_tb_eu_007_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax =plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["EU27 Industrial Production excl Constr SA"], 
        color="black",
        linewidth= l1, 
        linestyle='-',
        marker='P',
        markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA20 Industrial Production excl Constr SA"], 
        color="darkblue",
        linewidth=l1,
        linestyle='-', 
        marker='D', 
        markersize=s2)
plt.style.use('default')                          
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis="both", alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_007_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()

del g1
del df1
del list_c
del fig
del ax
del ax2

####IP
Title_r="Europe Industrial Production"
y_label="Index %"

x_label=title_r
list_c=["Germany IP SA",
        "France IP SA",
        "Italy IP SA",
        "Spain IP SA",
        "Netherlands IP SA"]

df1=hv_tb_eu_007_001_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig,ax = plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["Germany IP SA"], color="darkred",
        linewidth= l1, linestyle='-',marker='>',markersize=s2)
g1.plot(kind='line', ax=ax,y=["France IP SA"], color="darkgreen",
        linewidth= l1, linestyle="-",marker='>',markersize=s2)
g1.plot(kind='line', ax=ax, y=["Italy IP SA"], color="darkorange",
        linewidth= l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,y=["Spain IP SA"], 
        color="magenta",
        linewidth= l1, 
        linestyle='-',
        marker='o', 
        markersize=s2)
g1.plot(kind='line',ax=ax,y=["Netherlands IP SA"],
        color="yellow",
        linewidth= l1, 
        linestyle='-',
        marker='o',  
        markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_007_001_m_g_003.png", bbox_inches="tight")

####IP
Title_r="Europe Industrial Production"
y_label="Index %"

x_label=title_r
list_c=["Germany IP SA",
        "France IP SA",
        "Italy IP SA",
        "Spain IP SA",
        "Netherlands IP SA"]

df1=hv_tb_eu_007_001_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax = plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["Germany IP SA"], color="darkred",
        linewidth= l1, linestyle='-',marker='>',markersize=s2)
g1.plot(kind='line', ax=ax,y=["France IP SA"], color="darkgreen",
        linewidth= l1, linestyle="-",marker='>',markersize=s2)
g1.plot(kind='line', ax=ax, y=["Italy IP SA"], color="darkorange",
        linewidth= l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,y=["Spain IP SA"], 
        color="magenta",
        linewidth= l1, 
        linestyle='-',
        marker='o', 
        markersize=s2)
g1.plot(kind='line',ax=ax,y=["Netherlands IP SA"],
        color="yellow",
        linewidth= l1, 
        linestyle='-',
        marker='o',  
        markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_007_001_m_g_004.png", bbox_inches="tight")

### ip seasonality




##### COmplete seasonality analysis 
### first nsa then sa

list_color = ["green", "brown","yellow", "orange", "blue", "black"]
sei_m_tickers = ['w025qbcd', 's025qbcd', ]

hv_tb_se_001_001_m = Haver.data(sei_m_tickers, country_database, dates=True)
print(hv_tb_se_001_001_m)
print(hv_tb_se_001_001_m.columns)
for x in range(len(sei_m_tickers)):
    variable = str(sei_m_tickers[x])
    hv_tb_se_001_001_m[variable] = hv_tb_se_001_001_m[variable].diff()

hv_tb_se_001_001_m.rename(columns={"w025qbcd": "ea20_ipx_nsa"}, inplace=True)
hv_tb_se_001_001_m.rename(columns={"s025qbcd": "ea20_ipx_sa"}, inplace=True)
list_names = hv_tb_se_001_001_m.columns.tolist()
hv_tb_se_001_001_m['date']=hv_tb_se_001_001_m.index

#hv_tb_uk_008_001_m_g_001 = hv_tb_uk_008_001_m.copy()
#hv_tb_uk_008_001_m = hv_tb_uk_008_001_m.tail(horizon_1)
#hv_tb_uk_008_001_m = hv_tb_uk_008_001_m.transpose()
#hv_tb_uk_008_001_m.index.names = ['Variable']




df = hv_tb_se_001_001_m.copy()
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
# Filter last 5 years
last_5_years = df[df['date'] >= pd.Timestamp.now() - pd.DateOffset(years=5)]

# Get the last year in the dataset
last_year = last_5_years['year'].max()
years = sorted(last_5_years['year'].unique())
year_colors = {year: list_color[i % len(list_color)] for i, year in enumerate(years)}

# Define function to plot lines by year with the last year's line wider and a dot marker
def plot_by_year(data, value_col, title, ylabel, ax):
    for year, group in data.groupby('year'):
        line_width = 4.0 if year == last_year else 1.5  # Make the last year's line wider
        marker = 'o' if year == last_year else None    # Add dot marker for the last year's line
        ax.plot(group['month'], group[value_col], label=str(year), linewidth=line_width, 
                marker=marker, color=year_colors[year])  # Apply custom colors
    ax.set_title(title,fontsize=16)
    ax.set_xlabel('Month',fontsize=14)
    ax.set_ylabel(ylabel,fontsize=14)
    ax.legend(title='Year', loc='upper right', fontsize='small')
    #ax.grid(True, axis='x')  # Enable grid on x-axis
    ax.grid(True)  # Enable grid on x-axis
    ax.set_xticks(range(1, 13))  # Ensure all months (1 to 12) are shown on the x-axis
    ax.set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])


# Prepare the figure
fig, axs = plt.subplots(3, 2, figsize=(parameter_w_seas, parameter_h_seas))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
# Graph A: Retail Sales NSA by Year
plot_by_year(last_5_years, list_names[0], list_names[0],  'Index Value', axs[0, 0])
# Graph B: Retail Sales SA by Year
plot_by_year(last_5_years, list_names[1],  list_names[1],  'Index Value', axs[0, 1])
# Calculate MoM Returns
last_5_years['mom_return_nsa'] = last_5_years[list_names[0]].pct_change()
last_5_years['mom_return_sa'] = last_5_years[list_names[1]].pct_change()
# Graph C: MoM Returns NSA
plot_by_year(last_5_years.dropna(), 'mom_return_nsa', 
             'MoM Returns - NSA', 'MoM Return', axs[1, 0])
# Graph D: MoM Returns SA
plot_by_year(last_5_years.dropna(), 'mom_return_sa',
             'MoM Returns - SA', 'MoM Return', axs[1, 1])
# Calculate YoY Returns
last_5_years['yoy_return_nsa'] = last_5_years[list_names[0]].pct_change(12)
last_5_years['yoy_return_sa'] = last_5_years[list_names[1]].pct_change(12)
# Graph E: YoY Returns NSA
plot_by_year(last_5_years.dropna(), 'yoy_return_nsa',
             'YoY Returns - NSA', 'YoY Return', axs[2, 0])
# Graph F: YoY Returns SA
plot_by_year(last_5_years.dropna(), 'yoy_return_sa', 
             'YoY Returns - SA', 'YoY Return', axs[2, 1])
# Save the figure
plt.tight_layout()
plt.savefig('hv_tb_eu_007_001_m_g_005.png')




### 001 EA PPI   <a id="title_page"></a

print('tickers')
eu_m_tickers = ['h025dz', 'p023hfy']
print('getting from api')
hv_tb_eu_007_002_m = Haver.data(eu_m_tickers, 'EUDATA', dates=True)
print(hv_tb_eu_007_002_m)
print(hv_tb_eu_007_002_m.columns)
hv_tb_eu_007_002_m.rename(columns={'h025dz': 'EA20: Domestic PPI SA'}, inplace=True)
hv_tb_eu_007_002_m.rename(columns={'p023hfy': 'Euro area: HICP Flash Estimate NSA'}, inplace=True)
hv_tb_eu_007_002_m['EA20: Domestic PPI SA'] = hv_tb_eu_007_002_m['EA20: Domestic PPI SA'].shift(3)
#hv_tb_eu_007_002_m_g_001 = hv_tb_eu_007_002_m.copy()
#hv_tb_eu_007_002_m = hv_tb_eu_007_002_m.tail(horizon_tb)
#hv_tb_eu_007_002_m = hv_tb_eu_007_002_m.transpose()
#hv_tb_eu_007_002_m.index.names = ['Variable']

#print(path_display)
#hv_tb_eu_007_002_m.to_csv(path_display, index=True, header=True)
#print(hv_tb_eu_007_002_m)
#print('step2')

hv_tb_eu_007_002_m_g = hv_tb_eu_007_002_m.copy()
hv_tb_eu_007_002_m_g_001 = hv_tb_eu_007_002_m.copy()

hv_tb_eu_007_002_m.index=hv_tb_eu_007_002_m.index.date
hv_tb_eu_007_002_m = hv_tb_eu_007_002_m.tail(horizon_tb)
hv_tb_eu_007_002_t1=hv_tb_eu_007_002_m.tail(horizon_tb)

hv_tb_eu_007_002_m_t = hv_tb_eu_007_002_m.transpose()
hv_tb_eu_007_002_m_t.index.names = ['Variable']

hv_tb_eu_007_002_t1_t = hv_tb_eu_007_002_t1.transpose()
hv_tb_eu_007_002_t1_t.index.names = ['Variable']

### 001 EA PPI tabble


############################################################
######Table 1

#####here*******
title_table="eu_ppi"
df =hv_tb_eu_007_002_t1.copy()
df_transposed = hv_tb_eu_007_002_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_eu_007_002_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_eu_007_002_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_eu_007_002_m_t_002.png')





### 001 EA PPI  graphs

####PP1P
title_r="EA20: Domestic PPI / HICP FLASH"
y_label="Index %"
x_label=title_r
list_c=["Euro area: HICP Flash Estimate NSA",
        "EA20: Domestic PPI SA"]
df1=hv_tb_eu_007_002_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["Euro area: HICP Flash Estimate NSA"], color="darkgreen", linewidth= 11, linestyle="-",
        marker='P',markersize=s2)
g1.plot(kind='line', ax=ax2,y=["EA20: Domestic PPI SA"], color="darkblue", linewidth= 11,linestyle='-',
        marker='D', markersize=s2)
#plt.axhline (@, color="black", Lw=1, Linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
#ax2 = ax. twinx()
#ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_007_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

####PP1P
title_r="EA20: Domestic PPI / HICP FLASH"
y_label="Index %"
x_label=title_r
list_c=["Euro area: HICP Flash Estimate NSA",
        "EA20: Domestic PPI SA"]
df1=hv_tb_eu_007_002_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["Euro area: HICP Flash Estimate NSA"], color="darkgreen", linewidth= 11, linestyle="-",
        marker='P',markersize=s2)
g1.plot(kind='line', ax=ax2,y=["EA20: Domestic PPI SA"], color="darkblue", linewidth= 11,linestyle='-',
        marker='D', markersize=s2)
#plt.axhline (@, color="black", Lw=1, Linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
#ax2 = ax. twinx()
#ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_007_002_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax










### 001 GERMANY INFALTIOIN <a id="title_page"></a

eu_m_tickers = ['despct',
                'despcxe',
                'despcew',
                'despcxg',
                'despcf',
                'despcsv',
                'despcxv', 'despc160']
print("getting from api")                                                                                                  
hv_tb_eu_008_001_m=Haver.data(eu_m_tickers, "GERMANY", dates=True)
print(hv_tb_eu_008_001_m)
print(hv_tb_eu_008_001_m.columns)
for x in range(len(eu_m_tickers)):
    variable=str(eu_m_tickers [x])
    hv_tb_eu_008_001_m[variable]= hv_tb_eu_008_001_m[variable].pct_change(12).multiply(100).round(3)


print("renaming")
hv_tb_eu_008_001_m.rename(columns={"despct": "Headline SA Y/Y"}, inplace=True)
hv_tb_eu_008_001_m.rename(columns={"despcxe": "Headline excl Energy SA Y/Y"}, inplace=True)
hv_tb_eu_008_001_m.rename(columns={"despcew": "Energy SA Y/Y"}, inplace=True)
hv_tb_eu_008_001_m.rename(columns={"despcxg": "CPI Core SA Y/Y"}, inplace=True)
hv_tb_eu_008_001_m.rename(columns={"despcf": "Food SA Y/Y"}, inplace=True)
hv_tb_eu_008_001_m.rename(columns={"despcsv": "Services SA Y/Y"}, inplace=True)
hv_tb_eu_008_001_m.rename(columns={"despcxv": "Services excl Rent SA Y/Y"}, inplace=True)
hv_tb_eu_008_001_m.rename(columns={"despc160": "Actual Rents SA Y/Y"}, inplace=True)
#hv_tb_eu_008_001_m_g_001=hv_tb_eu_008_001_m.copy()
#hv_tb_eu_008_001_m=hv_tb_eu_008_001_m.tail(horizon_tb)
#hv_tb_eu_008_001_m = hv_tb_eu_008_001_m.transpose()
#hv_tb_eu_008_001_m.index.names = ['Variable']
#dashboard.to_clipboard()
#print(hv_tb_eu_008_001_m)

#hv_tb_eu_008_001_m.to_csv (path_display, index True, header=True)
#print(hv_tb_eu_008_001_m)
print("step2")



hv_tb_eu_008_001_m_g = hv_tb_eu_008_001_m.copy()
hv_tb_eu_008_001_m_g_001 = hv_tb_eu_008_001_m.copy()

hv_tb_eu_008_001_m.index=hv_tb_eu_008_001_m.index.date
hv_tb_eu_008_001_m = hv_tb_eu_008_001_m.tail(horizon_tb)
hv_tb_eu_008_001_t1=hv_tb_eu_008_001_m.tail(horizon_tb)

hv_tb_eu_008_001_m_t = hv_tb_eu_008_001_m.transpose()
hv_tb_eu_008_001_m_t.index.names = ['Variable']

hv_tb_eu_008_001_t1_t = hv_tb_eu_008_001_t1.transpose()
hv_tb_eu_008_001_t1_t.index.names = ['Variable']

### 001 EA Germany Inflation   table



############################################################
######Table 1

#####here*******
title_table="eu_germany_inflation"
df =hv_tb_eu_008_001_t1.copy()
df_transposed = hv_tb_eu_008_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_eu_008_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_eu_008_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_eu_008_001_m_t_002.png')



### 001 EA Germany Inflation   graphs

title_r="Germany Inflation"
y_label="Index %"
x_label=title_r
list_c=["Headline SA Y/Y", 
        "CPI Core SA Y/Y", "Food SA Y/Y"]
df1=hv_tb_eu_008_001_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig,ax =plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["Headline SA Y/Y"], color="darkred", 
        linewidth= l1, linestyle='-', marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["CPI Core SA Y/Y"], color="darkgreen", 
        linewidth= l1, linestyle='-', marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Food SA Y/Y"], color="darkorange", 
        linewidth= l1, linestyle='-', marker='*', markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_008_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r="Germany Inflation"
y_label="Index %"
x_label=title_r
list_c=["Headline SA Y/Y", 
        "CPI Core SA Y/Y", "Food SA Y/Y"]
df1=hv_tb_eu_008_001_m_g_001[list_c]
df1=df1.tail(12)
g1=df1.copy()
fig,ax =plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["Headline SA Y/Y"], color="darkred", 
        linewidth= l1, linestyle='-', marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["CPI Core SA Y/Y"], color="darkgreen", 
        linewidth= l1, linestyle='-', marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Food SA Y/Y"], color="darkorange", 
        linewidth= l1, linestyle='-', marker='*', markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params (labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2= ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_008_001_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r="Germany Inflation"
y_label="Index %"
x_label="title_r"
list_c=["Services SA Y/Y",
        "Services excl Rent SA Y/Y",
        "Actual Rents SA Y/Y"]
df1=hv_tb_eu_008_001_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s,parameter2_s))
g1.plot(kind='line', ax=ax, y=["Services SA Y/Y"], color="darkred",
        linewidth=l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Services excl Rent SA Y/Y"], color="darkgreen",
        linewidth=l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Actual Rents SA Y/Y"], color="darkorange",
        linewidth=l1, linestyle='-',
        marker='o', markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_008_001_m_g_002.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r="Germany Inflation"
y_label="Index %"
x_label="title_r"
list_c=["Services SA Y/Y",
        "Services excl Rent SA Y/Y",
        "Actual Rents SA Y/Y"]
df1=hv_tb_eu_008_001_m_g_001[list_c]
df1=df1.tail(12)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s,parameter2_s))
g1.plot(kind='line', ax=ax, y=["Services SA Y/Y"], color="darkred",
        linewidth=l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Services excl Rent SA Y/Y"], color="darkgreen",
        linewidth=l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Actual Rents SA Y/Y"], color="darkorange",
        linewidth=l1, linestyle='-',
        marker='o', markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_008_001_m_g_002z.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r="Germany Inflation"
y_label="Index %"
x_label=title_r
list_c=["Headline SA Y/Y",
        "Headline excl Energy SA Y/Y",
        "Energy SA Y/Y"]
df1=hv_tb_eu_008_001_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax,y=["Headline SA Y/Y"], color="darkred",
        linewidth= l1, linestyle='-',
        marker='s', markersize=s2)
g1.plot(kind="line", ax=ax, y=["Headline excl Energy SA Y/Y"], color="darkgreen",
        linewidth= l1, linestyle='-',
        marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Energy SA Y/Y"], color="darkorange",
        linewidth= l1, linestyle='-',
        marker='^', markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_008_001_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1

title_r="Germany Inflation"
y_label="Index %"
x_label=title_r
list_c=["Headline SA Y/Y",
        "Headline excl Energy SA Y/Y",
        "Energy SA Y/Y"]
df1=hv_tb_eu_008_001_m_g_001[list_c]
df1=df1.tail(12)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax,y=["Headline SA Y/Y"], color="darkred",
        linewidth= l1, linestyle='-',
        marker='s', markersize=s2)
g1.plot(kind="line", ax=ax, y=["Headline excl Energy SA Y/Y"], color="darkgreen",
        linewidth= l1, linestyle='-',
        marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Energy SA Y/Y"], color="darkorange",
        linewidth= l1, linestyle='-',
        marker='^', markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_008_001_m_g_003z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1

### 001  germany inflation QQ  <a id="title_page"></a

print("tickers")
eu_m_tickers = ['despct',
 'despcxe',
 'despcew',
 'despcxg',
 'despcf',
 'despcsv',
 'despcxv',
 'despc160']

print("getting from api")
hv_tb_eu_008_002_m=Haver.data(eu_m_tickers, "GERMANY", dates=True)
print(hv_tb_eu_008_002_m)

print(hv_tb_eu_008_002_m.columns)
for x in range(len(eu_m_tickers)):
    variable=str(eu_m_tickers[x])
    hv_tb_eu_008_002_m[variable] = hv_tb_eu_008_002_m[variable].pct_change(periods=4, fill_method='bfill').multiply(100).round(3)

print("renaming")
hv_tb_eu_008_002_m.rename(columns={"despct": "Headline SA Q/Q"}, inplace=True)
hv_tb_eu_008_002_m.rename(columns={"despcxe": "Headline excl Energy SA Q/Q"}, inplace=True)
hv_tb_eu_008_002_m.rename(columns={"despcew": "Energy SA Q/Q"}, inplace=True)
hv_tb_eu_008_002_m.rename(columns={"despcxg": "CPI Core SA Q/Q"}, inplace=True)
hv_tb_eu_008_002_m.rename(columns={"despcf": "Food SA Q/Q"}, inplace=True)
hv_tb_eu_008_002_m.rename(columns={"despcsv": "Services SA Q/Q"}, inplace=True)
hv_tb_eu_008_002_m.rename(columns={"despcxv": "Services excl Rent SA Q/Q"}, inplace=True)
hv_tb_eu_008_002_m.rename(columns={"despc160": "Actual Rents SA Q/Q"}, inplace=True)
#hv_tb_eu_008_002_m_g_001=hv_tb_eu_008_002_m.copy()

#print(hv_tb_eu_008_002_m_g_001.tail(1))



hv_tb_eu_008_002_m_g = hv_tb_eu_008_002_m.copy()
hv_tb_eu_008_002_m_g_001 = hv_tb_eu_008_002_m.copy()

hv_tb_eu_008_002_m.index=hv_tb_eu_008_002_m.index.date
hv_tb_eu_008_002_m = hv_tb_eu_008_002_m.tail(horizon_tb)
hv_tb_eu_008_002_t1=hv_tb_eu_008_002_m.tail(horizon_tb)

hv_tb_eu_008_002_m_t = hv_tb_eu_008_002_m.transpose()
hv_tb_eu_008_002_m_t.index.names = ['Variable']

hv_tb_eu_008_002_t1_t = hv_tb_eu_008_002_t1.transpose()
hv_tb_eu_008_002_t1_t.index.names = ['Variable']


### 001  germany inflation QQ table  <a id="title_page"></a


############################################################
######Table 1

#####here*******
title_table="eu_germany_inflation_qq"
df =hv_tb_eu_008_002_t1.copy()
df_transposed = hv_tb_eu_008_002_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_eu_008_002_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_eu_008_002_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_eu_008_002_m_t_002.png')


### 001  germany inflation QQ  graphs <a id="title_page"></a

title_r="Germany Inflation"
y_label="Index %"
x_label=title_r
list_c=["Headline SA Q/Q",
        "CPI Core SA Q/Q",
        "Food SA Q/Q"]
df1=hv_tb_eu_008_002_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig,ax= plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["Headline SA Q/Q"], color="darkred", linewidth= l1, linestyle='-',marker='s', markersize=s2)
g1.plot(kind='line', ax=ax,y=["CPI Core SA Q/Q"],   color="darkgreen",linewidth= l1, linestyle='-',  marker='>',markersize=s2)
g1.plot(kind='line', ax=ax, y=["Food SA Q/Q"],  color="darkorange", linewidth= l1, linestyle='-' ,  marker='>', markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_008_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

y_label="Index %"
x_label=title_r

list_c=["Headline SA Q/Q", 
        "CPI Core SA Q/Q","Food SA Q/Q"]
df1=hv_tb_eu_008_002_m_g_001[list_c]               
df1=df1.tail(24)
g1=df1.copy()
fig,ax= plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["Headline SA Q/Q"], color="darkred", linewidth= l1, linestyle='-',marker='s', markersize=s2)
g1.plot(kind='line', ax=ax,y=["CPI Core SA Q/Q"],   color="darkgreen",linewidth= l1, linestyle='-',  marker='>',markersize=s2)
g1.plot(kind='line', ax=ax, y=["Food SA Q/Q"],  color="darkorange", linewidth= l1, linestyle='-' ,  marker='>', markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_008_002_m_g_001z.png", bbox_inches='tight')
plt.close()
plt.close("all")
plt.clf()
plt.cla()
del g1
del df1
del fig
del ax

title_r="Germany Inflation"
y_label="Index %"
x_label="title_r"
list_c=["Services SA Q/Q", "Services excl Rent SA Q/Q", "Actual Rents SA Q/Q"]
df1=hv_tb_eu_008_002_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig,ax= plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y= ["Services SA Q/Q"],
        color="darkred", linewidth=l1, linestyle='-', marker='.', markersize=s2)
g1.plot(kind='line', ax=ax, y= ["Services excl Rent SA Q/Q"],
        color="darkgreen", linewidth=l1, linestyle='-', marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Actual Rents SA Q/Q"],
        color="darkorange", linewidth=l1, linestyle='-', marker='*', markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=0.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_008_002_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

title_r="Germany Inflation"
y_label="Index %"
x_label="title_r"
list_c=["Services SA Q/Q", "Services excl Rent SA Q/Q", "Actual Rents SA Q/Q"]
df1=hv_tb_eu_008_002_m_g_001[list_c]
df1=df1.tail(24)
g1=df1.copy()
fig,ax= plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y= ["Services SA Q/Q"],
        color="darkred", linewidth=l1, linestyle='-', marker='.', markersize=s2)
g1.plot(kind='line', ax=ax, y= ["Services excl Rent SA Q/Q"],
        color="darkgreen", linewidth=l1, linestyle='-', marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Actual Rents SA Q/Q"],
        color="darkorange", linewidth=l1, linestyle='-', marker='*', markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=0.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_008_002_m_g_002z.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax

title_r="Germany Inflation"
y_label="Index %"
x_label=title_r
list_c=["Headline SA Q/Q",
        "Headline excl Energy SA Q/Q",
        "Energy SA Q/Q"]
df1=hv_tb_eu_008_002_m_g_001[list_c]
df1-df1.tail(60)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["Headline SA Q/Q"], color="darkred",
        linewidth= l1, linestyle='-',
        marker=">",markersize=s2)
g1.plot(kind='line', ax=ax, y=["Headline excl Energy SA Q/Q"], color="darkgreen",
        linewidth= l1, linestyle='-',
        marker=">", markersize=s2)
g1.plot(kind='line', ax=ax,y=["Energy SA Q/Q"], color="darkorange",
        linewidth= l1, linestyle='-',
        marker=">", markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size= parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_008_002_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close("all")
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig

title_r="Germany Inflation"
y_label="Index %"
x_label=title_r
list_c=["Headline SA Q/Q",
        "Headline excl Energy SA Q/Q",
        "Energy SA Q/Q"]
df1=hv_tb_eu_008_002_m_g_001[list_c]
df1-df1.tail(24)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=["Headline SA Q/Q"], color="darkred",
        linewidth= l1, linestyle='-',
        marker=">",markersize=s2)
g1.plot(kind='line', ax=ax, y=["Headline excl Energy SA Q/Q"], color="darkgreen",
        linewidth= l1, linestyle='-',
        marker=">", markersize=s2)
g1.plot(kind='line', ax=ax,y=["Energy SA Q/Q"], color="darkorange",
        linewidth= l1, linestyle='-',
        marker=">", markersize=s2)
plt.style.use('default')
plt.ylabel(str(y_label), size= parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_008_002_m_g_003z.png", bbox_inches='tight')
plt.close()
plt.close("all")
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig

### 001  uk cpih inflation food  <a id="title_page"></a

print("tickers")
eu_m_tickers = ['l52h', 'l52i', 'l52j', 
                'l52k', 'l52l', 'l52m',
                'l52n', 'l52o', 'l52p', 
                'l52r', 'l52s', 'l52t']

print("getting from api")
hv_tb_eu_010_001_m = Haver.data(eu_m_tickers, "UK", dates=True)

print(hv_tb_eu_010_001_m)


for x in range(len(eu_m_tickers)):
    variable = str(eu_m_tickers[x])
    hv_tb_eu_010_001_m[variable] = hv_tb_eu_010_001_m[variable].pct_change(12).multiply(100).round(3)


hv_tb_eu_010_001_m.rename(columns={"l52h": "UK CPIH Food NSA Y/Y"}, inplace=True)
hv_tb_eu_010_001_m.rename(columns={"l52i": "UK CPIH Bread Cereals NSA Y/Y"}, inplace=True)
hv_tb_eu_010_001_m.rename(columns={"l52j": "UK CPIH Meat NSA Y/Y"}, inplace=True)
hv_tb_eu_010_001_m.rename(columns={"l52k": "UK CPIH Fish NSA Y/Y"}, inplace=True)
hv_tb_eu_010_001_m.rename(columns={"l52l": "UK CPIH Milk NSA Y/Y"}, inplace=True)
hv_tb_eu_010_001_m.rename(columns={"l52m": "UK CPIH Oils Fats NSA Y/Y"}, inplace=True)
hv_tb_eu_010_001_m.rename(columns={"l52n": "UK CPIH Fruit NSA Y/Y"}, inplace=True)
hv_tb_eu_010_001_m.rename(columns={"l52o": "UK CPIH Vegetables NSA Y/Y"}, inplace=True)
hv_tb_eu_010_001_m.rename(columns={"l52p": "UK CPIH Sugar NSA Y/Y"}, inplace=True)
hv_tb_eu_010_001_m.rename(columns={"l52r": "UK CPIH Nonalcoholic NSA Y/Y"}, inplace=True)
hv_tb_eu_010_001_m.rename(columns={"l52s": "UK CPIH Coffee NSA Y/Y"}, inplace=True)
hv_tb_eu_010_001_m.rename(columns={"l52t": "UK CPIH Soft Drink NSA Y/Y"}, inplace=True)

hv_tb_eu_010_001_m_g_001 = hv_tb_eu_010_001_m.copy()
hv_tb_eu_010_001_m = hv_tb_eu_010_001_m.tail(horizon_tb)
hv_tb_eu_010_001_m = hv_tb_eu_010_001_m.transpose()
hv_tb_eu_010_001_m.index.names = ['Variable']
# dashboard.to_clipboard()
#print(hv_tb_eu_010_001_m)
# dashboard.to_clipboard()
#path_display = tb_eu_010_001_m.csv'
#print(path_display)
#hv_tb_eu_010_001_m.to_csv(path_display, index=True, header=True)
#print(hv_tb_eu_010_001_m)
print("step2")





text_label=" NSA Y/Y"
text_label0= "UK CPIH "
title_r0 = text_label
title_r = title_r0
y_label = "Index %"
x_label = title_r

list_c = [
    (str(text_label0) + "Food" + str(text_label)),
    (str(text_label0) + "Bread Cereals" + str(text_label)),
    (str(text_label0) + "Meat" + str(text_label)),
    (str(text_label0) + "Fish" + str(text_label)),
    (str(text_label0) + "Milk" + str(text_label)),
    (str(text_label0) + "Oils Fats" + str(text_label)),
    (str(text_label0) + "Fruit" + str(text_label)),
    (str(text_label0) + "Vegetables" + str(text_label)),
    (str(text_label0) + "Sugar" + str(text_label)),
    (str(text_label0) + "Nonalcoholic" + str(text_label)),
    (str(text_label0) + "Coffee" + str(text_label)),
    (str(text_label0) + "Soft Drink" + str(text_label))
]

df1 = hv_tb_eu_010_001_m_g_001[list_c]
df1 = df1.tail(72)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Food" + str(text_label))], color="black",
        linewidth=l1, linestyle='', marker='P', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Bread Cereals" + str(text_label))], color="orange",
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Meat" + str(text_label))], color="orange",
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Fish" + str(text_label))], color="red",
        linewidth=l1, linestyle='', marker='D', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Milk" + str(text_label))], color="black",
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Oils Fats" + str(text_label))], color="black",
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Fruit" + str(text_label))], color="black",
        linewidth=l1, linestyle='-', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Vegetables" + str(text_label))], color="black",
        linewidth=l1, linestyle='-', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Sugar" + str(text_label))], color="red",
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Nonalcoholic" + str(text_label))], color="black",
        linewidth=l1, linestyle='', marker='X', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Coffee" + str(text_label))], color="red",
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Soft Drink" + str(text_label))], color="red",
        linewidth=l1, linestyle='', marker='', markersize=s1)

plt.style.use('default')
plt.ylabel(str(y_label), size= parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_010_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close("all")
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig





### 001  EU inflation food  <a id="title_page"></a

print("food comaprison")

eu_m_tickers = ['p122h11', 'p124h11', 'p172h11', 
                'p939h11', 'p946h11', 'p132h11',
                'p134h11', 'p136h11', 'p138h11', 
                'p184h11', 'p182h11', 'p174h11']
print("getting from api")
hv_tb_eu_010_002_m=Haver.data(eu_m_tickers, "EUDATA", dates=True)
print(hv_tb_eu_010_002_m)
print(hv_tb_eu_010_002_m.columns)

for x in range(len(eu_m_tickers)):
    variable=str(eu_m_tickers [x])
    hv_tb_eu_010_002_m[variable] = hv_tb_eu_010_002_m[variable].pct_change(12).multiply(100).round(3)


hv_tb_eu_010_002_m.rename(columns={"p122h11": "Austria HICP Food NSA Y/Y"}, inplace=True)
hv_tb_eu_010_002_m.rename(columns={"p124h11":"Belgium HICP Food NSA Y/Y"}, inplace=True)
hv_tb_eu_010_002_m.rename(columns={"p172h11": "Finland HICP Food NSA Y/Y"}, inplace=True)
hv_tb_eu_010_002_m.rename(columns={"p939h11": "Estonia HICP Food NSA Y/Y"}, inplace=True)
hv_tb_eu_010_002_m.rename(columns={"p946h11":"Lithuania HICP Food NSA Y/Y"}, inplace=True)
hv_tb_eu_010_002_m.rename(columns={"p132h11": "France HICP Food NSA Y/Y"}, inplace=True)
hv_tb_eu_010_002_m.rename(columns={"p134h11": "Germany HICP Food NSA Y/Y"}, inplace=True)
hv_tb_eu_010_002_m.rename(columns={"p136h11": "Italy HICP Food NSA Y/Y"}, inplace=True)
hv_tb_eu_010_002_m.rename(columns={"p138h11": "Netherlands HICP Food NSA Y/Y"}, inplace=True)
hv_tb_eu_010_002_m.rename(columns={"p184h11": "Spain HICP Food NSA Y/Y"}, inplace=True)
hv_tb_eu_010_002_m.rename(columns={"p182h11": "Portugal HICP Food NSA Y/Y"}, inplace=True)
hv_tb_eu_010_002_m.rename(columns={"p174h11": "Greece HICP Food NSA Y/Y"}, inplace=True)
#hv_tb_eu_010_002_m_g_001=hv_tb_eu_010_002_m.copy()
#hv_tb_eu_010_002_m=hv_tb_eu_010_002_m.tail(horizon_tb)
#hv_tb_eu_010_002_m = hv_tb_eu_010_002_m.transpose()
#hv_tb_eu_010_002_m.index.names = ['Variable']
##dashboard.to_clipboard()
#print(hv_tb_eu_010_002_m)
#dashboard.to_clipboard()
#path_display = o\tb_eu_010_002_m.csv'
#print(path_display)
#hv_tb_eu_010_002_m.to_csv (path_display, index= True, header=True)
#print(hv_tb_eu_010_002_m)


hv_tb_eu_010_002_m_g = hv_tb_eu_010_002_m.copy()
hv_tb_eu_010_002_m_g_001 = hv_tb_eu_010_002_m.copy()

hv_tb_eu_010_002_m.index=hv_tb_eu_010_002_m.index.date
hv_tb_eu_010_002_m = hv_tb_eu_010_002_m.tail(horizon_tb)
hv_tb_eu_010_002_t1=hv_tb_eu_010_002_m.tail(horizon_tb)

hv_tb_eu_010_002_m_t = hv_tb_eu_010_002_m.transpose()
hv_tb_eu_010_002_m_t.index.names = ['Variable']

hv_tb_eu_010_002_t1_t = hv_tb_eu_010_002_t1.transpose()
hv_tb_eu_010_002_t1_t.index.names = ['Variable']


### 001  ea HICP Food  table    <a id="title_page"></a


############################################################
######Table 1

#####here*******
title_table="eu_hicp_food"
df =hv_tb_eu_010_002_t1.copy()
df_transposed = hv_tb_eu_010_002_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_eu_010_002_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_eu_010_002_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_eu_010_002_m_t_002.png')




### 001  ea HICP Food  graphs    <a id="title_page"></a

text_label= " HICP Food NSA Y/Y"
text_label0 = ""
title_r = title_r0
y_label = "Index %"
x_label = title_r
list_c = [
    (str(text_label0) + "Austria" + str(text_label)),
    (str(text_label0) + "Belgium" + str(text_label)),
    (str(text_label0) + "Finland" + str(text_label)),
    (str(text_label0) + "Estonia" + str(text_label)),
    (str(text_label0) + "Lithuania" + str(text_label)),
    (str(text_label0) + "France" + str(text_label)),
    (str(text_label0) + "Germany" + str(text_label)),
    (str(text_label0) + "Italy" + str(text_label)),
    (str(text_label0) + "Netherlands" + str(text_label)),
    (str(text_label0) + "Spain" + str(text_label)),
    (str(text_label0) + "Portugal" + str(text_label))
]

df1 = hv_tb_eu_010_002_m_g_001[list_c]
df1 = df1.tail(72)
g1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Austria" + str(text_label))], color="orange",
        linewidth=l1, linestyle='', marker='P', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Belgium" + str(text_label))], color="black",
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Finland" + str(text_label))], color="black",
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Estonia" + str(text_label))], color="red",
        linewidth=l1, linestyle='', marker='D', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Lithuania" + str(text_label))], color="red",
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "France" + str(text_label))], color="black",
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Germany" + str(text_label))], color="black",
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Italy" + str(text_label))], color="black",
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Netherlands" + str(text_label))], color="green",
        linewidth=l1, linestyle='', marker='X', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Spain" + str(text_label))], color="black",
        linewidth=l1, linestyle='', marker='', markersize=s1)
g1.plot(kind='line', ax=ax, y=[(str(text_label0) + "Portugal" + str(text_label))], color="black",
        linewidth=l1, linestyle='', marker='', markersize=s1)

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)

plt.style.use('default')
plt.ylabel(str(y_label), size= parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 =ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_010_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close("all")
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig












### 001  ea compensation per employee   <a id="title_page"></a

eu_m_tickers=['d134cpe', 'd132cpe', 'd136cpe', 'd184cpe']

# National account data compensation per employee
# L025cesi

hv_tb_eu_012_001_m=Haver.data(eu_m_tickers, "EUNA", dates=True)
#print(hv_tb_eu_012_001_m)

for x in range(len(eu_m_tickers)):
#    print(x)
    variable=str(eu_m_tickers[x])
#    print(variable)
    hv_tb_eu_012_001_m[variable]=hv_tb_eu_012_001_m[variable].pct_change(4).multiply(100).round(3)
#    print(hv_tb_eu_012_001_m[variable])

# hv_tb_eu_012_001_m.rename(columns={"L025cesi": "ea compensation per employee"), inplace=True)

hv_tb_eu_012_001_m.rename(columns={"d134cpe": "germany compensation per employee"}, inplace=True)
hv_tb_eu_012_001_m.rename(columns={"d132cpe": "france compensation per employee"}, inplace=True)
hv_tb_eu_012_001_m.rename(columns={"d136cpe": "italy compensation per employee"}, inplace=True)
hv_tb_eu_012_001_m.rename(columns={"d184cpe": "spain compensation per employee"}, inplace=True)
print("Complete")

hv_tb_eu_012_001_m_g = hv_tb_eu_012_001_m.copy()
hv_tb_eu_012_001_m_g_001 = hv_tb_eu_012_001_m.copy()

hv_tb_eu_012_001_m.index=hv_tb_eu_012_001_m.index.date
hv_tb_eu_012_001_m = hv_tb_eu_012_001_m.tail(horizon_tb)
hv_tb_eu_012_001_t1=hv_tb_eu_012_001_m.tail(horizon_tb)

hv_tb_eu_012_001_m_t = hv_tb_eu_012_001_m.transpose()
hv_tb_eu_012_001_m_t.index.names = ['Variable']

hv_tb_eu_012_001_t1_t = hv_tb_eu_012_001_t1.transpose()
hv_tb_eu_012_001_t1_t.index.names = ['Variable']

### 001  ea compensation per employee table   <a id="title_page"></a


############################################################
######Table 1

#####here*******
title_table="eu_compensation"
df =hv_tb_eu_012_001_t1.copy()
df_transposed = hv_tb_eu_012_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_eu_012_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_eu_012_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_eu_012_001_m_t_002.png')




### 001  ea compensation per employee graph   <a id="title_page"></a

title_r="EA national account compensation per employee"
y_label="Index %"
x_label=title_r
df1=hv_tb_eu_012_001_m.copy()
df1_list=df1.columns.tolist()
df1=df1.tail(36)
g1=df1.copy()
df1.index=pd.to_datetime(df1.index)
fig,ax=plt.subplots(figsize=(parameter_size1, parameter_size2))
g1.plot(kind='line', ax=ax, y=(df1_list[0]), color="orange", linewidth=(l1+3), linestyle='-', marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=(df1_list[1]), color="red", linewidth=(l1+2), linestyle='-', marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=(df1_list[2]), color="navy", linewidth=(l1+2), linestyle='-', marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=(df1_list[3]), color="black", linewidth=(l1+2), linestyle='-', marker='o', markersize=s2)
# g1.plot(kind='line', ax=ax, y=(df1_list[4]), color="green", linewidth=(1.1+2), linestyle='-',




for series_name in df1_list[0:5]:
    # Find the last non-NA value in the series
    last_valid_index = g1[series_name].last_valid_index()
    last_valid_value = g1.loc[last_valid_index, series_name]

    # Annotate using the last non-NA value
    plt.annotate(series_name.split()[0],
                 xy=(last_valid_index, last_valid_value),
                 xytext=(50, 10), textcoords="offset points",
                 arrowprops=dict(facecolor="black", arrowstyle="->"))

# ax.xaxis_date()
# fig.autofmt_xdate()
# Adjusting the x-axis to show all datetime indices (quarters)
# plt.xticks(df1.index, df1.index.strftime('%Y-%m-%d'), rotation=45, ha="right")
# ax.xaxis.set_major_Locator(mdates.MonthLocator())  # Set major ticks to be every month
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))  # Format date as Year-Month
# plt.xticks(rotation=45)
# Adjusting x-axis to show all dates
# ax.set_xticks(df1.index)  # Set x-ticks to all dates in the index
# ax.set_xticklabels(df1.index, rotation=45)  # Rotate and format date labels for better visibility
# ax.set_xticks(df1.index)  # Ensure every date in the index is used as an x-tick
# ax.set_xticklabels(df1.index.strftime('%Y-%m-%d'), rotation=45, ha='right')  # Format and rotate labels for readability
# ax.xaxis.set_major_Locator(mdates.MonthLocator())  # Set major ticks to be every month
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))  # Format date as Year-Month
# plt.xticks(rotation=45)  # Rotate the dates for better visibility

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_012_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del fig
del ax

title_r="EA national account compensation per employee"
y_label="Index %"
x_label=title_r
df1=hv_tb_eu_012_001_m.copy()
df1_list=df1.columns.tolist()
df1=df1.tail(18)
g1=df1.copy()
df1.index=pd.to_datetime(df1.index)
fig,ax=plt.subplots(figsize=(parameter_size1, parameter_size2))
g1.plot(kind='line', ax=ax, y=(df1_list[0]), color="orange", linewidth=(l1+3), linestyle='-', marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=(df1_list[1]), color="red", linewidth=(l1+2), linestyle='-', marker='D', markersize=s2)
g1.plot(kind='line', ax=ax, y=(df1_list[2]), color="navy", linewidth=(l1+2), linestyle='-', marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=(df1_list[3]), color="black", linewidth=(l1+2), linestyle='-', marker='o', markersize=s2)
# g1.plot(kind='line', ax=ax, y=(df1_list[4]), color="green", linewidth=(1.1+2), linestyle='-',




for series_name in df1_list[0:5]:
    # Find the last non-NA value in the series
    last_valid_index = g1[series_name].last_valid_index()
    last_valid_value = g1.loc[last_valid_index, series_name]

    # Annotate using the last non-NA value
    plt.annotate(series_name.split()[0],
                 xy=(last_valid_index, last_valid_value),
                 xytext=(50, 10), textcoords="offset points",
                 arrowprops=dict(facecolor="black", arrowstyle="->"))

# ax.xaxis_date()
# fig.autofmt_xdate()
# Adjusting the x-axis to show all datetime indices (quarters)
# plt.xticks(df1.index, df1.index.strftime('%Y-%m-%d'), rotation=45, ha="right")
# ax.xaxis.set_major_Locator(mdates.MonthLocator())  # Set major ticks to be every month
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))  # Format date as Year-Month
# plt.xticks(rotation=45)
# Adjusting x-axis to show all dates
# ax.set_xticks(df1.index)  # Set x-ticks to all dates in the index
# ax.set_xticklabels(df1.index, rotation=45)  # Rotate and format date labels for better visibility
# ax.set_xticks(df1.index)  # Ensure every date in the index is used as an x-tick
# ax.set_xticklabels(df1.index.strftime('%Y-%m-%d'), rotation=45, ha='right')  # Format and rotate labels for readability
# ax.xaxis.set_major_Locator(mdates.MonthLocator())  # Set major ticks to be every month
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))  # Format date as Year-Month
# plt.xticks(rotation=45)  # Rotate the dates for better visibility

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_012_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del fig
del ax



### 001  ea ea hh gross saving rate   <a id="title_page"></a

#Saving rate
eu_m_tickers=['j025hsrg']
hv_tb_eu_012_001_m=Haver.data(eu_m_tickers, "EUDATA", dates=True)
hv_tb_eu_012_001_m.rename(columns={"j025hsrg":"ea hh gross saving rate"}, inplace=True)

title_r="EA hh gross saving rate"
y_label="Index %"
x_label=title_r
df1=hv_tb_eu_012_001_m.copy()
df1_list=df1.columns.tolist()
df1=df1.tail(36)
g1=df1.copy()
df1.index = pd.to_datetime(df1.index)
fig, ax = plt.subplots(figsize=(parameter_size1, parameter_size2))
g1.plot(kind="line", ax=ax, y=(df1_list[0]), color="orange", linewidth=(l1+3), linestyle="-")
#plt.axhline(0, color="black", lw=1, linestyle="dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_012_001_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del fig
del ax



################# heatmap
################# heatmap
################# heatmap
################# heatmap
################# heatmap

### 001  HEATMAP  <a id="title_page"></a

import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt
from PIL import Image 
country_database = "EUDATA"
horizon_00 = 120
print("monthly")
print("tickers")
eu_m_tickers1 = ['p023h', 'p023hoe', 
                 'p023hoeu', 'p023hoef', 
                 'p023hf', 'p023hpf',
                 'p023huf', 'p023he', 
                 'p023hnig', 'p023hs',
                 'h025hoeu', 's025r',
                 's025r47', 'e025c',
                 'n023vsgx','e025i',
                 'm023bhla', 'i025yoy',
                 'e025coin', 's025qbcd']

hv_tb_eu_000_001_m=Haver.data(eu_m_tickers1, "EUDATA", dates=True)
#print(hv_tb_au_000_001_m)
#print(hv_tb_eu_000_001_m)
#ausww annual
eu_m_tickers2 = ['m025i4tt', 'm025i7tt']
hv_tb_eu_000_002_m=Haver.data(eu_m_tickers2, "EUSRVYS", dates=True)
#print(hv_tb_eu_000_002_m)
eu_m_tickers3 = ['s0257z', 'i025hpi', 'f025gdpf', 'f025gdpy', 'j025gdpr', 'j025tcr', 'j025gcfr',]
hv_tb_eu_000_003_m=Haver.data(eu_m_tickers3, "EUDATA", dates=True)
#print(hv_tb_eu_000_003_m)
eu_m_tickers4 = ["desvbia"]
hv_tb_eu_000_004_m=Haver.data(eu_m_tickers4, "GERMANR", dates=True)
#print(hv_tb_eu_000_004_m)
eu_m_tickers5 = ['frnvec']
hv_tb_eu_000_005_m=Haver.data(eu_m_tickers5, "france", dates=True)
#print(hv_tb_eu_000_005_m)
#print("tickera")
####!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#eu_m_tickers6 = ['m023tg', 'm023to',
#                 'm023te',
#                 'm023tp',
#                 'm023tx',
#                 'm023tpo', 'm023tb']
#print("getting from api")                                                                    
#hv_tb_eu_000_006_m=Haver.data(eu_m_tickers6, "MKTPMI", dates=True)
#print(hv_tb_eu_000_006_m)
###!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
hv_tb_eu_000_001_m=pd.concat([hv_tb_eu_000_001_m, hv_tb_eu_000_002_m], axis=1, join="outer")
hv_tb_eu_000_001_m=pd.concat([hv_tb_eu_000_001_m, hv_tb_eu_000_003_m], axis=1, join="outer")
hv_tb_eu_000_001_m=pd.concat([hv_tb_eu_000_001_m, hv_tb_eu_000_004_m], axis=1, join="outer")
hv_tb_eu_000_001_m=pd.concat([hv_tb_eu_000_001_m, hv_tb_eu_000_005_m], axis=1, join="outer")
#hv_tb_eu_000_001_m=pd.concat([hv_tb_eu_000_001_m, hv_tb_eu_000_006_m], axis=1, join="outer")
#eu_m_tickers = eu_m_tickers1 + eu_m_tickers2 + eu_m_tickers3 + eu_m_tickers4 + eu_m_tickers5 + eu_m_tickers6
eu_m_tickers = eu_m_tickers1 + eu_m_tickers2 + eu_m_tickers3 + eu_m_tickers4 + eu_m_tickers5
hv_tb_eu_000_001_m = hv_tb_eu_000_001_m.fillna(method='bfill')
hv_tb_eu_000_001_m_mm = hv_tb_eu_000_001_m.copy()

hv_tb_eu_000_001_m["e025coin"] = hv_tb_eu_000_001_m["e025coin"].round(1)
hv_tb_eu_000_001_m.rename(columns={"e025coin": "Real: EURO Area EUROCOIN Monthly GDP flash NSA"}, inplace=True)
hv_tb_eu_000_001_m.rename(columns={"f025gdpf": "Real: EURO Area Preliminary GDP flash SWDA QQ"}, inplace=True)
hv_tb_eu_000_001_m.rename(columns={"f025gdpy": "Real: EURO Area Preliminary GDP flash SWDA YY"}, inplace=True)
hv_tb_eu_000_001_m.rename(columns={"j025gdpr": "Real: EURO Area GDP Growth rate QQ SA WDA"}, inplace=True)
hv_tb_eu_000_001_m.rename(columns={"j025tcr": "Real: EURO Area Final Consumption Growth rate QQ SA WDA"}, inplace=True)
hv_tb_eu_000_001_m.rename(columns={"j025gcfr": "Real: EURO Area Gross Capital formation Growth rate QQ SA WDA"}, inplace=True)

# hv_tb_eu_000_001_m["s025qbcd"] = hv_tb_eu_000_001_m["s025qbcd"].pct_change(periods=12, fill_method="bfill").multiply(100).round(3)
## hv_tb_eu_000_001_m.rename(columns={"s025qbcd": "Real: IP Industry excluding Construction SWDA YY"}, inplace=True)
#hv_tb_eu_000_001_m["s025r47"].pct_change(periods=12, fill_method="bfill").multiply(100).round(3)
# hv_tb_eu_000_001_m["s025r47"] =
# hv_tb_eu_000_001_m.rename(columns={"s025r47": "Real: EA20 Retail Sales Value"}, inplace=True)
#hv_tb_eu_000_001_m["s025qbcd"]= hv_tb_eu_000_001_m["s025qbcd"].pct_change(periods=12, fill_method="bfill").multiply(100).round(3)
#hv_tb_eu_000_001_m.rename(columns={"s025qbcd": "Real: IP Industry excluding Construction SWDA YY"}, inplace=True)
#hv_tb_eu_000_001_m["s025r47"]= hv_tb_eu_000_001_m["s025r47"].pct_change(periods=12, fill_method='bfill').multiply(100).round(3)
#hv_tb_eu_000_001_m.rename(columns={"s025r47": "Real: EA20 Retail Sales Value"}, inplace=True)
#hv_tb_eu_000_001_m.rename(columns={"h025hoeu": "Price: EA20 Core CPI 1M1M"}, inplace=True)
#hv_tb_eu_000_001_m[(str(variable))]= hv_tb_eu_000_001_m[variable].pct_change(periods=1, fill_method="bfill").multiply(100).round(3)
#hv_tb_eu_000_001_m[(str(variable)+"_mavg6m")]= hv_tb_eu_000_001_m[variable].rolling(6).mean().round(3)



hv_tb_eu_000_001_m.rename(columns={"i025hpi": "Real: EA20 House Pricing"}, inplace=True)
hv_tb_eu_000_001_m.rename(columns={"m023bhla": "Real: EA MFI Loans to Households Growth Rate"}, inplace=True)


hv_tb_eu_000_001_m["Prices: EA20 Core CPI 3M Annualized"]= hv_tb_eu_000_001_m["p023hoef"]
hv_tb_eu_000_001_m["Prices: EA20 Core CPI 3M Annualized"]= hv_tb_eu_000_001_m["Prices: EA20 Core CPI 3M Annualized"].pct_change(periods=3, fill_method="bfill")
hv_tb_eu_000_001_m["Prices: EA20 Core CPI 3M Annualized"]= hv_tb_eu_000_001_m["Prices: EA20 Core CPI 3M Annualized"].apply(lambda x: x**4)
hv_tb_eu_000_001_m["Prices: EA20 Core CPI 3M Annualized"]=hv_tb_eu_000_001_m["Prices: EA20 Core CPI 3M Annualized"]-1
hv_tb_eu_000_001_m["Prices: EA20 Core CPI 3M Annualized"]=hv_tb_eu_000_001_m["Prices: EA20 Core CPI 3M Annualized"].multiply(100).round(1)



hv_tb_eu_000_001_m["Prices: EA20 Core CPI 6M Annualized"]= hv_tb_eu_000_001_m["p023hoef"]
hv_tb_eu_000_001_m["Prices: EA20 Core CPI 6M Annualized"]= hv_tb_eu_000_001_m["Prices: EA20 Core CPI 6M Annualized"].pct_change(periods=6, fill_method="bfill")
hv_tb_eu_000_001_m["Prices: EA20 Core CPI 6M Annualized"]= hv_tb_eu_000_001_m["Prices: EA20 Core CPI 6M Annualized"].apply(lambda x: x**2)
hv_tb_eu_000_001_m["Prices: EA20 Core CPI 6M Annualized"]=hv_tb_eu_000_001_m["Prices: EA20 Core CPI 6M Annualized"]-1
hv_tb_eu_000_001_m["Prices: EA20 Core CPI 6M Annualized"]=hv_tb_eu_000_001_m["Prices: EA20 Core CPI 6M Annualized"].multiply(100).round(1)



hv_tb_eu_000_001_m.rename(columns={"p023h": "Prices: EA11-20: HICP Overall NSA Y/Y"}, inplace=True)
hv_tb_eu_000_001_m.rename(columns={"p023hoe": "Prices: EA11-20: HICP excl Energy NSA Y/Y"}, inplace=True)
hv_tb_eu_000_001_m.rename(columns={"p023hoeu": "Prices: EA11-20: HICP excl Energy, Unpr Food NSA Y/Y"}, inplace=True)
hv_tb_eu_000_001_m.rename(columns={"p023hoef": "Prices: EA11-20: HICP excl Enrgy, Fd, Alchl NSA Y/Y"}, inplace=True)
hv_tb_eu_000_001_m.rename(columns={"p023hf": "Prices: EA11-20: HICP Food & Alcohol NSA Y/Y"}, inplace=True)
hv_tb_eu_000_001_m.rename(columns={"p023hpf": "Prices: EA11-20: HICP Processed Food & Alcohol NSA Y/Y"}, inplace=True)
hv_tb_eu_000_001_m.rename(columns={"p023huf": "Prices: EA11-20: HICP Unprocessed Food NSA Y/Y"}, inplace=True)
hv_tb_eu_000_001_m.rename(columns={"p023he":"Prices: EA11-20: HICP Energy NSA Y/Y"}, inplace=True)
hv_tb_eu_000_001_m.rename(columns={"p023hnig": "Prices: EA11-20: HICP Nonenergy goods NSA Y/Y"}, inplace=True)
hv_tb_eu_000_001_m.rename(columns={"p023hs": "Prices: EA11-20: HICP Services NSA Y/Y"}, inplace=True)
hv_tb_eu_000_001_m.rename(columns={"m025i4tt": "Prices: CES Inflation perception next 12m% Median"}, inplace=True)
hv_tb_eu_000_001_m.rename(columns={"m025i7tt": "Prices: CES Inflation perception next 3y% Median"}, inplace=True)
                         
hv_tb_eu_000_001_m["s025r"]=hv_tb_eu_000_001_m["s025r"].round(1)
hv_tb_eu_000_001_m.rename(columns={"s025r": "Employment: EA20 Unemployment Rate"}, inplace=True)
hv_tb_eu_000_001_m["s0257z"]=hv_tb_eu_000_001_m["s0257z"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_eu_000_001_m.rename(columns={"s0257z": "Employment: EA20 Wages & Salaries Quarterly"}, inplace=True)
hv_tb_eu_000_001_m.rename(columns={"i025yoy": "Employment: Euro Area Indeed Wage Tracker"}, inplace=True)
hv_tb_eu_000_001_m["desvbia"]=hv_tb_eu_000_001_m["desvbia"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_eu_000_001_m.rename(columns={"desvbia": "Cycle: IFO Germany Business Climate"}, inplace=True)
hv_tb_eu_000_001_m["e025c"]=hv_tb_eu_000_001_m["e025c"].round(0)
hv_tb_eu_000_001_m.rename(columns={"e025c":"Cycle: EA20 Consumer Confidence"}, inplace=True)
hv_tb_eu_000_001_m["n023vsgx"]=hv_tb_eu_000_001_m["n023vsgx"].round(0)
hv_tb_eu_000_001_m.rename(columns={"n023vsgx": "Cycle: EA20 Sentix"}, inplace=True)
hv_tb_eu_000_001_m["e0251"]=hv_tb_eu_000_001_m["e025i"].round(0)
hv_tb_eu_000_001_m.rename(columns={"e0251":"Cycle: EA20 Industrial Confidence"}, inplace=True)


hv_tb_eu_000_001_m["frnvec"]=hv_tb_eu_000_001_m["frnvec"].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_eu_000_001_m.rename(columns={"frnvec":"Cycle: Insee france employment climate indicator"}, inplace=True)
#hv_tb_eu_000_001_m.rename(columns={"m023tg": "Cycle: Euro Area PMI Composite SA"}, inplace=True)
#hv_tb_eu_000_001_m.rename(columns={"m023to":"Cycle: Euro Area PMI New Orders SA"}, inplace=True)
#hv_tb_eu_000_001_m.rename(columns={"m023te": "Cycle: Euro Area PMI Employment SA"}, inplace=True)
#hv_tb_eu_000_001_m.rename(columns={"m023tp": "Cycle: Euro Area PMI Input Prices SA"}, inplace=True)
#hv_tb_eu_000_001_m.rename(columns={"m023tx": "Cycle: Euro Area PMI New Export Orders SA"}, inplace=True)
#hv_tb_eu_000_001_m.rename(columns={"m023tpo": "Cycle: Euro Area PMI Output prices SA"}, inplace=True)
#hv_tb_eu_000_001_m.rename(columns={"m023tb": "Cycle: Euro Area PMI Backlogs of work SA"}, inplace=True)
###!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# .diff()
# .pct_change(periods=12, fill_method="bfill").multiply(100).round(1)

hv_tb_eu_000_001_m.index = hv_tb_eu_000_001_m.index.date

list_c = [
    "Real: EURO Area EUROCOIN Monthly GDP flash NSA",
    "Real: EURO Area Preliminary GDP flash SWDA QQ",
    "Real: EURO Area GDP Growth rate QQ SA WDA",
    "Real: EURO Area Final Consumption Growth rate QQ SA WDA",
    "Real: EURO Area Gross Capital formation Growth rate QQ SA WDA",
    "Real: EURO Area Preliminary GDP flash SWDA YY",
    "Real: EA MFI Loans to Households Growth Rate",
    # "Real: IP Industry excluding Construction SINDA YY",
    # "Real: EA20 Retail Sales Value",
    # "Real: EA20 House Pricing",
    # "Real: EA MFI Loans to Households Growth Rate",
    "Prices: EA11-20: HICP Overall NSA Y/Y",
    "Prices: EA11-20: HICP excl Enrgy, Fd, Alchl NSA Y/Y",
    "Prices: EA20 Core CPI 3M Annualized",
    "Prices: EA20 Core CPI 6M Annualized",
    "Prices: EA11-20: HICP Food & Alcohol NSA Y/Y",
    "Prices: EA11-20: HICP Energy NSA Y/Y",
    "Prices: EA11-20: HICP Nonenergy goods NSA Y/Y",
    "Prices: EA11-20: HICP Services NSA Y/Y",
    "Prices: CES Inflation perception next 12m% Median",
    "Prices: CES Inflation perception next 3y% Median",
    "Employment: EA20 Unemployment Rate",
    "Employment: EA20 Wages & Salaries Quarterly",
    # "Employment: Euro Area Indeed Wage Tracker",
    "Cycle: IFO Germany Business Climate",
    "Cycle: EA20 Consumer Confidence",
    "Cycle: EA20 Sentix",
    "Cycle: EA20 Industrial Confidence",
    "Cycle: Insee france employment climate indicator",
]

hv_tb_eu_000_001_m = hv_tb_eu_000_001_m[list_c]
hv_tb_eu_000_001_m_c = hv_tb_eu_000_001_m.copy()
hv_tb_eu_000_001_m_c = hv_tb_eu_000_001_m_c.tail(120)
hv_tb_eu_000_001_m = hv_tb_eu_000_001_m.tail(60)


n_time= 60
#size figure
#wide
size1=32
#height
size2=size1/1.4
##heatmaps inside
font_size_h=10
number_vbs=23
#x size Label axis
x_sizel=17
#axis 2 Label
x2_sizel=x_sizel-5
xlabel_size=20
### axes-1 Label size dates.
axes_1label=12
title_s=32

df1=hv_tb_eu_000_001_m.copy()
df1=df1.tail(n_time)
df1=df1.transpose()
df1.index.names = ['Variable']

num_rows = df1.shape[0]
for x in range(num_rows):
    # print(x)
    locals()[str(str("data_r") + str(x))] = pd.DataFrame([df1.iloc[x]])
    # print("end Loop")

for x in range(num_rows):
    # print(x)
    locals()[str(str("vmin_") + str(x))] = hv_tb_eu_000_001_m_c.iloc[:, x].min()
    locals()[str(str("vmax_") + str(x))] = hv_tb_eu_000_001_m_c.iloc[:, x].max()
    # print("end Loop")

print(vmin_0)
print(vmax_0)
# data = np.random.random((10, 12))
# df = pd.DataFrame(data)

red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")
reversed_red_to_blue = list(reversed(reversed_red_to_blue))
# sns.color_palette("coolwarm", as_cmap=True)

fig, axes = plt.subplots(number_vbs, 1, figsize=(size1, size2), sharex=True)

sns.heatmap(data_r0, cmap=red_to_blue, annot=True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r1, cmap=red_to_blue, annot=True, ax=axes[1], cbar=False, vmin=vmin_1, vmax=vmax_1, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r2, cmap=red_to_blue, annot=True, ax=axes[2], cbar=False, vmin=vmin_2, vmax=vmax_2, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r3, cmap=red_to_blue, annot=True, ax=axes[3], cbar=False, vmin=vmin_3, vmax=vmax_3, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r4, cmap=red_to_blue, annot=True, ax=axes[4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r5, cmap=red_to_blue, annot=True, ax=axes[5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r6, cmap=red_to_blue, annot=True, ax=axes[6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r7, cmap=red_to_blue, annot=True, ax=axes[7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={'label': 'Red to blue'})

sns.heatmap(data_r8, cmap=red_to_blue, annot=True, ax=axes[8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r9, cmap=red_to_blue, annot=True, ax=axes[9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r10, cmap=red_to_blue, annot=True, ax=axes[10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r11, cmap=red_to_blue, annot=True, ax=axes[11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r12, cmap=red_to_blue, annot=True, ax=axes[12], cbar=False, vmin=vmin_12, vmax=vmax_12, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r13, cmap=red_to_blue, annot=True, ax=axes[13], cbar=False, vmin=vmin_13, vmax=vmax_13, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r14, cmap=red_to_blue, annot=True, ax=axes[14], cbar=False, vmin=vmin_14, vmax=vmax_14, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r15, cmap=red_to_blue, annot=True, ax=axes[15], cbar=False, vmin=vmin_15, vmax=vmax_15, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r16, cmap=red_to_blue, annot=True, ax=axes[16], cbar=False, vmin=vmin_16, vmax=vmax_16, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r17, cmap=red_to_blue, annot=True, ax=axes[17], cbar=False, vmin=vmin_17, vmax=vmax_17, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r18, cmap=red_to_blue, annot=True, ax=axes[18], cbar=False, vmin=vmin_18, vmax=vmax_18, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r19, cmap=red_to_blue, annot=True, ax=axes[19], cbar=False, vmin=vmin_19, vmax=vmax_19, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r20, cmap=red_to_blue, annot=True, ax=axes[20], cbar=False, vmin=vmin_20, vmax=vmax_20, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r21, cmap=red_to_blue, annot=True, ax=axes[21], cbar=False, vmin=vmin_21, vmax=vmax_21, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r22, cmap=red_to_blue, annot=True, ax=axes[22], cbar=False, vmin=vmin_22, vmax=vmax_22, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
#sns.heatmap(data_r23, cmap=red_to_blue, annot=True, ax=axes[23], cbar=False, vmin=vmin_23, vmax=vmax_23, fmt='g',
#            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to Blue'})

n=0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_sizel, rotation=0)
    locals() [str(str("axes_t")+str(n))]= ax.twinx()
    locals()[str(str("axes_t")+str(n))].set_yticklabels(ax.get_yticklabels(), fontsize=x2_sizel, rotation=0,va="center")
    n=(n+1)

axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=axes_1label,size=0)
fig.suptitle("Euro Area Economic Dashboard", fontsize=title_s)
plt.figtext(0.5,0.01, "Euro Area Economic Dashboard]", fontsize=title_s, ha="center")
plt.subplots_adjust(hspace=-.1)
plt.tight_layout (rect=[0,0.03,1,0.97])
plt.savefig('euro_heatmap_001.png', bbox_inches='tight',dpi=300)
plt.show()
plt.close()

#Monthly CPI headlines

#Components of MONTHLY CPI
#MONTHLY CPI on MONTHLY ANNUALIZED

#MONTHLY UNEMPLOYMENT RATE
#RBA com. notices

##############################
#####macro momentum
####macro momentum
####macro momentum
####macro momentum
####macro momentum
####macro momentum

### 001  economics z score   <a id="title_page"></a

#usai_m_tickers=hv_tb_usa_000_001_m.columns
#for x in range(len(usai_m_tickers)):
#    variable=str(usai_m_tickers[x])
#    print(x)
#    print(variable)
#    hv_tb_usa_000_001_m[(str(variable)+str("_qq"))]= hv_tb_usa_000_001_m[variable].pct_change(4).multiply(100).round(3)
#    hv_tb_usa_000_001_m[(str(variable)+str("_yy"))]= hv_tb_usa_000_001_m[variable].pct_change(12).multiply (100).round(3)
#    hv_tb_usa_000_001_m[(str(variable)+str("_mm"))]= hv_tb_usa_000_001_m[variable].pct_change(1).multiply(100).round(3)

print("gebneratin z score")
window_z10=[6,12,24,36,]
window_z1=window_z10
usai_m_tickers=hv_tb_eu_000_001_m.columns
for x in range(len(usai_m_tickers)):
    variable=str(usai_m_tickers [x])
    for y in range(len(window_z1)):
        window_z=(window_z1[y])
        hv_tb_eu_000_001_m[ (str(variable)+str("_zscore")+str(window_z))]=(zscore(hv_tb_eu_000_001_m[variable], window_z)).round(2)
        hv_tb_eu_000_001_m[(str(variable)+str("_zavg")+str(window_z))]=(zscore_avg(hv_tb_eu_000_001_m[variable], window_z)).round(2)


        
#KeyError: "['Employment: Euro Area Indeed Wage Tracker_zscore3',
#'Prices: EA11-20: HICP excl Energy NSA Y/Y_zscore3',
#'Prices: EA11-20: HICP excl Energy, Unpr Food NSA Y/Y_zscore3', 
#'Prices: EA11-20: HICP Processed Food & Alcohol NSA Y/Y_zscore3', 
#'Prices: EA11-20: HICP Unprocessed Food NSA Y/Y_zscore3'] not in index"

#hv_tb_eu_000_001_m.rename(columns={"p023h": "Prices: EA11-20: HICP Overall NSA Y/Y"}, inplace=True)
#hv_tb_eu_000_001_m.rename(columns={"p023hoe": "Prices: EA11-20: HICP excl Energy NSA Y/Y"}, inplace=True)
#hv_tb_eu_000_001_m.rename(columns={"p023hoeu": "Prices: EA11-20: HICP excl Energy, Unpr Food NSA Y/Y"}, inplace=True)
###hv_tb_eu_000_001_m.rename(columns={"p023hoef": "Prices: EA11-20: HICP excl Enrgy, Fd, Alchl NSA Y/Y"}, inplace=True)
#hv_tb_eu_000_001_m.rename(columns={"p023hf": "Prices: EA11-20: HICP Food & Alcohol NSA Y/Y"}, inplace=True)
#hv_tb_eu_000_001_m.rename(columns={"p023hpf": "Prices: EA11-20: HICP Processed Food & Alcohol NSA Y/Y"}, inplace=True)
#hv_tb_eu_000_001_m.rename(columns={"p023huf": "Prices: EA11-20: HICP Unprocessed Food NSA Y/Y"}, inplace=True)
#hv_tb_eu_000_001_m.rename(columns={"p023he":"Prices: EA11-20: HICP Energy NSA Y/Y"}, inplace=True)

#print(hv_tb_eu_000_001_m.columns.tolist())



#'Prices: EA11-20: HICP excl Energy NSA Y/Y_zscore3',
#'Prices: EA11-20: HICP excl Energy, Unpr Food NSA Y/Y_zscore3', 
#'Prices: EA11-20: HICP Processed Food & Alcohol NSA Y/Y_zscore3',
#'Prices: EA11-20: HICP Unprocessed Food NSA Y/Y_zscore3'] not in index"

print("generating charts")
window_z1=window_z10

#window_zt=[12]
for x in range(len(window_z1)):
    print(x)
    window_z=(window_z1[x])
    window_z_1=str("zscore"+str(window_z))
    print(window_z)
    usai_m_tickers=[
        "Real: EURO Area EUROCOIN Monthly GDP flash NSA_zscore"+str(window_z),
        "Real: EURO Area Preliminary GDP flash SWDA QQ_zscore"+str(window_z),
        "Real: EURO Area Preliminary GDP flash SWDA YY_zscore"+str(window_z),
        "Real: EURO Area GDP Growth rate QQ SA WDA_zscore"+str(window_z),
        "Real: EURO Area Final Consumption Growth rate QQ SA WDA_zscore"+str(window_z),
        "Real: EURO Area Gross Capital formation Growth rate QQ SA WDA_zscore"+str(window_z),
        "Employment: EA20 Wages & Salaries Quarterly_zscore"+str(window_z),
       # "Employment: Euro Area Indeed Wage Tracker_zscore"+str(window_z),
        "Prices: EA11-20: HICP Overall NSA Y/Y_zscore"+str(window_z),
   #     "Prices: EA11-20: HICP excl Energy NSA Y/Y_zscore"+str(window_z),
#        "Prices: EA11-20: HICP excl Energy, Unpr Food NSA Y/Y_zscore"+str(window_z),
        "Prices: EA11-20: HICP excl Enrgy, Fd, Alchl NSA Y/Y_zscore"+str(window_z),
        "Prices: EA11-20: HICP Food & Alcohol NSA Y/Y_zscore"+str(window_z),
  #      "Prices: EA11-20: HICP Processed Food & Alcohol NSA Y/Y_zscore"+str(window_z),
  #      "Prices: EA11-20: HICP Unprocessed Food NSA Y/Y_zscore"+str(window_z),
        "Prices: EA11-20: HICP Energy NSA Y/Y_zscore"+str(window_z),
        "Prices: EA11-20: HICP Nonenergy goods NSA Y/Y_zscore"+str(window_z),
        "Prices: EA11-20: HICP Services NSA Y/Y_zscore"+str(window_z),
        #"Cycle: Euro Area PMI Composite SA_zscore" + str(window_z),
        #"Cycle: Euro Area PMI New Orders SA_zscore" + str(window_z),
        #"Cycle: Euro Area PMI Employment SA_zscore" + str(window_z),
        #"Cycle: Euro Area PMI Input Prices SA_zscore" + str(window_z),
        #"Cycle: Euro Area PMI New Export Orders SA_zscore" + str(window_z),
        #"Cycle: Euro Area PMI Output prices SA_zscore" + str(window_z),
        #"Cycle: Euro Area PMI Backlogs of work SA_zscore" + str(window_z),
        "Cycle: EA20 Consumer Confidence_zscore" + str(window_z),
        "Cycle: EA20 Sentix_zscore" + str(window_z),
        "Cycle: EA20 Industrial Confidence_zscore" + str(window_z),
        "Cycle: IFO Germany Business Climate_zscore" + str(window_z),
        #"Cycle: Insee France employment climate indicator_zscore" + str(window_z)
    ]

    usai_m_tickers_r = [
        "Real: EURO Area EUROCOIN Monthly GDP flash NSA_zscore" + str(window_z),
        "Real: EURO Area Preliminary GDP flash SWDA QQ_zscore" + str(window_z),
        "Real: EURO Area Preliminary GDP flash SWDA YY_zscore" + str(window_z),
        "Real: EURO Area GDP Growth rate QQ SA WDA_zscore" + str(window_z),
        "Real: EURO Area Final Consumption Growth rate QQ SA WDA_zscore" + str(window_z),
        "Real: EURO Area Gross Capital formation Growth rate QQ SA WDA_zscore" + str(window_z)]
    
    usai_m_tickers_e = [
        "Employment: EA20 Wages & Salaries Quarterly_zscore" + str(window_z),
      #  "Employment: Euro Area Indeed Wage Tracker_zscore" + str(window_z)
    ]
    
    usai_m_tickers_p = [
        "Prices: EA11-20: HICP Overall NSA Y/Y_zscore" + str(window_z),
 #       "Prices: EA11-20: HICP excl Energy NSA Y/Y_zscore" + str(window_z),
     #   "Prices: EA11-20: HICP excl Energy, Unpr Food NSA Y/Y_zscore" + str(window_z),
        "Prices: EA11-20: HICP excl Enrgy, Fd, Alchl NSA Y/Y_zscore" + str(window_z),
        "Prices: EA11-20: HICP Food & Alcohol NSA Y/Y_zscore" + str(window_z),
     #   "Prices: EA11-20: HICP Processed Food & Alcohol NSA Y/Y_zscore" + str(window_z),
   #     "Prices: EA11-20: HICP Unprocessed Food NSA Y/Y_zscore" + str(window_z),
        "Prices: EA11-20: HICP Energy NSA Y/Y_zscore" + str(window_z),
        "Prices: EA11-20: HICP Nonenergy goods NSA Y/Y_zscore" + str(window_z),
        "Prices: EA11-20: HICP Services NSA Y/Y_zscore" + str(window_z)]

    usai_m_tickers_c = [
        #"Cycle: Euro Area PMI Composite SA_zscore" + str(window_z),
        #          "Cycle: Euro Area PMI New Orders SA_zscore" + str(window_z),
        #          "Cycle: Euro Area PMI Employment SA_zscore" + str(window_z),
        #          "Cycle: Euro Area PMI Input Prices SA_zscore" + str(window_z),
        #          "Cycle: Euro Area PMI New Export Orders SA_zscore" + str(window_z),
        #          "Cycle: Euro Area PMI Output prices SA_zscore" + str(window_z),
        #          "Cycle: Euro Area PMI Backlogs of work SA_zscore" + str(window_z),
                  "Cycle: EA20 Consumer Confidence_zscore" + str(window_z),
                  "Cycle: EA20 Sentix_zscore" + str(window_z),
                  "Cycle: EA20 Industrial Confidence_zscore" + str(window_z),
                  "Cycle: IFO Germany Business Climate_zscore" + str(window_z),
         #         "Cycle: Insee France employment climate indicator_zscore" + str(window_z)
    ]

    #print("tickers updated")
    #print(usai_m_tickers)
    hv_tb_eu_000_002_m = hv_tb_eu_000_001_m[usai_m_tickers]
    hv_tb_eu_000_002_m.sort_index(ascending=False, axis=1, inplace=True)
    hv_tb_eu_000_002_m = hv_tb_eu_000_002_m.tail(24)
    hv_tb_eu_000_002_m = hv_tb_eu_000_002_m.transpose()
    hv_tb_eu_000_002_m.index.names = ['Variable']
    #path_display = r'\\table_eu_000_0027'
    #path_display = str(path_display) + str(window_z) + ".csv"
    #print(path_display)
    #hv_tb_eu_000_002_m.to_csv(path_display, index=True, header=True)
    #print(hv_tb_eu_000_002_m)

    #####STACKED BARCHART
    #####STACKED BARCHART
    #####STACKED BARCHART
    hv_tb_eu_000_003_m=hv_tb_eu_000_001_m[usai_m_tickers]
    div=len(usai_m_tickers)
    div=div+0
    #print(div)
    hv_tb_eu_000_003_m= (hv_tb_eu_000_003_m/div)
    hv_tb_eu_000_003_m=hv_tb_eu_000_003_m.tail(120)
    #print(hv_tb_eu_000_003_m)
    
    ########## bar chart
    df1=hv_tb_eu_000_003_m.copy()
    h1=df1.copy()
    #df1.index=df1.index.date
    fig, ax = plt.subplots(figsize=(parameter3_s, 
                                    parameter4_s))
    #ax= df.plot(kind='bar', stacked=True, figsize=(10, 6))
    colors = ["orange", "orange", "blue", "blue", "blue", "blue",
              "green", "green", "green", "green", "green",
              "yellow", "yellow", "yellow", "yellow", "yellow"]
    h1.plot(kind='bar', stacked=True, ax=ax, color=colors)
    title_r=str('eu_MacroMomentum_z'+str(window_z))
    plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
    plt.style.use('default')
    plt.title(str(title_r), size=parameter5)
    plt.ylabel(str(window_z_1), size=parameter3)
    plt.xlabel(str(title_r), size=parameter3)
    plt.legend(title='labels', bbox_to_anchor=(1.0, 1), loc='upper left')
    plt.grid(axis="both", alpha=.3)
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    loc = plticker.MultipleLocator(base=4) # this Locator puts ticks at regular intervals
    ax.xaxis.set_major_locator(loc)
    #date_form = DateFormatter("%m-%Y")
    #ax.xaxis.set_major_formatter(date_form)
    #ax.xaxis.set_major_Locator(mdates.YearLocator())
    #half_year_Locator = mdates.MonthLocator(interval=1)
    #ax.xaxis.set_major_Locator(half_year_Locator)
    #ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
    plt.savefig(str('eu_MacroMomentum_bar_z'+str(window_z)+".png"), bbox_inches='tight')
    plt.show()
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    del h1
    del df1
    del fig
    del ax
    del ax2
    
    ########timeseries
    hv_tb_eu_000_003_m[str('eu_MacroMomentum_z'+str(window_z))] = hv_tb_eu_000_003_m[usai_m_tickers].mean(axis=1)
    hv_tb_eu_000_004_m=hv_tb_eu_000_003_m[str('eu_MacroMomentum_z'+str(window_z))]
    df1=hv_tb_eu_000_004_m.copy()    
    g1=df1.copy()
    title_r=str('eu_MacroMomentum_z'+str(window_z))
    fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
    g1.plot(kind='line', ax=ax,y=[str('eu_MacroMomentum_z'+str(window_z))], color="darkorange",
            linewidth= l1, linestyle='-',
            marker='s', markersize=s2)
    plt.axhline(0, color='black', lw=1, linestyle ='dashed', alpha=0.75)
    plt.style.use('default')
    plt.ylabel(str(window_z_1), size= parameter3)
    plt.xlabel(str(str('eu_MacroMomentum_z'+str(window_z))), size= parameter3)
    plt.tick_params(labelsize=parameter4)
    plt.title(str(title_r), size=parameter5)
    plt.grid(axis='both', alpha=.3)
    ax2=ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    plt.savefig(str('eu_MacroMomentum_z'+str(window_z)+".png"), bbox_inches='tight')
    plt.show()
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    del g1

    
    #KeyError: "['eu_MacroMomentum_z_r_6', 'eu_MacroMomentum_z_e_6', 'eu_MacroMomentum_z_p_6'] not in index"
    
    hv_tb_eu_000_003_m[str("eu_MacroMomentum_z_r_"+str(window_z))] = hv_tb_eu_000_003_m[usai_m_tickers_r].mean(axis=1)
    hv_tb_eu_000_003_m[str("eu_MacroMomentum_z_e_"+str(window_z))] = hv_tb_eu_000_003_m[usai_m_tickers_e].mean(axis=1)
    hv_tb_eu_000_003_m[str("eu_MacroMomentum_z_p_"+str(window_z))] = hv_tb_eu_000_003_m[usai_m_tickers_p].mean(axis=1)
    hv_tb_eu_000_003_m[str("eu_MacroMomentum_z_c_"+str(window_z))] = hv_tb_eu_000_003_m[usai_m_tickers_c].mean(axis=1)

    
    hv_tb_eu_000_005_m=hv_tb_eu_000_003_m[[str('eu_MacroMomentum_z_r_'+str(window_z)),
                                       str('eu_MacroMomentum_z_e_'+str(window_z)),
                                       str('eu_MacroMomentum_z_p_'+str(window_z)),
                                       str('eu_MacroMomentum_z_c_'+str(window_z))]]
    df2=hv_tb_eu_000_005_m.copy()
    g1=df2.copy()
    title_r=str('eu_MacroMomentum_z'+str(window_z))
    fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
    g1.plot(kind='line', ax=ax,y=[str('eu_MacroMomentum_z_r_'+str(window_z))], color="orange",
            linewidth= l1, linestyle='-', marker='s', markersize=s2)
    g1.plot(kind='line',ax=ax,y=[str('eu_MacroMomentum_z_e_'+str(window_z))], color="blue",
            linewidth= l1, linestyle='-', marker='s', markersize=s2)
    g1.plot(kind='line',ax=ax,y=[str('eu_MacroMomentum_z_p_'+str(window_z))], color="green",
            linewidth= l1, linestyle='-', marker='s', markersize=s2)
    g1.plot(kind='line',ax=ax,y=[str('eu_MacroMomentum_z_c_'+str(window_z))], color="yellow",
            linewidth= l1, linestyle='-', marker='s', markersize=s2)
    plt.axhline(0, color='black', lw=1, linestyle = 'dashed', alpha=0.75)
    plt.style.use('default')
    plt.ylabel(str(window_z_1), size=parameter3)
    plt.xlabel(str(str('eu_MacroMomentum_z'+str(window_z))), size=parameter3)
    plt.tick_params(labelsize=parameter4)
    plt.title(str(title_r), size= parameter5)
    plt.grid(axis='both', alpha=.3)
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    plt.savefig(str('eu_MacroMomentum_zd'+str(window_z)+".png"), bbox_inches='tight')
    plt.show()
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    del g1
    del df2
    del fig
    del ax
    del ax2
    
    df2=hv_tb_eu_000_005_m.tail(24)
    g1=df2.copy()
    title_r=str('eu_MacroMomentum_z'+str(window_z))
    fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
    g1.plot(kind='line', ax=ax, y=[str('eu_MacroMomentum_z_r_' + str(window_z))], color="orange",
            linewidth=l1, linestyle='-', marker='s', markersize=s2)
    g1.plot(kind='line', ax=ax, y=[str('eu_MacroMomentum_z_e_' + str(window_z))], color="blue",
            linewidth=l1, linestyle='-', marker='s', markersize=s2)
    g1.plot(kind='line', ax=ax, y=[str('eu_MacroMomentum_z_p_' + str(window_z))], color="green",
            linewidth=l1, linestyle='-', marker='s', markersize=s2)
    g1.plot(kind='line', ax=ax, y=[str('eu_MacroMomentum_z_c_' + str(window_z))], color="yellow",
            linewidth=l1, linestyle='-', marker='s', markersize=s2)
    plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
    plt.style.use('default')
    plt.ylabel(str(window_z_1), size=parameter3)
    plt.xlabel(str('eu_MacroMomentum_z' + str(window_z)), size=parameter3)
    plt.tick_params(labelsize=parameter4)
    plt.title(str(title_r), size=parameter5)
    plt.grid(axis='both', alpha=.3)
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    plt.savefig(str('eu_MacroMomentum_zd' + str(window_z) + "z.png"), bbox_inches='tight')
    plt.show()
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    del g1
    del df2
    del fig
    del ax
    del ax2
    del hv_tb_eu_000_002_m
    del hv_tb_eu_000_003_m
    del hv_tb_eu_000_004_m
    del hv_tb_eu_000_005_m










### 001  EU  employment dashboard  <a id="title_page"></a

##############################
###################################
###labire data

### 001  TABLE EMPLOYMENT <a id="title_page"></a

owner=""

import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import matplotlib.ticker as plticker
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import MultipleLocator
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt
from PIL import Image
import warnings

# Suppress all warnings
warnings.filterwarnings('ignore')

eu_list1= ["EA20", "EU27", "France", "Germany", "Italy",
           "Spain", "Netherlands", "Austria", "Belgium", "Ireland",]
eu_list2= ["Greece", "Portugal", "Finland", "Slovakia", "Slovenia", 
           "Latvia", "Lithuania", "Luxembourg", "Cyprus", "Estonia", "Malta",]

#grsele, grnele,, grselur, grnelur, atnele, atselur, atseurh, atnelur, ptselep, ptnelep, ptsur, ptnur,
#g
#grnelev
#besele, benell, beneil, benelur, beseez
#beseez
###Labor monthyl data
#grsele, grnele,, grselur, grnelur, atnele, atselur, atseurh, atnelur, ptselep, ptnelep, ptsur, ptnur,
#q
#grnelev
#besele, benetl, beneil, benelur, beseez
#beseez

###Labor monthyl data

#monthly
eu_m_tickers1 = ["grsele", "grnele", "atnele", "ptselep", "ptnelep"]
hv_tb_eu_000_001=Haver.data(eu_m_tickers1, "ALPMED", dates=True)
#q
eu_m_tickers2 = ['grnelev']
hv_tb_eu_000_002=Haver.data(eu_m_tickers2, "ALPMED", dates=True)
#m
eu_m_tickers3 = ['besele', 'benell', 'beneil', 'nlset', 'nlnet']
hv_tb_eu_000_003=Haver.data(eu_m_tickers3, "BENELUX", dates=True)
#m
eu_m_tickers4 = ["frselxa"]
hv_tb_eu_000_004=Haver.data(eu_m_tickers4, "FRANCE", dates=True)
#germay
eu_m_tickers5 = ['desele']
hv_tb_eu_000_005=Haver.data(eu_m_tickers5, "GERMANY", dates=True)
#M
#italy
eu_m_tickers6= ['itseetm']
hv_tb_eu_000_006=Haver.data(eu_m_tickers6, "ITALY", dates=True)
#spain
eu_m_tickers7 = ['essett', 'esnett']
hv_tb_eu_000_007=Haver.data(eu_m_tickers7, "SPAIN", dates=True)
hv_tb_eu_000_000_m=pd.concat([hv_tb_eu_000_001, hv_tb_eu_000_002], axis=1, join="outer")
hv_tb_eu_000_000_m=pd.concat([hv_tb_eu_000_000_m, hv_tb_eu_000_003], axis=1, join="outer")
hv_tb_eu_000_000_m=pd.concat([hv_tb_eu_000_000_m, hv_tb_eu_000_004], axis=1, join="outer")
hv_tb_eu_000_000_m=pd.concat([hv_tb_eu_000_000_m, hv_tb_eu_000_005], axis=1, join="outer")
hv_tb_eu_000_000_m=pd.concat([hv_tb_eu_000_000_m, hv_tb_eu_000_006], axis=1, join="outer")
hv_tb_eu_000_000_m=pd.concat([hv_tb_eu_000_000_m, hv_tb_eu_000_007], axis=1, join="outer")

#print(hv_tb_eu_000_000_m)

#Employment
#ALPMED
hv_tb_eu_000_000_m["grsele"]=hv_tb_eu_000_000_m["grsele"].round(0)
hv_tb_eu_000_000_m.rename(columns={"grsele":"Greece - lfs employment thousands monthly sa"}, inplace=True)
hv_tb_eu_000_000_m.rename(columns={"grnele":"Greece - lfs employment thousands monthly nsa"}, inplace=True)
hv_tb_eu_000_000_m.rename(columns={"grnelev": "Greece - lfs ft employment thousands quarterly nsa"}, inplace=True)
hv_tb_eu_000_000_m["atnele"]=hv_tb_eu_000_000_m["atnele"]/1000
hv_tb_eu_000_000_m["atnele"]=hv_tb_eu_000_000_m["atnele"].round(0)
hv_tb_eu_000_000_m.rename(columns={"atnele":"Austria - lfs employment monthly sa (thousands)"}, inplace=True)
hv_tb_eu_000_000_m.rename(columns={"ptselep": "Portugal - employment monthly thousands sa"}, inplace=True)
hv_tb_eu_000_000_m.rename(columns={"ptnelep": "Portugal - employment monthly thousands nsa"}, inplace=True)
#BENELUX
hv_tb_eu_000_000_m.rename(columns={"besele":"Belgium - nace employment quarterly thousands swda"}, inplace=True)
hv_tb_eu_000_000_m.rename(columns={"benell": "Belgium - lfs employment quarterly nsa"}, inplace=True)
hv_tb_eu_000_000_m.rename(columns={"beneil": "Belgium - ilo employment quarterly nsa"}, inplace=True)
##nether
hv_tb_eu_000_000_m.rename(columns={"nlset": "Netherlands - nace2 employment quarterly sa"}, inplace=True)
hv_tb_eu_000_000_m.rename(columns={"nlnet": "Netherlands - nace2 employment quarterly nsa"}, inplace=True)
#france
hv_tb_eu_000_000_m["frselxa"]=hv_tb_eu_000_000_m["frselxa"].round(0)
hv_tb_eu_000_000_m.rename(columns={"frselxa": "France - nace2 employment quarterly sa"}, inplace=True)
#germany
hv_tb_eu_000_000_m["desele"]=hv_tb_eu_000_000_m["desele"].round(1)
hv_tb_eu_000_000_m.rename(columns={"desele":"Germany - lfs employment monthly sa"}, inplace=True)
#italy
hv_tb_eu_000_000_m.rename(columns={"itseetm": "Italy - lfs employment thousands monthly sa"}, inplace=True)
#spain
hv_tb_eu_000_000_m["essett"]=hv_tb_eu_000_000_m["essett"].round(0)

hv_tb_eu_000_000_m.rename(columns={"essett":"Spain - nipa employment thousands quarterly sa"}, inplace=True)
hv_tb_eu_000_000_m.rename(columns={"esnett": "Spain -  nipa employment thousands quarterly nsa"}, inplace=True)
##########
hv_tb_eu_000_000_m=hv_tb_eu_000_000_m.bfill()
hv_tb_eu_000_000_m=hv_tb_eu_000_000_m.diff()
# hv_tb_eu_000_000_m.to_clipboard()


print(hv_tb_eu_000_000_m.columns.tolist())
print(hv_tb_eu_000_000_m)

list_sa=["Germany - lfs employment monthly sa",
         "France - nace2 employment quarterly sa",
         "Italy - lfs employment thousands monthly sa",
         "Spain - nipa employment thousands quarterly sa",
         "Belgium - nace employment quarterly thousands swda",
         "Netherlands - nace2 employment quarterly sa",
         "Austria - lfs employment monthly sa (thousands)",
         "Greece - lfs employment thousands monthly sa",
         "Portugal - employment monthly thousands sa"]


list_emplo=['Greece lfs employment thousands monthly sa', 
 'Greece lfs employment thousands monthly nsa', 
 'Austria lfs employment monthly sa (thousands)',
 'Portugal employment monthly thousands sa', 
 'Portugal employment monthly thousands nsa', 
 'Greece lfs ft employment thousands quarterly nsa', 
 'Belgium nace employment quarterly thousands swda',
 'Belgium lfs employment quarterly nsa', 
 'Belgium ilo employment quarterly nsa', 
 'Netherlands nace2 employment quarterly sa',
 'Netherlands nace2 employment quarterly nsa',
 'France nace2 employment quarterly sa', 
 'Germany 1fs employment monthly sa',
 'Italy ifs employment thousands monthly sa',
 'Spain nipa employment thousands quarterly sa', 
 'Spain nipa employment thousands quarterly nsa']

n_time=60
# size figure
# wide
size1=32
# height
size2=12
## heatmaps inside
font_size_h=15
number_vbs=9
# x size Label axis
x_size1=18
# axis 2 Label
x2_size1=x_size1-5
xlabel_size=22
### axes-1 Lael sie dates
### axes-1 Lael sie dates
axes_1label=13
title_s=32
df1=hv_tb_eu_000_000_m.copy()
df1=df1[list_sa]
df1.replace(0, np.nan, inplace=True)
df1=df1.tail(48)
df_range=df1.copy()
df1.index=df1.index.date
df1=df1.tail(n_time)
df1=df1.transpose()

df1.index.names = ['Variable']
num_rows = df1.shape[0]
for x in range(num_rows):
    #print(x)
    locals()[str(str("data_r")+str(x))] = pd.DataFrame([df1.iloc[x]])
    #print("end Loop")

for x in range(num_rows):
    #print(x)
    locals()[str(str("vmin_")+str(x))] = df_range.iloc[:,x].min()
    locals()[str(str("vmax_")+str(x))] = df_range.iloc[:,x].max()
    #print("end Loop")

print(vmin_0)
print(vmax_0)
#data = np.random.random((10,12))
#df=pd.DataFrame (data)
red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")
reversed_red_to_blue=list(reversed(reversed_red_to_blue))
#sns.color_palette("coolwarm", as_cmap=True)


fig, axes = plt.subplots(number_vbs,1,figsize=(size1,size2),sharex=True)   
sns.heatmap(data_r0,cmap=red_to_blue, annot=True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r1,cmap=red_to_blue, annot=True, ax=axes [1], cbar=False, vmin=vmin_1, vmax=vmax_1, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r2, cmap=red_to_blue, annot=True, ax=axes [2], cbar=False, vmin=vmin_2, vmax=vmax_2, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r3,cmap=red_to_blue, annot=True, ax=axes [3], cbar=False, vmin=vmin_3, vmax=vmax_3, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r4,cmap=red_to_blue, annot=True, ax=axes [4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r5,cmap=red_to_blue, annot=True, ax=axes [5], cbar=False, vmin=vmin_5,vmax=vmax_5, fmt='g',                                   
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r6,cmap=red_to_blue, annot= True, ax=axes [6], cbar=False, vmin=vmin_6, vmax=vmax_6,fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r7,cmap=red_to_blue, annot=True, ax=axes [7], cbar=False, vmin=vmin_7, vmax=vmax_7,fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r8,cmap=red_to_blue, annot=True, ax=axes [8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
n=0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_size1, rotation=0)
    locals() [str(str("axes_t")+str(n))]= ax.twinx()
    locals()[str(str("axes_t")+str(n))].set_yticklabels(ax.get_yticklabels(), fontsize=x2_size1, rotation=0,va="center")
    #ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    n=(n+1)

#axes[0].set_xticks([])
#axes[1].set_xticks([])
#xes[1].set_xticks([])
axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=axes_1label, size=0)
#axes[-1].set_xticklabels(axis="x", which="both", Length=0, Labelrotation=45)
#.set_xticks([])

fig.suptitle("Euro Area Employment Dashboard", fontsize=title_s)
plt.figtext(0.5,0.01, "Euro Area Employment Dashboard", fontsize=title_s, ha="center")
plt.subplots_adjust(hspace=-.1)
plt.tight_layout(rect=[0,0.03,1,0.97])
plt.savefig('hv_tb_eu_020_001_m_g_hh01.png', bbox_inches='tight',dpi=300)
plt.savefig('hv_tb_eu_020_001_m_g_hh.png', bbox_inches='tight',dpi=300)
#plt.savefig('euro_heatmap_nfp_001.png', bbox_inches='tight', dpi=300)
plt.show()
plt.close()

### 001  TABLE EMPLOYMENT BIRD EYE <a id="title_page"></a

####ads#ad#ad#asd#daad
###Euro nfp bird eye style s
parameter1_o=6
parameter2_o=4
n=0
mks=3
linew=2
print(" ojo ave, ojo ave, ojo ave, ojo ave, ojo aveojo ave, ojo ave,, ojo aveojo ave ")
df1=hv_tb_eu_000_000_m.copy()
df1=df1[list_sa]
df0=df1.copy()
list_c=df0.columns.tolist()

n=1
for y in list_c:
    print(y)
    #print("filtering time horizon")
    df1=df0.copy()
    df1=pd.DataFrame(df1[str(y)])
    #List_c=df1.columns.tolist()
    df1=df1.tail(60)
    g1=df1.copy()
    g1.index=g1.index.date
    fig, ax = plt.subplots(figsize=((5),(3)))
    
    g1.plot(kind='bar', ax=ax, y=str(y), 
            color="orange",
            linewidth=(linew + 1))
    
    x_last = g1.index[-1] # Assuming the Dataframe index is date or sequential
    y_last = g1 [str(y)].iloc[-1]
    # Set x-ticks to show only the year
    plt.style.use('default')
    plt.tick_params (labelsize=parameter4)
    plt.title(str(df1.columns.tolist()[0]), size=(parameter5-2))
    plt.grid(axis='both', alpha=.3)
    ax2 =ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    #plt.savefig(str("hv_tb_eu_nfp_ov"+str(n)+".png"), bbox_inches-'tight')
    plt.savefig(str('hv_tb_eu_020_001_m_g_ov'+str(n)+'.png'), bbox_inches='tight', dpi=300)
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    del g1
    del df1
    #del List_c
    del fig
    del ax
    del ax2
    n=n+1
    





### 001  TABLE UR quarterly  <a id="title_page"></a

##############ur

country_database = "EUDATA"

##### unemplyoment rate
print("Quarterly")
#print("tickers")
eu_m_tickers = ["q997uwtt", "q025uwtt", "q122uwtt", "q124uwtt", "q423uwtt", "q939uwtt", "q172uwtt", "q132uwtt",
"q134uwtt", "q174uwtt", "q178uwtt", "q136uwtt", "q941uwtt", "q946uwtt",
"q137uwtt", "q181uwtt", "q138uwtt", "q182uwtt", "q936uwtt", "q961uwtt", "q184uwtt"]

#print("getting from api")
hv_tb_eu_004_001_m = Haver.data(eu_m_tickers, "EULABOR", dates=True)

print(hv_tb_eu_004_001_m)
#print(hv_tb_eu_004_001_m.columns)

#print("renaming")
hv_tb_eu_004_001_m.rename(columns={"q025uwtt": "EA20 ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"q997uwtt": "EU27 ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"q122uwtt": "Austria ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"q124uwtt": "Belgium ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"q423uwtt": "Cyprus ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"q939uwtt": "Estonia ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"q172uwtt": "Finland ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"q132uwtt": "France ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"q134uwtt": "Germany ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"q174uwtt": "Greece ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"q178uwtt": "Ireland ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"q136uwtt": "Italy ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"q941uwtt": "Latvia ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"q946uwtt": "Lithuania ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"q137uwtt": "Luxembourg ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"q181uwtt": "Malta ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"q138uwtt": "Netherlands ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"q182uwtt": "Portugal ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"q936uwtt": "Slovakia ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"q961uwtt": "Slovenia ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"q184uwtt": "Spain ur [15-64] quarterly nsa"}, inplace=True)

hv_tb_eu_004_001_m.columns = [col.replace(" ur [15-64] quarterly nsa", "") for col in hv_tb_eu_004_001_m.columns]
eu_m_tickers = hv_tb_eu_004_001_m.columns.tolist()
hv_tb_eu_004_001_m_hh=hv_tb_eu_004_001_m.copy()


hv_tb_eu_004_001_m=hv_tb_eu_004_001_m.ffill()
hv_tb_eu_004_001_m=hv_tb_eu_004_001_m.round(1)

#hv_tb_eu_000_000_m.to_clipboard()

list_sa=["Greece ur [15-64] quarterly nsa", "Austria ur [15-64] quarterly nsa", "Portugal ur [15-64] quarterly nsa",
         "Belgium ur [15-64] quarterly nsa", "Netherlands ur [15-64] quarterly nsa", "France ur [15-64] quarterly nsa",
         "Germany ur [15-64] quarterly nsa", "Italy ur [15-64] quarterly nsa", "Spain ur [15-64] quarterly nsa"]


print("Quarterly")

### 001  TABLE UR quarterly heatmap   <a id="title_page"></a

n_time = 60
#size figure
#wide
size1 = 32
#height
size2 = 17
##heatmaps inside
font_size_h = 14
number_vbs = 21
#x size Label axis
x_size1 = 18
#axis 2 Label
x2_size1 = x_size1 - 5
xlabel_size = 21
### axes-1 Lael sie dates
axes_1label = 12
title_s = 32
df1 = hv_tb_eu_004_001_m_hh.copy()
df1 = df1.tail(48)
df_range = df1.copy()
df1.index = df1.index.date
df1 = df1.tail(n_time)
df1 = df1.transpose()
df1.index.names = ['Variable']

num_rows = df1.shape[0]
for x in range(num_rows):
    #print(x)
    locals() [str(str("data_r")+str(x))] = pd.DataFrame([df1.iloc[x]])
    #print("end Loop")

for x in range(num_rows): #print(x)
    locals() [str(str("vmin_")+str(x))] = df_range.iloc[:,x].min()
    locals() [str(str("vmax_")+str(x))] = df_range.iloc[:,x].max()
    #print("end Loop")

print(vmin_0)
print(vmax_0)

#data = np.random.random((10,12))
#df=pd.DataFrame (data)

red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")

reversed_red_to_blue=list(reversed (reversed_red_to_blue))
#sns.color_palette("coolwarm", as_cmap=True)

fig, axes = plt.subplots (number_vbs,1,
                          figsize=(size1, size2),
                                   sharex=True,)   

sns.heatmap(data_r0, cmap=red_to_blue, annot=True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r1, cmap=red_to_blue, annot=True, ax=axes[1], cbar=False, vmin=vmin_1, vmax=vmax_1, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r2, cmap=red_to_blue, annot=True, ax=axes[2], cbar=False, vmin=vmin_2, vmax=vmax_2, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r3, cmap=red_to_blue, annot=True, ax=axes[3], cbar=False, vmin=vmin_3, vmax=vmax_3, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r4, cmap=red_to_blue, annot=True, ax=axes[4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r5, cmap=red_to_blue, annot=True, ax=axes[5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r6, cmap=red_to_blue, annot=True, ax=axes[6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r7, cmap=red_to_blue, annot=True, ax=axes[7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r8, cmap=red_to_blue, annot=True, ax=axes[8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r9, cmap=red_to_blue, annot=True, ax=axes[9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r10, cmap=red_to_blue, annot=True, ax=axes[10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r11, cmap=red_to_blue, annot=True, ax=axes[11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r12, cmap=red_to_blue, annot=True, ax=axes[12], cbar=False, vmin=vmin_12, vmax=vmax_12, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r13, cmap=red_to_blue, annot=True, ax=axes[13], cbar=False, vmin=vmin_13, vmax=vmax_13, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r14, cmap=red_to_blue, annot=True, ax=axes[14], cbar=False, vmin=vmin_14, vmax=vmax_14, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r15, cmap=red_to_blue, annot=True, ax=axes[15], cbar=False, vmin=vmin_15, vmax=vmax_15, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r16, cmap=red_to_blue, annot=True, ax=axes[16], cbar=False, vmin=vmin_16, vmax=vmax_16, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r17, cmap=red_to_blue, annot=True, ax=axes[17], cbar=False, vmin=vmin_17, vmax=vmax_17, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r18, cmap=red_to_blue, annot=True, ax=axes[18], cbar=False, vmin=vmin_18, vmax=vmax_18, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r19, cmap=red_to_blue, annot=True, ax=axes[19], cbar=False, vmin=vmin_19, vmax=vmax_19, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r20, cmap=red_to_blue, annot=True, ax=axes[20], cbar=False, vmin=vmin_20, vmax=vmax_20, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})

# sns.heatmap(data_r21, cmap='red_to_blue', annot=True, ax=axes[21], cbar=False, vmin=vmin_21, vmax=vmax_21, fmt='g',
#            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
n=0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_size1, rotation=0)
    locals()[str(str("axes_t") + str(n))] = ax.twinx()
    locals()[str(str("axes_t") + str(n))].set_yticklabels(ax.get_yticklabels(), fontsize=x2_size1, rotation=0, va="center")
    # ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    n = (n + 1)

# axes[0].set_xticks([])
# axes[1].set_xticks([])
# axes[1].set_xticks([])
axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=axes_1label, size=0)
# axes[-1].set_xticklabels(axis="x", which="both", Length=0, Labelrotation=45)
# .set_xticks([])
fig.suptitle("Euro Area Quarterly UR Dashboard", fontsize=title_s)
plt.figtext(0.5, 0.01, "Euro Area Quarterly UR Dashboard", fontsize=title_s, ha="center")
plt.subplots_adjust(hspace=-.1)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig('hv_tb_eu_021_001_m_g_hh.png', bbox_inches='tight', dpi=300)
plt.savefig('hv_tb_eu_021_001_m_g_hh1.png', bbox_inches='tight', dpi=300)
plt.show()
plt.close()


print("Quarterly")

### 001  TABLE UR quarterly graphs   <a id="title_page"></a

print(hv_tb_eu_004_001_m)



eu_m_tickers=["Greece", "Austria", "Portugal",
         "Belgium", "Netherlands", "France",
         "Germany", "Italy", "Spain"]

#hv_tb_eu_004_001_m.rename(columns={"q184uwtt": "Spain ur [15-64] quarterly nsa"}, inplace=True)
hv_tb_eu_004_001_m
hv_tb_eu_004_001_m1=hv_tb_eu_004_001_m[eu_m_tickers]
l1=2
s2=2
df1=hv_tb_eu_004_001_m1.copy()
df1=df1.tail(120)
list_c=eu_m_tickers
title_r0="ur [15-64] quarterly nsa"
title_r=title_r0
y_label="Index %"
x_label=title_r
g1=df1.copy()
fig,ax= plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_c[0]], color="black",
        linewidth= l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=[list_c[1]], color="darkred",
        linewidth= l1, linestyle='-',
        marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=[list_c[2]], color="darkgreen",
        linewidth= l1, linestyle='-',
        marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y= [list_c[3]], color="darkorange",
        linewidth= l1, linestyle='-',
        marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=[list_c[4]], color="magenta",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind="line", ax=ax, y=[list_c[5]], color="yellow",
        linewidth= l1, linestyle='-',
        marker="o", markersize=s2)
g1.plot(kind="line", ax=ax, y=[list_c[6]], color="darkblue",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)

g1.plot(kind='line', ax=ax,y=[list_c[7]], color="red", linewidth= l1, linestyle='-',
        marker='o', markersize=s2)

#plt.axhline(0, color="black', Lw=1, Linestyle = 'dashed', alpha=0.75)

for series_name in list_c[0:7]:
  last_y_value = g1[series_name][-1]
  print(last_y_value)
  print(series_name)

  plt.annotate(f'{series_name} {last_y_value}',
                xy=(g1.index.max(), last_y_value),
                xytext=(30, 0),
                textcoords= 'offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size =parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)

ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

plt.text(0.15, 0.15, str(owner),
         color='gray',
         fontsize=25,
         alpha=0.5,
         ha='center',
         va='center',
         rotation=30,
         transform=plt.gca().transAxes)

plt.savefig("hv_tb_eu_021_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2





#######pending
#######pending
#######pending
#######pending
#######pending

#hv_tb_eu_022_001_m_g_001

### 001  TABLE UR monthly   <a id="title_page"></a

print("Monthyl ")

#### ur
# # # monthly data
# # # high frequnecy unemplyoment
# monthly
eu_m_tickers1 = ["grselur", "grnelur", "atselur", "atseurh", "atnelur", "ptsur", "ptnur"]
hv_tb_eu_000_001 = Haver.data(eu_m_tickers1, "ALPMED", dates=True)
# g
eu_m_tickers2 = ["benelur"]
hv_tb_eu_000_002 = Haver.data(eu_m_tickers2, "BENELUX", dates=True)
eu_m_tickers3 = ["nlseiur", "nlneiur"]
hv_tb_eu_000_003 = Haver.data(eu_m_tickers3, "BENELUX", dates=True)
# m
eu_m_tickers4 = ["frselrm"]
hv_tb_eu_000_004 = Haver.data(eu_m_tickers4, "FRANCE", dates=True)
# M
# germany
eu_m_tickers5 = ["deseur", "debeur"]
hv_tb_eu_000_005 = Haver.data(eu_m_tickers5, "GERMANY", dates=True)
# italy
eu_m_tickers6 = ["itsustm"]
hv_tb_eu_000_006 = Haver.data(eu_m_tickers6, "ITALY", dates=True)
# spain
eu_m_tickers7 = ["esnelur"]
hv_tb_eu_000_007 = Haver.data(eu_m_tickers7, "SPAIN", dates=True)
hv_tb_eu_000_000_m = pd.concat([hv_tb_eu_000_001, hv_tb_eu_000_002], axis=1, join="outer")
hv_tb_eu_000_000_m = pd.concat([hv_tb_eu_000_000_m, hv_tb_eu_000_003], axis=1, join="outer")
hv_tb_eu_000_000_m = pd.concat([hv_tb_eu_000_000_m, hv_tb_eu_000_004], axis=1, join="outer")
hv_tb_eu_000_000_m = pd.concat([hv_tb_eu_000_000_m, hv_tb_eu_000_005], axis=1, join="outer")
hv_tb_eu_000_000_m = pd.concat([hv_tb_eu_000_000_m, hv_tb_eu_000_006], axis=1, join="outer")
hv_tb_eu_000_000_m = pd.concat([hv_tb_eu_000_000_m, hv_tb_eu_000_007], axis=1, join="outer")
# eu_m_tickers = eu_m_tickers1 + eu_m_tickers2 + eu_m_tickers3 + eu_m_tickers4 + eu_m_tickers5 + eu_m_tickers6
# hv_tb_eu_000_001_m = hv_tb_eu_000_001_m.fillna(method='bfill')

# hv_tb_eu_000_001_m_mm = hv_tb_eu_000_001_m.copy()

#ALPMED
hv_tb_eu_000_000_m.rename(columns={"grselur": "Greece lfs ur monthly sa"}, inplace=True)
hv_tb_eu_000_000_m.rename(columns={"grnelur": "Greece lfs ur monthly nsa"}, inplace=True)
#######
hv_tb_eu_000_000_m.rename(columns={"atselur": "Austria ur monthly sa"}, inplace=True)
hv_tb_eu_000_000_m.rename(columns={"atseurh": "Austria harmonized ur monthly sa"}, inplace=True)
######
hv_tb_eu_000_000_m.rename(columns={"atnelur": "Austria ur monthly nsa"}, inplace=True)
hv_tb_eu_000_000_m.rename(columns={"ptsur": "Portugal ur monthly sa"}, inplace=True)
####
hv_tb_eu_000_000_m.rename(columns={"ptnur": "Portugal ur monthly nsa"}, inplace=True)
#benelur, niseiur, ninetur
####
#BENELUX
hv_tb_eu_000_000_m.rename(columns={"benelur": "Belgium lfs ur quarterly nsa"}, inplace=True)
#####
hv_tb_eu_000_000_m.rename(columns={"nlseiur": "Netherlands ilo ur monthly nsa"}, inplace=True)
hv_tb_eu_000_000_m.rename(columns={"nlneiur": "Netherlands ilo ur monthly sa"}, inplace=True)
#####
#FRANCE
hv_tb_eu_000_000_m.rename(columns={"frselrm": "France harmonized ur monthly sa"}, inplace=True)
######
#germany
hv_tb_eu_000_000_m.rename(columns={"deseur": "Germany ur monthly sa"}, inplace=True)
hv_tb_eu_000_000_m.rename(columns={"debeur": "Germany ur monthly bsa"}, inplace=True)
#####
#italy
hv_tb_eu_000_000_m.rename(columns={"itsustm": "Italy lfs ur monthly sa"}, inplace=True)
######
#spain
hv_tb_eu_000_000_m.rename(columns={"esnelur": "Spain ine ur quarterly sa"}, inplace=True)


#hv_tb_eu_004_001_m.columns = [col.replace(" ur [15-64] quarterly nsa", "") for col in hv_tb_eu_004_001_m.columns]
#eu_m_tickers = hv_tb_eu_004_001_m.columns.tolist()
hv_tb_eu_004_001_m_hh=hv_tb_eu_000_000_m.copy()




hv_tb_eu_000_000_m=hv_tb_eu_000_000_m.ffill()
hv_tb_eu_000_000_m=hv_tb_eu_000_000_m.round(1)

#hv_tb_eu_000_000_m.to_clipboard()

list_sa=["Greece lfs ur monthly sa", "Austria ur monthly sa", "Portugal ur monthly sa",
         "Belgium lfs ur quarterly nsa", "Netherlands ilo ur monthly sa", "France harmonized ur monthly sa",
         "Germany ur monthly sa", "Italy lfs ur monthly sa", "Spain ine ur quarterly sa"]

hv_tb_eu_000_000_m_g=hv_tb_eu_000_000_m[list_sa]

### 001  TABLE UR monthly heatmap  <a id="title_page"></a

n_time = 60
#size figure
#wide
size1 = 32
#height
size2 = 17
##heatmaps inside
font_size_h = 14
number_vbs = 21
#x size Label axis
x_size1 = 18
#axis 2 Label
x2_size1 = x_size1 - 5
xlabel_size = 21
### axes-1 Lael sie dates
axes_1label = 12
title_s = 32
df1 = hv_tb_eu_004_001_m_hh.copy()
df1 = df1.tail(48)
df_range = df1.copy()
df1.index = df1.index.date
df1 = df1.tail(n_time)
df1 = df1.transpose()
df1.index.names = ['Variable']

num_rows = df1.shape[0]
for x in range(num_rows):
    #print(x)
    locals() [str(str("data_r")+str(x))] = pd.DataFrame([df1.iloc[x]])
    #print("end Loop")

for x in range(num_rows): #print(x)
    locals() [str(str("vmin_")+str(x))] = df_range.iloc[:,x].min()
    locals() [str(str("vmax_")+str(x))] = df_range.iloc[:,x].max()
    #print("end Loop")

print(vmin_0)
print(vmax_0)

#data = np.random.random((10,12))
#df=pd.DataFrame (data)

red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")

reversed_red_to_blue=list(reversed (reversed_red_to_blue))
#sns.color_palette("coolwarm", as_cmap=True)

fig, axes = plt.subplots (number_vbs,1,
                          figsize=(size1, size2),
                                   sharex=True,)   

sns.heatmap(data_r0, cmap=red_to_blue, annot=True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r1, cmap=red_to_blue, annot=True, ax=axes[1], cbar=False, vmin=vmin_1, vmax=vmax_1, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r2, cmap=red_to_blue, annot=True, ax=axes[2], cbar=False, vmin=vmin_2, vmax=vmax_2, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r3, cmap=red_to_blue, annot=True, ax=axes[3], cbar=False, vmin=vmin_3, vmax=vmax_3, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r4, cmap=red_to_blue, annot=True, ax=axes[4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r5, cmap=red_to_blue, annot=True, ax=axes[5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r6, cmap=red_to_blue, annot=True, ax=axes[6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r7, cmap=red_to_blue, annot=True, ax=axes[7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r8, cmap=red_to_blue, annot=True, ax=axes[8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r9, cmap=red_to_blue, annot=True, ax=axes[9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r10, cmap=red_to_blue, annot=True, ax=axes[10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r11, cmap=red_to_blue, annot=True, ax=axes[11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r12, cmap=red_to_blue, annot=True, ax=axes[12], cbar=False, vmin=vmin_12, vmax=vmax_12, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r13, cmap=red_to_blue, annot=True, ax=axes[13], cbar=False, vmin=vmin_13, vmax=vmax_13, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r14, cmap=red_to_blue, annot=True, ax=axes[14], cbar=False, vmin=vmin_14, vmax=vmax_14, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r15, cmap=red_to_blue, annot=True, ax=axes[15], cbar=False, vmin=vmin_15, vmax=vmax_15, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r16, cmap=red_to_blue, annot=True, ax=axes[16], cbar=False, vmin=vmin_16, vmax=vmax_16, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r17, cmap=red_to_blue, annot=True, ax=axes[17], cbar=False, vmin=vmin_17, vmax=vmax_17, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r18, cmap=red_to_blue, annot=True, ax=axes[18], cbar=False, vmin=vmin_18, vmax=vmax_18, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r19, cmap=red_to_blue, annot=True, ax=axes[19], cbar=False, vmin=vmin_19, vmax=vmax_19, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r20, cmap=red_to_blue, annot=True, ax=axes[20], cbar=False, vmin=vmin_20, vmax=vmax_20, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})

# sns.heatmap(data_r21, cmap='red_to_blue', annot=True, ax=axes[21], cbar=False, vmin=vmin_21, vmax=vmax_21, fmt='g',
#            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
n=0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_size1, rotation=0)
    locals()[str(str("axes_t") + str(n))] = ax.twinx()
    locals()[str(str("axes_t") + str(n))].set_yticklabels(ax.get_yticklabels(), fontsize=x2_size1, rotation=0, va="center")
    # ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    n = (n + 1)

# axes[0].set_xticks([])
# axes[1].set_xticks([])
# axes[1].set_xticks([])
axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=axes_1label, size=0)
# axes[-1].set_xticklabels(axis="x", which="both", Length=0, Labelrotation=45)
# .set_xticks([])
fig.suptitle("Euro Area Monthly UR Dashboard", fontsize=title_s)
plt.figtext(0.5, 0.01, "Euro Area Monthly UR Dashboard", fontsize=title_s, ha="center")
plt.subplots_adjust(hspace=-.1)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig('hv_tb_eu_022_001_m_g_hh.png', bbox_inches='tight', dpi=300)
plt.savefig('hv_tb_eu_022_001_m_g_hh1.png', bbox_inches='tight', dpi=300)
plt.show()
plt.close()


print("monthly")

### 001  TABLE UR monthly   graphs  <a id="title_page"></a

l1=2
s2=2
df1=hv_tb_eu_000_000_m_g.copy()
df1=df1.tail(120)
list_c=list_sa
title_r0="unemployment rate high frequency"
title_r=title_r0
y_label="Index %"
x_label=title_r
g1=df1.copy()
fig,ax= plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_c[0]], color="black",
        linewidth= l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=[list_c[1]], color="darkred",
        linewidth= l1, linestyle='-',
        marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=[list_c[2]], color="darkgreen",
        linewidth= l1, linestyle='-',
        marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y= [list_c[3]], color="darkorange",
        linewidth= l1, linestyle='-',
        marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=[list_c[4]], color="magenta",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind="line", ax=ax, y=[list_c[5]], color="yellow",
        linewidth= l1, linestyle='-',
        marker="o", markersize=s2)
g1.plot(kind="line", ax=ax, y=[list_c[6]], color="darkblue",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)

g1.plot(kind='line', ax=ax,y=[list_c[7]], color="red", linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,y=[list_c[8]], color="gold",linewidth= l1, linestyle='-',
        marker='o', markersize=s2)

#plt.axhline(0, color="black', Lw=1, Linestyle = 'dashed', alpha=0.75)

for series_name in list_c[0:9]:
  last_y_value = g1[series_name][-1]
  print(last_y_value)
  print(series_name)

  plt.annotate(f'{series_name} {last_y_value}',
                xy=(g1.index.max(), last_y_value),
                xytext=(30, 0),
                textcoords= 'offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size =parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)

ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

plt.text(0.15, 0.15, str(owner),
         color='gray',
         fontsize=25,
         alpha=0.5,
         ha='center',
         va='center',
         rotation=30,
         transform=plt.gca().transAxes)

plt.savefig("hv_tb_eu_022_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

#hv_tb_eu_022_001_m_g_002
df1=hv_tb_eu_000_000_m_g.copy()
df1=df1.tail(60)
list_c=list_sa
title_r0="unemployment rate high frequency"
title_r=title_r0
y_label="Index %"
x_label=title_r
g1=df1.copy()

fig,ax= plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_c[0]], color="black",
        linewidth= l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=[list_c[1]], color="darkred",
        linewidth= l1, linestyle='-',
        marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=[list_c[2]], color="darkgreen",
        linewidth= l1, linestyle='-',
        marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y= [list_c[3]], color="darkorange",
        linewidth= l1, linestyle='-',
        marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=[list_c[4]], color="magenta",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind="line", ax=ax, y=[list_c[5]], color="yellow",
        linewidth= l1, linestyle='-',
        marker="o", markersize=s2)
g1.plot(kind="line", ax=ax, y=[list_c[6]], color="darkblue",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)

g1.plot(kind='line', ax=ax,y=[list_c[7]], color="red", linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,y=[list_c[8]], color="gold",linewidth= l1, linestyle='-',
        marker='o', markersize=s2)

#plt.axhline(0, color="black', Lw=1, Linestyle = 'dashed', alpha=0.75)

for series_name in list_c[0:9]:
  last_y_value = g1[series_name][-1]
  print(last_y_value)
  print(series_name)

  plt.annotate(f'{series_name} {last_y_value}',
                xy=(g1.index.max(), last_y_value),
                xytext=(30, 0),
                textcoords= 'offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size =parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)

ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

plt.text(0.15, 0.15, str(owner),
         color='gray',
         fontsize=25,
         alpha=0.5,
         ha='center',
         va='center',
         rotation=30,
         transform=plt.gca().transAxes)

plt.savefig("hv_tb_eu_022_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2



### 001  TABLE EMPLOYMENT <a id="title_page"></a

#hv_tb_eu_022_001_m_g_hh

n_time=60
#size figure
#wide
size1=32
#height
size2=17
#heatmaps inside
font_size_h=14
number_vbs=15
#x size Label axis
x_sizel=17
#axis 2 Label
x2_sizel=x_sizel-5
xlabel_size=20
#axes-1 Lael sie dates
axes_1label=12
title_s=32
df1=hv_tb_eu_000_000_m.copy()
df1=df1.tail(48)
df_range=df1.copy()
df1.index=df1.index.date
df1=df1.tail(n_time)
df1=df1.transpose()
df1.index.names = ['Variable']

num_rows = df1.shape[0]
for x in range(num_rows):
    #print(x)
    locals()[str(str("data_r")+str(x))] = pd.DataFrame([df1.iloc[x]])
    #print("end Loop")

for x in range(num_rows):
    #print(x)
    locals() [str(str("vmin_")+str(x))] = df_range.iloc[:,x].min()
    locals() [str(str("vmax_")+str(x))] = df_range.iloc[:,x].max()
    #print("end Loop")


print(vmin_0)
print(vmax_0)

# data
# df=pd.DataFrame(data)
np.random.random((10, 12))

red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")

reversed_red_to_blue = list(reversed(reversed_red_to_blue))
# sns.color_palette("coolwarm", as_cmap=True)

fig, axes = plt.subplots(number_vbs, 1,
                         figsize=(size1, size2),
                         sharex=True,)

sns.heatmap(data_r0, cmap=red_to_blue, annot=True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r1, cmap=red_to_blue, annot=True, ax=axes[1], cbar=False, vmin=vmin_1, vmax=vmax_1, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r2, cmap=red_to_blue, annot=True, ax=axes[2], cbar=False, vmin=vmin_2, vmax=vmax_2, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r3, cmap=red_to_blue, annot=True, ax=axes[3], cbar=False, vmin=vmin_3, vmax=vmax_3, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r4, cmap=red_to_blue, annot=True, ax=axes[4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r5, cmap=red_to_blue, annot=True, ax=axes[5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r6, cmap=red_to_blue, annot=True, ax=axes[6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r7, cmap=red_to_blue, annot=True, ax=axes[7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r8, cmap=red_to_blue, annot=True, ax=axes[8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r9, cmap=red_to_blue, annot=True, ax=axes[9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r10, cmap=red_to_blue, annot=True, ax=axes[10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r11, cmap=red_to_blue, annot=True, ax=axes[11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r12, cmap=red_to_blue, annot=True, ax=axes[12], cbar=False, vmin=vmin_12, vmax=vmax_12, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r13, cmap=red_to_blue, annot=True, ax=axes[13], cbar=False, vmin=vmin_13, vmax=vmax_13, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r14, cmap=red_to_blue, annot=True, ax=axes[14], cbar=False, vmin=vmin_14, vmax=vmax_14, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})

n=0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_sizel, rotation=0)
    locals() [str(str("axes_t")+str(n))]= ax.twinx()    
    locals()[str(str("axes_t")+str(n))].set_yticklabels(ax.get_yticklabels(), fontsize=x2_sizel, rotation=0,va="center")
    #ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    n=n+1

#axes[0].set_xticks([])
#axes[1].set_xticks([])
#xes[1].set_xticks([])
axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=axes_1label, size=0)
#axes[-1].set_xticklabels(axis="x", which="both", Length=0, Labelrotation=45)
#.set_xticks([])
fig.suptitle("Euro. Area UR Monthly Dashboard", fontsize=title_s)
plt.figtext(0.5,0.01, "Euro Area UR Monthly Dashboard", fontsize=title_s, ha="center")
plt.subplots_adjust(hspace=-.1)
plt.tight_layout(rect=[0,0.03,1,0.97])
plt.savefig('hv_tb_eu_022_001_m_g_hh.png', bbox_inches='tight',dpi=300)
plt.show()
plt.close()



### 001  TABLE eu unemployment ur unemployment rate bar chart  <a id="title_page"></a


#hv_tb_eu_022_001_m_g_003

#Barchart Last datapoint
parameter_w1=0.5
table_w_simulation=hv_tb_eu_000_000_m.copy()
table_w_simulation=table_w_simulation.tail(1)
table_w_simulation =table_w_simulation.transpose()
table_w_sc=table_w_simulation.copy()
#table_w_simulation table_w_simulation.reindex()
#table_w_sc=table_w_simulation.copy()
#print(table_w_sc)
table_w_simulation.index.names= ["Variable"]
table_w_simulation.columns=["Weight"]
#print(table_w_simulation)
table_w_simulation=table_w_simulation.sort_values('Weight')

plt.figure(figsize=(15, 7))
bars =plt.bar(table_w_simulation.index, table_w_simulation ["Weight"], color="darkgreen")
plt.ylabel('', size=7)
plt.xlabel(" ", size=7)
plt.tick_params (labelsize=16)
#plt.title(str("PER_"+str(ccy)+"_"+str(time_w)), size-ti_size)
plt.grid(axis='both', alpha=.3)
plt.title("EA UR Montlhy last datapoint available", size=15)
for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2, #x-coordinate position of text, adjusted to be centered in the bar
             bar.get_height(), #y-coordinate position of text
             f'{bar.get_height():.2f}', #Text to be displayed; can format the number here
             size=20,
                ha='center', # Center alignment of text horizontally
                va='bottom') # Bottom alignment of text vertically
plt.xticks (rotation=30, ha='right')                                                
plt.savefig("hv_tb_eu_022_001_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()

### 001  TABLE Compensarion per employeeee<a id="title_page"></a

#####Compensarion per employeeee###Compensarion per employeeee
####Compensarion per employeeee

print("tickera")
eu_m_tickers =["d122cpe", "d124cpe", "d423cpe", "d939cpe", "d172cpe", "d132cpe",
               "d134cpe", "d174cpe","d178cpe", "d136cpe", "d941cpe", "d946cpe",
               "d137cpe", "d181cpe", "d138cpe", "d182cpe","d936cpe", "d961cpe", "d184cpe"]
print("getting from api")
hv_tb_eu_004_001_m=Haver.data(eu_m_tickers, "EUNA", dates=True)
#print(hv_tb_eu_004_001_m)
#print(hv_tb_eu_004_001_m.columns)

print("renaming")
hv_tb_eu_004_001_m.rename(columns={"d122cpe": "Austria Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d124cpe": "Belgium Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d423cpe": "Cyprus Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d939cpe": "Estonia Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d172cpe": "Finland Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d132cpe": "France Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d134cpe": "Germany Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d174cpe": "Greece Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d178cpe": "Ireland Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d136cpe": "Italy Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d941cpe": "Latvia Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d946cpe": "Lithuania Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d137cpe": "Luxembourg Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d181cpe": "Malta Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d138cpe": "Netherlands Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d182cpe": "Portugal Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d936cpe": "Slovakia Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d961cpe": "Slovenia Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d184cpe": "Spain Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d182cpe": "Portugal Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d936cpe": "Slovakia Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d961cpe": "Slovenia Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"d184cpe": "Spain Compensation per Employee nsa"}, inplace=True)
hv_tb_eu_004_001_m.columns = [col.replace(' Compensation per Employee nsa', '') for col in hv_tb_eu_004_001_m.columns]
eu_m_tickers = hv_tb_eu_004_001_m.columns.tolist()
hv_tb_eu_004_001_m0 = hv_tb_eu_004_001_m.copy()
print(hv_tb_eu_004_001_m.tail(2))

for x in range(len(eu_m_tickers)):
    variable = str(eu_m_tickers[x])
    hv_tb_eu_004_001_m0[variable] = hv_tb_eu_004_001_m0[variable].pct_change(4).multiply(100).round(3)


hv_tb_eu_004_001_m0 = hv_tb_eu_004_001_m0.round(1)
hv_tb_eu_004_001_m0_compensation = hv_tb_eu_004_001_m0.copy()

parameter_w1 = 0.5
table_w_simulation = hv_tb_eu_004_001_m0.copy()
table_w_simulation = table_w_simulation.tail(1)
table_w_simulation = table_w_simulation.transpose()
table_w_sc = table_w_simulation.copy()
# table_w_simulation = table_w_simulation.reindex()
# table_w_sc = table_w_simulation.copy()
# print(table_w_sc)
table_w_simulation.index.names = ['Variable']
table_w_simulation.columns = ["Weight"]
# print(table_w_simulation)
table_w_simulation = table_w_simulation.sort_values('Weight')
table_w_simulation["Weight"] = table_w_simulation["Weight"]
# table_w_simulation = table_w_simulation[table_w_simulation["Weight"] >= parameter_w1]
# hv_tb_eu_004_001_m = hv_tb_eu_004_001_m.tail(1)
#hv_tb_eu_004_001_m=hv_tb_eu_004_001_m.tail(1)



plt.figure(figsize=(15, 7))
bars= plt.bar(table_w_simulation.index, table_w_simulation ["Weight"], color="orange")
plt.ylabel('', size=7)
plt.xlabel('', size=7)
plt.tick_params(labelsize=16)
#plt.title(str("PER_"+str(ccy)+"_"+str(time_w)), size-ti_size)
plt.grid(axis='both', alpha=.3)
plt.title("EA Compensation per Employee YY nsa", size=15)

for bar in bars:         
    plt.text(bar.get_x() + bar.get_width() / 2, #x-coordinate position of text, adjusted to be centered in the bar
            bar.get_height(), #y-coordinate position of text
            f'{bar.get_height():.0f}', # Text to be displayed; can format the number here
            size=20,
            ha='center', #Center alignment of text horizontally
            va='bottom') # Bottom alignment of text vertically
plt.xticks (rotation=30, ha='right')                                                
plt.savefig("hv_tb_eu_023_001_m_g_001.png", bbox_inches='tight')
plt.savefig("hv_tb_eu_023_001_m_g_001a.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()

hv_tb_eu_004_001_m0=hv_tb_eu_004_001_m.copy()
hv_tb_eu_004_001_m0=hv_tb_eu_004_001_m0.round(0)
parameter_w1=0.5
table_w_simulation=hv_tb_eu_004_001_m0.copy()
table_w_simulation=table_w_simulation.tail(1)
table_w_simulation= table_w_simulation.transpose()
table_w_sc=table_w_simulation.copy()
#table_w_simulation = table_w_simulation.reindex()
#table_w_sc=table_w_simulation.copy()
#print(table_w_sc)
table_w_simulation.index.names = ['Variable']
table_w_simulation.columns=["Weight"]
#print(table_w_simulation)
table_w_simulation = table_w_simulation.sort_values('Weight')

table_w_simulation["Weight"] = table_w_simulation ["Weight"]
#table_w_simulation = table_w_simulation[table_w_simulation["Weight"]>=parameter_w1]
#hv_tb_eu_004_001_m = hv_tb_eu_004_001_m.tail(1)
plt.figure(figsize=(15, 7))
bars = plt.bar(table_w_simulation.index, table_w_simulation["Weight"], color="blue")
plt.ylabel('', size=7)
plt.xlabel('', size=7)
plt.tick_params(labelsize=16)
#plt.title(str("PER_"+str(ccy)+"_"+str(time_w)), size-ti_size)
plt.grid(axis='both', alpha=.3)
plt.title("EA Compensation per Employee nsa", size=15)
for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2,  # x-coordinate position of text, adjusted to be centered in the bar
             bar.get_height(),  # y-coordinate position of text
             f'{bar.get_height():.0f}',  # Text to be displayed; can format the number here
             size=20,
             ha='center',  # Center alignment of text horizontally
             va='bottom')  # Bottom alignment of text vertically
plt.xticks(rotation=30, ha='right')
plt.savefig("hv_tb_eu_023_001_m_g_002.png", bbox_inches='tight')
plt.savefig("hv_tb_eu_023_001_m_g_002a.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()





### 001  TABLE Avg weekly hours worked hours<a id="title_page"></a

#hv_tb_eu_024_001_m_g_001
# AVERAGE WEEKLY HOURS
eu_m_tickers = ["n122etzt", "n124etzt", "n423etzt", "n939etzt", "n172etzt", "n132etzt",
                "n134etzt", "n174etzt", "n178etzt", "n136etzt", "n941etzt", "n946etzt",
                "n137etzt","n181etzt", "n138etzt", "n182etzt", "n936etzt", "n961etzt", "n184etzt"]
#print("getting from api")
hv_tb_eu_004_001_m = Haver.data(eu_m_tickers, "EULABOR", dates=True)
#print(hv_tb_eu_004_001_m)
#print(hv_tb_eu_004_001_m.columns)
print("renaming")
hv_tb_eu_004_001_m.rename(columns={"n997etzt": "EU27 Avg weekly hours worked hours nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"n025etzt": "EA20 Avg weekly hours worked hours nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"n122etzt": "Austria Avg weekly hours worked hours nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"n124etzt": "Belgium Avg weekly hours worked hours nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"n423etzt": "Cyprus Avg weekly hours worked hours nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"n939etzt": "Estonia Avg weekly hours worked hours nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"n172etzt": "Finland Avg weekly hours worked hours nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"n132etzt": "France Avg weekly hours worked hours nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"n134etzt": "Germany Avg weekly hours worked hours nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"n174etzt": "Greece Avg weekly hours worked hours nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"n178etzt": "Ireland Avg weekly hours worked hours nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"n136etzt": "Italy Avg weekly hours worked hours nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"n941etzt": "Latvia Avg weekly hours worked hours nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"n946etzt": "Lithuania Avg weekly hours worked hours nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"n137etzt": "Luxembourg Avg weekly hours worked hours nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"n181etzt": "Malta Avg weekly hours worked hours nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"n138etzt": "Netherlands Avg weekly hours worked hours nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"n182etzt": "Portugal Avg weekly hours worked hours nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"n936etzt": "Slovakia Avg weekly hours worked hours nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"n961etzt": "Slovenia Avg weekly hours worked hours nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"n184etzt": "Spain Avg weekly hours worked hours nsa"}, inplace=True)
#print(hv_tb_eu_004_001_m)
hv_tb_eu_004_001_m.columns = [col.replace(' Avg weekly hours worked hours nsa', '') for col in hv_tb_eu_004_001_m.columns]

#### year on year
## year on year
eu_m_tickers=hv_tb_eu_004_001_m.columns.tolist()
hv_tb_eu_004_001_m_yy=hv_tb_eu_004_001_m.copy()

for x in range(len(eu_m_tickers)):
    variable=str(eu_m_tickers[x])
    hv_tb_eu_004_001_m_yy [str(variable)]= hv_tb_eu_004_001_m_yy [str(variable)].pct_change(4).multiply(100).round(3)

### 001  TABLE Avg weekly hours worked hours<a id="title_page"></a

hv_tb_eu_004_001_m_yy=hv_tb_eu_004_001_m_yy.round(1)
hv_tb_eu_004_001_m_yy_hours=hv_tb_eu_004_001_m_yy.copy()
parameter_w1=0.5
table_w_simulation=hv_tb_eu_004_001_m_yy.copy()
table_w_simulation=table_w_simulation.tail(1)
table_w_simulation = table_w_simulation.transpose()
table_w_sc=table_w_simulation.copy()
#table_w_simulation = table_w_simulation.reindex()
#table_w_sc=table_w_simulation.copy()
#print(table_w_sc)
table_w_simulation.index.names = ['Variable']
table_w_simulation.columns=["Weight"]
#print(table_w_simulation)
table_w_simulation=table_w_simulation.sort_values('Weight')
table_w_simulation["Weight"]=table_w_simulation["Weight"]
#table_w_simulation=table_w_simulation[table_w_simulation["weight"]>=parameter_w1]

#hv_tb_eu_004_001_m=hv_tb_eu_004_001_m.tail(1)
#hv_tb_eu_004_001_m=hv_tb_eu_004_001_m.tail(1)



plt.figure(figsize=(15, 7))
bars= plt.bar(table_w_simulation.index, table_w_simulation ["Weight"], color="orange")
plt.ylabel('', size=7)
plt.xlabel('', size=7)
plt.tick_params(labelsize=16)
#plt.title(str("PER_"+str(ccy)+"_"+str(time_w)), size-ti_size)
plt.grid(axis='both', alpha=.3)
plt.title("EA Avg weekly hours worked hours YY nsa", size=15)

for bar in bars:        
    plt.text(bar.get_x() + bar.get_width() / 2, #x-coordinate position of text, adjusted to be centered in the bar
        bar.get_height(), #y-coordinate position of text
        f'{bar.get_height():.1f}', # Text to be displayed; can format the number here
        size=20,ha='center',va='bottom') # Bottom alignment of text vertically

plt.xticks (rotation=30, ha='right')
plt.savefig("hv_tb_eu_024_001_m_g_001.png", bbox_inches='tight')
plt.savefig("hv_tb_eu_024_001_m_g_001a.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()

### 001  TABLE Avg weekly hours worked hours graph levelm <a id="title_page"></a

########## Level
parameter_w1=0.5
table_w_simulation=hv_tb_eu_004_001_m.copy()
table_w_simulation=table_w_simulation.tail(1)
table_w_simulation = table_w_simulation.transpose()
table_w_sc=table_w_simulation.copy()
#table_w_simulation = table_w_simulation.reindex()
#toble_w_sc=table_w_simulation.copy()
#print(table_w_sc)
table_w_simulation.index.names = ['Variable']
table_w_simulation.columns=["Weight"]
#print(table_w_simulation)
table_w_simulation=table_w_simulation.sort_values('Weight')
table_w_simulation ["Weight"]=table_w_simulation ["Weight"]
#table_w_simulation=table_w_simulation[table_w_simulation["Weight"]>=parameter_w1]
#hv_tb_eu_004_001_m=hv_tb_eu_004_001_m.tail(1)
plt.figure(figsize=(15, 7))
bars= plt.bar(table_w_simulation.index, table_w_simulation["Weight"], color="blue")
plt.ylabel('', size=7)
plt.xlabel('', size=7)
plt.tick_params(labelsize=16)
#plt.title(str("PER_"+str(ccy)+"_"+str(time_w)), size-ti_size)
plt.grid(axis='both', alpha=.3)
plt.title("EA Avg weekly hours worked hours nsa", size=15)
for bar in bars:         
    plt.text(bar.get_x() + bar.get_width() / 2, #x-coordinate position of text, adjusted to be centered in the bar
             bar.get_height(), #y-coordinate position of text
             f'{bar.get_height():.1f}', #Text to be displayed; con format the number here
             size=20,
             ha='center', 
             va='bottom') # Bottom alignment of text vertically
plt.xticks (rotation=30, ha='right')          
plt.savefig("hv_tb_eu_024_001_m_g_002a.png", bbox_inches='tight')
plt.savefig("hv_tb_eu_024_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()



### 001  TABLE Avg weekly hours worked hours graph levelm  Scatterplot

hv_tb_eu_004_001_m0_compensation=hv_tb_eu_004_001_m0_compensation.tail(1)
hv_tb_eu_004_001_m0_compensation=hv_tb_eu_004_001_m0_compensation.transpose()
hv_tb_eu_004_001_m0_compensation.index.names = ['Variable']
print(hv_tb_eu_004_001_m0_compensation)
#print(hv_tb_eu_004_001_m0_compensation)
hv_tb_eu_004_001_m_yy_hours=hv_tb_eu_004_001_m_yy_hours.tail(1)
hv_tb_eu_004_001_m_yy_hours=hv_tb_eu_004_001_m_yy_hours.transpose()
hv_tb_eu_004_001_m_yy_hours.index.names = ['Variable']
#print(hv_tb_eu_004_001_m_yy_hours)
str1="EU Growth Compensation YY"
str2="EU Growth Hours worked YY"
concatenated_df = pd.concat([hv_tb_eu_004_001_m0_compensation, 
                             hv_tb_eu_004_001_m_yy_hours], axis=1)
concatenated_df.columns=[str(str1), str(str2)]
df=concatenated_df.copy()
print(df)

plt.figure(figsize=(7, 7))
plt.scatter(df[str(str1)], df [str(str2)], color='blue')

for i in range(len(df)): 
    plt.text(df[str(str1)][i],
             df [str(str2)][i], df.index[i],
             fontsize=11, ha='left')

mid_x = (df[str(str1)].max() + df[str(str1)].min()) / 2   
mid_y = (df[str(str2)].max() + df[str(str2)].min()) / 2  
plt.axvline(x=mid_x, color='blue', linestyle='--', linewidth=1)
plt.axhline(y=mid_y, color='blue', linestyle='--', linewidth=1)
plt.xlabel(str(str1))
plt.ylabel(str(str2))
plt.title(str(str(str1)+' (X axis) vs \n '+str(str2) +' (Y axis)'))
plt.grid(True)
plt.tight_layout()
#Save the scatter plot image
plt.savefig('hv_tb_eu_025_001_m_g_001.png')
plt.savefig('hv_tb_eu_025_001_m_g_001a.png')
plt.show()
plt.close()
plt.close('all')
plt.clf()
plt.cla()
##

### 001  MUICP Overall<a id="title_page"></a

##### Inflation detail
### Inflation

#Persistent and Common Component of Inflation or PCCI

eu_m_tickers =["h023h", "h023hoeu", "h023hoet",
               "h023hoef", "h023hoea", "h023hct",
               "h023hg", "h023hs", "h023hsl",
               "h023hslx", "h023hslr",
               "p023h", "p023hoeu", "p023hoet",
               "p023hope","p023hop", "p023hoef",
               "p023hoea","p023hct", "p023hg","p023hs",
               "p023hsl", "p023hslx", "p023hslr"]
print("getting from api")
hv_tb_eu_004_001_m=Haver.data(eu_m_tickers, "EUDATA", dates=True)
print(hv_tb_eu_004_001_m)
#print(hv_tb_eu_004_001_m.columns)

hv_tb_eu_004_001_m.rename(columns={"h023h": "EA11-20 MUICP Overall hicp sa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"h023hoeu": "EA11-20 MUICP hicp ex energy unprocessed food sa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"h023hoet":"EA11-20 MUICP hicp ex tobacco sa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"h023hoef": "EA11-20 MUICP hicp ex energy food alcohol tobacco sa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"h023hoea":"EA11-20 MUICP hicp ex energy seasonal food sa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"h023hct": "EA11-20 MUICP hicp constant tax rate sa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"h023hg":"EA11-20 MUICP goods sa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"h023hs": "EA11-20 MUICP services sa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"h023hsl":"EA11-20 MUICP core services sa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"h023hslx": "EA11-20 MUICP core services ex health recreation package holidays sa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"h023hslr": "EA11-20 MUICP core services ex recreation package holidays sa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023h":"EA11-20 MUICP Overall hicp nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hoeu":"EA11-20 MUICP hicp ex energy unprocessed food nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hoet":"EA11-20 MUICP hicp ex tobacco nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hope":"EA11-20 MUICP hicp ex administered prices nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hop":"EA11-20 MUICP hicp administered prices nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hoef":"EA11-20 MUICP hicp ex energy food alcohol tobacco nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hoea":"EA11-20 MUICP hicp ex energy seasonal food nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hct":"EA11-20 MUICP hicp constant tax rate nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hg":"EA11-20 MUICP goods nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hs":"EA11-20 MUICP services nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hsl":"EA11-20 MUICP core services nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hslx":"EA11-20 MUICP core services ex health recreation package holidays nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hslr":"EA11-20 MUICP core services ex recreation package holidays nsa"}, inplace=True)






eu_m_tickers=hv_tb_eu_004_001_m.columns.tolist()
for x in range(len(eu_m_tickers)):
    variable=str(eu_m_tickers[x]) 
    hv_tb_eu_004_001_m[str(variable)]= hv_tb_eu_004_001_m[str(variable)].pct_change(12).multiply(100).round(1)

###### heatmap
#####adad simmualtion and montrecalros resutis with the gtrpahs s.




### 001  MUICP Overall heeatmap <a id="title_page"></a

n_time=60
#size figure

#wide
size1=37
#height
size2=18
##heatmaps inside
font_size_h=12
number_vbs=24
#x size Label axis
x_sizel=17
#axis 2 Label
x2_sizel=x_sizel-6
xlabel_size=18
### axes-1 Lael sie dates
axes_1label=12
title_s=30
df1=hv_tb_eu_004_001_m.copy()
df1=df1.tail(48)
df_range=df1.copy()
df1.index=df1.index.date
df1=df1.tail(n_time)
df1=df1.transpose()
df1.index.names = ['Variable']
num_rows =df1.shape[0]
for x in range(num_rows):
    locals()[str(str("data_r") + str(x))] = pd.DataFrame([df1.iloc[x]])

for x in range(num_rows):
    locals()[str(str("vmin_") + str(x))] = df_range.iloc[:, x].min()
    locals()[str(str("vmax_") + str(x))] = df_range.iloc[:, x].max()

print(vmin_0)
print(vmax_0)

# data
# df=pd.DataFrame(data)
np.random.random((10, 12))
red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")
reversed_red_to_blue = list(reversed(reversed_red_to_blue))
# sns.color_palette("coolwarm", as_cmap=True)
fig, axes = plt.subplots(number_vbs, 1,
                         figsize=(size1, size2),
                         sharex=True,)

sns.heatmap(data_r0, cmap=red_to_blue, annot=True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r1, cmap=red_to_blue, annot=True, ax=axes[1], cbar=False, vmin=vmin_1, vmax=vmax_1, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r2, cmap=red_to_blue, annot=True, ax=axes[2], cbar=False, vmin=vmin_2, vmax=vmax_2, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r3, cmap=red_to_blue, annot=True, ax=axes[3], cbar=False, vmin=vmin_3, vmax=vmax_3, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r4, cmap=red_to_blue, annot=True, ax=axes[4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r5, cmap=red_to_blue, annot=True, ax=axes[5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r6, cmap=red_to_blue, annot=True, ax=axes[6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r7, cmap=red_to_blue, annot=True, ax=axes[7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r8, cmap=red_to_blue, annot=True, ax=axes[8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r9, cmap=red_to_blue, annot=True, ax=axes[9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r10, cmap=red_to_blue, annot=True, ax=axes[10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r11, cmap=red_to_blue, annot=True, ax=axes[11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r12, cmap=red_to_blue, annot=True, ax=axes[12], cbar=False, vmin=vmin_12, vmax=vmax_12, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r13, cmap=red_to_blue, annot=True, ax=axes[13], cbar=False, vmin=vmin_13, vmax=vmax_13, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r14, cmap=red_to_blue, annot=True, ax=axes[14], cbar=False, vmin=vmin_14, vmax=vmax_14, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})

sns.heatmap(data_r15, cmap=red_to_blue, annot=True, ax=axes[15], cbar=False, vmin=vmin_15, vmax=vmax_15, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r16, cmap=red_to_blue, annot=True, ax=axes[16], cbar=False, vmin=vmin_16, vmax=vmax_16, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r17, cmap=red_to_blue, annot=True, ax=axes[17], cbar=False, vmin=vmin_17, vmax=vmax_17, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r18, cmap=red_to_blue, annot=True, ax=axes[18], cbar=False, vmin=vmin_18, vmax=vmax_18, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r19, cmap=red_to_blue, annot=True, ax=axes[19], cbar=False, vmin=vmin_19, vmax=vmax_19, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r20, cmap=red_to_blue, annot=True, ax=axes[20], cbar=False, vmin=vmin_20, vmax=vmax_20, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r21, cmap=red_to_blue, annot=True, ax=axes[21], cbar=False, vmin=vmin_21, vmax=vmax_21, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r22, cmap=red_to_blue, annot=True, ax=axes[22], cbar=False, vmin=vmin_22, vmax=vmax_22, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r23, cmap=red_to_blue, annot=True, ax=axes[23], cbar=False, vmin=vmin_23, vmax=vmax_23, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to Blue'})

n=0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_sizel, rotation=0)
    locals() [str(str("axes_t")+str(n))]= ax.twinx()    
    locals()[str(str("axes_t")+str(n))].set_yticklabels(ax.get_yticklabels(), fontsize=x2_sizel, rotation=0,va="center")
    #ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    n=n+1


# axes[0].set_xticks([])
# axes[1].set_xticks([])
# xes[1].set_xticks([])
axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=axes_1label, size=0)
# axes[-1].set_xticklabels(axis="x", which="both", Length=0, Labelrotation=45)
# .set_xticks([])
fig.suptitle("Euro Area Inflation Monthly Dashboard", fontsize=title_s)
plt.figtext(0.5, 0.01, "Euro Area Inflation Monthly Dashboard", fontsize=title_s, ha="center")
plt.subplots_adjust(hspace=-.1)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig('hv_tb_eu_027_001_m_g_hh.png', bbox_inches='tight', dpi=300)
plt.savefig('hv_tb_eu_027_001_m_g_hh1.png', bbox_inches='tight', dpi=300)
plt.show()
plt.close()

# hv_tb_eu_021_001_m_g_hh

##### Inflation detail
##### Inflation detail
##### Inflation detail
##### Inflation detail

# print("tickera")
                                                                                                                                                                  
                                                                                                                                                                  
                                                                                                                                                                



### 001  EA11-20 hicp trimmed mean<a id="title_page"></a


######## pending s

###\\\ CPI DETAIL 

#print("tickera")
#hv_tb_eu_026_001_m_g_001
#Harmonized Indexes of Consumer Prices
#Euro Area Trimmed Mean HICP

#"Monthly, Not Seasonally Adjusted

#Overall HICP (year/year % change)
eu_m_tickers =["p023hm05","p023hm10", "p023hm15","p023hm20",
               "p023hm25","p023hm30", "p023hm35","p023hm40",
               "p023hm45", "p023hm50", "p023rmed"]
#print("getting from api")
hv_tb_eu_004_001_m=Haver.data(eu_m_tickers, "EUDATA", dates=True)
print(hv_tb_eu_004_001_m)
#print(hv_tb_eu_004_001_m.columns)
#print("renaming") 
hv_tb_eu_004_001_m.rename(columns={"p023hm05":"EA11-20 hicp trimmed mean 5% nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hm10":"EA11-20 hicp trimmed mean 10% nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hm15":"EA11-20 hicp trimmed mean 15% nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hm20":"EA11-20 hicp trimmed mean 20% nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hm25":"EA11-20 hicp trimmed mean 25% nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hm30":"EA11-20 hicp trimmed mean 30% nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hm35":"EA11-20 hicp trimmed mean 35% nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hm40":"EA11-20 hicp trimmed mean 40% nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hm45":"EA11-20 hicp trimmed mean 45% nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023hm50":"EA11-20 hicp trimmed mean 50% nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023rmed": "EA11-20 hicp weighted median nsa"}, inplace=True)
#hv_tb_eu_004_001_m.columns = [col.replace('ur [15-64] quarterly nsa', '') for col in hv_tb_eu_004_001_m.columns]
#eu_m_tickers=hv_tb_eu_004_001_m.columns.tolist()
#hv_tb_eu_004_001_m0=hv_tb_eu_004_001_m.copy()

### 001  EA11-20 hicp trimmed mean heatmpa <a id="title_page"></a

n_time=60
#size figure

#wide
size1=37
#height
size2=18
##heatmaps inside
font_size_h=12
number_vbs=11
#x size Label axis
x_sizel=17
#axis 2 Label
x2_sizel=x_sizel-6
xlabel_size=18
### axes-1 Lael sie dates
axes_1label=12
title_s=30
df1=hv_tb_eu_004_001_m.copy()
df1=df1.tail(48)
df_range=df1.copy()
df1.index=df1.index.date
df1=df1.tail(n_time)
df1=df1.transpose()
df1.index.names = ['Variable']
num_rows =df1.shape[0]
for x in range(num_rows):
    locals()[str(str("data_r") + str(x))] = pd.DataFrame([df1.iloc[x]])

for x in range(num_rows):
    locals()[str(str("vmin_") + str(x))] = df_range.iloc[:, x].min()
    locals()[str(str("vmax_") + str(x))] = df_range.iloc[:, x].max()

print(vmin_0)
print(vmax_0)

# data
# df=pd.DataFrame(data)
np.random.random((10, 12))
red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")
reversed_red_to_blue = list(reversed(reversed_red_to_blue))
# sns.color_palette("coolwarm", as_cmap=True)
fig, axes = plt.subplots(number_vbs, 1,
                         figsize=(size1, size2),
                         sharex=True,)

sns.heatmap(data_r0, cmap=red_to_blue, annot=True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r1, cmap=red_to_blue, annot=True, ax=axes[1], cbar=False, vmin=vmin_1, vmax=vmax_1, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r2, cmap=red_to_blue, annot=True, ax=axes[2], cbar=False, vmin=vmin_2, vmax=vmax_2, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r3, cmap=red_to_blue, annot=True, ax=axes[3], cbar=False, vmin=vmin_3, vmax=vmax_3, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r4, cmap=red_to_blue, annot=True, ax=axes[4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r5, cmap=red_to_blue, annot=True, ax=axes[5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r6, cmap=red_to_blue, annot=True, ax=axes[6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r7, cmap=red_to_blue, annot=True, ax=axes[7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r8, cmap=red_to_blue, annot=True, ax=axes[8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r9, cmap=red_to_blue, annot=True, ax=axes[9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r10, cmap=red_to_blue, annot=True, ax=axes[10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
#sns.heatmap(data_r11, cmap=red_to_blue, annot=True, ax=axes[11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g',
#            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
#sns.heatmap(data_r12, cmap=red_to_blue, annot=True, ax=axes[12], cbar=False, vmin=vmin_12, vmax=vmax_12, fmt='g',
#            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
#sns.heatmap(data_r13, cmap=red_to_blue, annot=True, ax=axes[13], cbar=False, vmin=vmin_13, vmax=vmax_13, fmt='g',
#            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})

n=0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_sizel, rotation=0)
    locals() [str(str("axes_t")+str(n))]= ax.twinx()    
    locals()[str(str("axes_t")+str(n))].set_yticklabels(ax.get_yticklabels(), fontsize=x2_sizel, rotation=0,va="center")
    #ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    n=n+1


# axes[0].set_xticks([])
# axes[1].set_xticks([])
# xes[1].set_xticks([])
axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=axes_1label, size=0)
# axes[-1].set_xticklabels(axis="x", which="both", Length=0, Labelrotation=45)
# .set_xticks([])
fig.suptitle("Euro Area HICP  Trimmed Inflation Monthly Dashboard ", fontsize=title_s)
plt.figtext(0.5, 0.01, "Euro Area HICP Trimmed Inflation Monthly Dashboard ", fontsize=title_s, ha="center")
plt.subplots_adjust(hspace=-.1)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig('hv_tb_eu_026_001_m_g_hh.png', bbox_inches='tight', dpi=300)
plt.savefig('hv_tb_eu_026_001_m_g_hh1.png', bbox_inches='tight', dpi=300)
plt.show()
plt.close()

# hv_tb_eu_021_001_m_g_hh

##### Inflation detail
##### Inflation detail
##### Inflation detail
##### Inflation detail

# print("tickera")
                                                                                                                                                                  
                           

### 001  EA11-20 hicp trimmed mean graph <a id="title_page"></a

l1=2
s2=2
df1=hv_tb_eu_004_001_m.copy()
df1=df1.tail(60)
list_c=df1.columns.tolist()
print("Charts")
title_r0="EA11-20 hicp trimmed mean yy nsa"
title_r=title_r0
y_label="Index %"
x_label=title_r

g1=df1.copy()
fig, ax = plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax,y=[list_c[0]], color="black",
        linewidth= l1, linestyle='-',
        marker="P", markersize=s2)
g1.plot(kind='line', ax=ax,y=[list_c[1]], color="black",
        linewidth= l1, linestyle='-',
        marker="P", markersize=s2)
g1.plot(kind="line", ax=ax,y=[list_c[2]], color="black",
        linewidth= l1, linestyle='-',
        marker='>', markersize=s2)
g1.plot(kind='line', ax=ax,y=[list_c[3]], color="black",
        linewidth= l1, linestyle='-',
        marker='>', markersize=s2)
g1.plot(kind='line', ax=ax,y=[list_c[4]], color="brown",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,y=[list_c[5]], color="brown",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,y=[list_c[6]], color="darkred",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind="line", ax=ax, y=[list_c[7]], color="darkred",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,y=[list_c[8]], color="red",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)


#plt.hline(0, color="black", lw=1, linestyle = 'dashed', alpha=0.75)

#for series_name in list_c[0:9]:
#    last_y_value = g1[series_name][-1]
#    print(last_y_value)
#    print(series_name)
#    plt.annotate(f"{series_name} {last_y_value}", 
#                 xy=(g1.index.max(), last_y_value), 
#                 xytext=(30, 0), 
#                 textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle='->'))

plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)

ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

plt.text(0.15, 0.15, str(owner), 
         fontsize=25, 
         color="gray", 
         alpha=0.5, 
         ha='center', 
         va='center', 
         rotation=30, 
         transform=plt.gca().transAxes)

plt.savefig("hv_tb_eu_026_001_m_g_001.png", bbox_inches='tight')
plt.close()

plt.close('all')
plt.clf()
plt.cla()

del g1
del df1
del list_c
del fig
del ax
del ax2

l1=2
s2=2
df1=hv_tb_eu_004_001_m.copy()
df1=df1.tail(24)
list_c=df1.columns.tolist()
print("Charts")
title_r0="EA11-20 hicp trimmed mean yy nsa"
title_r=title_r0
y_label="Index %"
x_label=title_r

g1=df1.copy()
fig, ax = plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax,y=[list_c[0]], color="black",
        linewidth= l1, linestyle='-',
        marker="P", markersize=s2)
g1.plot(kind='line', ax=ax,y=[list_c[1]], color="black",
        linewidth= l1, linestyle='-',
        marker="P", markersize=s2)
g1.plot(kind="line", ax=ax,y=[list_c[2]], color="black",
        linewidth= l1, linestyle='-',
        marker='>', markersize=s2)
g1.plot(kind='line', ax=ax,y=[list_c[3]], color="black",
        linewidth= l1, linestyle='-',
        marker='>', markersize=s2)
g1.plot(kind='line', ax=ax,y=[list_c[4]], color="brown",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,y=[list_c[5]], color="brown",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,y=[list_c[6]], color="darkred",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind="line", ax=ax, y=[list_c[7]], color="darkred",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,y=[list_c[8]], color="red",
        linewidth= l1, linestyle='-',
        marker='o', markersize=s2)


#plt.hline(0, color="black", lw=1, linestyle = 'dashed', alpha=0.75)

#for series_name in list_c[0:9]:
#    last_y_value = g1[series_name][-1]
#    print(last_y_value)
#    print(series_name)
#    plt.annotate(f"{series_name} {last_y_value}", 
#                 xy=(g1.index.max(), last_y_value), 
#                 xytext=(30, 0), 
#                 textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle='->'))

plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)

ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

plt.text(0.15, 0.15, str(owner), 
         fontsize=25, 
         color="gray", 
         alpha=0.5, 
         ha='center', 
         va='center', 
         rotation=30, 
         transform=plt.gca().transAxes)

plt.savefig("hv_tb_eu_026_001_m_g_002.png", bbox_inches='tight')
plt.close()

plt.close('all')
plt.clf()
plt.cla()

del g1
del df1
del list_c
del fig
del ax
del ax2



















### infation

### 001  EA11-20 pcci overall <a id="title_page"></a

### infation
#Persistent and Common Component of Inflation or PCCI
eu_m_tickers=["p023rcci", "p023rccx", "p023rcix",]
print("getting from api")
hv_tb_eu_004_001_m=Haver.data(eu_m_tickers, "EUDATA", dates=True)
#print(hv_tb_eu_004_001_m)
#print(hv_tb_eu_004_001_m.columns)
#Persistent and Common Component of Inflation or PCCI
print("renaming")    
hv_tb_eu_004_001_m.rename(columns={"p023rcci":"EA11-20 pcci overall inflation nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023rccx": "EA11-20 pcci inflation ex food energy nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p023rcix":"EA11-20 pcci inflation ex energy nsa"}, inplace=True)
l1=2
s2=2

### 001  EA11-20 pcci overall heatmap





### 001  EA11-20 pcci overall graph

df1=hv_tb_eu_004_001_m.copy()
df1=df1.tail(60)
list_c=df1.columns.tolist()
print("Charts")
title_r0="EA11-20 Persistent and Common Component of Inflation "
title_r=title_r0
y_label="Index %"
x_label=title_r
g1=df1.copy()
fig,ax =plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_c[0]], color="red",
        linewidth= l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=[list_c[1]], color="blue",
        linewidth= l1, linestyle='-',
        marker='s', markersize=s2)
g1.plot(kind="line", ax=ax,y=[list_c[2]], color="green",
        linewidth= l1, linestyle='-',
        marker=">", markersize=s2)
#plt.axhline(0, color="black", Lw=1, Linestyle dashed", alpha=8.75)
# for series_name in list_c[0:9]:
#     last_y_value = g1[series_name][-1]
#     print(last_y_value)
#     print(series_name)
#     plt.annotate(f'{series_name} {last_y_value}',
#                  xy=(g1.index.max(), last_y_value),
#                  xytext=(30, 0),
#                  textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle="->"))

plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)

ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

plt.text(0.15, 0.15, str(owner),
         fontsize=25,
         color="gray",
         alpha=0.5,
         ha='center',
         va='center',
         rotation=30,
         transform=plt.gca().transAxes)

plt.savefig("hv_tb_eu_026_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1

#hv_tb_eu_026_002_m_g_002
#hv_tb_eu_026_002_m_g_002
df1=hv_tb_eu_004_001_m.copy()
df1=df1.tail(24)
list_c=df1.columns.tolist()
print("Charts")
title_r0="EA11-20 Persistent and Common Component of Inflation"
title_r=title_r0
y_label="Index %"
x_label=title_r
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=[list_c[0]], color="red",
        linewidth= l1, linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=[list_c[1]], color="blue",
        linewidth= l1, linestyle='-',
        marker='s', markersize=s2)
g1.plot(kind="line", ax=ax,y=[list_c[2]], color="green",
        linewidth= 11, linestyle='-',
        marker=">", markersize=s2)
#plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)

#for series_name in list_c[0:9]:
#    last_y_value = g1[series_name][-1]
#    print(series_name)
#    print(last_y_value)

#    plt.annotate(f'{series_name} {last_y_value}',
#                 xy=(g1.index.max(), last_y_value),
#                 xytext=(30, 0),
#                 textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.text(0.15, 0.15, str(owner),
                   fontsize=25,
                   color="gray",
                   alpha=0.5,
                   ha='center',
                   va='center',
                   rotation=30,
                   transform=plt.gca().transAxes)
plt.savefig("hv_tb_eu_026_002_m_g_002.png", bbox_inches='tight')
plt.close()

plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2


### 001  EA11-20 INFLATION CONTRIBUTION  stacked chart <a id="title_page"></a

#hv_tb_eu_028_001_m_g_001
# Contribution Inflation stacked bar chart.
eu_m_tickers=["c023h11", "c023h12", "c023h21","c023h22",
"c023h31","c023h32","c023h41", "c023h43",
"c023h44","c023h45","c023h51",
"c023h52","c023h53","c023h54",
"c023h55","c023h56","c023h61",
"c023h62","c023h63",
"c023h71","c023h72","c023h73","c023h81","c023h8x", "c023h91",
"c023h92","c023h93","c023h94", "c023h95",
"c023h96", "c023h10",
"c023hr1", "c023hr2", "c023hm1", "c023hm3",
"c023hm4","c023hm5","c023hm6","c023hm7"]

print("getting from api")
hv_tb_eu_004_001_m=Haver.data(eu_m_tickers, "EUDATA", dates=True)

#print(hv_tb_eu_004_001_m)
#print(hv_tb_eu_004_001_m.columns)

##foods
hv_tb_eu_004_001_m.rename(columns={"c023h11":"EA11-20 Food contribution nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h12":"EA11-20 Nonalcoholic beverage contribution nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h21":"EA11-20 Alcoholic beverages contribution nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h22":"EA11-20 Tobacco contribution nsa"}, inplace=True)

###clothing
hv_tb_eu_004_001_m.rename(columns={"c023h31":"EA11-20 Clothing contribution nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h32":"EA11-20 Footwear contribution nsa"}, inplace=True)
### housing

hv_tb_eu_004_001_m.rename(columns={"c023h41":"EA11-20 Actual rental housing contribution nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h43":"EA11-20 Maintenance repair dwelling contribution nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h44": "EA11-20 Water supply contribution nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h45":"EA11-20 Electricity gas fuels contribution nsa"}, inplace=True)

### furnishings
hv_tb_eu_004_001_m.rename(columns={"c023h51":"EA11-20 Furniture furnishings contribution nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h52":"EA11-20 household textiles contribution nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h53": "EA11-20 household appliances contribution nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h54":"EA11-20 Glassware tableware contribution nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h55":"EA11-20 Tools house contribution nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h56":"EA11-20 Goods service hh maintenance nsa"}, inplace=True)

hv_tb_eu_004_001_m.rename(columns={"c023h61":"EA11-20 Medical products nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h62":"EA11-20 Outpatient services nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h63":"EA11-20 Hospital services nsa"}, inplace=True)

hv_tb_eu_004_001_m.rename(columns={"c023h71":"EA11-20 Purchase vehicles nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h72":"EA11-20 Operation personal transport nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h73":"EA11-20 Transport services nsa"}, inplace=True)

hv_tb_eu_004_001_m.rename(columns={"c023h81":"EA11-20 Postal services nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h8x":"EA11-20 Telephone equipment nsa"}, inplace=True)

hv_tb_eu_004_001_m.rename(columns={"c023h91":"EA11-20 Audiovisual equipment nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h92":"EA11-20 Other durable recreation nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h93":"EA11-20 Other recreational items nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h94":"EA11-20 Recreational cultural services nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h95":"EA11-20 Newspapers nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023h96":"EA11-20 Package holidays nsa"}, inplace=True)

####education
hv_tb_eu_004_001_m.rename(columns={"c023h10": "EA11-20 education nsa"}, inplace=True)

### restaurants
hv_tb_eu_004_001_m.rename(columns={"c023hr1":"EA11-20 catering services nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023hr2":"EA11-20 accommodation services nsa"}, inplace=True)

###miscellanoous goods services
hv_tb_eu_004_001_m.rename(columns={"c023hm1":"EA11-20 personal care nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023hm3":"EA11-20 personal effects nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023hm4": "EA11-20 social protection nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023hm5":"EA11-20 insurance nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023hm6": "EA11-20 financial services nsa"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"c023hm7":"EA11-20 other services nsa"}, inplace=True)
hv_tb_eu_004_001_m=hv_tb_eu_004_001_m.tail(60)
df=hv_tb_eu_004_001_m.copy()
# Plotting

colors = ['green', 'green', 'green', 'green',
          'magenta', 'magenta',
          'orange', 'orange', 'orange', 'orange',
          'navy', 'navy', 'navy', 'navy', 'navy', 'navy',
          'pink', 'pink', 'pink',
          'grey', 'grey', 'grey',
          'lime', 'lime',
          'teal', 'teal', 'teal', 'teal', 'teal', 'teal',
          'lavender',
          'gold', 'gold',
          'salmon', 'salmon', 'salmon', 'salmon', 'salmon', 'salmon',]

# Plotting
fig, ax1 = plt.subplots(figsize=(15, 8))

# Define the bar width
bar_width = 20
bottom = np.zeros(len(df))

for i, col in enumerate(df.columns):
    plt.bar(df.index, df[col], width=bar_width, bottom=bottom, color=colors[i], label=col)
    bottom += df[col].values

plt.xlabel("Date")
plt.ylabel("Value")
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), ncol=1)
plt.title("Stacked Bar Chart of Monthly Time Series Data")
# Format x-axis to show monthly dates
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.xticks(rotation=45,ha='right')
plt.tight_layout()
plt.savefig("hv_tb_eu_028_001_m_g_001.png", bbox_inches='tight')
plt.savefig("hv_tb_eu_028_001_m_g_001a.png", bbox_inches='tight')
plt.show()
plt.close()

plt.close('all')
plt.clf()
plt.cla()

#hv_tb_eu_028_001_m_g_002
hv_tb_eu_004_001_m=hv_tb_eu_004_001_m.tail(24)
df=hv_tb_eu_004_001_m.copy()
# Plotting
colors = ['green', 'green', 'green', 'green',
          'magenta', 'magenta',
          'orange', 'orange', 'orange', 'orange',
          'navy', 'navy', 'navy', 'navy', 'navy', 'navy',
          'pink', 'pink', 'pink',
          'grey', 'grey', 'grey',
          'lime', 'lime',
          'teal', 'teal', 'teal', 'teal', 'teal', 'teal',
          'lavender',
          'gold', 'gold',
          'salmon', 'salmon', 'salmon', 'salmon', 'salmon', 'salmon',]

# Plotting
fig, ax1 = plt.subplots(figsize=(15, 8))
# Define the bar width
bar_width = 20
bottom = np.zeros(len(df))
for i, col in enumerate(df.columns):
    plt.bar(df.index, df[col], width=bar_width, bottom=bottom, color=colors[i], label=col)
    bottom += df[col].values

plt.xlabel("Date")
plt.ylabel("Value")
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), ncol=1)
plt.title("Stacked Bar Chart of Monthly Time Series Data")
# Format x-axis to show monthly dates
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig("hv_tb_eu_028_001_m_g_002a.png", bbox_inches='tight')
plt.savefig("hv_tb_eu_028_001_m_g_002.png", bbox_inches='tight')
plt.show()
plt.close()

plt.close('all')
plt.clf()
plt.cla()

### 001  EA11-20  gg gross debt gdp ameco <a id="title_page"></a

plt.close('all')
plt.clf()
plt.cla()

#hv_tb_eu_029_001_m_g_003
#### ameco
#### ameco
#### ameco
#### ameco
#### ameco debt to gdp change
eu_m_tickers = ["r997prbj", "r025prbj", "r122prbj", "r124prbj", "r423prbj",
"r939prbj", "r172prbj", "r132prbj",
"r134prbj", "r174prbj", "r178prbj",
"r136prbj", "r941prbj", "r946prbj",
"r137prbj", "r181prbj", "r138prbj",
"r182prbj", "r936prbj", "r961prbj",
"r184prbj"]

print("getting from api")
hv_tb_eu_004_001_m=Haver.data(eu_m_tickers, "AMECO", dates=True)

#print(hv_tb_eu_004_001_m)
#print(hv_tb_eu_004_001_m.columns)

#print("renaming")
hv_tb_eu_004_001_m.rename(columns={"r997prbj":"EU27 gg gross debt gdp ameco"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"r025prbj":"EA20 gg gross debt gdp ameco"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"r122prbj":"Austria gg gross debt gdp ameco"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"r124prbj":"Belgium gg gross debt gdp ameco"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"r423prbj": "Cyprus gg gross debt gdp ameco"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"r939prbj": "Estonia gg gross debt gdp ameco"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"r172prbj": "Finland gg gross debt gdp ameco"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"r132prbj": "France gg gross debt gdp ameco"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"r134prbj": "Germanygg gross debt gdp ameco"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"r174prbj": "Greece gg gross debt gdp ameco"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"r178prbj": "Ireland gg gross debt gdp ameco"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"r136prbj": "Italy gg gross debt gdp ameco"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"r941prbj": "Latvia gg gross debt gdp ameco"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"r946prbj": "Lithuania gg gross debt gdp ameco"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"r137prbj": "Luxembourg gg gross debt gdp ameco"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"r181prbj": "Malta gg gross debt gdp ameco"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"r138prbj": "Netherlands gg gross debt gdp ameco"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"r182prbj": "Portugal gg gross debt gdp ameco"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"r936prbj": "Slovakia gg gross debt gdp ameco"}, inplace=True)               
hv_tb_eu_004_001_m.rename(columns={"r961prbj": "Slovenia gg gross debt gdp ameco"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"r184prbj": "Spain gg gross debt gdp ameco"}, inplace=True)
##print(hv_tb eu 004 001_m)
hv_tb_eu_004_001_m.columns = [col.replace('gg gross debt gdp ameco','') for col in hv_tb_eu_004_001_m.columns]
eu_m_tickers=hv_tb_eu_004_001_m.columns.tolist()
hv_tb_eu_004_001_m0=hv_tb_eu_004_001_m.copy()

hv_tb_eu_004_001_m_t=hv_tb_eu_004_001_m.copy()
hv_tb_eu_004_001_m_t = hv_tb_eu_004_001_m_t.iloc[[-2]]
hv_tb_eu_004_001_m_debt=hv_tb_eu_004_001_m_t.copy()

hv_tb_eu_004_001_m_t=hv_tb_eu_004_001_m_t.transpose()
hv_tb_eu_004_001_m_t.index.names=['Variable']
hv_tb_eu_004_001_m_t.columns=["Debt to GDP Current year"]
#print(hv_tb_eu_004_001_m_t)

hv_tb_eu_004_001_m_t2 =hv_tb_eu_004_001_m.copy()
hv_tb_eu_004_001_m_t2=hv_tb_eu_004_001_m_t2.diff()
hv_tb_eu_004_001_m_t2=hv_tb_eu_004_001_m_t2.tail(1)
hv_tb_eu_004_001_m_change=hv_tb_eu_004_001_m_t2.copy()
hv_tb_eu_004_001_m_t2=hv_tb_eu_004_001_m_t2.transpose()
hv_tb_eu_004_001_m_t2.index.names = ['Variable2']
hv_tb_eu_004_001_m_t2.columns=["Expected change in Debt to GDP Next year AMECO"]


#print(hv_tb_eu_004_001_m_t)
#print(hv_tb_eu_004_001_m_t2)

concatenated_df = pd.concat([hv_tb_eu_004_001_m_t, hv_tb_eu_004_001_m_t2], axis=1)
#print(concatenated_df)

df = concatenated_df.copy()
plt.figure(figsize=(7, 7))
plt.scatter(df['Expected change in Debt to GDP Next year AMECO'],
            df['Debt to GDP Current year'], color='blue')

# Add labels to each scatter dot
for i in range(len(df)):
    plt.text(df['Expected change in Debt to GDP Next year AMECO'][i], df['Debt to GDP Current year'][i], df.index[i],
             fontsize=11, ha='left')

max_val_x = df['Expected change in Debt to GDP Next year AMECO'].max()
min_val_x = df['Expected change in Debt to GDP Next year AMECO'].min()
max_val_y = df['Debt to GDP Current year'].max()
min_val_y = df['Debt to GDP Current year'].min()
# plt.plot([80, -4], [60, 2], color='red', linestyle='', linewidth=1)
mid_x = (df['Expected change in Debt to GDP Next year AMECO'].max() + df['Expected change in Debt to GDP Next year AMECO'].min()) / 2
mid_y = (df['Debt to GDP Current year'].max() + df['Debt to GDP Current year'].min()) / 2
plt.axvline(x=mid_x, color='blue', linestyle='', linewidth=1)
plt.axhline(y=mid_y, color='blue', linestyle='', linewidth=1)
plt.xlabel('Expected change in Debt to GDP Next year AMECO')
plt.ylabel('Debt to GDP Current year')
plt.title('Debt to GDP Current year (X axis) vs \n Expected change in Debt to GDP Next year AMECO (Y axis)')
plt.grid(True)
plt.tight_layout()
# Save the scatter plot image
plt.savefig("hv_tb_eu_029_001_m_g_003.png")
plt.savefig("hv_tb_eu_029_001_m_g_003a.png")
plt.show()
plt.close()
plt.close('all')
plt.clf()
plt.cla()



##hv_tb_eu_029_001_m_g_002
#print(hv_tb_eu_004_001_m_debt)

#bar charts

table_w_simulation=hv_tb_eu_004_001_m_debt.copy()
table_w_simulation=table_w_simulation.transpose()
table_w_simulation.columns=["Weight"]
table_w_simulation=table_w_simulation.sort_values('Weight')

plt.figure(figsize=(15, 5))
bars= plt.bar(table_w_simulation.index, table_w_simulation["Weight"], color="blue")
plt.ylabel('', size=7)
plt.xlabel('', size=7)
plt.tick_params(labelsize=16)
#plt.title(str("PER_"+str(ccy)+"_"+str(time_w)), size-ti_size)
plt.grid(axis='both', alpha=.3)
plt.title("EA Debt to GDP current year expected AMECO", size=15)
for bar in bars:         
    plt.text(bar.get_x() + bar.get_width() / 2, #x-coordinate position of text, adjusted to be centered in the bar
             bar.get_height(), #y-coordinate position of text
             f'{bar.get_height():.1f}', # Text to be displayed; can format the number here
             size=20,ha='center', va='bottom') # Bottom alignment of text vertically
plt.xticks (rotation=30, ha='right')   
plt.savefig("hv_tb_eu_029_001_m_g_001a.png", bbox_inches='tight')
plt.savefig("hv_tb_eu_029_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()

#plt.savefig("hv_tb_eu_029_001_m_g_003.png")


#plt.savefig("hv_tb_eu_029_001_m_g_003.png")
table_w_simulation=hv_tb_eu_004_001_m_change.copy()
table_w_simulation=table_w_simulation.transpose()
table_w_simulation.columns=["Weight"]
table_w_simulation=table_w_simulation.sort_values('Weight')
plt.figure(figsize=(15,5))
bars= plt.bar(table_w_simulation.index, table_w_simulation["Weight"], color="green")
plt.ylabel('', size=7)
plt.xlabel('', size=7)
plt.tick_params(labelsize=16)
#plt.title(str("PER_"+str(ccy)+"_"+str(time_w)), size=ti_size)
plt.grid(axis='both', alpha=.3)
plt.title("EA Debt to GDP delta change next year expected AMECO", size=15)

for bar in bars:          
    plt.text(bar.get_x() + bar.get_width() / 2, #x-coordinate position of text, adjusted to be centered in the bar
    bar.get_height(), #y-coordinate position of text
             f'{bar.get_height():.1f}', # Text to be displayed; can format the number here
             ha='center', # Center alignment of text horizontally 
             size=20,
             va='bottom') # Bottom alignment of text vertically
plt.xticks(rotation=30, ha='right')
plt.savefig("hv_tb_eu_029_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()

##revenues and expenses
##revenues and expenses
##revenues and expenses

### 001  EA11-20  Revenues Growth next year AMECO forecast <a id="title_page"></a

# Revenues and expenses
# Revenues and expenses
# Revenues and expenses

# General government
# Gross Domestic Product (Income Approach), Labor Costs

# 16.1 Revenue (ESA 2010)
# TOTAL REVENUE (TR) (URTG) billions Euro

eu_m_tickers = ["p997nwah", "p025nwah", "p122nwah", "p124nwah", "p423nwah", 
                "p939nwah", "p172nwah", "p132nwah", "p134nwah", "p174nwah", 
                "p178nwah", "p136nwah", "p941nwah", "p946nwah", "p137nwah",
                "p181nwah", "p138nwah", "p182nwah", "p936nwah", "p961nwah", "p184nwah"]

print("getting from api")
hv_tb_eu_004_001_m = Haver.data(eu_m_tickers, "AMECO", dates=True)

# print(hv_tb_eu_004_001_m)
# print(hv_tb_eu_004_001_m.columns)

print("renaming")
hv_tb_eu_004_001_m.rename(columns={"p997nwah": "EU27"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p025nwah": "EA20"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p122nwah": "Austria"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p124nwah": "Belgium"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p423nwah": "Cyprus"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p939nwah": "Estonia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p172nwah": "Finland"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p132nwah": "France"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p134nwah": "Germany"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p174nwah": "Greece"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p178nwah": "Ireland"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p136nwah": "Italy"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p941nwah": "Latvia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p946nwah": "Lithuania"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p137nwah": "Luxembourg"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p181nwah": "Malta"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p138nwah": "Netherlands"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p182nwah": "Portugal"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p182nwah": "Portugal"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p936nwah": "Slovakia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p961nwah": "Slovenia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p184nwah": "Spain"}, inplace=True)

eu_m_tickers=hv_tb_eu_004_001_m.columns.tolist()
for x in range(len(eu_m_tickers)):
    variable=str(eu_m_tickers[x])
    hv_tb_eu_004_001_m[variable] = hv_tb_eu_004_001_m[variable].pct_change(1).multiply(100).round(3)

hv_tb_eu_004_001_m=hv_tb_eu_004_001_m.tail(1)
hv_tb_eu_001_001_m_r=hv_tb_eu_004_001_m.copy()
hv_tb_eu_001_001_m_r=hv_tb_eu_001_001_m_r.transpose()
hv_tb_eu_001_001_m_r.index.names = ['Variable']
hv_tb_eu_001_001_m_r.columns=["Revenues Growth next year AMECO forecast"]
#16.2 EXPENDITURE (ESA 2010)
#TOTAL EXPENDITURE (TE) (UUTG)

#hv_tb_eu_030_001_m_g_003

eu_m_tickers = ["p997omaa", "p025omaa", "p122omaa", "p124omaa", "p423omaa", 
                "p939omaa", "p172omaa", "p132omaa", "p134omaa", "p174omaa",
                "p178omaa", "p136omaa", "p941omaa", "p946omaa", "p137omaa", 
                "p181omaa", "p138omaa", "p182omaa", "p936omaa", "p961omaa", "p184omaa"]

print("getting from api")
hv_tb_eu_004_001_m = Haver.data(eu_m_tickers, "AMECO", dates=True)

#print(hv_tb_eu_004_001_m)
#print(hv_tb_eu_004_001_m.columns)

print("renaming")
hv_tb_eu_004_001_m.rename(columns={"p997omaa": "EU27"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p025omaa": "EA20"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p122omaa": "Austria"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p124omaa": "Belgium"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p423omaa": "Cyprus"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p939omaa": "Estonia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p172omaa": "Finland"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p132omaa": "France"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p134omaa": "Germany"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p174omaa": "Greece"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p178omaa": "Ireland"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p136omaa": "Italy"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p941omaa": "Latvia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p946omaa": "Lithuania"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p137omaa": "Luxembourg"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p181omaa": "Malta"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p138omaa": "Netherlands"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p182omaa": "Portugal"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p936omaa": "Slovakia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p961omaa": "Slovenia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p184omaa": "Spain"}, inplace=True)
eu_m_tickers = hv_tb_eu_004_001_m.columns.tolist()

for x in range(len(eu_m_tickers)):
    variable = str(eu_m_tickers[x])
    hv_tb_eu_004_001_m[variable] = hv_tb_eu_004_001_m[variable].pct_change(1).multiply(100).round(3)

hv_tb_eu_004_001_m = hv_tb_eu_004_001_m.tail(1)
hv_tb_eu_001_001_m_e = hv_tb_eu_004_001_m.copy()
hv_tb_eu_001_001_m_e = hv_tb_eu_001_001_m_e.transpose()
hv_tb_eu_001_001_m_e.index.names = ['Variable']
hv_tb_eu_001_001_m_e.columns = ["Expenses Growth next year AMECO forecast"]

concatenated_df = pd.concat([hv_tb_eu_001_001_m_e, hv_tb_eu_001_001_m_r], axis=1)
str1 = "Revenues Growth next year AMECO forecast"
str2 = "Expenses Growth next year AMECO forecast"




df = concatenated_df.copy()
plt.figure(figsize=(7, 7))
plt.scatter(df[str(str1)], df[str(str2)], color='blue')
for i in range(len(df)):
    plt.text(df[str(str1)][i], df[str(str2)][i], df.index[i], fontsize=11, ha='left')

mid_x = (df[str(str1)].max() + df[str(str1)].min()) / 2
mid_y = (df[str(str2)].max() + df[str(str2)].min()) / 2
plt.axvline(x=mid_x, color="blue", linestyle='-', linewidth=1)
plt.axhline(y=mid_y, color='blue', linestyle='-', linewidth=1)
plt.xlabel(str(str1))
plt.ylabel(str(str2))
plt.title(str(str(str1) + "(X axis) vs \n" + str(str2) + " (Y axis)"))
plt.grid(True)
plt.tight_layout()
plt.savefig('hv_tb_eu_030_001_m_g_003a.png')
plt.savefig('hv_tb_eu_030_001_m_g_003.png')
plt.close()
plt.close('all')
plt.clf()
plt.cla()




#hv_tb_eu_030_001_m_g_002
#vertical bar reneveus next year,
#expense snext year
table_w_simulation=hv_tb_eu_001_001_m_e.copy()
table_w_simulation.columns=["Weight"]
table_w_simulation=table_w_simulation.sort_values("Weight")
plt.figure(figsize=(15, 5))
bars= plt.bar(table_w_simulation.index, table_w_simulation["Weight"], color="orange")
plt.ylabel('', size=7)
plt.xlabel('', size=7)
plt.tick_params (labelsize=16)
#plt.title(str("PER_"+str(ccy)+"_"+str(time_w)), size=ti_size)
plt.grid(axis='both', alpha=.3)
plt.title("EA expenses", size=15)
for bar in bars:        
    plt.text(bar.get_x() + bar.get_width() / 2, #x-coordinate position of text, adjusted to be centered in the bar
                        bar.get_height(), #y-coordinate position of text
             f'{bar.get_height():.2f}', # Text to be displayed; can format the number here
             size=20,
             ha='center', # Center alignment of text horizontally
             va='bottom') #Bottom alignment of text vertically
plt.xticks (rotation=30, ha='right')
plt.savefig("hv_tb_eu_030_001_m_g_001.png", bbox_inches= 'tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()

table_w_simulation = hv_tb_eu_001_001_m_r.copy()
table_w_simulation.columns = ["Weight"]
table_w_simulation = table_w_simulation.sort_values('Weight')
plt.figure(figsize=(15, 5))
bars = plt.bar(table_w_simulation.index, table_w_simulation["Weight"], color="blue")
plt.ylabel("", size=7)
plt.xlabel("", size=7)
plt.tick_params(labelsize=16)
#plt.title(str("PER_"+str(ccy)+"_"+str(time_w)), size=ti_size)
plt.grid(axis='both', alpha=.3)
plt.title("EA expenses", size=15)
for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2, # x-coordinate position of text, adjusted to be centered in the bar
             bar.get_height(), # y-coordinate position of text
             f"{bar.get_height():.2f}", # Text to be displayed; can format the number here
             size=20,
             ha='center', # Center alignment of text horizontally
             va='bottom') # Bottom alignment of text vertically
plt.xticks(rotation=30, ha='right')
plt.savefig("hv_tb_eu_030_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
#Ameco
#Ameco
#Ameco

## 16.4 Excessive Deficit Procedure
# Gross Domestic Product (Income Approach), Labor Costs

# 16.4 EXCESSIVE DEFICIT PROCEDURE
# INTEREST (UYIGE)

### 001  EA11-20  Revenues eXPOENSES  Growth next year AMECO forecast <a id="title_page"></a

#Ameco
#Ameco
#Ameco
#16.4 Excessive Deficit Procedure
#Gross Domestic Product (Income Approach), Labor Costs
#16.4 EXCESSIVE DEFICIT PROCEDURE
#INTEREST (UYIGE)

eu_m_tickers = ["p997oubj", "p025oubj", "p122oubj", "p124oubj", "p423oubj",
                "p939oubj", "p172oubj", "p132oubj",
                "p134oubj", "p174oubj", "p178oubj",
                "p136oubj", "p941oubj", "p946oubj",
                "p137oubj", "p181oubj", "p138oubj",
                "p182oubj", "p936oubj", "p961oubj",
                "p184oubj"]

print("getting from api")
hv_tb_eu_004_001_m = Haver.data(eu_m_tickers, "AMECO", dates=True)
#print(hv_tb_eu_004_001_m)
#print(hv_tb_eu_004_001_m.columns)
print("renaming")
hv_tb_eu_004_001_m.rename(columns={"p997oubj": "EU27"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p025oubj": "EA20"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p122oubj": "Austria"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p124oubj": "Belgium"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p423oubj": "Cyprus"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p939oubj": "Estonia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p172oubj": "Finland"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p132oubj": "France"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p134oubj": "Germany"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p174oubj": "Greece"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p178oubj": "Ireland"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p136oubj": "Italy"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p941oubj": "Latvia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p946oubj": "Lithuania"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p137oubj": "Luxembourg"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p181oubj": "Malta"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p138oubj": "Netherlands"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p182oubj": "Portugal"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p936oubj": "Slovakia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p961oubj": "Slovenia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p184oubj": "Spain"}, inplace=True)
eu_m_tickers=hv_tb_eu_004_001_m.columns.tolist()
hv_tb_eu_000_001_int=hv_tb_eu_004_001_m.copy()

### Gross saving #16.4 EXCESSIVE DEFICIT PROCEDURE

print("GROSS SAVING (USGGE)")

#####Gross saving
#16.4 EXCESSIVE DEFICIT PROCEDURE

#GROSS SAVING (USGGE)

eu_m_tickers =["p997ovbj", "p025ovbj",
               "p122ovbj", "p124ovbj", "p423ovbj",
               "p939ovbj", "p172ovbj", "p132ovbj",
               "p134ovbj", "p174ovbj", "p178ovbj",
               "p136ovbj", "p941ovbj", "p946ovbj",
               "p137ovbj", "p181ovbj", "p138ovbj",
               "p182ovbj", "p936ovbj", "p961ovbj",
               "p184ovbj"]

print("getting from api")
hv_tb_eu_004_001_m=Haver.data(eu_m_tickers, "AMECO", dates=True)

#print(hv_tb_eu_004_001_m)
#print(hv_tb_eu_004_001_m.columns)

print("renaming")
hv_tb_eu_004_001_m.rename(columns={"p997ovbj": "EU27"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p025ovbj": "EA20"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p122ovbj": "Austria"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p124ovbj": "Belgium"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p423ovbj":"Cyprus"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p939ovbj": "Estonia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p172ovbj": "Finland"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p132ovbj": "France"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p134ovbj": "Germany"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p174ovbj": "Greece"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p178ovbj": "Ireland"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p1360vbj": "Italy"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p941ovbj":"Latvia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p946ovbj":"Lithuania"},inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p137ovbj": "Luxembourg"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p181ovbj": "Malta"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p138ovbj": "Netherlands"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p182ovbj": "Portugal"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p936ovbj": "Slovakia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p961ovbj": "Slovenia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p184ovbj": "Spain"}, inplace=True)
eu_m_tickers=hv_tb_eu_004_001_m.columns.tolist()
hv_tb_eu_000_001_gs=hv_tb_eu_004_001_m.copy()

### 001  TOTAL CURRENT EXPENDITURE (UUCGE) EXCESSIVE DEFICIT PROCEDURE  <a id="title_page"></a

print("TOTAL CURRENT EXPENDITURE (UUCGE) EXCESSIVE DEFICIT PROCEDURE")

#16.4
#TOTAL CURRENT EXPENDITURE (UUCGE)
#EXCESSIVE DEFICIT PROCEDURE

eu_m_tickers   =["p997owbj","p025owbj",
                 "p122owbj", "p124owbj", "p423owbj",
                 "p939owbj", "p172owbj", "p132owbj",
                 "p134owbj", "p174owbj", "p178owbj",
                 "p136owbj","p941owbj", "p946owbj",
                 "p137owbj","p181owbj", "p138owbj",
                 "p182owbj","p936owbj", "p961owbj", "p184owbj"]

print("getting from api")
hv_tb_eu_004_001_m=Haver.data(eu_m_tickers, "AMECO", dates=True)
#print(hv_tb_eu_004_001_m)
#print(hv_tb_eu_004_001_m.columns)

print("renaming")
hv_tb_eu_004_001_m.rename(columns={"p997owbj":"EU27"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p025owbj": "EA20"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p122owbj":"Austria"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p124owbj":"Belgium"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p423owbj": "Cyprus"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p939owbj":"Estonia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p172owbj": "Finland"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p132owbj": "France"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p134owbj": "Germany"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p174owbj": "Greece"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p178owbj": "Ireland"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p1360wbj":"Italy"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p941owbj":"Latvia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p9460wbj":"Lithuania"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p137owbj":"Luxembourg"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p18lowbj": "Malta"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p138owbj": "Netherlands"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p182owbj": "Portugal"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p936owbj":"Slovakia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p961owbj": "Slovenia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p184owbj": "Spain"}, inplace=True)
eu_m_tickers=hv_tb_eu_004_001_m.columns.tolist()
hv_tb_eu_000_001_ce=hv_tb_eu_004_001_m.copy()

### 001  #16.4 EXCESSIVE DEFICIT PROCEDURE #TOTAL EXPENDITURE (UUTGE)  <a id="title_page"></a

print("#TOTAL EXPENDITURE (UUTGE)")

#16.4 EXCESSIVE DEFICIT PROCEDURE #TOTAL EXPENDITURE (UUTGE)


eu_m_tickers =["p997oxbj", "p025oxbj",
               "p122oxbj", "p124oxbj", "p423oxbj",
               "p939oxbj", "p172oxbj", "p132oxbj",
               "p134oxbj", "p174oxbj", "p178oxbj",
               "p136oxbj", "p941oxbj", "p946oxbj",
               "p137oxbj", "p181oxbj", "p138oxbj",
               "p182oxbj", "p936oxbj", "p961oxbj",
               "p184oxbj"]
print("getting from api")
hv_tb_eu_004_001_m=Haver.data(eu_m_tickers, "AMECO", dates=True)

print(hv_tb_eu_004_001_m)
#print(hv_tb_eu_004_001_m.columns)

print("renaming")
hv_tb_eu_004_001_m.rename(columns={"p997oxbj":"EU27"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p025oxbj":"EA20"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p122oxbj":"Austria"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p124oxbj":"Belgium"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p423oxbj":"Cyprus"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p939oxbj":"Estonia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p172oxbj": "Finland"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p132oxbj": "France"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p134oxbj":"Germany"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p174oxbj": "Greece"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p178oxbj": "Ireland"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p136oxbj": "Italy"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p941oxbj": "Latvia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p946oxbj":"Lithuania"},inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p137oxbj": "Luxembourg"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p181oxbj": "Malta"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p138oxbj": "Netherlands"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p182oxbj": "Portugal"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p936oxbj": "Slovakia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p961oxbj": "Slovenia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p184oxbj":"Spain"}, inplace=True)
eu_m_tickers=hv_tb_eu_004_001_m.columns.tolist()
hv_tb_eu_000_001_te=hv_tb_eu_004_001_m.copy()



### 001  NET LENDING <a id="title_page"></a

#16.4
#NET LENDING (UBLGE)
#EXCESSIVE DEFICIT PROCEDURE

eu_m_tickers = ["p997oybj", "p025oybj", "p122oybj", "p124oybj", "p423oybj",
                "p939oybj", "p172oybj", "p132oybj", "p134oybj", "p174oybj",
                "p178oybj", "p136oybj", "p941oybj", "p946oybj", "p137oybj",
                "p181oybj", "p138oybj", "p182oybj", "p936oybj", "p961oybj", "p184oybj"]

print("getting from api")
hv_tb_eu_004_001_m = Haver.data(eu_m_tickers, "AMECO", dates=True)
#print(hv_tb_eu_004_001_m)
#print(hv_tb_eu_004_001_m.columns)

print("renaming")
hv_tb_eu_004_001_m.rename(columns={"p997oybj": "EU27"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p025oybj": "EA20"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p122oybj": "Austria"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p124oybj": "Belgium"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p423oybj": "Cyprus"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p939oybj": "Estonia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p172oybj": "Finland"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p132oybj": "France"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p134oybj": "Germany"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p174oybj": "Greece"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p178oybj": "Ireland"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p136oybj": "Italy"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p941oybj": "Latvia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p946oybj": "Lithuania"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p137oybj": "Luxembourg"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p181oybj": "Malta"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p138oybj": "Netherlands"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p182oybj": "Portugal"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p936oybj": "Slovakia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p961oybj": "Slovenia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p184oybj": "Spain"}, inplace=True)
eu_m_tickers = hv_tb_eu_004_001_m.columns.tolist()
hv_tb_eu_000_001_n1 = hv_tb_eu_004_001_m.copy()




### 001  EXCESSIVE DEFICIT PROCEDURES <a id="title_page"></a

#16.4 - EXCESSIVE DEFICIT PROCEDURE

#NET LENDING EXCLUDING INTEREST (UBLGIE)

eu_m_tickers = ["p997ozbj", "p025ozbj", "p122ozbj", "p124ozbj", "p423ozbj",
                "p939ozbj", "p172ozbj", "p132ozbj", "p134ozbj", "p174ozbj", 
                "p178ozbj", "p136ozbj", "p941ozbj", "p946ozbj", "p137ozbj",
                "p181ozbj", "p138ozbj", "p182ozbj", "p936ozbj", "p961ozbj", "p184ozbj"]

print("getting from api")
hv_tb_eu_004_001_m=Haver.data(eu_m_tickers, "AMECO", dates=True)

#print(hv_tb_eu_004_001_m)
#print(hv_tb_eu_004_001_m.columns)

print("renaming")
hv_tb_eu_004_001_m.rename(columns={"p997ozbj": "EU27"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p025ozbj":"EA20"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p122ozbj":"Austria"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p124ozbj":"Belgium"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p423ozbj": "Cyprus"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p939ozbj": "Estonia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p172ozbj": "Finland"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p132ozbj": "France"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p134ozbj":"Germany"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p174ozbj":"Greece"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p178ozbj":"Ireland"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p136ozbj":"Italy"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p941ozbj":"Latvia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p946ozbj": "Lithuania"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p137ozbj":"Luxembourg"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p181ozbj": "Malta"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p138ozbj":"Netherlands"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p182ozbj":"Portugal"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p936ozbj": "Slovakia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p961ozbj": "Slovenia"}, inplace=True)
hv_tb_eu_004_001_m.rename(columns={"p184ozbj": "Spain"}, inplace=True)
eu_m_tickers = hv_tb_eu_004_001_m.columns.tolist()
hv_tb_eu_000_001_nlei = hv_tb_eu_004_001_m.copy()


### 001  HISTORICAL DEFICTIS <a id="title_page"></a

# Historical time series net deficit and interest.
#hv_tb_eu_000_001_int.to_clipboard()
#hv_tb_eu_000_001_gs.to_clipboard()
#hv_tb_eu_000_001_ce.to_clipboard()
#hv_tb_eu_000_001_te.to_clipboard()
#hv_tb_eu_000_001_nlei.to_clipboard()
#hv_tb_eu_000_001_nl.to_clipboard()

# Interest (UYIGE)
# Gross Saving (USGGE)
# Total Current Expenditure (UUCGE)
# Total Expenditure (UUTGE)

# Net Lending (UBLGE)
# Net Lending Excluding Interest (UBLGIE)
eu_list10= ["EU27", "EA20", "France", "Germany", "Italy",
            "Spain", "Netherlands", "Austria", "Belgium", "Ireland",
            "Greece", "Portugal", "Finland", "Slovakia", "Slovenia",
            "Latvia", "Lithuania", "Luxembourg", "Cyprus", "Estonia", "Malta"]

#hv_tb_eu_000_001_int
#hv_tb_eu_000_001_nlei
str1="Interest (UYIGE)"
str2="Net Lending Excluding Interest (UBLGIE)"
#window_zl=[12]
n=0
for x in range(len(eu_list10)):
    print(x)
    country=(eu_list10[x])
    print(country)
    inte=hv_tb_eu_000_001_int[str(country)] 
    inte=inte.tail(24)
    inte=inte * -1
    nlei=hv_tb_eu_000_001_nlei[str(country)]
    nlei-nlei.tail(24)
    concatenated_df= pd.concat([inte, nlei], axis=1)
    concatenated_df.columns=[str(str1), str(str2)]
    #print(concatenated_df)
    
    df=concatenated_df.copy()
    #df.set_index('Year', inplace=True)
    #Create stacked bar chart
    plt.figure(figsize=(7,3))
    # Define the bar width
    bar_width = 180
    # Calculate cumulative sum for stacking
    cum_sum =np.zeros(len(df))
    #Plot bars for Column1
    plt.bar(df.index, df[str(str1)], width=bar_width, color='blue', label=str(str1))
    # Update cumulative sum
    cum_sum += df[str(str1)]
    # Plot bars for Column2, stacking on top of Column1
    plt.bar(df.index, df[str(str2)], width=bar_width, bottom=cum_sum, color='orange', label=str(str2))
    #Add Labels and title
    plt.xlabel('Year')
    plt.ylabel('% GDP')
    plt.title(str('AMECO Historical Excessive Deficit Procedure % GDP '+str(country)))
    plt.xticks(rotation=45, ha='right') # Rotate x tick labels for better readability
    plt.legend(loc='best')
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(str('hv_tb_eu_031_001_m_g_'+str(n)+'.png'))
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()  
    n=n+1
    



### ecb wage tracker

#Overall HICP (year/year % change)
eu_m_tickers =["n023wts","n023wt1", "n023wtx",]
#print("getting from api")
hv_tb_eu_031_001_m=Haver.data(eu_m_tickers, "EUDATA", dates=True)
hv_tb_eu_031_001_m.rename(columns={"n023wts":"ecb_wage_tracker_negotiated_wages_smoothed_one_off"}, inplace=True)
hv_tb_eu_031_001_m.rename(columns={"n023wt1":"ecb_wage_tracker_negotiated_wages_inc_one_off"}, inplace=True)
hv_tb_eu_031_001_m.rename(columns={"n023wtx":"ecb_wage_tracker_negotiated_wages_exc_one_off"}, inplace=True)



l1=2
s2=2
df1=hv_tb_eu_031_001_m.copy()
df1=df1.tail(60)
list_c=df1.columns.tolist()
print("Charts")
title_r0=list_c[0]
title_r=title_r0
y_label="Index %"
x_label=title_r
g1=df1.copy()
fig, ax = plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax,y=[list_c[0]], color="green",
        linewidth= l1, linestyle='-',
        marker="P", markersize=s2)

plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_031_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del fig
del ax
del ax2


##############

title_r0=list_c[1]
title_r=title_r0
y_label="Index %"
x_label=title_r
g1=df1.copy()
fig, ax = plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax,y=[list_c[1]], color="black",
        linewidth= l1, linestyle='-',
        marker="P", markersize=s2)

plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_031_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del fig
del ax
del ax2


###
title_r0=list_c[2]
title_r=title_r0
y_label="Index %"
x_label=title_r
g1=df1.copy()
fig, ax = plt.subplots (figsize=(parameter1_s, parameter2_s))
g1.plot(kind="line", ax=ax,y=[list_c[2]], color="orange",
        linewidth= l1, linestyle='-',
        marker="P", markersize=s2)

plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_eu_031_001_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del fig
del ax
del ax2




### 001  FORECASTS ECB <a id="title_page"></a

######FORECASTS ECB
######FORECASTS ECB
######FORECASTS ECB
######FORECASTS ECB


country_database = "EUDATA"
uki_m_tickers1 = ["q025gdpm","q025ram","q025rame","q025ramf","q025ramt","q025raie","q025raif",
                        "q025hsr","q025ump","q025labp","q025pyr","q025gctm","q025iftm","q025pctm"]
hv_tb_uk_000_001_m = Haver.data(uki_m_tickers1, country_database, dates=True)

#uki_m_tickers3 = ['gdpp','gdpc',]
#hv_tb_uk_000_003_m = Haver.data(uki_m_tickers2, country_database, dates=True)
#hv_tb_uk_000_001_m=pd.concat([hv_tb_uk_000_001_m, hv_tb_uk_000_003_m], axis=1, join="outer")
hv_tb_uk_000_001_m=hv_tb_uk_000_001_m.tail(16)
print(hv_tb_uk_000_001_m)
table_F=hv_tb_uk_000_001_m.copy()

#hv_tb_uk_002_005_m_g_001 = hv_tb_uk_002_005_m.copy()
#hv_tb_uk_002_005_m = hv_tb_uk_002_005_m.tail(horizon_1)
#hv_tb_uk_002_005_m = hv_tb_uk_002_005_m.transpose()
#hv_tb_uk_002_005_m.index.names = ['Variable']
#hv_tb_uk_002_005_m['Variable_'] = hv_tb_uk_002_005_m.index
## dashboard.to_clipboard()
#print(hv_tb_uk_002_005_m)



table_F.rename(columns={"q025gdpm": "ecb staff: ea gdp qq"}, inplace=True)

table_F.rename(columns={"q025ram": "ecb staff: ea hicp yy"}, inplace=True)
table_F.rename(columns={"q025rame": "ecb staff: ea hicp ex energy yy"}, inplace=True)
table_F.rename(columns={"q025ramf": "ecb staff: ea hicp ex ef yy"}, inplace=True)
table_F.rename(columns={"q025ramt": "ecb staff: ea hicp ex eft yy"}, inplace=True)
table_F.rename(columns={"q025raie": "ecb staff: ea hicp energy yy"}, inplace=True)
table_F.rename(columns={"q025raif": "ecb staff: ea hicp food yy"}, inplace=True)


table_F.rename(columns={"q025hsr": "ecb staff: ea hh saving ratio"}, inplace=True)
table_F.rename(columns={"q025ump": "ecb staff: ea unemployment rate"}, inplace=True)
table_F.rename(columns={"q025labp": "ecb staff: ea labor prod"}, inplace=True)
table_F.rename(columns={"q025pyr": "ecb staff: ea real disposable hhi"}, inplace=True)
table_F.rename(columns={"q025gctm": "ecb staff: ea govt consumption"}, inplace=True)
table_F.rename(columns={"q025iftm": "ecb staff: ea gross fixed capital formation"}, inplace=True)
table_F.rename(columns={"q025pctm": "ecb staff: ea private consumption"}, inplace=True)

df = table_F.copy()
df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)

fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='center',
        height=40  # Increased height of the header row
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=14),  # Increase cell font size here
        align='center'
    ), columnwidth=[370, 80] + [80] * (len(new_columns) - 2)  # Adjust first column width, rest to 80
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1400,
                  height=800,
                  title=" Forecast")  # Add title here
fig.write_image('hv_tb_eu_forecast_001.png')

country_database = "EUDATA"
uki_m_tickers1 = ["q025gdpm","q025ram","q025rame","q025ramf","q025ramt","q025raie","q025raif",]
hv_tb_uk_000_001_m = Haver.data(uki_m_tickers1, country_database, dates=True)

#uki_m_tickers3 = ['gdpp','gdpc',]
#hv_tb_uk_000_003_m = Haver.data(uki_m_tickers2, country_database, dates=True)
#hv_tb_uk_000_001_m=pd.concat([hv_tb_uk_000_001_m, hv_tb_uk_000_003_m], axis=1, join="outer")
hv_tb_uk_000_001_m=hv_tb_uk_000_001_m.tail(16)
print(hv_tb_uk_000_001_m)
table_F=hv_tb_uk_000_001_m.copy()

#hv_tb_uk_002_005_m_g_001 = hv_tb_uk_002_005_m.copy()
#hv_tb_uk_002_005_m = hv_tb_uk_002_005_m.tail(horizon_1)
#hv_tb_uk_002_005_m = hv_tb_uk_002_005_m.transpose()
#hv_tb_uk_002_005_m.index.names = ['Variable']
#hv_tb_uk_002_005_m['Variable_'] = hv_tb_uk_002_005_m.index
## dashboard.to_clipboard()
#print(hv_tb_uk_002_005_m)



table_F.rename(columns={"q025gdpm": "ecb staff: ea gdp qq"}, inplace=True)

table_F.rename(columns={"q025ram": "ecb staff: ea hicp yy"}, inplace=True)
table_F.rename(columns={"q025rame": "ecb staff: ea hicp ex energy yy"}, inplace=True)
table_F.rename(columns={"q025ramf": "ecb staff: ea hicp ex ef yy"}, inplace=True)
table_F.rename(columns={"q025ramt": "ecb staff: ea hicp ex eft yy"}, inplace=True)
table_F.rename(columns={"q025raie": "ecb staff: ea hicp energy yy"}, inplace=True)
table_F.rename(columns={"q025raif": "ecb staff: ea hicp food yy"}, inplace=True)



df = table_F.copy()
df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)

fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='center',
        height=40  # Increased height of the header row
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=14),  # Increase cell font size here
        align='center'
    ), columnwidth=[370, 80] + [80] * (len(new_columns) - 2)  # Adjust first column width, rest to 80
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1400,
                  height=300,
                  title=" Forecast")  # Add title here
fig.write_image('hv_tb_eu_forecast_002.png')

### delete all files

import gc

# Get a list of all variables in the current environment
all_variables = [var for var in globals() if not var.startswith('_')]

# Remove DataFrames from the environment
for var_name in all_variables:
    try:
        if isinstance(globals()[var_name], pd.DataFrame):
            del globals()[var_name]
    except:
        pass

# Force garbage collection to release memory
gc.collect()

print("Complete")

### 001  BOTTOM  <a id="title_page"></a
