# %%
### 001_top <a id="title_page"></a>
- [Top](#table_contents)

#Jupyter M008_Dashboard_Eco-Copy1 Last Checkpoint: 6 minutes ago

#Table Contents
#  - table
#  - packages
#  - world
#  - bird

from IPython.display import display, HTML

### packages <a id="table_contents"></a>


###econiomics DASHBOARD
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display, HTML
import Haver
Haver.path(Haver.direct(1))    
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import os
def clear():
    os.system('cls')
# then you can clear the window with:
from matplotlib.dates import date2num
import os
os.chdir('C:/database/dashboard')
#C:\database\dashboard
print(os.getcwd())

import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import matplotlib.ticker as plticker
import matplotlib.dates as mdates
from matplotlib.ticker import MultipleLocator

from matplotlib.colors import LinearSegmentedColormap

import matplotlib.pyplot as pit
from PIL import Image
import seaborn as sns
import plotly.graph_objects as go

parameter1_s=9
parameter2_s=6
parameter3_s=11
parameter4_s=7
parameter5_s=20
parameter3=15
parameter4=15
parameter5=20
s0=1
s1=5
s2=6
s3=7
s4=12
s5=14
s6=15
l0=1.0
l1=1.0
l2=1.5
tail_y=12
tail_0=24
tail_1=60
tail_2=72
tail_4=36
parameter_size1=8
parameter_size2=6

million = 1000000

horizon_tb = 24
#DAA0236BLUECHIP

def zscore(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  o = arr.rolling(window = window).std()
  return (x-u)/o

def zscore_avg(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  return (x-u)





### 01 01 policy <a id="title_page"></a>

###### POLICY rates
###### POLICY rates
w_s_tickers = ["n193rtar", "n156rtar", "n023rtar", "n196rtar", "n142rtar", 
               "n144rtar", "n146rtar", "n112rtar", "n111rtar"]
print("getting from api")
hv_tb_w_001_001_m = Haver.data(w_s_tickers, "G10", dates=True)
#print(hv_tb_w_001_001_m)
#print(hv_tb_w_001_001_m.columns)
hv_tb_w_001_001_m.rename(columns={"n193rtar": "Australia Policy Rate"}, inplace=True)
hv_tb_w_001_001_m.rename(columns={"n156rtar": "Canada Policy Rate"}, inplace=True)
hv_tb_w_001_001_m.rename(columns={"n023rtar": "EA Policy Rate"}, inplace=True)
hv_tb_w_001_001_m.rename(columns={"n196rtar": "New Zealand Policy Rate"}, inplace=True)
hv_tb_w_001_001_m.rename(columns={"n142rtar": "Norway Policy Rate"}, inplace=True)
hv_tb_w_001_001_m.rename(columns={"n144rtar": "Sweden Policy Rate"}, inplace=True)
hv_tb_w_001_001_m.rename(columns={"n146rtar": "Switzerland Policy Rate"}, inplace=True)
hv_tb_w_001_001_m.rename(columns={"n112rtar": "UK Policy Rate"}, inplace=True)
hv_tb_w_001_001_m.rename(columns={"n111rtar": "USA Policy Rate"}, inplace=True)



hv_tb_w_001_001_m_g0 = hv_tb_w_001_001_m.copy()
hv_tb_w_001_001_m_g0_001 = hv_tb_w_001_001_m.copy()

hv_tb_w_001_001_m_table=hv_tb_w_001_001_m.copy()
hv_tb_w_001_001_m_table = hv_tb_w_001_001_m_table.tail(60)

hv_tb_w_001_001_t1_t = hv_tb_w_001_001_m_table.transpose()
hv_tb_w_001_001_t1_t.index.names = ['Variable']
print(hv_tb_w_001_001_t1_t.shape[0])
print(hv_tb_w_001_001_t1_t.shape[1])




title_table = "Policy Rate eop"
df = hv_tb_w_001_001_m_table.copy()
df_transposed = hv_tb_w_001_001_t1_t.copy()

fig, ax = plt.subplots(figsize=(36, 8))  # Increase figure width for more space
# Use a mask to prevent NaN values from displaying incorrectly
mask = df_transposed.isnull()

sns.heatmap(df_transposed, annot=True, fmt=".2f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, 
            annot_kws={"fontsize": 13, "fontweight": "bold"},
            mask=mask)  # Mask NaNs to prevent display issues

# Set x-axis labels (months)
xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)
# Set y-axis labels (variable names) on both left and right in horizontal orientation
ytick_labels = df_transposed.index.tolist()  # Extract variable names
ax.set_yticks(np.arange(len(ytick_labels)) + 0.5)  # Align y-ticks
ax.set_yticklabels(ytick_labels, fontsize=12, fontweight="bold", rotation=0)  # Horizontal y-labels
# Enable both left and right y-axis labels
ax.tick_params(axis="y", labelleft=True, labelright=True, left=True, right=True, labelsize=12)
# Fine-tune x-axis limits to fully show the last column on the right
ax.set_xlim(-0.5, len(df_transposed.columns) - 0.01)  # Expands slightly beyond last column
# Adjust layout to prevent cut-off on the right
plt.subplots_adjust(left=0.12, right=0.98, bottom=0.12, top=0.93)  # Extra space on the right
ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

#### Save the figure
plt.savefig("hv_tb_w_001_001_m_table_001.png", dpi=300, bbox_inches="tight")
plt.close()



#print("saving for charts")
hv_tb_w_001_001_m_g_001 = hv_tb_w_001_001_m.copy()
#print("transpose")
hv_tb_w_001_001_m = hv_tb_w_001_001_m.tail(horizon_tb)
hv_tb_w_001_001_m = hv_tb_w_001_001_m.transpose()
hv_tb_w_001_001_m.index.name = 'Variable'
label_t="Policy Rate"
print("step2")
# Set variables
title_r0 = "Policy Rate"
title_r=title_r0
y_label = "Index %"
x_label = title_r
list_c = ["USA " + str(label_t), 
          "UK " + str(label_t),
          "EA " + str(label_t),
          "Canada " + str(label_t),
         "Australia "  + str(label_t)]

# Filter data
df1 = hv_tb_w_001_001_m_g_001[list_c]
df1 = df1.tail(60)
g1=df1.copy()
# Create plot
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

# Create line plots
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)], 
        color="black", linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK " + str(label_t)], 
        color="darkred", linewidth=l1, linestyle='-', marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA " + str(label_t)], 
        color="darkgreen", linewidth=l1, linestyle='-', marker='^', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Canada " + str(label_t)],
        color="darkorange", linewidth=l1, linestyle='-', marker='x', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Australia " + str(label_t)],
        color="magenta", linewidth=l1, linestyle='-', marker='d', markersize=s2)



# Add horizontal line
plt.axhline(0, color='black', linewidth=1, linestyle='dashed', alpha=0.75)
# Set plot style
plt.style.use('default')
# Set labels and title
plt.ylabel(str(y_label), fontsize=parameter3)
plt.xlabel(str(x_label), fontsize=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), fontsize=parameter5)
plt.grid(axis='both', alpha=0.3)
# Create secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
# Save plot
plt.savefig("hv_tb_w_001_001_m_g_001.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_001_m_g_001.jpg", bbox_inches='tight')
plt.close()
# Clear plot
plt.close('all')
plt.clf()
plt.cla()
# Delete objects




df1 = hv_tb_w_001_001_m_g_001[list_c]
df1 = df1.tail(12)
g1=df1.copy()
# Create plot
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

# Create line plots
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)], 
        color="black", linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK " + str(label_t)], 
        color="darkred", linewidth=l1, linestyle='-', marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA " + str(label_t)], 
        color="darkgreen", linewidth=l1, linestyle='-', marker='^', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Canada " + str(label_t)],
        color="darkorange", linewidth=l1, linestyle='-', marker='x', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Australia " + str(label_t)],
        color="magenta", linewidth=l1, linestyle='-', marker='d', markersize=s2)



# Add horizontal line
plt.axhline(0, color='black', linewidth=1, linestyle='dashed', alpha=0.75)
# Set plot style
plt.style.use('default')
# Set labels and title
plt.ylabel(str(y_label), fontsize=parameter3)
plt.xlabel(str(x_label), fontsize=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), fontsize=parameter5)
plt.grid(axis='both', alpha=0.3)
# Create secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
# Save plot
plt.savefig("hv_tb_w_001_001_m_g_001z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_001_m_g_001z.jpg", bbox_inches='tight')
plt.close()
# Clear plot
plt.close('all')
plt.clf()
plt.cla()
# Delete objects
del g1
del df1
del list_c
del fig
del ax
del ax2

###### POLICY rates
#hv_tb_w_001_001_n_g_002
label_t="Policy Rate"
print("step2")
# Set variables
title_r0 = "Policy Rate"
title_r=title_r0
y_label = "Index %"
x_label = title_r
list_c = ["Norway " + str(label_t), 
          "Sweden " + str(label_t),
          "Switzerland " + str(label_t),]

# Filter data
df1 = hv_tb_w_001_001_m_g_001[list_c]
df1 = df1.tail(60)
g1=df1.copy()
# Create plot
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

# Create line plots
g1.plot(kind='line', ax=ax, y=["Norway " + str(label_t)], 
        color="black", linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Sweden " + str(label_t)], 
        color="darkred", linewidth=l1, linestyle='-', marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Switzerland " + str(label_t)], 
        color="darkgreen", linewidth=l1, linestyle='-', marker='^', markersize=s2)

# Add horizontal line
plt.axhline(0, color='black', linewidth=1, linestyle='dashed', alpha=0.75)
# Set plot style
plt.style.use('default')
# Set labels and title
plt.ylabel(str(y_label), fontsize=parameter3)
plt.xlabel(str(x_label), fontsize=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), fontsize=parameter5)
plt.grid(axis='both', alpha=0.3)
# Create secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
# Save plot
plt.savefig("hv_tb_w_001_001_m_g_002.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_001_m_g_002.jpg", bbox_inches='tight')
plt.close()
# Clear plot
plt.close('all')
plt.clf()
plt.cla()
# Delete objects


df1 = hv_tb_w_001_001_m_g_001[list_c]
df1 = df1.tail(12)
g1=df1.copy()
# Create plot
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

# Create line plots
g1.plot(kind='line', ax=ax, y=["Norway " + str(label_t)], 
        color="black", linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Sweden " + str(label_t)], 
        color="darkred", linewidth=l1, linestyle='-', marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Switzerland " + str(label_t)], 
        color="darkgreen", linewidth=l1, linestyle='-', marker='^', markersize=s2)

# Add horizontal line
plt.axhline(0, color='black', linewidth=1, linestyle='dashed', alpha=0.75)
# Set plot style
plt.style.use('default')
# Set labels and title
plt.ylabel(str(y_label), fontsize=parameter3)
plt.xlabel(str(x_label), fontsize=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), fontsize=parameter5)
plt.grid(axis='both', alpha=0.3)
# Create secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
# Save plot
plt.savefig("hv_tb_w_001_001_m_g_002z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_001_m_g_002z.jpg", bbox_inches='tight')
plt.close()
# Clear plot
plt.close('all')
plt.clf()
plt.cla()
# Delete objects
del g1
del df1
del list_c
del fig
del ax
del ax2

###### POLICY rates
#hv_tb_w_001_001_m_g_003z

label_t="Policy Rate"
print("step2")
# Set variables
title_r0 = "Policy Rate"
title_r=title_r0
y_label = "Index %"
x_label = title_r
list_c = ["Australia " + str(label_t), 
          "New Zealand " + str(label_t),]

# Filter data
df1 = hv_tb_w_001_001_m_g_001[list_c]
df1 = df1.tail(60)
g1=df1.copy()
# Create plot
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

# Create line plots
g1.plot(kind='line', ax=ax, y=["Australia " + str(label_t)], 
        color="black", linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["New Zealand " + str(label_t)], 
        color="darkred", linewidth=l1, linestyle='-', marker='s', markersize=s2)

# Add horizontal line
plt.axhline(0, color='black', linewidth=1, linestyle='dashed', alpha=0.75)
# Set plot style
plt.style.use('default')
# Set labels and title
plt.ylabel(str(y_label), fontsize=parameter3)
plt.xlabel(str(x_label), fontsize=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), fontsize=parameter5)
plt.grid(axis='both', alpha=0.3)
# Create secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
# Save plot
plt.savefig("hv_tb_w_001_001_m_g_003.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_001_m_g_003.jpg", bbox_inches='tight')
plt.close()
# Clear plot
plt.close('all')
plt.clf()
plt.cla()
# Delete objects



df1 = hv_tb_w_001_001_m_g_001[list_c]
df1 = df1.tail(12)
g1=df1.copy()
# Create plot
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

# Create line plots
g1.plot(kind='line', ax=ax, y=["Australia " + str(label_t)], 
        color="black", linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["New Zealand " + str(label_t)], 
        color="darkred", linewidth=l1, linestyle='-', marker='s', markersize=s2)

# Add horizontal line
plt.axhline(0, color='black', linewidth=1, linestyle='dashed', alpha=0.75)
# Set plot style
plt.style.use('default')
# Set labels and title
plt.ylabel(str(y_label), fontsize=parameter3)
plt.xlabel(str(x_label), fontsize=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), fontsize=parameter5)
plt.grid(axis='both', alpha=0.3)
# Create secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
# Save plot
plt.savefig("hv_tb_w_001_001_m_g_003z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_001_m_g_003z.jpg", bbox_inches='tight')
plt.close()
# Clear plot
plt.close('all')
plt.clf()
plt.cla()
# Delete objects
del g1
del df1
del list_c
del fig
del ax
del ax2

###### POLICY rates
#hv_tb_w_001_001_m_g_004


label_t="Policy Rate"
print("step2")
# Set variables
title_r0 = "Policy Rate"
title_r=title_r0
y_label = "Index %"
x_label = title_r
list_c = ["USA " + str(label_t), 
          "Canada " + str(label_t),]

# Filter data
df1 = hv_tb_w_001_001_m_g_001[list_c]
df1 = df1.tail(60)
g1=df1.copy()
# Create plot
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

# Create line plots
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)], 
        color="black", linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Canada " + str(label_t)], 
        color="darkred", linewidth=l1, linestyle='-', marker='s', markersize=s2)

# Add horizontal line
plt.axhline(0, color='black', linewidth=1, linestyle='dashed', alpha=0.75)
# Set plot style
plt.style.use('default')
# Set labels and title
plt.ylabel(str(y_label), fontsize=parameter3)
plt.xlabel(str(x_label), fontsize=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), fontsize=parameter5)
plt.grid(axis='both', alpha=0.3)
# Create secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
# Save plot
plt.savefig("hv_tb_w_001_001_m_g_004.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_001_m_g_004.jpg", bbox_inches='tight')
plt.close()
# Clear plot
plt.close('all')
plt.clf()
plt.cla()
# Delete objects



# Filter data
df1 = hv_tb_w_001_001_m_g_001[list_c]
df1 = df1.tail(12)
g1=df1.copy()
# Create plot
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

# Create line plots
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)], 
        color="black", linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Canada " + str(label_t)], 
        color="darkred", linewidth=l1, linestyle='-', marker='s', markersize=s2)

# Add horizontal line
plt.axhline(0, color='black', linewidth=1, linestyle='dashed', alpha=0.75)
# Set plot style
plt.style.use('default')
# Set labels and title
plt.ylabel(str(y_label), fontsize=parameter3)
plt.xlabel(str(x_label), fontsize=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), fontsize=parameter5)
plt.grid(axis='both', alpha=0.3)
# Create secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
# Save plot
plt.savefig("hv_tb_w_001_001_m_g_004z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_001_m_g_004z.jpg", bbox_inches='tight')
plt.close()
# Clear plot
plt.close('all')
plt.clf()
plt.cla()
# Delete objects
del g1
del df1
del list_c
del fig
del ax
del ax2

### 01 02 headline     <a id="title_page"></a>

#### headline inflation
#### headline inflation
#### headline inflation
#### headline inflation
#### headline inflation
print("COUNTRY")
print("INTERNATIONAL")
# Ticker

w_m_tickers = ["h124pc","s156pc",
 "h997pc","h025pc",
 "h023pc","h132pc","s134pc",
 "h136pc","h158pc",
 "h138pc","s142pc","h184pc",
 "h144pc","h146pc",
 "h112pc","s111pc"]

#print("getting from api")
hv_tb_w_001_002_m = Haver.data(w_m_tickers,"g10", dates=True)
#print(hv_tb_w_001_002_m)
#print(hv_tb_w_001_002_m.shape[0],hv_tb_w_001_002_m.shape[1])
# Add more tickers
w_m_tickers1 = ['s193pc', 's196pc']
hv_tb_w_001_002_m1 = Haver.data(w_m_tickers1, "g10", dates=True)
#print(hv_tb_w_001_002_m1)
# Concatenate dataframes
hv_tb_w_001_002_m = pd.concat([hv_tb_w_001_002_m,
                               hv_tb_w_001_002_m1], 
                              axis=1, join="outer")

# Fill missing values
hv_tb_w_001_002_m['s196pc'] = hv_tb_w_001_002_m['s196pc'].fillna(method='bfill')
hv_tb_w_001_002_m['s196pc'] = hv_tb_w_001_002_m['s196pc'].fillna(method='ffill')
hv_tb_w_001_002_m['s193pc'] = hv_tb_w_001_002_m['s193pc'].fillna(method='bfill')
hv_tb_w_001_002_m['s193pc'] = hv_tb_w_001_002_m['s193pc'].fillna(method='ffill')
#print(hv_tb_w_001_002_m)
# Copy data to clipboard
#hv_tb_w_001_002_m.to_clipboard()
# Print column names
#print(hv_tb_w_001_002_m.columns)
w_m_tickers=w_m_tickers+w_m_tickers1
# Calculate year-over-year percentage changes
for x in range(len(w_m_tickers)):
    variable = str(w_m_tickers[x])
    hv_tb_w_001_002_m[variable] = hv_tb_w_001_002_m[variable].pct_change(12).multiply(100).round(3)


print(hv_tb_w_001_002_m.tail(5))

# Rename columns
label_t="CPI All Groups SA Y/Y"
#hv_tb_w_001_002_m.rename(columns={"x193pc": "Australia Monthly CPI All Groups SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"s193pc": "Australia CPI All Groups SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"s196pc": "New Zealand CPI All Groups SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h124pc": "Belgium CPI All Groups SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"s156pc": "Canada CPI All Groups SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h997pc": "EU27 CPI All Groups SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h025pc": "EA20 CPI All Groups SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h023pc": "EA11-20 CPI All Groups SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h132pc": "France CPI All Groups SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"s134pc": "Germany CPI All Groups SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h136pc": "Italy CPI All Groups SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h158pc": "Japan CPI All Groups SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h138pc": "Netherlands CPI All Groups SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"s142pc": "Norway CPI All Groups SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h184pc": "Spain CPI All Groups SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h144pc": "Sweden CPI All Groups SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h146pc": "Switzerland CPI All Groups SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h112pc": "UK CPI All Groups SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"s111pc": "USA CPI All Groups SA Y/Y"}, inplace=True)



hv_tb_w_001_002_m_g0 = hv_tb_w_001_002_m.copy()
hv_tb_w_001_002_m_g0_001 = hv_tb_w_001_002_m.copy()

hv_tb_w_001_002_m_table=hv_tb_w_001_002_m.copy()
hv_tb_w_001_002_m_table = hv_tb_w_001_002_m_table.tail(60)

hv_tb_w_001_002_t1_t = hv_tb_w_001_002_m_table.transpose()
hv_tb_w_001_002_t1_t.index.names = ['Variable']


title_table = "Headline inflation eop"
df = hv_tb_w_001_002_m_table.copy()
df_transposed = hv_tb_w_001_002_t1_t.copy()

fig, ax = plt.subplots(figsize=(36, 13))  # Increase figure width for more space
# Use a mask to prevent NaN values from displaying incorrectly
mask = df_transposed.isnull()

sns.heatmap(df_transposed, annot=True, fmt=".2f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, 
            annot_kws={"fontsize": 12, "fontweight": "bold"},
            mask=mask)  # Mask NaNs to prevent display issues

# Set x-axis labels (months)
xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)
# Set y-axis labels (variable names) on both left and right in horizontal orientation
ytick_labels = df_transposed.index.tolist()  # Extract variable names
ax.set_yticks(np.arange(len(ytick_labels)) + 0.5)  # Align y-ticks
ax.set_yticklabels(ytick_labels, fontsize=12, fontweight="bold", rotation=0)  # Horizontal y-labels
# Enable both left and right y-axis labels
ax.tick_params(axis="y", labelleft=True, labelright=True, left=True, right=True, labelsize=12)
# Fine-tune x-axis limits to fully show the last column on the right
ax.set_xlim(-0.5, len(df_transposed.columns) - 0.01)  # Expands slightly beyond last column
# Adjust layout to prevent cut-off on the right
plt.subplots_adjust(left=0.12, right=0.98, bottom=0.12, top=0.93)  # Extra space on the right
ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

#### Save the figure
plt.savefig("hv_tb_w_001_002_m_table_001.png", dpi=300, bbox_inches="tight")
plt.close()



#print("saving for charts")
hv_tb_w_001_002_m_g_001 = hv_tb_w_001_002_m.copy()
#print("transpose")
hv_tb_w_001_002_m = hv_tb_w_001_002_m.tail(horizon_tb)
hv_tb_w_001_002_m = hv_tb_w_001_002_m.transpose()
hv_tb_w_001_002_m.index.name = 'Variable'
#hv_tb_w_001_002_m.to_clipboard()
#print(hv_tb_w_001_002_m)
#path_displayer = #dashboard_eco\tb_w_001_002_m.csv"
#print(path_displayer)
#hv_tb_w_001_002_m.to_csv(path_displayer, index=True, header=True)
#print(hv_tb_w_001_002_m)
#print("step2")
#hv_tb_w_001_002_m.to_csv(path_displayer, index=True, header=True)
#print(hv_tb_w_001_002_m)

####CPI All Groups SA Y/Y"
####CPI All Groups SA Y/Y"
title_r0 = "CPI All Groups SA Y/Y"
print("step2")
# Set variables
label_t="CPI All Groups SA Y/Y"
title_r=title_r0
y_label = "Index %"
x_label = title_r
list_c = ["USA " + str(label_t), 
          "UK " + str(label_t),
          "EU27 " + str(label_t),
          "EA20 " + str(label_t),
          "EA11-20 " + str(label_t)]

# Filter data
df1 = hv_tb_w_001_002_m_g_001[list_c]
df1 = df1.tail(60)
g1=df1.copy()

# Create plot
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

# Create line plots
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)], 
        color="black", linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK " + str(label_t)], 
        color="darkred", linewidth=l1, linestyle='-', marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EU27 " + str(label_t)], 
        color="darkgreen", linewidth=l1, linestyle='-', marker='^', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA20 " + str(label_t)],
        color="darkorange", linewidth=l1, linestyle='-', marker='x', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA11-20 " + str(label_t)],
        color="magenta", linewidth=l1, linestyle='-', marker='d', markersize=s2)
# Add horizontal line
plt.axhline(0, color='black', linewidth=1, linestyle='dashed', alpha=0.75)
# Set plot style
plt.style.use('default')
# Set labels and title
plt.ylabel(str(y_label), fontsize=parameter3)
plt.xlabel(str(x_label), fontsize=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), fontsize=parameter5)
plt.grid(axis='both', alpha=0.3)
# Create secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
# Save plot
plt.savefig("hv_tb_w_001_002_m_g_001.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_002_m_g_001.jpg", bbox_inches='tight')
plt.close()
# Clear plot
plt.close('all')
plt.clf()
plt.cla()
# Delete objects



# Set variables
title_r = title_r0
y_label = "Index"
x_label = title_r
list_c = ["USA " + str(label_t), 
          "UK " + str(label_t), 
          "EU27 " + str(label_t),
          "EA20 " + str(label_t), 
          "EA11-20 " + str(label_t)]

# Filter data
df1 = hv_tb_w_001_002_m_g_001[list_c]
df1 = df1.tail(12)
g1 = df1.copy()
# Create plot
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)],
        color="black", linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK " + str(label_t)],
        color="darkred", linewidth=l1, linestyle='-', marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EU27 " + str(label_t)], 
        color="darkgreen", linewidth=l1, linestyle='-', marker='^', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA20 " + str(label_t)], 
        color="darkorange", linewidth=l1, linestyle='-', marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA11-20 " + str(label_t)],
        color="magenta", linewidth=l1, linestyle='-', marker='d', markersize=s2)

# Add horizontal line
plt.axhline(0, color='black', linewidth=1, linestyle='dashed', alpha=0.75)
# Set plot style
plt.style.use('default')
# Set labels and title
plt.ylabel(str(y_label), fontsize=parameter3)
plt.xlabel(str(x_label), fontsize=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), fontsize=parameter5)
plt.grid(axis='both', alpha=0.3)
# Create secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

# Save plot
plt.savefig("hv_tb_w_001_002_m_g_001z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_002_m_g_001z.jpg", bbox_inches='tight')
plt.close()

# Clear plot
plt.close('all')
plt.clf()
plt.cla()

# Delete objects
del g1
del df1
del list_c
del fig
del ax
del ax2

####CPI All Groups SA Y/Y"
####CPI All Groups SA Y/Y"

####CPI All Groups SA Y/Y"
####CPI All Groups SA Y/Y"
y_label = "Index"
x_labels = title_r

list_colors = ["Germany "+str(label_t),
                "France "+str(label_t),
                "Spain "+str(label_t),
                "Italy "+str(label_t),
                "Netherlands "+str(label_t)]

df1 = hv_tb_w_001_002_m_g_001[list_colors]
df1 = df1.tail(60)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

g1.plot(kind='line', ax=ax, 
        y="Germany "+str(label_t), color='black',
        linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, 
        y="France "+str(label_t), color='darkred',
        linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,
        y="Spain "+str(label_t), color='darkgreen',
        linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,
        y="Italy "+str(label_t), color='darkorange', 
        linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, 
        y="Netherlands "+str(label_t), color='magenta', 
        linewidth=l1, linestyle='-', marker='o', markersize=s2)

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)

plt.style.use("default")
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)

ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

plt.savefig("hv_tb_w_001_002_m_g_002.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_002_m_g_002.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()

del g1
del df1
del list_colors
del fig



title_r=title_r0
y_label="Index"
x_label=title_r

list_c=["Germany "+str(label_t),
        "France "+str(label_t),
        "Spain "+str(label_t),
        "Italy "+str(label_t),
        "Netherlands "+str(label_t)]

df1=hv_tb_w_001_002_m_g_001[list_c]
df1=df1.tail(12)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

g1.plot(kind='line', ax=ax, y=["Germany "+str(label_t)], color="black",
        linewidth=l1, linestyle="-",
        marker="P", markersize=s2)
g1.plot(kind='line', ax=ax, y=["France "+str(label_t)], color="darkred",
        linewidth= l1, linestyle="-",
        marker="s", markersize=s2)
g1.plot(kind='line', ax=ax, y=["Spain "+str(label_t)], color="darkgreen",
        linewidth= l1, linestyle="-",
        marker=">", markersize=s2)
g1.plot(kind='line', ax=ax, y=["Italy "+str(label_t)], color="darkorange",
        linewidth= l1, linestyle="-",
        marker="x", markersize=s2)
g1.plot(kind='line', ax=ax, y=["Netherlands "+str(label_t)], color="magenta",
        linewidth= l1, linestyle="-",
        marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_002_m_g_002z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_002_m_g_002z.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2


####CPI All Groups SA Y/Y"
####CPI All Groups SA Y/Y"
title_r=title_r0
y_label="Index"
x_label=title_r
list_c=["EU27 "+str(label_t),
        "UK "+str(label_t),
        "Norway "+str(label_t),
        "Sweden "+str(label_t),
        "Switzerland "+str(label_t)]
df1=hv_tb_w_001_002_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s,parameter2_s))
g1.plot(kind='line', ax=ax,y=["EU27 "+str(label_t)], color="black",
                                         linewidth= l1, linestyle='-',
                                         marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK "+str(label_t)], color="darkred",
                                         linewidth= l1, linestyle='-',
                                         marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Norway "+str(label_t)], color="darkgreen",
                                         linewidth= l1, linestyle='-',
                                         marker='>', markersize=s2)
g1.plot(kind="line", ax=ax, y=["Sweden "+str(label_t)], color="darkorange",
                                         linewidth= l1, linestyle='-',
                                         marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Switzerland "+str(label_t)], color="magenta",
                                         linewidth= l1, linestyle='-',
                                         marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_002_m_g_003.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_002_m_g_003.jpg", bbox_inches='tight')
plt.close()
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2


title_r=title_r0
y_label="Index"
x_label=title_r
list_c=["EU27 "+str(label_t),
        "UK "+str(label_t),
        "Norway "+str(label_t),
        "Sweden "+str(label_t),
        "Switzerland "+str(label_t)]
df1=hv_tb_w_001_002_m_g_001[list_c]
df1=df1.tail(12)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s,parameter2_s))
g1.plot(kind='line', ax=ax,y=["EU27 "+str(label_t)], color="black",
                                         linewidth= l1, linestyle='-',
                                         marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK "+str(label_t)], color="darkred",
                                         linewidth= l1, linestyle='-',
                                         marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Norway "+str(label_t)], color="darkgreen",
                                         linewidth= l1, linestyle='-',
                                         marker='>', markersize=s2)
g1.plot(kind="line", ax=ax, y=["Sweden "+str(label_t)], color="darkorange",
                                         linewidth= l1, linestyle='-',
                                         marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Switzerland "+str(label_t)], color="magenta",
                                         linewidth= l1, linestyle='-',
                                         marker='o', markersize=s2)

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_002_m_g_003z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_002_m_g_003z.jpg", bbox_inches='tight')
plt.close()
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

####CPI All Groups SA Y/Y"
####CPI All Groups SA Y/Y"
title_r=title_r0
y_label="Index"
x_label=title_r
list_c = ["USA " + str(label_t),
          "EU27 " + str(label_t),
          "Australia " + str(label_t),
          "New Zealand " + str(label_t),
          "Japan " + str(label_t)]

df1 = hv_tb_w_001_002_m_g_001[list_c]
df1 = df1.tail(60)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)], color="black",
         linewidth=l1, linestyle='-',
         marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EU27 " + str(label_t)], color="darkred",
         linewidth=l1, linestyle='-',
         marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Australia " + str(label_t)], color="darkgreen",
         linewidth=l1, linestyle='-',
         marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=["New Zealand " + str(label_t)], color="darkorange",
         linewidth=l1, linestyle='-',
         marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Japan " + str(label_t)], color="magenta",
         linewidth=l1, linestyle='-',
         marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_002_m_g_004.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_002_m_g_004.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r=title_r0
y_label="Index"
x_label=title_r
list_c = ["USA " + str(label_t),
          "EU27 " + str(label_t),
          "Australia " + str(label_t),
          "New Zealand " + str(label_t),
          "Japan " + str(label_t)]

df1 = hv_tb_w_001_002_m_g_001[list_c]
df1 = df1.tail(12)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)], color="black",
         linewidth=l1, linestyle='-',
         marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EU27 " + str(label_t)], color="darkred",
         linewidth=l1, linestyle='-',
         marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Australia " + str(label_t)], color="darkgreen",
         linewidth=l1, linestyle='-',
         marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=["New Zealand " + str(label_t)], color="darkorange",
         linewidth=l1, linestyle='-',
         marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Japan " + str(label_t)], color="magenta",
         linewidth=l1, linestyle='-',
         marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_002_m_g_004z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_002_m_g_004z.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2











### 01 03   core cross comparison
<a id="title_page"></a>

####Core XCComparison SA Y/Y
###Core XCComparison SA Y/Y
# Cross Country Consumer Expectations Survey (CES)
# Euro Area --> Total --> (Mean) --> Inflation expectations over the

# COUNTRY
print("COUNTRY")
print("INTERNATIONAL")
# Ticker
w_m_tickers = ['s111pcx', 'h112pcx', 'h997pcx',
           'h025pcx', 'h023pcx', 'h132pcx', 
           'h134pcx', 'h136pcx', 'h124pcx', 'h138pcx', 'h184pcx', 
           'h156pcx', 'h158pcx', 'h142pcx', 'h144pcx', 'h146pcx']

#print("getting from api")
hv_tb_w_001_002_m = Haver.data(w_m_tickers,"g10", dates=True)
#print(hv_tb_w_001_002_m)
#print(hv_tb_w_001_002_m.shape[0],hv_tb_w_001_002_m.shape[1])
# Add more tickers
w_m_tickers1 = ['h196pcx', 'h193pcx']
hv_tb_w_001_002_m1 = Haver.data(w_m_tickers1, "g10", dates=True)
# Concatenate dataframes
hv_tb_w_001_002_m = pd.concat([hv_tb_w_001_002_m, hv_tb_w_001_002_m1], axis=1, join="outer")

# Fill missing values
hv_tb_w_001_002_m['h196pcx'] = hv_tb_w_001_002_m['h196pcx'].fillna(method='bfill')
hv_tb_w_001_002_m['h196pcx'] = hv_tb_w_001_002_m['h196pcx'].fillna(method='ffill')
hv_tb_w_001_002_m['h193pcx'] = hv_tb_w_001_002_m['h193pcx'].fillna(method='bfill')
hv_tb_w_001_002_m['h193pcx'] = hv_tb_w_001_002_m['h193pcx'].fillna(method='ffill')
#print(hv_tb_w_001_002_m)
# Copy data to clipboard
#hv_tb_w_001_002_m.to_clipboard()
# Print column names
#print(hv_tb_w_001_002_m.columns)
w_m_tickers=w_m_tickers+w_m_tickers1
# Calculate year-over-year percentage changes
for x in range(len(w_m_tickers)):
    variable = str(w_m_tickers[x])
    hv_tb_w_001_002_m[variable] = hv_tb_w_001_002_m[variable].pct_change(12).multiply(100).round(3)

# Rename columns
label_t="Core XCComparison SA Y/Y"
hv_tb_w_001_002_m.rename(columns={"h193pcx": "Australia Core XCComparison SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h196pcx": "New Zealand Core XCComparison SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h124pcx": "Belgium Core XCComparison SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h156pcx": "Canada Core XCComparison SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h997pcx": "EU27 Core XCComparison SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h025pcx": "EA20 Core XCComparison SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h023pcx": "EA11-20 Core XCComparison SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h132pcx": "France Core XCComparison SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h134pcx": "Germany Core XCComparison SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h136pcx": "Italy Core XCComparison SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h158pcx": "Japan Core XCComparison SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h138pcx": "Netherlands Core XCComparison SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h142pcx": "Norway Core XCComparison SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h184pcx": "Spain Core XCComparison SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h144pcx": "Sweden Core XCComparison SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h146pcx": "Switzerland Core XCComparison SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"h112pcx": "UK Core XCComparison SA Y/Y"}, inplace=True)
hv_tb_w_001_002_m.rename(columns={"s111pcx": "USA Core XCComparison SA Y/Y"}, inplace=True)



hv_tb_w_001_002_m_g0 = hv_tb_w_001_002_m.copy()
hv_tb_w_001_002_m_g0_001 = hv_tb_w_001_002_m.copy()

hv_tb_w_001_002_m_table=hv_tb_w_001_002_m.copy()
hv_tb_w_001_002_m_table = hv_tb_w_001_002_m_table.tail(60)

hv_tb_w_001_002_t1_t = hv_tb_w_001_002_m_table.transpose()
hv_tb_w_001_002_t1_t.index.names = ['Variable']




title_table = "Core inflation cross eop"
df = hv_tb_w_001_002_m_table.copy()
df_transposed = hv_tb_w_001_002_t1_t.copy()

fig, ax = plt.subplots(figsize=(36, 8))  # Increase figure width for more space
# Use a mask to prevent NaN values from displaying incorrectly
mask = df_transposed.isnull()

sns.heatmap(df_transposed, annot=True, fmt=".2f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, 
            annot_kws={"fontsize": 13, "fontweight": "bold"},
            mask=mask)  # Mask NaNs to prevent display issues

# Set x-axis labels (months)
xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)
# Set y-axis labels (variable names) on both left and right in horizontal orientation
ytick_labels = df_transposed.index.tolist()  # Extract variable names
ax.set_yticks(np.arange(len(ytick_labels)) + 0.5)  # Align y-ticks
ax.set_yticklabels(ytick_labels, fontsize=12, fontweight="bold", rotation=0)  # Horizontal y-labels
# Enable both left and right y-axis labels
ax.tick_params(axis="y", labelleft=True, labelright=True, left=True, right=True, labelsize=12)
# Fine-tune x-axis limits to fully show the last column on the right
ax.set_xlim(-0.5, len(df_transposed.columns) - 0.01)  # Expands slightly beyond last column
# Adjust layout to prevent cut-off on the right
plt.subplots_adjust(left=0.12, right=0.98, bottom=0.12, top=0.93)  # Extra space on the right
ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

#### Save the figure
plt.savefig("hv_tb_w_001_003_m_table_001.png", dpi=300, bbox_inches="tight")
plt.close()




#print("saving for charts")
hv_tb_w_001_002_m_g_001 = hv_tb_w_001_002_m.copy()
#print("transpose")
hv_tb_w_001_002_m = hv_tb_w_001_002_m.tail(horizon_tb)
hv_tb_w_001_002_m = hv_tb_w_001_002_m.transpose()
hv_tb_w_001_002_m.index.name = 'Variable'
#hv_tb_w_001_002_m.to_clipboard()
#print(hv_tb_w_001_002_m)
#path_displayer = #dashboard_eco\tb_w_001_002_m.csv"
#print(path_displayer)
#hv_tb_w_001_002_m.to_csv(path_displayer, index=True, header=True)
#print(hv_tb_w_001_002_m)
#print("step2")
#hv_tb_w_001_002_m.to_csv(path_displayer, index=True, header=True)
#print(hv_tb_w_001_002_m)
print("step2")
# Set variables
title_r0 = "Core XCComparison SA"
title_r=title_r0
y_label = "Index %"
x_label = title_r
list_c = ["USA " + str(label_t), 
          "UK " + str(label_t),
          "EU27 " + str(label_t),
          "EA20 " + str(label_t),
          "EA11-20 " + str(label_t)]

# Filter data
df1 = hv_tb_w_001_002_m_g_001[list_c]
df1 = df1.tail(60)
g1=df1.copy()

# Create plot
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

# Create line plots
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)], 
        color="black", linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK " + str(label_t)], 
        color="darkred", linewidth=l1, linestyle='-', marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EU27 " + str(label_t)], 
        color="darkgreen", linewidth=l1, linestyle='-', marker='^', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA20 " + str(label_t)],
        color="darkorange", linewidth=l1, linestyle='-', marker='x', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA11-20 " + str(label_t)],
        color="magenta", linewidth=l1, linestyle='-', marker='d', markersize=s2)
# Add horizontal line
plt.axhline(0, color='black', linewidth=1, linestyle='dashed', alpha=0.75)
# Set plot style
plt.style.use('default')
# Set labels and title
plt.ylabel(str(y_label), fontsize=parameter3)
plt.xlabel(str(x_label), fontsize=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), fontsize=parameter5)
plt.grid(axis='both', alpha=0.3)
# Create secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
# Save plot
plt.savefig("hv_tb_w_001_003_m_g_001.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_003_m_g_001.jpg", bbox_inches='tight')
plt.close()
# Clear plot
plt.close('all')
plt.clf()
plt.cla()
# Delete objects
del g1
del df1
del list_c
del fig
del ax
del ax2


# Set variables
title_r = title_r0
y_label = "Index"
x_label = title_r
list_c = ["USA " + str(label_t), 
          "UK " + str(label_t), 
          "EU27 " + str(label_t),
          "EA20 " + str(label_t), 
          "EA11-20 " + str(label_t)]

# Filter data
df1 = hv_tb_w_001_002_m_g_001[list_c]
df1 = df1.tail(12)
g1 = df1.copy()
# Create plot
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)],
        color="black", linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK " + str(label_t)],
        color="darkred", linewidth=l1, linestyle='-', marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EU27 " + str(label_t)], 
        color="darkgreen", linewidth=l1, linestyle='-', marker='^', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA20 " + str(label_t)], 
        color="darkorange", linewidth=l1, linestyle='-', marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA11-20 " + str(label_t)],
        color="magenta", linewidth=l1, linestyle='-', marker='d', markersize=s2)

# Add horizontal line
plt.axhline(0, color='black', linewidth=1, linestyle='dashed', alpha=0.75)
# Set plot style
plt.style.use('default')
# Set labels and title
plt.ylabel(str(y_label), fontsize=parameter3)
plt.xlabel(str(x_label), fontsize=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), fontsize=parameter5)
plt.grid(axis='both', alpha=0.3)
# Create secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

# Save plot
plt.savefig("hv_tb_w_001_003_m_g_001z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_003_m_g_001z.jpg", bbox_inches='tight')
plt.close()

# Clear plot
plt.close('all')
plt.clf()
plt.cla()

# Delete objects
del g1
del df1
del list_c
del fig
del ax
del ax2

####Core XCComparison SA Y/Y
###Core XCComparison SA Y/Y


#"Netherlands HICP Core SA Y/Y",
#"France HICP Core SA Y/Y",
#"Spain HICP Core SA Y/Y",
#"Germany HICP Core SA Y/Y",
#"Italy HICP Core SA Y/Y",

title_r = title_r
y_label = "Index"
x_labels = title_r

list_colors = ["Germany "+str(label_t),
                "France "+str(label_t),
                "Spain "+str(label_t),
                "Italy "+str(label_t),
                "Netherlands "+str(label_t)]

df1 = hv_tb_w_001_002_m_g_001[list_colors]
df1 = df1.tail(60)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

g1.plot(kind='line', ax=ax, 
        y="Germany "+str(label_t), color='black',
        linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, 
        y="France "+str(label_t), color='darkred',
        linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,
        y="Spain "+str(label_t), color='darkgreen',
        linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,
        y="Italy "+str(label_t), color='darkorange', 
        linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, 
        y="Netherlands "+str(label_t), color='magenta', 
        linewidth=l1, linestyle='-', marker='o', markersize=s2)

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)

plt.style.use("default")
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)

ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

plt.savefig("hv_tb_w_001_003_m_g_002.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_003_m_g_002.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()

del g1
del df1
del list_colors
del fig

####Core XCComparison SA Y/Y
###Core XCComparison SA Y/Y


title_r=title_r0
y_label="Index"
x_label=title_r

list_c=["Germany "+str(label_t),
        "France "+str(label_t),
        "Spain "+str(label_t),
        "Italy "+str(label_t),
        "Netherlands "+str(label_t)]

df1=hv_tb_w_001_002_m_g_001[list_c]
df1=df1.tail(12)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

g1.plot(kind='line', ax=ax, y=["Germany "+str(label_t)], color="black",
        linewidth=l1, linestyle="-",
        marker="P", markersize=s2)
g1.plot(kind='line', ax=ax, y=["France "+str(label_t)], color="darkred",
        linewidth= l1, linestyle="-",
        marker="s", markersize=s2)
g1.plot(kind='line', ax=ax, y=["Spain "+str(label_t)], color="darkgreen",
        linewidth= l1, linestyle="-",
        marker=">", markersize=s2)
g1.plot(kind='line', ax=ax, y=["Italy "+str(label_t)], color="darkorange",
        linewidth= l1, linestyle="-",
        marker="x", markersize=s2)
g1.plot(kind='line', ax=ax, y=["Netherlands "+str(label_t)], color="magenta",
        linewidth= l1, linestyle="-",
        marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_003_m_g_002z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_003_m_g_002z.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2






####Core XCComparison SA Y/Y
###Core XCComparison SA Y/Y


title_r=title_r0
y_label="Index"
x_label=title_r
list_c=["EU27 "+str(label_t),
        "UK "+str(label_t),
        "Norway "+str(label_t),
        "Sweden "+str(label_t),
        "Switzerland "+str(label_t)]
df1=hv_tb_w_001_002_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s,parameter2_s))
g1.plot(kind='line', ax=ax,y=["EU27 "+str(label_t)], color="black",
                                         linewidth= l1, linestyle='-',
                                         marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK "+str(label_t)], color="darkred",
                                         linewidth= l1, linestyle='-',
                                         marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Norway "+str(label_t)], color="darkgreen",
                                         linewidth= l1, linestyle='-',
                                         marker='>', markersize=s2)
g1.plot(kind="line", ax=ax, y=["Sweden "+str(label_t)], color="darkorange",
                                         linewidth= l1, linestyle='-',
                                         marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Switzerland "+str(label_t)], color="magenta",
                                         linewidth= l1, linestyle='-',
                                         marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_003_m_g_003.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_003_m_g_003.jpg", bbox_inches='tight')
plt.close()
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2


title_r=title_r0
y_label="Index"
x_label=title_r
list_c=["EU27 "+str(label_t),
        "UK "+str(label_t),
        "Norway "+str(label_t),
        "Sweden "+str(label_t),
        "Switzerland "+str(label_t)]
df1=hv_tb_w_001_002_m_g_001[list_c]
df1=df1.tail(12)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s,parameter2_s))
g1.plot(kind='line', ax=ax,y=["EU27 "+str(label_t)], color="black",
                                         linewidth= l1, linestyle='-',
                                         marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK "+str(label_t)], color="darkred",
                                         linewidth= l1, linestyle='-',
                                         marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Norway "+str(label_t)], color="darkgreen",
                                         linewidth= l1, linestyle='-',
                                         marker='>', markersize=s2)
g1.plot(kind="line", ax=ax, y=["Sweden "+str(label_t)], color="darkorange",
                                         linewidth= l1, linestyle='-',
                                         marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Switzerland "+str(label_t)], color="magenta",
                                         linewidth= l1, linestyle='-',
                                         marker='o', markersize=s2)

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_003_m_g_003z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_003_m_g_003z.jpg", bbox_inches='tight')
plt.close()
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2
####Core XCComparison SA Y/Y
###Core XCComparison SA Y/Y

####Core XCComparison SA Y/Y
###Core XCComparison SA Y/Y


title_r=title_r0
y_label="Index"
x_label=title_r
list_c = ["USA " + str(label_t),
          "EU27 " + str(label_t),
          "Australia " + str(label_t),
          "New Zealand " + str(label_t),
          "Japan " + str(label_t)]

df1 = hv_tb_w_001_002_m_g_001[list_c]
df1 = df1.tail(60)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)], color="black",
         linewidth=l1, linestyle='-',
         marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EU27 " + str(label_t)], color="darkred",
         linewidth=l1, linestyle='-',
         marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Australia " + str(label_t)], color="darkgreen",
         linewidth=l1, linestyle='-',
         marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=["New Zealand " + str(label_t)], color="darkorange",
         linewidth=l1, linestyle='-',
         marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Japan " + str(label_t)], color="magenta",
         linewidth=l1, linestyle='-',
         marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_003_m_g_004.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_003_m_g_004.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r=title_r0
y_label="Index"
x_label=title_r
list_c = ["USA " + str(label_t),
          "EU27 " + str(label_t),
          "Australia " + str(label_t),
          "New Zealand " + str(label_t),
          "Japan " + str(label_t)]

df1 = hv_tb_w_001_002_m_g_001[list_c]
df1 = df1.tail(12)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)], color="black",
         linewidth=l1, linestyle='-',
         marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EU27 " + str(label_t)], color="darkred",
         linewidth=l1, linestyle='-',
         marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Australia " + str(label_t)], color="darkgreen",
         linewidth=l1, linestyle='-',
         marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=["New Zealand " + str(label_t)], color="darkorange",
         linewidth=l1, linestyle='-',
         marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Japan " + str(label_t)], color="magenta",
         linewidth=l1, linestyle='-',
         marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_003_m_g_004z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_003_m_g_004z.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2
####Core XCComparison SA Y/Y
###Core XCComparison SA Y/Y


### 01 04 core headline     <a id="title_page"></a>

###Core (Headline Series) S
###Core (Headline Series) S
###Core (Headline Series) S




# Ticker
w_m_tickers = ["h193pcix","h196pcxf",
               "h124pcxn","s156pcxg",
               "h025phxc","h023phxc","h997phxc","s132pcxg",
               "s134pcxe",
               #"h138pcxg",
               "h136pcxg","h158pcxf",
               "h142pcxe","h184pcxg","h144pcxi","h146pcxg",
               "h112pcxf","s111pcxg"]

#'g10:h125phxc', 'g10:h123phxc', 'g10:s134pcke', 'g10:h138pcxg', 'g10:h158pcaf']

#print("getting from api")
hv_tb_w_001_003_m = Haver.data(w_m_tickers,"g10", dates=True)
print(hv_tb_w_001_003_m)
#print(hv_tb_w_001_002_m.shape[0],hv_tb_w_001_002_m.shape[1])
# Add more tickers
#codesnotfound': ['g10:h125phxc', 'g10:h123phxc', 'g10:s134pcke', 'g10:h138pcxg', 'g10:h158pcaf']

print(hv_tb_w_001_003_m.columns)

for x in range(len(w_m_tickers)):
    variable = str(w_m_tickers[x])
    hv_tb_w_001_003_m[variable]=hv_tb_w_001_003_m[variable].pct_change(12).multiply(100).round(3)

print("renaming")
label_t="Core (Headline Series) SA Y/Y"
hv_tb_w_001_003_m.rename(columns={"h193pcix": "Australia Core (Headline Series) SA Y/Y"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"h196pcxf": "New Zealand Core (Headline Series) SA Y/Y"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"h124pcxn": "Belgium Core (Headline Series) SA Y/Y"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s156pcxg": "Canada Core (Headline Series) SA Y/Y"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"h025phxc": "EA20 Core (Headline Series) SA Y/Y"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"h023phxc": "EA11-20 Core (Headline Series) SA Y/Y"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"h997phxc": "EU27 Core (Headline Series) SA Y/Y"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s132pcxg": "France Core (Headline Series) SA Y/Y"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s134pcxe": "Germany Core (Headline Series) SA Y/Y"}, inplace=True)
#hv_tb_w_001_003_m.rename(columns={"h138pcxg": "Netherlands Core (Headline Series) SA Y/Y"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"h136pcxg": "Italy Core (Headline Series) SA Y/Y"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"h158pcxf": "Japan Core (Headline Series) SA Y/Y"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"h142pcxe": "Norway Core (Headline Series) SA Y/Y"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"h184pcxg": "Spain Core (Headline Series) SA Y/Y"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"h144pcxi": "Sweden Core (Headline Series) SA Y/Y"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"h146pcxg": "Switzerland Core (Headline Series) SA Y/Y"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"h112pcxf": "UK Core (Headline Series) SA Y/Y"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s111pcxg": "USA Core (Headline Series) SA Y/Y"}, inplace=True)

hv_tb_w_001_003_m_g0 = hv_tb_w_001_003_m.copy()
hv_tb_w_001_003_m_g0_001 = hv_tb_w_001_003_m.copy()

hv_tb_w_001_003_m_table=hv_tb_w_001_003_m.copy()
hv_tb_w_001_003_m_table = hv_tb_w_001_003_m_table.tail(60)

hv_tb_w_001_003_t1_t = hv_tb_w_001_003_m_table.transpose()
hv_tb_w_001_003_t1_t.index.names = ['Variable']
print(hv_tb_w_001_003_t1_t.shape[0])
print(hv_tb_w_001_003_t1_t.shape[1])

title_table = "Core inflation Headline series eop"
df = hv_tb_w_001_003_m_table.copy()
df_transposed = hv_tb_w_001_003_t1_t.copy()

fig, ax = plt.subplots(figsize=(36, 8))  # Increase figure width for more space
# Use a mask to prevent NaN values from displaying incorrectly
mask = df_transposed.isnull()

sns.heatmap(df_transposed, annot=True, fmt=".2f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, 
            annot_kws={"fontsize": 12, "fontweight": "bold"},
            mask=mask)  # Mask NaNs to prevent display issues

# Set x-axis labels (months)
xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)
# Set y-axis labels (variable names) on both left and right in horizontal orientation
ytick_labels = df_transposed.index.tolist()  # Extract variable names
ax.set_yticks(np.arange(len(ytick_labels)) + 0.5)  # Align y-ticks
ax.set_yticklabels(ytick_labels, fontsize=12, fontweight="bold", rotation=0)  # Horizontal y-labels
# Enable both left and right y-axis labels
ax.tick_params(axis="y", labelleft=True, labelright=True, left=True, right=True, labelsize=12)
# Fine-tune x-axis limits to fully show the last column on the right
ax.set_xlim(-0.5, len(df_transposed.columns) - 0.01)  # Expands slightly beyond last column
# Adjust layout to prevent cut-off on the right
plt.subplots_adjust(left=0.12, right=0.98, bottom=0.12, top=0.93)  # Extra space on the right
ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

#### Save the figure
plt.savefig("hv_tb_w_001_004_m_table_001.png", dpi=300, bbox_inches="tight")
plt.close()





print(hv_tb_w_001_003_m.columns.tolist())
print("saving for charts")
hv_tb_w_001_003_m_g_001 = hv_tb_w_001_003_m.copy()
print("transpose")
hv_tb_w_001_003_m = hv_tb_w_001_003_m.tail(horizon_tb)
hv_tb_w_001_003_m = hv_tb_w_001_003_m.transpose()
hv_tb_w_001_003_m.index.names = ['Variable']
# dashboard.to_clipboard()
#print(hv_tb_w_001_003_m)
# dashboard.to_clipboard()
#path_display = rtb_w_001_003_m.csv"
#print(path_display)
#hv_tb_w_001_003_m.to_csv(path_display, index=True, header=True)
#print(hv_tb_w_001_003_m)
print("step2")

###graphs
###"Core (Headline Series) SA Y/Y"
##"Core (Headline Series) SA Y/Y"
title_r0 = "Core (Headline Series) SA Y/Y"
title_r=title_r0
y_label = "Index %"
x_label = title_r
list_c = [("USA " + str(label_t)),
          
          ("UK " + str(label_t)),
          ("EU27 " + str(label_t)),
          ("EA20 " + str(label_t)),
          ("EA11-20 " + str(label_t))]
#print(list_c)
# Filter data
df1 = hv_tb_w_001_003_m_g_001[list_c]
df1 = df1.tail(60)
g1=df1.copy()
# Create plot
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

# Create line plots
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)], 
        color="black", linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK " + str(label_t)], 
        color="darkred", linewidth=l1, linestyle='-', marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EU27 " + str(label_t)], 
        color="darkgreen", linewidth=l1, linestyle='-', marker='^', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA20 " + str(label_t)],
        color="darkorange", linewidth=l1, linestyle='-', marker='x', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA11-20 " + str(label_t)],
        color="magenta", linewidth=l1, linestyle='-', marker='d', markersize=s2)
# Add horizontal line
plt.axhline(0, color='black', linewidth=1, linestyle='dashed', alpha=0.75)
# Set plot style
plt.style.use('default')
# Set labels and title
plt.ylabel(str(y_label), fontsize=parameter3)
plt.xlabel(str(x_label), fontsize=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), fontsize=parameter5)
plt.grid(axis='both', alpha=0.3)
# Create secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
# Save plot
plt.savefig("hv_tb_w_001_004_m_g_001.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_004_m_g_001.jpg", bbox_inches='tight')
plt.close()
# Clear plot
plt.close('all')
plt.clf()
plt.cla()
# Delete objects
del g1
del df1
del list_c
del fig
del ax
del ax2


# Set variables
title_r = title_r0
y_label = "Index"
x_label = title_r
list_c = ["USA " + str(label_t), 
          "UK " + str(label_t), 
          "EU27 " + str(label_t),
          "EA20 " + str(label_t), 
          "EA11-20 " + str(label_t)]
# Filter data
df1 = hv_tb_w_001_003_m_g_001[list_c]
df1 = df1.tail(12)
g1 = df1.copy()
# Create plot
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)],
        color="black", linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK " + str(label_t)],
        color="darkred", linewidth=l1, linestyle='-', marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EU27 " + str(label_t)], 
        color="darkgreen", linewidth=l1, linestyle='-', marker='^', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA20 " + str(label_t)], 
        color="darkorange", linewidth=l1, linestyle='-', marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA11-20 " + str(label_t)],
        color="magenta", linewidth=l1, linestyle='-', marker='d', markersize=s2)
# Add horizontal line
plt.axhline(0, color='black', linewidth=1, linestyle='dashed', alpha=0.75)
# Set plot style
plt.style.use('default')
# Set labels and title
plt.ylabel(str(y_label), fontsize=parameter3)
plt.xlabel(str(x_label), fontsize=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), fontsize=parameter5)
plt.grid(axis='both', alpha=0.3)
# Create secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
# Save plot
plt.savefig("hv_tb_w_001_004_m_g_001z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_004_m_g_001z.jpg", bbox_inches='tight')
plt.close()
# Clear plot
plt.close('all')
plt.clf()
plt.cla()
# Delete objects
del g1
del df1
del list_c
del fig
del ax
del ax2

###"Core (Headline Series) SA Y/Y"

###"Core (Headline Series) SA Y/Y"
title_r = title_r
y_label = "Index"
x_labels = title_r
list_c = ["Germany "+str(label_t),
                "France "+str(label_t),
                "Spain "+str(label_t),
                "Italy "+str(label_t)]
df1 = hv_tb_w_001_003_m_g_001[list_c]
df1 = df1.tail(60)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

g1.plot(kind='line', ax=ax, 
        y="Germany "+str(label_t), color='black',
        linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, 
        y="France "+str(label_t), color='darkred',
        linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,
        y="Spain "+str(label_t), color='darkgreen',
        linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,
        y="Italy "+str(label_t), color='darkorange', 
        linewidth=l1, linestyle='-', marker='o', markersize=s2)


plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use("default")
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_004_m_g_002.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_004_m_g_002.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del fig

####Core XCComparison SA Y/Y
###Core XCComparison SA Y/Y


title_r=title_r0
y_label="Index"
x_label=title_r

list_c=["Germany "+str(label_t),
        "France "+str(label_t),
        "Spain "+str(label_t),
        "Italy "+str(label_t),]

df1=hv_tb_w_001_003_m_g_001[list_c]
df1=df1.tail(12)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

g1.plot(kind='line', ax=ax, y=["Germany "+str(label_t)], color="black",
        linewidth=l1, linestyle="-",
        marker="P", markersize=s2)
g1.plot(kind='line', ax=ax, y=["France "+str(label_t)], color="darkred",
        linewidth= l1, linestyle="-",
        marker="s", markersize=s2)
g1.plot(kind='line', ax=ax, y=["Spain "+str(label_t)], color="darkgreen",
        linewidth= l1, linestyle="-",
        marker=">", markersize=s2)
g1.plot(kind='line', ax=ax, y=["Italy "+str(label_t)], color="darkorange",
        linewidth= l1, linestyle="-",
        marker="x", markersize=s2)

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_004_m_g_002z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_004_m_g_002z.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2


###"Core (Headline Series) SA Y/Y"

###"Core (Headline Series) SA Y/Y"
title_r=title_r0
y_label="Index"
x_label=title_r
list_c=["EU27 "+str(label_t),
        "UK "+str(label_t),
        "Norway "+str(label_t),
        "Sweden "+str(label_t),
        "Switzerland "+str(label_t)]
df1=hv_tb_w_001_003_m_g_001[list_c]
df1=df1.tail(60)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s,parameter2_s))
g1.plot(kind='line', ax=ax,y=["EU27 "+str(label_t)], color="black",
                                         linewidth= l1, linestyle='-',
                                         marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK "+str(label_t)], color="darkred",
                                         linewidth= l1, linestyle='-',
                                         marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Norway "+str(label_t)], color="darkgreen",
                                         linewidth= l1, linestyle='-',
                                         marker='>', markersize=s2)
g1.plot(kind="line", ax=ax, y=["Sweden "+str(label_t)], color="darkorange",
                                         linewidth= l1, linestyle='-',
                                         marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Switzerland "+str(label_t)], color="magenta",
                                         linewidth= l1, linestyle='-',
                                         marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_004_m_g_003.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_004_m_g_003.jpg", bbox_inches='tight')
plt.close()
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2


title_r=title_r0
y_label="Index"
x_label=title_r
list_c=["EU27 "+str(label_t),
        "UK "+str(label_t),
        "Norway "+str(label_t),
        "Sweden "+str(label_t),
        "Switzerland "+str(label_t)]
df1=hv_tb_w_001_003_m_g_001[list_c]
df1=df1.tail(12)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s,parameter2_s))
g1.plot(kind='line', ax=ax,y=["EU27 "+str(label_t)], color="black",
                                         linewidth= l1, linestyle='-',
                                         marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK "+str(label_t)], color="darkred",
                                         linewidth= l1, linestyle='-',
                                         marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Norway "+str(label_t)], color="darkgreen",
                                         linewidth= l1, linestyle='-',
                                         marker='>', markersize=s2)
g1.plot(kind="line", ax=ax, y=["Sweden "+str(label_t)], color="darkorange",
                                         linewidth= l1, linestyle='-',
                                         marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Switzerland "+str(label_t)], color="magenta",
                                         linewidth= l1, linestyle='-',
                                         marker='o', markersize=s2)

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_004_m_g_003z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_004_m_g_003z.jpg", bbox_inches='tight')
plt.close()
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2
###"Core (Headline Series) SA Y/Y"

###"Core (Headline Series) SA Y/Y"
title_r=title_r0
y_label="Index"
x_label=title_r
list_c = ["USA " + str(label_t),
          "EU27 " + str(label_t),
          "Australia " + str(label_t),
          "New Zealand " + str(label_t),
          "Japan " + str(label_t)]

df1 = hv_tb_w_001_003_m_g_001[list_c]
df1 = df1.tail(60)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)], color="black",
         linewidth=l1, linestyle='-',
         marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EU27 " + str(label_t)], color="darkred",
         linewidth=l1, linestyle='-',
         marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Australia " + str(label_t)], color="darkgreen",
         linewidth=l1, linestyle='-',
         marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=["New Zealand " + str(label_t)], color="darkorange",
         linewidth=l1, linestyle='-',
         marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Japan " + str(label_t)], color="magenta",
         linewidth=l1, linestyle='-',
         marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_004_m_g_004.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_004_m_g_004.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r=title_r0
y_label="Index"
x_label=title_r
list_c = ["USA " + str(label_t),
          "EU27 " + str(label_t),
          "Australia " + str(label_t),
          "New Zealand " + str(label_t),
          "Japan " + str(label_t)]

df1 = hv_tb_w_001_003_m_g_001[list_c]
df1 = df1.tail(12)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)], color="black",
         linewidth=l1, linestyle='-',
         marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EU27 " + str(label_t)], color="darkred",
         linewidth=l1, linestyle='-',
         marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Australia " + str(label_t)], color="darkgreen",
         linewidth=l1, linestyle='-',
         marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=["New Zealand " + str(label_t)], color="darkorange",
         linewidth=l1, linestyle='-',
         marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Japan " + str(label_t)], color="magenta",
         linewidth=l1, linestyle='-',
         marker='o', markersize=s2)
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_004_m_g_004z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_004_m_g_004z.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2













###"Core (Headline Series) SA Y/Y"

### 01 05 labor force     <a id="title_page"></a>

#### Labor force partifcaption rate
#### Labor force partifcaption rate
#### Labor force partifcaption rate
#G10+: Major Economic and Financial Indicators 
#Labor Force Participation Rate (15-64) 

# Ticker
w_m_tickers = ["s193elpr",
               "h196elpr",
               "h124elpr",
               "s156elpr",
               "h025elpr",
               #"h023elpr",
               "h997elpr",
               "s132elpr",
               "h134elpr",
               #"h138elpr",
               "h136elpr",
               "h158elpr",
               "h142elpr",
               "h184elpr",
               "h144elpr",
               "h146elpr",
               "s112elpr",
               "s111elpr"]


#h196elpr

#print("getting from api")
hv_tb_w_001_003_m = Haver.data(w_m_tickers,"g10", dates=True)
print(hv_tb_w_001_003_m)
#print(hv_tb_w_001_002_m.shape[0],hv_tb_w_001_002_m.shape[1])
# Add more tickers
#codesnotfound': ['g10:h125phxc', 'g10:h123phxc', 'g10:s134pcke', 'g10:h138pcxg', 'g10:h158pcaf']

print(hv_tb_w_001_003_m.columns)

#for x in range(len(w_m_tickers)):
#    variable = str(w_m_tickers[x])
#    hv_tb_w_001_003_m[variable]=hv_tb_w_001_003_m[variable].pct_change(12).multiply(100).round(3)

print("renaming")
label_t="LF Participation SA"
hv_tb_w_001_003_m.rename(columns={"s193elpr": "Australia LF Participation SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"h196elpr": "New Zealand LF Participation SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"h124elpr": "Belgium LF Participation SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s156elpr": "Canada LF Participation SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"h025elpr": "EA20 LF Participation SA"}, inplace=True)
#hv_tb_w_001_003_m.rename(columns={"h023elpr": "EA11-20 LF Participation SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"h997elpr": "EU27 LF Participation SA"}, inplace=True)
#q
hv_tb_w_001_003_m.rename(columns={"s132elpr": "France LF Participation SA"}, inplace=True)
#q
hv_tb_w_001_003_m.rename(columns={"h134elpr": "Germany LF Participation SA"}, inplace=True)
#hv_tb_w_001_003_m.rename(columns={"h138pcxg": "Netherlands Core (Headline Series) SA Y/Y"}, inplace=True)
#q
hv_tb_w_001_003_m.rename(columns={"h136elpr": "Italy LF Participation SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"h158elpr": "Japan LF Participation SA"}, inplace=True)
#q
hv_tb_w_001_003_m.rename(columns={"h142elpr": "Norway LF Participation SA"}, inplace=True)
#q
hv_tb_w_001_003_m.rename(columns={"h184elpr": "Spain LF Participation SA"}, inplace=True)
#q
hv_tb_w_001_003_m.rename(columns={"h144elpr": "Sweden LF Participation SA"}, inplace=True)
#q
hv_tb_w_001_003_m.rename(columns={"h146elpr": "Switzerland LF Participation SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s112elpr": "UK LF Participation SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s111elpr": "USA LF Participation SA"}, inplace=True)

hv_tb_w_001_003_m_g0 = hv_tb_w_001_003_m.copy()
hv_tb_w_001_003_m_g0_001 = hv_tb_w_001_003_m.copy()

hv_tb_w_001_003_m_table=hv_tb_w_001_003_m.copy()
hv_tb_w_001_003_m_table = hv_tb_w_001_003_m_table.tail(60)

hv_tb_w_001_003_t1_t = hv_tb_w_001_003_m_table.transpose()
hv_tb_w_001_003_t1_t.index.names = ['Variable']
#print(hv_tb_w_001_001_t1_t.shape[0])
#print(hv_tb_w_001_001_t1_t.shape[1])



title_table = "LF eop"
df = hv_tb_w_001_003_m_table.copy()
df_transposed = hv_tb_w_001_003_t1_t.copy()

fig, ax = plt.subplots(figsize=(36, 8))  # Increase figure width for more space
# Use a mask to prevent NaN values from displaying incorrectly
mask = df_transposed.isnull()

sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, 
            annot_kws={"fontsize": 13, "fontweight": "bold"},
            mask=mask)  # Mask NaNs to prevent display issues

# Set x-axis labels (months)
xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)
# Set y-axis labels (variable names) on both left and right in horizontal orientation
ytick_labels = df_transposed.index.tolist()  # Extract variable names
ax.set_yticks(np.arange(len(ytick_labels)) + 0.5)  # Align y-ticks
ax.set_yticklabels(ytick_labels, fontsize=12, fontweight="bold", rotation=0)  # Horizontal y-labels
# Enable both left and right y-axis labels
ax.tick_params(axis="y", labelleft=True, labelright=True, left=True, right=True, labelsize=12)
# Fine-tune x-axis limits to fully show the last column on the right
ax.set_xlim(-0.5, len(df_transposed.columns) - 0.01)  # Expands slightly beyond last column
# Adjust layout to prevent cut-off on the right
plt.subplots_adjust(left=0.12, right=0.98, bottom=0.12, top=0.93)  # Extra space on the right
ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

#### Save the figure
plt.savefig("hv_tb_w_001_005_m_table_001.png", dpi=300, bbox_inches="tight")
plt.close()










print(hv_tb_w_001_003_m.columns.tolist())
print("saving for charts")
hv_tb_w_001_003_m_g_001 = hv_tb_w_001_003_m.copy()
print("transpose")
hv_tb_w_001_003_m = hv_tb_w_001_003_m.tail(horizon_tb)
hv_tb_w_001_003_m = hv_tb_w_001_003_m.transpose()
hv_tb_w_001_003_m.index.names = ['Variable']
# dashboard.to_clipboard()
#print(hv_tb_w_001_003_m)
# dashboard.to_clipboard()
#path_display = rtb_w_001_003_m.csv"
#print(path_display)
#hv_tb_w_001_003_m.to_csv(path_display, index=True, header=True)
#print(hv_tb_w_001_003_m)
print("step2")

###graphs
#### Labor force partifcaption rate
title_r0 = "LF Participation SA"
title_r=title_r0
y_label = "Index %"
x_label = title_r
list_c = [("USA " + str(label_t)),
          
          ("UK " + str(label_t)),
          ("EU27 " + str(label_t)),
          ("EA20 " + str(label_t))]
#print(list_c)
# Filter data
df1 = hv_tb_w_001_003_m_g_001[list_c]
df1 = df1.tail(100)
g1=df1.copy()
# Create plot
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

# Create line plots
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)], 
        color="black", linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK " + str(label_t)], 
        color="darkred", linewidth=l1, linestyle='-', marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EU27 " + str(label_t)], 
        color="darkgreen", linewidth=l1, linestyle='-', marker='^', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA20 " + str(label_t)],
        color="darkorange", linewidth=l1, linestyle='-', marker='x', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["EA11-20 " + str(label_t)],
#        color="magenta", linewidth=l1, linestyle='-', marker='d', markersize=s2)
# Add horizontal line
#plt.axhline(0, color='black', linewidth=1, linestyle='dashed', alpha=0.75)
# Set plot style
plt.style.use('default')
# Set labels and title
plt.ylabel(str(y_label), fontsize=parameter3)
plt.xlabel(str(x_label), fontsize=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), fontsize=parameter5)
plt.grid(axis='both', alpha=0.3)
# Create secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
# Save plot
plt.savefig("hv_tb_w_001_005_m_g_001.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_005_m_g_001.jpg", bbox_inches='tight')
plt.close()
# Clear plot
plt.close('all')
plt.clf()
plt.cla()
# Delete objects
del g1
del df1
del list_c
del fig
del ax
del ax2


# Set variables
title_r = title_r0
y_label = "Index"
x_label = title_r
list_c = ["USA " + str(label_t), 
          "UK " + str(label_t), 
          "EU27 " + str(label_t),
          "EA20 " + str(label_t),]
# Filter data
df1 = hv_tb_w_001_003_m_g_001[list_c]
df1 = df1.tail(50)
g1 = df1.copy()
# Create plot
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)],
        color="black", linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK " + str(label_t)],
        color="darkred", linewidth=l1, linestyle='-', marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EU27 " + str(label_t)], 
        color="darkgreen", linewidth=l1, linestyle='-', marker='^', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA20 " + str(label_t)], 
        color="darkorange", linewidth=l1, linestyle='-', marker='*', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["EA11-20 " + str(label_t)],
#        color="magenta", linewidth=l1, linestyle='-', marker='d', markersize=s2)
# Add horizontal line
#plt.axhline(0, color='black', linewidth=1, linestyle='dashed', alpha=0.75)
# Set plot style
plt.style.use('default')
# Set labels and title
plt.ylabel(str(y_label), fontsize=parameter3)
plt.xlabel(str(x_label), fontsize=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), fontsize=parameter5)
plt.grid(axis='both', alpha=0.3)
# Create secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
# Save plot
plt.savefig("hv_tb_w_001_005_m_g_001z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_005_m_g_001z.jpg", bbox_inches='tight')
plt.close()
# Clear plot
plt.close('all')
plt.clf()
plt.cla()
# Delete objects
del g1
del df1
del list_c
del fig
del ax
del ax2
#### Labor force partifcaption rate

#### Labor force partifcaption rate


title_r = title_r
y_label = "Index"
x_labels = title_r
list_c = ["Germany "+str(label_t),
                "France "+str(label_t),
                "Spain "+str(label_t),
                "Italy "+str(label_t)]
df1 = hv_tb_w_001_003_m_g_001[list_c]
df1 = df1.tail(100)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

g1.plot(kind='line', ax=ax, 
        y="Germany "+str(label_t), color='black',
        linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, 
        y="France "+str(label_t), color='darkred',
        linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,
        y="Spain "+str(label_t), color='darkgreen',
        linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,
        y="Italy "+str(label_t), color='darkorange', 
        linewidth=l1, linestyle='-', marker='o', markersize=s2)


#plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use("default")
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_005_m_g_002.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_005_m_g_002.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del fig

####Core XCComparison SA Y/Y
###Core XCComparison SA Y/Y


title_r=title_r0
y_label="Index"
x_label=title_r

list_c=["Germany "+str(label_t),
        "France "+str(label_t),
        "Spain "+str(label_t),
        "Italy "+str(label_t),]

df1=hv_tb_w_001_003_m_g_001[list_c]
df1=df1.tail(50)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

g1.plot(kind='line', ax=ax, y=["Germany "+str(label_t)], color="black",
        linewidth=l1, linestyle="-",
        marker="P", markersize=s2)
g1.plot(kind='line', ax=ax, y=["France "+str(label_t)], color="darkred",
        linewidth= l1, linestyle="-",
        marker="s", markersize=s2)
g1.plot(kind='line', ax=ax, y=["Spain "+str(label_t)], color="darkgreen",
        linewidth= l1, linestyle="-",
        marker=">", markersize=s2)
g1.plot(kind='line', ax=ax, y=["Italy "+str(label_t)], color="darkorange",
        linewidth= l1, linestyle="-",
        marker="x", markersize=s2)

#plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_005_m_g_002z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_005_m_g_002z.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2
#### Labor force partifcaption rate

#### Labor force partifcaption rate

title_r=title_r0
y_label="Index"
x_label=title_r
list_c=["EU27 "+str(label_t),
        "UK "+str(label_t),
        "Norway "+str(label_t),
        "Sweden "+str(label_t),
        "Switzerland "+str(label_t)]
df1=hv_tb_w_001_003_m_g_001[list_c]
df1=df1.tail(100)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s,parameter2_s))
g1.plot(kind='line', ax=ax,y=["EU27 "+str(label_t)], color="black",
                                         linewidth= l1, linestyle='-',
                                         marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK "+str(label_t)], color="darkred",
                                         linewidth= l1, linestyle='-',
                                         marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Norway "+str(label_t)], color="darkgreen",
                                         linewidth= l1, linestyle='-',
                                         marker='>', markersize=s2)
g1.plot(kind="line", ax=ax, y=["Sweden "+str(label_t)], color="darkorange",
                                         linewidth= l1, linestyle='-',
                                         marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Switzerland "+str(label_t)], color="magenta",
                                         linewidth= l1, linestyle='-',
                                         marker='o', markersize=s2)
#plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_005_m_g_003.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_005_m_g_003.jpg", bbox_inches='tight')
plt.close()
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2


title_r=title_r0
y_label="Index"
x_label=title_r
list_c=["EU27 "+str(label_t),
        "UK "+str(label_t),
        "Norway "+str(label_t),
        "Sweden "+str(label_t),
        "Switzerland "+str(label_t)]
df1=hv_tb_w_001_003_m_g_001[list_c]
df1=df1.tail(50)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s,parameter2_s))
g1.plot(kind='line', ax=ax,y=["EU27 "+str(label_t)], color="black",
                                         linewidth= l1, linestyle='-',
                                         marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK "+str(label_t)], color="darkred",
                                         linewidth= l1, linestyle='-',
                                         marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Norway "+str(label_t)], color="darkgreen",
                                         linewidth= l1, linestyle='-',
                                         marker='>', markersize=s2)
g1.plot(kind="line", ax=ax, y=["Sweden "+str(label_t)], color="darkorange",
                                         linewidth= l1, linestyle='-',
                                         marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Switzerland "+str(label_t)], color="magenta",
                                         linewidth= l1, linestyle='-',
                                         marker='o', markersize=s2)

#plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_005_m_g_003z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_005_m_g_003z.jpg", bbox_inches='tight')
plt.close()
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

#### Labor force partifcaption rate

#### Labor force partifcaption rate

title_r=title_r0
y_label="Index"
x_label=title_r
list_c = ["USA " + str(label_t),
          "EU27 " + str(label_t),
          "Australia " + str(label_t),
          "New Zealand " + str(label_t),
          "Japan " + str(label_t)]

df1 = hv_tb_w_001_003_m_g_001[list_c]
df1 = df1.tail(100)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)], color="black",
         linewidth=l1, linestyle='-',
         marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EU27 " + str(label_t)], color="darkred",
         linewidth=l1, linestyle='-',
         marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Australia " + str(label_t)], color="darkgreen",
         linewidth=l1, linestyle='-',
         marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=["New Zealand " + str(label_t)], color="darkorange",
         linewidth=l1, linestyle='-',
         marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Japan " + str(label_t)], color="magenta",
         linewidth=l1, linestyle='-',
         marker='o', markersize=s2)
#plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_005_m_g_004.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_005_m_g_004.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r=title_r0
y_label="Index"
x_label=title_r
list_c = ["USA " + str(label_t),
          "EU27 " + str(label_t),
          "Australia " + str(label_t),
          "New Zealand " + str(label_t),
          "Japan " + str(label_t)]

df1 = hv_tb_w_001_003_m_g_001[list_c]
df1 = df1.tail(50)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)], color="black",
         linewidth=l1, linestyle='-',
         marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EU27 " + str(label_t)], color="darkred",
         linewidth=l1, linestyle='-',
         marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Australia " + str(label_t)], color="darkgreen",
         linewidth=l1, linestyle='-',
         marker='>', markersize=s2)
g1.plot(kind='line', ax=ax, y=["New Zealand " + str(label_t)], color="darkorange",
         linewidth=l1, linestyle='-',
         marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Japan " + str(label_t)], color="magenta",
         linewidth=l1, linestyle='-',
         marker='o', markersize=s2)
#plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_005_m_g_004z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_005_m_g_004z.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2



#### Labor force partifcaption rate

### 01 06 ur    <a id="title_page"></a>

###### Unemplyoment rate

# Ticker
w_m_tickers = ["s193elur",
      #         "s196elur",
               "s124elur",
               "s156elur",
               "s025elur",
               #"h023elpr",
               "s997elur",
  #             "s132elur",
               "s134elur",
               #"h138elpr",
               "s136elur",
               "s158elur",
               "s142elur",
            #   "s184elur",
               "s144elur",
               "s146elur",
               "s112elur",
               "s111elur"]




#codesnotfound': ['g10:h196elur', 'g10:h124elur', 'g10:h025elur',
#'g10:h997elur', 'g10:h134elur', 'g10:h136elur',
#'g10:h158elur', 'g10:h142elur', 'g10:h146elur'],

#h196elpr

#print("getting from api")
hv_tb_w_001_003_m = Haver.data(w_m_tickers,"g10", dates=True)
print(hv_tb_w_001_003_m)
#print(hv_tb_w_001_002_m.shape[0],hv_tb_w_001_002_m.shape[1])
# Add more tickers
#codesnotfound': ['g10:h125phxc', 'g10:h123phxc', 'g10:s134pcke', 'g10:h138pcxg', 'g10:h158pcaf']

print(hv_tb_w_001_003_m.columns)

#for x in range(len(w_m_tickers)):
#    variable = str(w_m_tickers[x])
#    hv_tb_w_001_003_m[variable]=hv_tb_w_001_003_m[variable].pct_change(12).multiply(100).round(3)

print("renaming")
label_t="UR SA"
hv_tb_w_001_003_m.rename(columns={"s193elur": "Australia UR SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s196elur": "New Zealand UR SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s124elur": "Belgium UR SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s156elur": "Canada UR SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s025elur": "EA20 UR SA"}, inplace=True)
#hv_tb_w_001_003_m.rename(columns={"h023elpr": "EA11-20 LF Participation SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s997elur": "EU27 UR SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s132elur": "France UR SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s134elur": "Germany UR SA"}, inplace=True)
#hv_tb_w_001_003_m.rename(columns={"h138pcxg": "Netherlands Core (Headline Series) SA Y/Y"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s136elur": "Italy UR SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s158elur": "Japan UR SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s142elur": "Norway UR SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s184elur": "Spain UR SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s144elur": "Sweden UR SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s146elur": "Switzerland UR SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s112elur": "UK UR SA"}, inplace=True)
hv_tb_w_001_003_m.rename(columns={"s111elur": "USA UR SA"}, inplace=True)



hv_tb_w_001_003_m_g0 = hv_tb_w_001_003_m.copy()
hv_tb_w_001_003_m_g0_001 = hv_tb_w_001_003_m.copy()

hv_tb_w_001_003_m_table=hv_tb_w_001_003_m.copy()
hv_tb_w_001_003_m_table = hv_tb_w_001_003_m_table.tail(60)

hv_tb_w_001_003_t1_t = hv_tb_w_001_003_m_table.transpose()
hv_tb_w_001_003_t1_t.index.names = ['Variable']
#print(hv_tb_w_001_001_t1_t.shape[0])
#print(hv_tb_w_001_001_t1_t.shape[1])



title_table = "UR eop"
df = hv_tb_w_001_003_m_table.copy()
df_transposed = hv_tb_w_001_003_t1_t.copy()

fig, ax = plt.subplots(figsize=(36, 8))  # Increase figure width for more space
# Use a mask to prevent NaN values from displaying incorrectly
mask = df_transposed.isnull()

sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, 
            annot_kws={"fontsize": 13, "fontweight": "bold"},
            mask=mask)  # Mask NaNs to prevent display issues

# Set x-axis labels (months)
xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)
# Set y-axis labels (variable names) on both left and right in horizontal orientation
ytick_labels = df_transposed.index.tolist()  # Extract variable names
ax.set_yticks(np.arange(len(ytick_labels)) + 0.5)  # Align y-ticks
ax.set_yticklabels(ytick_labels, fontsize=12, fontweight="bold", rotation=0)  # Horizontal y-labels
# Enable both left and right y-axis labels
ax.tick_params(axis="y", labelleft=True, labelright=True, left=True, right=True, labelsize=12)
# Fine-tune x-axis limits to fully show the last column on the right
ax.set_xlim(-0.5, len(df_transposed.columns) - 0.01)  # Expands slightly beyond last column
# Adjust layout to prevent cut-off on the right
plt.subplots_adjust(left=0.12, right=0.98, bottom=0.12, top=0.93)  # Extra space on the right
ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

#### Save the figure
plt.savefig("hv_tb_w_001_006_m_table_001.png", dpi=300, bbox_inches="tight")
plt.close()




print(hv_tb_w_001_003_m.columns.tolist())
print("saving for charts")
hv_tb_w_001_003_m_g_001 = hv_tb_w_001_003_m.copy()
print("transpose")
hv_tb_w_001_003_m = hv_tb_w_001_003_m.tail(horizon_tb)
hv_tb_w_001_003_m = hv_tb_w_001_003_m.transpose()
hv_tb_w_001_003_m.index.names = ['Variable']
# dashboard.to_clipboard()
#print(hv_tb_w_001_003_m)
# dashboard.to_clipboard()
#path_display = rtb_w_001_003_m.csv"
#print(path_display)
#hv_tb_w_001_003_m.to_csv(path_display, index=True, header=True)
#print(hv_tb_w_001_003_m)
#print("step2")


###### Unemplyoment rate

###### Unemplyoment rate


title_r0 = "UR SA"
title_r=title_r0
y_label = "Index %"
x_label = title_r
list_c = [("USA " + str(label_t)),
          
          ("UK " + str(label_t)),
          ("EU27 " + str(label_t)),
          ("EA20 " + str(label_t))]
#print(list_c)
# Filter data
df1 = hv_tb_w_001_003_m_g_001[list_c]
df1 = df1.tail(100)
g1=df1.copy()
# Create plot
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

# Create line plots
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)], 
        color="black", linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK " + str(label_t)], 
        color="darkred", linewidth=l1, linestyle='-', marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EU27 " + str(label_t)], 
        color="darkgreen", linewidth=l1, linestyle='-', marker='^', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA20 " + str(label_t)],
        color="darkorange", linewidth=l1, linestyle='-', marker='x', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["EA11-20 " + str(label_t)],
#        color="magenta", linewidth=l1, linestyle='-', marker='d', markersize=s2)
# Add horizontal line
#plt.axhline(0, color='black', linewidth=1, linestyle='dashed', alpha=0.75)
# Set plot style
plt.style.use('default')
# Set labels and title
plt.ylabel(str(y_label), fontsize=parameter3)
plt.xlabel(str(x_label), fontsize=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), fontsize=parameter5)
plt.grid(axis='both', alpha=0.3)
# Create secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
# Save plot
plt.savefig("hv_tb_w_001_006_m_g_001.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_006_m_g_001.jpg", bbox_inches='tight')
plt.close()
# Clear plot
plt.close('all')
plt.clf()
plt.cla()
# Delete objects
del g1
del df1
del list_c
del fig
del ax
del ax2


# Set variables
title_r = title_r0
y_label = "Index"
x_label = title_r
list_c = ["USA " + str(label_t), 
          "UK " + str(label_t), 
          "EU27 " + str(label_t),
          "EA20 " + str(label_t),]
# Filter data
df1 = hv_tb_w_001_003_m_g_001[list_c]
df1 = df1.tail(50)
g1 = df1.copy()
# Create plot
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)],
        color="black", linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK " + str(label_t)],
        color="darkred", linewidth=l1, linestyle='-', marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EU27 " + str(label_t)], 
        color="darkgreen", linewidth=l1, linestyle='-', marker='^', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EA20 " + str(label_t)], 
        color="darkorange", linewidth=l1, linestyle='-', marker='*', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["EA11-20 " + str(label_t)],
#        color="magenta", linewidth=l1, linestyle='-', marker='d', markersize=s2)
# Add horizontal line
#plt.axhline(0, color='black', linewidth=1, linestyle='dashed', alpha=0.75)
# Set plot style
plt.style.use('default')
# Set labels and title
plt.ylabel(str(y_label), fontsize=parameter3)
plt.xlabel(str(x_label), fontsize=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), fontsize=parameter5)
plt.grid(axis='both', alpha=0.3)
# Create secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
# Save plot
plt.savefig("hv_tb_w_001_006_m_g_001z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_006_m_g_001z.jpg", bbox_inches='tight')
plt.close()
# Clear plot
plt.close('all')
plt.clf()
plt.cla()
# Delete objects
del g1
del df1
del list_c
del fig
del ax
del ax2

###### Unemplyoment rate

###### Unemplyoment rate

title_r = title_r
y_label = "Index"
x_labels = title_r
list_c = ["Germany "+str(label_t),
               # "France "+str(label_t),
              #  "Spain "+str(label_t),
                "Italy "+str(label_t)]
df1 = hv_tb_w_001_003_m_g_001[list_c]
df1 = df1.tail(100)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

g1.plot(kind='line', ax=ax, 
        y="Germany "+str(label_t), color='black',
        linewidth=l1, linestyle='-', marker='o', markersize=s2)
#g1.plot(kind='line', ax=ax, 
#        y="France "+str(label_t), color='darkred',
#        linewidth=l1, linestyle='-', marker='o', markersize=s2)
#g1.plot(kind='line', ax=ax,
#        y="Spain "+str(label_t), color='darkgreen',
#        linewidth=l1, linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax,
        y="Italy "+str(label_t), color='darkorange', 
        linewidth=l1, linestyle='-', marker='o', markersize=s2)


#plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use("default")
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_006_m_g_002.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_006_m_g_002.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del fig


title_r=title_r0
y_label="Index"
x_label=title_r

list_c=["Germany "+str(label_t),
    #    "France "+str(label_t),
     #   "Spain "+str(label_t),
        "Italy "+str(label_t),]

df1=hv_tb_w_001_003_m_g_001[list_c]
df1=df1.tail(50)
g1=df1.copy()
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))

g1.plot(kind='line', ax=ax, y=["Germany "+str(label_t)], color="black",
        linewidth=l1, linestyle="-",
        marker="P", markersize=s2)
#g1.plot(kind='line', ax=ax, y=["France "+str(label_t)], color="darkred",
#        linewidth= l1, linestyle="-",
#        marker="s", markersize=s2)
#g1.plot(kind='line', ax=ax, y=["Spain "+str(label_t)], color="darkgreen",
#        linewidth= l1, linestyle="-",
#        marker=">", markersize=s2)
g1.plot(kind='line', ax=ax, y=["Italy "+str(label_t)], color="darkorange",
        linewidth= l1, linestyle="-",
        marker="x", markersize=s2)

#plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_006_m_g_002z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_006_m_g_002z.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2


###### Unemplyoment rate

###### Unemplyoment rate


title_r=title_r0
y_label="Index"
x_label=title_r
list_c=["EU27 "+str(label_t),
        "UK "+str(label_t),
        "Norway "+str(label_t),
        "Sweden "+str(label_t),
        "Switzerland "+str(label_t)]
df1=hv_tb_w_001_003_m_g_001[list_c]
df1=df1.tail(100)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s,parameter2_s))
g1.plot(kind='line', ax=ax,y=["EU27 "+str(label_t)], color="black",
                                         linewidth= l1, linestyle='-',
                                         marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK "+str(label_t)], color="darkred",
                                         linewidth= l1, linestyle='-',
                                         marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Norway "+str(label_t)], color="darkgreen",
                                         linewidth= l1, linestyle='-',
                                         marker='>', markersize=s2)
g1.plot(kind="line", ax=ax, y=["Sweden "+str(label_t)], color="darkorange",
                                         linewidth= l1, linestyle='-',
                                         marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Switzerland "+str(label_t)], color="magenta",
                                         linewidth= l1, linestyle='-',
                                         marker='o', markersize=s2)
#plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_006_m_g_003.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_006_m_g_003.jpg", bbox_inches='tight')
plt.close()
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2


title_r=title_r0
y_label="Index"
x_label=title_r
list_c=["EU27 "+str(label_t),
        "UK "+str(label_t),
        "Norway "+str(label_t),
        "Sweden "+str(label_t),
        "Switzerland "+str(label_t)]
df1=hv_tb_w_001_003_m_g_001[list_c]
df1=df1.tail(50)
g1=df1.copy()
fig,ax=plt.subplots(figsize=(parameter1_s,parameter2_s))
g1.plot(kind='line', ax=ax,y=["EU27 "+str(label_t)], color="black",
                                         linewidth= l1, linestyle='-',
                                         marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["UK "+str(label_t)], color="darkred",
                                         linewidth= l1, linestyle='-',
                                         marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Norway "+str(label_t)], color="darkgreen",
                                         linewidth= l1, linestyle='-',
                                         marker='>', markersize=s2)
g1.plot(kind="line", ax=ax, y=["Sweden "+str(label_t)], color="darkorange",
                                         linewidth= l1, linestyle='-',
                                         marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Switzerland "+str(label_t)], color="magenta",
                                         linewidth= l1, linestyle='-',
                                         marker='o', markersize=s2)

#plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_006_m_g_003z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_006_m_g_003z.jpg", bbox_inches='tight')
plt.close()
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

###### Unemplyoment rate

###### Unemplyoment rate


title_r=title_r0
y_label="Index"
x_label=title_r
list_c = ["USA " + str(label_t),
          "EU27 " + str(label_t),
          "Australia " + str(label_t),
        #  "New Zealand " + str(label_t),
          "Japan " + str(label_t)]

df1 = hv_tb_w_001_003_m_g_001[list_c]
df1 = df1.tail(100)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)], color="black",
         linewidth=l1, linestyle='-',
         marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EU27 " + str(label_t)], color="darkred",
         linewidth=l1, linestyle='-',
         marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Australia " + str(label_t)], color="darkgreen",
         linewidth=l1, linestyle='-',
         marker='>', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["New Zealand " + str(label_t)], color="darkorange",
#         linewidth=l1, linestyle='-',
#         marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Japan " + str(label_t)], color="magenta",
         linewidth=l1, linestyle='-',
         marker='o', markersize=s2)
#plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_006_m_g_004.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_006_m_g_004.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2

title_r=title_r0
y_label="Index"
x_label=title_r
list_c = ["USA " + str(label_t),
          "EU27 " + str(label_t),
          "Australia " + str(label_t),
     #     "New Zealand " + str(label_t),
          "Japan " + str(label_t)]

df1 = hv_tb_w_001_003_m_g_001[list_c]
df1 = df1.tail(50)
g1=df1.copy()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=["USA " + str(label_t)], color="black",
         linewidth=l1, linestyle='-',
         marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=["EU27 " + str(label_t)], color="darkred",
         linewidth=l1, linestyle='-',
         marker='s', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Australia " + str(label_t)], color="darkgreen",
         linewidth=l1, linestyle='-',
         marker='>', markersize=s2)
#g1.plot(kind='line', ax=ax, y=["New Zealand " + str(label_t)], color="darkorange",
##         linewidth=l1, linestyle='-',
#         marker='*', markersize=s2)
g1.plot(kind='line', ax=ax, y=["Japan " + str(label_t)], color="magenta",
         linewidth=l1, linestyle='-',
         marker='o', markersize=s2)
#plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_001_006_m_g_004z.png", bbox_inches='tight')
plt.savefig("hv_tb_w_001_006_m_g_004z.jpg", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
del list_c
del fig
del ax
del ax2


###### Unemplyoment rate

### 011 policy rate   <a id="title_page"></a>

###### POLICY rates
w_s_tickers = ["n193rtar", "n156rtar", "n023rtar", "n196rtar", "n142rtar", 
               "n144rtar", "n146rtar", "n112rtar", "n111rtar"]


#hv_tb_w_001_001_m.rename(columns={"n193rtar": "Australia Policy Rate"}, inplace=True)
#hv_tb_w_001_001_m.rename(columns={"n156rtar": "Canada Policy Rate"}, inplace=True)
#hv_tb_w_001_001_m.rename(columns={"n023rtar": "EA Policy Rate"}, inplace=True)
#hv_tb_w_001_001_m.rename(columns={"n196rtar": "New Zealand Policy Rate"}, inplace=True)
#]hv_tb_w_001_001_m.rename(columns={"n142rtar": "Norway Policy Rate"}, inplace=True)
#h#v_tb_w_001_001_m.rename(columns={"n144rtar": "Sweden Policy Rate"}, inplace=True)
#h#v_tb_w_001_001_m.rename(columns={"n146rtar": "Switzerland Policy Rate"}, inplace=True)
#hv_tb_w_001_001_m.rename(columns={"n112rtar": "UK Policy Rate"}, inplace=True)
#hv_tb_w_001_001_m.rename(columns={"n111rtar": "USA Policy Rate"}, inplace=True)


list_p = ["n111rtar",
          "n156rtar",
          "n023rtar","n023rtar","n023rtar","n023rtar",
          "n112rtar",
          "n142rtar","n144rtar",
          "n146rtar",
          "n193rtar","n196rtar"]

list_p_n = ["USA Policy Rate",
          "Canada Policy Rate",
          "EA Policy Rate","EA Policy Rate","EA Policy Rate","EA Policy Rate",
          "UK Policy Rate",
          "Norway Policy Rate","Sweden Policy Rate",
          "Switzerland Policy Rate",
          "Australia Policy Rate","New Zealand Policy Rate"]


#hv_tb_w_001_003_m.rename(columns={"s193elur": "Australia UR SA"}, inplace=True)
#hv_tb_w_001_003_m.rename(columns={"s196elur": "New Zealand UR SA"}, inplace=True)
#hv_tb_w_001_003_m.rename(columns={"s124elur": "Belgium UR SA"}, inplace=True)
#hv_tb_w_001_003_m.rename(columns={"s156elur": "Canada UR SA"}, inplace=True)
#hv_tb_w_001_003_m.rename(columns={"s025elur": "EA20 UR SA"}, inplace=True)
###hv_tb_w_001_003_m.rename(columns={"h023elpr": "EA11-20 LF Participation SA"}, inplace=True)
#hv_tb_w_001_003_m.rename(columns={"s997elur": "EU27 UR SA"}, inplace=True)
#hv_tb_w_001_003_m.rename(columns={"s132elur": "France UR SA"}, inplace=True)
#hv_tb_w_001_003_m.rename(columns={"s134elur": "Germany UR SA"}, inplace=True)
##hv_tb_w_001_003_m.rename(columns={"h138pcxg": "Netherlands Core (Headline Series) SA Y/Y"}, inplace=True)
#hv_tb_w_001_003_m.rename(columns={"s136elur": "Italy UR SA"}, inplace=True)
#hv_tb_w_001_003_m.rename(columns={"s158elur": "Japan UR SA"}, inplace=True)
#hv_tb_w_001_003_m.rename(columns={"s142elur": "Norway UR SA"}, inplace=True)
#hv_tb_w_001_003_m.rename(columns={"s184elur": "Spain UR SA"}, inplace=True)
#hv_tb_w_001_003_m.rename(columns={"s144elur": "Sweden UR SA"}, inplace=True)
#hv_tb_w_001_003_m.rename(columns={"s146elur": "Switzerland UR SA"}, inplace=True)
#hv_tb_w_001_003_m.rename(columns={"s112elur": "UK UR SA"}, inplace=True)
#hv_tb_w_001_003_m.rename(columns={"s111elur": "USA UR SA"}, inplace=True)

list_u = ["s111elur",
          "s156elur",
          "s025elur","s997elur","s132elur","s134elur",
          "s112elur",
          "s142elur","s144elur",
          "s146elur",
          "s193elur","s196elur"]

list_u_n = ["USA UR",
          "Canada UR",
          "EA20 UR","EU27 UR","France UR","Germany UR",
          "UK UR",
          "Norway UR","Sweden UR",
          "Switzerland UR",
          "Australia UR","New Zealand UR"]



n=0
# Calculate year-over-year percentage changes
for x in range(len(list_p)):
    variable_p = str(list_p[x])
    variable_p_n = str(list_p_n[x])
    variable_u = str(list_u[x])
    variable_u_n = str(list_u_n[x])
    list_h = [variable_p,
              variable_u]
    #print(list_h)
    hv_tb_w_000_001_m=Haver.data(list_h, "G10", dates=True)
    hv_tb_w_000_001_m.rename(columns={str(variable_p): str(variable_p_n)}, 
                             inplace=True)
    hv_tb_w_000_001_m.rename(columns={str(variable_u): str(variable_u_n)}, 
                             inplace=True)
    #print(hv_tb_w_000_001_m)
    hv_tb_w_000_001_m_g_001=hv_tb_w_000_001_m.tail(48)
    df1=hv_tb_w_000_001_m_g_001.copy()
    df1_list=df1.columns.tolist()
    df1.index= df1.index.date
    g1=df1.copy()
    fig, ax = plt.subplots (figsize=(6,6))
    title_r=str(variable_p_n) + " vs " +str(variable_u_n)
    y_label=str(variable_p_n)
    x_label=str(variable_u_n)
    plt.scatter (g1[str(variable_u_n)],
                 g1[str(variable_p_n)], 
                 cmap="brg", zorder=2)
    plt.plot(g1[str(variable_u_n)], 
             g1 [str(variable_p_n)], 
             zorder=1)
    
    for line in range(0, g1.shape[0], 1):
        plt.annotate(
            g1.index[line],
            (g1[str(variable_u_n)].iloc[line],
             g1[str(variable_p_n)].iloc[line]),
            va='top',
            textcoords="offset points", # how to position the text
            xytext=(0,10), # distance from text to points (x,y)
            ha='center',
            size = 5)
    
    plt.legend()
    plt.style.use('default')
    
    plt.ylabel(str(y_label), 
               size=12)
    plt.xlabel(str(x_label), 
               size=12)
    plt.title(str(title_r), 
              size=12)
    plt.tick_params(labelsize=7)
    plt.grid(axis='both', alpha=.3)
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    plt.savefig("hv_tb_w_001_007_m_g_00"+str(n)+".png", 
                bbox_inches="tight")
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    del df1
    n=n+1









####US Credit Impulse



w_m_tickers = ['s111cimg', 's112cimg', 
               's023cimg', 'h132cimg', 
               'h134cimg']
#print("getting from api")
hv_tb_w_011_001_m=Haver.data(w_m_tickers, "g10", dates=True)
print(hv_tb_w_011_001_m)
#print(hv_tb_w_011_001_m.columns)
hv_tb_w_011_001_m.rename(columns={"s111cimg": "US Credit Impulse"}, inplace=True)
hv_tb_w_011_001_m.rename(columns={"s112cimg": "UK Credit Impulse"}, inplace=True)
hv_tb_w_011_001_m.rename(columns={"s023cimg": "EU Credit Impulse"}, inplace=True)
hv_tb_w_011_001_m.rename(columns={"h132cimg": "France Credit Impulse"}, inplace=True)
hv_tb_w_011_001_m.rename(columns={"h134cimg": "Germany Credit Impulse"}, inplace=True)
hv_tb_w_011_001_m_1=hv_tb_w_011_001_m.copy()
hv_tb_w_011_001_m_g_001=hv_tb_w_011_001_m.copy()                                                                                                                         
hv_tb_w_011_001_m=hv_tb_w_011_001_m.tail(84)
hv_tb_w_011_001_m_t=hv_tb_w_011_001_m.tail(12)
hv_tb_w_011_001_m_t = hv_tb_w_011_001_m_t.transpose()
hv_tb_w_011_001_m_t.index.names = ["Variable"]
print("step2")
title_r="Credit Impulse SA "
y_label="Index %"
x_label=title_r
df1=hv_tb_w_011_001_m_g_001.copy()
df1_list=df1.columns.tolist()
df1=hv_tb_w_011_001_m_g_001.copy()
df1=df1.tail(18)
g1=df1.copy()
fig, ax = plt.subplots (figsize=(parameter_size1, parameter_size2))

g1.plot(kind='line', ax=ax, y=(df1_list[0]), color="orange", linewidth= (l1+3), linestyle='-',
        marker='P', markersize=s2)
g1.plot(kind='line', ax=ax, y=(df1_list[1]), color="red", linewidth= (11+2), linestyle='-',
        marker= 'D', markersize=s2)
g1.plot(kind='line', ax=ax, y=(df1_list[2]), color="navy", linewidth= (11+2), linestyle='-',
        marker='s',markersize=s2)
g1.plot(kind='line', ax=ax, y=(df1_list[3]), color="black", linewidth= (11+2), linestyle='-',
        marker="o", markersize=s2)                                                
g1.plot(kind='line', ax=ax, y=(df1_list[4]), color="green", linewidth= (11+2), linestyle='-',
        marker="o",markersize=s2)

for series_name in df1_list[0:5]:
    last_y_value = g1[series_name][-1]
    plt.annotate(f"{series_name}", xy=(g1.index.max(), last_y_value),
        xytext=(30, 15), textcoords= 'offset points', arrowprops=dict(facecolor="black", arrowstyle='->'))

plt.axhline(0, color='black', lw=1, linestyle = 'dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size =parameter3)
plt.xlabel(str(x_label), size =parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size =parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_011_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1
del fig
del ax

### 012 money supply   

####EA 11-20: Money Suppl

w_m_tickers = ['m0233fst', 'm0233rmt',
               'm0233ltt', 'm0233ext', 
               'm0233ggt', 'm0233pst']
print("getting from api")
hv_tb_w_012_001_m=Haver.data(w_m_tickers, "eudata", dates=True)
print(hv_tb_w_012_001_m)

hv_tb_w_012_001_m.rename(columns={"m0233fst": "EA 11-20: Money Supply: M3: Annual Growth (SWDA, %)"}, inplace=True)
hv_tb_w_012_001_m.rename(columns={"m0233ggt":"EA 11-20: Contributions to M3 Ann Growth: Credit to General Gov (SWDA, % Points"}, inplace=True)
hv_tb_w_012_001_m.rename(columns={"m0233pst": "EA 11-20: Contributions to M3 Ann Growth: Credit to Private Sector (SWDA, % Pts"}, inplace=True)
#hv_tb_w_012_001_m["EA 11-28: Contributions to M3 Ann Growth: Remaining Contributions (SWDA, % Pts)"]=(hv_tb_w_012_001_m["m0233ltt"] 
#                                                                                                      - hv_tb_w_012_001_m["m0233ggt"] 
#                                                                                                      - hv_tb_w_012_001_m["m0233pst"])
hv_tb_w_012_001_m_1=hv_tb_w_012_001_m.copy()
hv_tb_w_012_001_m_g_001=hv_tb_w_012_001_m
hv_tb_w_012_001_m=hv_tb_w_012_001_m.tail(84)
hv_tb_w_012_001_m_t=hv_tb_w_012_001_m.tail(12)
hv_tb_w_012_001_m_t = hv_tb_w_012_001_m_t.transpose()
hv_tb_w_012_001_m_t.index.names = ['Variable']

df1 = hv_tb_w_012_001_m_g_001.copy()
df1_list = df1.columns.tolist()
# title
title_r = df1_list[0]
# labels
x_label = title_r
y_label = "Index %"
# figure and axis
fig, ax = plt.subplots(figsize=(parameter_size1, parameter_size2))
# plot lines
g1 = df1.tail(120)
g1.plot(kind='line', ax=ax, y=(df1_list[0]), color="black", linewidth=(l1+3), linestyle='-', marker='P', markersize=s2)
# g1.plot(kind='line', ax=ax, y=(df1_list[1]), color="red", linewidth=(L1+2), linestyle='-', marker='D', markersize=52)
# g1.plot(kind='line', ax=ax, y=(df1_list[2]), color="navy", linewidth=(L1+2), linestyle='-', marker='s', markersize=s2)
# g1.plot(kind='line', ax=ax, y=(df1_list[3]), color="black", linewidth=(L1+2), linestyle='-', marker='o', markersize=s2)
# g1.plot(kind='line', ax=ax, y=(df1_list[4]), color="green", linewidth=(L1+2), linestyle='-', marker="*", markersize=s2)

# annotate last value
for series_name in df1_list[8:1]:
    last_y_value = g1[series_name][-1]
    plt.annotate(f'{series_name}', xy=(g1.index.max(), last_y_value), 
                 xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle='->'))
# horizontal line
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
# style
plt.style.use('default')
# labels
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
# secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
# save and close
plt.savefig("hv_tb_w_012_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del fig
del ax



####EA 11-20: Money Suppl

df1 = hv_tb_w_012_001_m_g_001.copy()
df1_list = df1.columns.tolist()
# title
title_r = df1_list[0]
# labels
x_label = title_r
y_label = "Index %"
# figure and axis
fig, ax = plt.subplots(figsize=(parameter_size1, parameter_size2))
# plot lines
g1 = df1.tail(60)
g1.plot(kind='line', ax=ax, y=(df1_list[0]), color="black", linewidth=(l1+3), linestyle='-', marker='P', markersize=s2)
# g1.plot(kind='line', ax=ax, y=(df1_list[1]), color="red", linewidth=(L1+2), linestyle='-', marker='D', markersize=52)
# g1.plot(kind='line', ax=ax, y=(df1_list[2]), color="navy", linewidth=(L1+2), linestyle='-', marker='s', markersize=s2)
# g1.plot(kind='line', ax=ax, y=(df1_list[3]), color="black", linewidth=(L1+2), linestyle='-', marker='o', markersize=s2)
# g1.plot(kind='line', ax=ax, y=(df1_list[4]), color="green", linewidth=(L1+2), linestyle='-', marker="*", markersize=s2)

# annotate last value
for series_name in df1_list[8:1]:
    last_y_value = g1[series_name][-1]
    plt.annotate(f'{series_name}', xy=(g1.index.max(), last_y_value), 
                 xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle='->'))
# horizontal line
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
# style
plt.style.use('default')
# labels
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
# secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
# save and close
plt.savefig("hv_tb_w_012_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del fig
del ax
####EA 11-20: Money Suppl



#hv_tb_w_013_001_m_g_001


w_m_tickers = ['h134cimg', 'h132cimg', 
               'h136cimg', 's023cimg', 
               'h182cimg', 'h184cimg',
               'h134fcpg', 'h132fcpg', 
               'h136fcpg', 'h025fcpg', 
               'h182fcpg', 'h184fcpg']

print("getting from api")
hv_tb_w_013_001_m=Haver.data(w_m_tickers, "G10", dates=True)
print(hv_tb_w_013_001_m)
print(hv_tb_w_013_001_m.columns)

hv_tb_w_013_001_m.rename(columns={"h134cimg": "Germany Credit Impulse"}, inplace=True)
hv_tb_w_013_001_m.rename(columns={"h132cimg": "France Credit Impulse"}, inplace=True)
hv_tb_w_013_001_m.rename(columns={"h136cimg": "Italy Credit Impulse"}, inplace=True)
hv_tb_w_013_001_m.rename(columns={"s023cimg": "Euroarea Credit Impulse"}, inplace=True)
hv_tb_w_013_001_m.rename(columns={"h182cimg": "Portugal Credit Impulse"}, inplace=True)
hv_tb_w_013_001_m.rename(columns={"h184cimg": "Spain Credit Impulse"}, inplace=True)
hv_tb_w_013_001_m.rename(columns={"h134fcpg":"Germany Credit Gdp"}, inplace=True)
hv_tb_w_013_001_m.rename(columns={"h132fcpg":"France Credit Gdp"}, inplace=True)
hv_tb_w_013_001_m.rename(columns={"h136fcpg": "Italy Credit Gdp"}, inplace=True)
hv_tb_w_013_001_m.rename(columns={"h025fcpg": "Euroarea Credit Gdp"}, inplace=True)
hv_tb_w_013_001_m.rename(columns={"h182fcpg": "Portugal Credit Gdp"}, inplace=True)
hv_tb_w_013_001_m.rename(columns={"h184fcpg":"Spain Credit Gdp"}, inplace=True)
hv_tb_w_013_001_m_1=hv_tb_w_013_001_m.copy()
hv_tb_w_013_001_m_g_001=hv_tb_w_013_001_m.tail(6)
hv_tb_w_013_001_m=hv_tb_w_013_001_m.tail(84)
hv_tb_w_013_001_m_t=hv_tb_w_013_001_m.tail(12)
hv_tb_w_013_001_m_t = hv_tb_w_013_001_m_t.transpose()
hv_tb_w_013_001_m_t.index.names = ['Variable']

print("step2")
df1=hv_tb_w_013_001_m_g_001.copy()
df1_list=df1.columns.tolist()
df1.index= df1.index.date
g1=df1.copy()
fig, ax = plt.subplots (figsize=(7,7))
title_r="Credit/Gdp vs Credit Impulse"
y_label="Credit Gdp"
x_label="Credit Impulse"
plt.scatter (g1["Germany Credit Impulse"], g1["Germany Credit Gdp"], cmap="brg", zorder=2)
plt.scatter(g1["France Credit Impulse"], g1["France Credit Gdp"], cmap="brg", zorder=2)
plt.scatter (g1["Italy Credit Impulse"], g1 ["Italy Credit Gdp"], cmap="brg", zorder=2)
plt.scatter (g1["Euroarea Credit Impulse"], g1 ["Euroarea Credit Gdp"], cmap="brg", zorder=2)
#pLt.scatter (gi["Portugal Credit Impulse"], gi["Portugal Credit Gdp"], cmap="brg", zorder=2)
plt.scatter(g1 ["Spain Credit Impulse"], g1 ["Spain Credit Gdp"], cmap="brg", zorder=2)

plt.plot(g1["Germany Credit Impulse"], g1 ["Germany Credit Gdp"], zorder=1)
plt.plot(g1["France Credit Impulse"], g1 ["France Credit Gdp"], zorder=1)
plt.plot(g1["Italy Credit Impulse"], g1 ["Italy Credit Gdp"], zorder=1)
plt.plot(g1["Euroarea Credit Impulse"], g1 ["Euroarea Credit Gdp"], zorder=1)
#plt.plot(91["Portugal Credit Impulse"], 91["Portugal Credit Gdp"], zorder=1)
plt.plot(g1["Spain Credit Impulse"], g1 ["Spain Credit Gdp"], zorder=1)

for line in range(0, g1.shape[0], 1):
    plt.annotate(
        g1.index[line],
        (g1["Germany Credit Impulse"].iloc[line],g1["Germany Credit Gdp"].iloc[line]),
        va='top',
        textcoords="offset points", # how to position the text
        xytext=(-5,10), # distance from text to points (x,y)
        ha='center',
        size = 4)

for line in range(0, g1.shape[0], 1):
    plt.annotate(
        g1.index[line],
        (g1["France Credit Impulse"].iloc[line], g1 ["France Credit Gdp"].iloc[line]),
        va="top",
        textcoords="offset points", # how to position the text
        xytext=(-5,10), # distance from text to points (x,y)
        ha='center',
        size = 4)

for line in range(0, g1.shape[0], 1):
    plt.annotate(
        g1.index[line],
        (g1["Italy Credit Impulse"].iloc[line], g1 ["Italy Credit Gdp"].iloc[line]),
        va='top',
        textcoords="offset points", # how to position the text
        xytext=(-5,10), # distance from text to points (x,y)
        ha='center',
        size = 4)


for line in range(0, g1.shape[0], 1):
    plt.annotate(
        g1.index[line],
        (g1["Euroarea Credit Impulse"].iloc[line], g1["Euroarea Credit Gdp"].iloc[line]),
        va="top",
        textcoords="offset points",  # how to position the text
        xytext=(-5, 10),  # distance from text to points (x,y)
        ha='center',
        size=4
    )
for line in range(0, g1.shape[0], 1):
    plt.annotate(
        g1.index[line],
        (g1["Spain Credit Impulse"].iloc[line], g1["Spain Credit Gdp"].iloc[line]),
        va='top',
        textcoords="offset points",  # how to position the text
        xytext=(-5, 10),  # distance from text to points (x,y)
        ha='center',
        size=4
    )

plt.annotate(f"Germany now", xy=(g1["Germany Credit Impulse"][-1], g1["Germany Credit Gdp"][-1]),
             xytext=(-25, 15), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.annotate(f"France now", xy=(g1["France Credit Impulse"][-1], g1["France Credit Gdp"][-1]),
             xytext=(-25, 15), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.annotate(f"Italy now", xy=(g1["Italy Credit Impulse"][-1], g1["Italy Credit Gdp"][-1]),
             xytext=(-25, 15), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.annotate(f"Euroarea now", xy=(g1["Euroarea Credit Impulse"][-1], g1["Euroarea Credit Gdp"][-1]),
             xytext=(-25, 15), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.annotate(f"Spain now", xy=(g1["Spain Credit Impulse"][-1], g1["Spain Credit Gdp"][-1]),
             xytext=(-25, 15), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.legend()
plt.style.use('default')

plt.ylabel(str(y_label), size=12)
plt.xlabel(str(x_label), size=12)
plt.title(str(title_r), size=12)
plt.tick_params(labelsize=7)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_013_001_m_g_001.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1

#hv_tb_w_014_001_m_g_001


w_m_tickers = ['n023fapg', 'n158fapg']
hv_tb_w_014_001_me = Haver.data(w_m_tickers, "G10", dates=True)
w_m_tickers = ['n111fapg']
print("getting from api")
hv_tb_w_014_001_m1 = Haver.data(w_m_tickers, "G10", dates=True)
print(hv_tb_w_014_001_me)
w_m_tickers = ['fii10']
print("getting from api")
hv_tb_w_014_001_m2 = Haver.data(w_m_tickers, "daily", dates=True)
hv_tb_w_014_001_m2.rename(columns={"fii10":"UST10Y"}, inplace=True)
print(hv_tb_w_014_001_m1)
hv_tb_w_014_001_m = pd.concat([hv_tb_w_014_001_me, hv_tb_w_014_001_m1], axis=1)
hv_tb_w_014_001_m["Central Bank Asset as GDP%"] = hv_tb_w_014_001_m[['n023fapg', 'n158fapg', 'n111fapg']].mean(axis=1)
hv_tb_w_014_001_m["Central Bank Asset as GDP%"] = hv_tb_w_014_001_m["Central Bank Asset as GDP%"].diff(periods=4)
hv_tb_w_014_001_m["Central Bank Asset as GDP%"] = -hv_tb_w_014_001_m["Central Bank Asset as GDP%"]
hv_tb_w_014_001_m = pd.concat([hv_tb_w_014_001_m, hv_tb_w_014_001_m2], axis=1, join="outer")
hv_tb_w_014_001_m["UST10Y"] = hv_tb_w_014_001_m["UST10Y"].bfill()
hv_tb_w_014_001_m["Central Bank Asset as GDP%"] = hv_tb_w_014_001_m["Central Bank Asset as GDP%"].bfill()
hv_tb_w_014_001_m_g_001 = hv_tb_w_014_001_m.tail(4000)
print(hv_tb_w_014_001_m)
print(hv_tb_w_014_001_m.columns)




#w_m_tickers = w_m_tickers + w_m_tickers2
title_r = "Central Bank Asset as GDP%"
x_label = title_r
y_label = "Index %"
df1 = hv_tb_w_014_001_m_g_001.copy()
df1_list = df1.columns.tolist()

g1 = df1.copy()
ax2 = ax.twinx()
fig, ax = plt.subplots(figsize=(parameter_size1, parameter_size2))
g1.plot(kind='line', ax=ax, y=(df1_list[4]), color="black", linewidth=(l1), linestyle="-", marker="", markersize=s2)
g1.plot(kind='line', ax=ax2, y=(df1_list[3]), color="red", linewidth=(l1), linestyle="-", marker="", markersize=s2)

for series_name in df1_list[3:5]:
    last_y_value = g1[series_name][-1]
    #print(last_y_value)

    plt.annotate(f'{series_name}', xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)

plt.savefig("hv_tb_w_014_001_m_g_001.png", bbox_inches='tight')
plt.close('all')
plt.close()
plt.cla()
plt.clf()

del df1
del fig
del ax

### 015 productivity    <a id="title_page"></a>





##### Productivity
##### Productivity
##### Productivity
# ['g10:sll2elpi', 'g10:slllelpi'],

w_m_tickers = ['s193elpi', 's156elpi', 
               's025elpi', 's112elpi', 
               's111elpi', 's132elpi', 's134elpi']
print("getting from api")
hv_tb_w_015_001_m=Haver.data(w_m_tickers, "G10", dates=True)
print(hv_tb_w_015_001_m)
#print(hv_tb_w_015_001_m.columns)
hv_tb_w_015_001_m.rename(columns={"s193elpi": "Australia Productivity"}, inplace=True)
hv_tb_w_015_001_m.rename(columns={"s156elpi": "Canada Productivity"}, inplace=True)
hv_tb_w_015_001_m.rename(columns={"s025elpi": "EA Productivity"}, inplace=True)
hv_tb_w_015_001_m.rename(columns={"s112elpi": "UK Productivity"}, inplace=True)
hv_tb_w_015_001_m.rename(columns={"s111elpi": "US Productivity"}, inplace=True)
hv_tb_w_015_001_m.rename(columns={"s132elpi": "France Productivity"}, inplace=True)
hv_tb_w_015_001_m.rename(columns={"s134elpi": "Germany Productivity"}, inplace=True)
print(hv_tb_w_015_001_m.columns.tolist())
w_m_tickers=hv_tb_w_015_001_m.columns.tolist()

for x in range(len(w_m_tickers)):
    #print(x) 
    variable=str(w_m_tickers[x])
    #print(variable)
    #print(hv_tb_w_015_001_m[variable])
    hv_tb_w_015_001_m[(str(variable)+"_mavg4")] = hv_tb_w_015_001_m[variable].rolling(4).mean().round(3)
    hv_tb_w_015_001_m[(str(variable)+"_yy%")] = hv_tb_w_015_001_m[variable].pct_change(periods=4, fill_method="bfill").multiply(100).round(3)

hv_tb_w_015_001_m=hv_tb_w_015_001_m.fillna(method='ffill')
hv_tb_w_015_001_m=hv_tb_w_015_001_m.tail(6)
hv_tb_w_015_001_m_g_001=hv_tb_w_015_001_m.copy()
df1=hv_tb_w_015_001_m_g_001.copy()
df1_list=df1.columns.tolist()
df1.index= df1.index.date
g1=df1.copy()
fig, ax = plt.subplots(figsize=(7, 7))
title_n = "Productivity Growth"
#x = g1["Canada Policy Rate EOP"]
#y = g1["Canada UR SA"]
#z = g1["Canada Policy Rate EOP"]
y_label="mavg"
x_label = "Productivity Growth"
plt.scatter(g1["Australia Productivity_yy%"],g1["Australia Productivity_mavg4"], cmap="brg", zorder=2)
plt.scatter(g1["Canada Productivity_yy%"], g1["Canada Productivity_mavg4"], cmap="brg", zorder=2)
plt.scatter(g1["EA Productivity_yy%"], g1["EA Productivity_mavg4"], cmap="brg", zorder=2)
plt.scatter(g1["UK Productivity_yy%"], g1["UK Productivity_mavg4"], cmap="brg", zorder=2)
plt.scatter(g1["US Productivity_yy%"], g1["US Productivity_mavg4"], cmap="brg", zorder=2)
plt.scatter(g1["France Productivity_yy%"], g1["France Productivity_mavg4"], cmap="brg", zorder=2)
plt.scatter(g1["Germany Productivity_yy%"], g1["Germany Productivity_mavg4"], cmap="brg", zorder=2)

for line in range(0, g1.shape[0], 1):
    plt.annotate(
        g1.index[line],
        (g1["Australia Productivity_yy%"].iloc[line], g1["Australia Productivity_mavg4"].iloc[line]),
        va='top',
        textcoords="offset points",  # how to position the text
        xytext=(-5, 10),  # distance from text to points (x,y)
        ha='center',
        size=4
    )

for line in range(0, g1.shape[0], 1):
    plt.annotate(
        g1.index[line],
        (g1["Canada Productivity_yy%"].iloc[line], g1["Canada Productivity_mavg4"].iloc[line]),
        va='top',
        textcoords="offset points",  # how to position the text
        xytext=(-5, 10),  # distance from text to points (x,y)
        ha='center',
        size=4
    )

for line in range(0, g1.shape[0], 1):
    plt.annotate(
        g1.index[line],
        (g1["EA Productivity_yy%"].iloc[line], g1["EA Productivity_mavg4"].iloc[line]),
        va='top',
        textcoords="offset points",  # how to position the text
        xytext=(-5, 10),  # distance from text to points (x,y)
        ha='center',
        size=4
    )

for line in range(0, g1.shape[0], 1):
    plt.annotate(
        g1.index[line],
        (g1["UK Productivity_yy%"].iloc[line], g1["UK Productivity_mavg4"].iloc[line]),
        va='top',
        textcoords="offset points",  # how to position the text
        xytext=(-5, 18),  # distance from text to points (x,y)
        ha='center',
        size=4
    )

for line in range(0, g1.shape[0], 1):
    plt.annotate(
        g1.index[line],
        (g1["US Productivity_yy%"].iloc[line], g1["US Productivity_mavg4"].iloc[line]),
        va='top',
        textcoords="offset points",  # how to position the text
        xytext=(-5, 18),  # distance from text to points (x,y)
        ha='center',
        size=4
    )


for line in range(0, g1.shape[0], 1):
    plt.annotate(
        g1.index[line],
        (g1["France Productivity_yy%"].iloc[line], g1["France Productivity_mavg4"].iloc[line]),
        va='top',
        textcoords="offset points",  # how to position the text
        xytext=(-5, 18),  # distance from text to points (x,y)
        ha='center',
        size=4
    )



for line in range(0, g1.shape[0], 1):
    plt.annotate(
        g1.index[line],
        (g1["Germany Productivity_yy%"].iloc[line], g1["Germany Productivity_mavg4"].iloc[line]),
        va='top',
        textcoords="offset points",  # how to position the text
        xytext=(-5, 18),  # distance from text to points (x,y)
        ha='center',
        size=4
    )


plt.plot(g1["Australia Productivity_yy%"], g1["Australia Productivity_mavg4"], zorder=1)
plt.plot(g1["Canada Productivity_yy%"], g1["Canada Productivity_mavg4"], zorder=1)
plt.plot(g1["EA Productivity_yy%"], g1["EA Productivity_mavg4"], zorder=1)
plt.plot(g1["UK Productivity_yy%"], g1["UK Productivity_mavg4"], zorder=1)
plt.plot(g1["US Productivity_yy%"], g1["US Productivity_mavg4"], zorder=1)
plt.plot(g1["France Productivity_yy%"], g1["France Productivity_mavg4"], zorder=1)
plt.plot(g1["Germany Productivity_yy%"], g1["Germany Productivity_mavg4"], zorder=1)

plt.annotate(f"('Australia now')", xy=(g1["Australia Productivity_yy%"][-1], g1["Australia Productivity_mavg4"][-1]),
             xytext=(-25, 15), textcoords="offset points", arrowprops=dict(facecolor='black', arrowstyle="->"))

plt.annotate(f"('Canada now')", xy=(g1["Canada Productivity_yy%"][-1], g1["Canada Productivity_mavg4"][-1]),
             xytext=(-25, 15), textcoords="offset points", arrowprops=dict(facecolor='black', arrowstyle="->"))

plt.annotate(f"('EA now')", xy=(g1["EA Productivity_yy%"][-1], g1["EA Productivity_mavg4"][-1]),
             xytext=(-25, 15), textcoords="offset points", arrowprops=dict(facecolor='black', arrowstyle="->"))

plt.annotate(f"('UK now')", xy=(g1["UK Productivity_yy%"][-1], g1["UK Productivity_mavg4"][-1]),
             xytext=(-25, 15), textcoords="offset points", arrowprops=dict(facecolor='black', arrowstyle="->"))

plt.annotate(f"('US now')", xy=(g1["US Productivity_yy%"][-1], g1["US Productivity_mavg4"][-1]),
             xytext=(-25, 15), textcoords="offset points", arrowprops=dict(facecolor='black', arrowstyle="->"))

plt.annotate(f"('France now')", xy=(g1["France Productivity_yy%"][-1], g1["France Productivity_mavg4"][-1]),
             xytext=(-25, 15), textcoords="offset points", arrowprops=dict(facecolor='black', arrowstyle="->"))

plt.annotate(f"('Germany now')", xy=(g1["Germany Productivity_yy%"][-1], g1["Germany Productivity_mavg4"][-1]),
             xytext=(-25, 15), textcoords="offset points", arrowprops=dict(facecolor='black', arrowstyle="->"))

plt.legend()
plt.style.use('default')
plt.ylabel(str(y_label), size=12)
plt.xlabel(str(x_label), size=12)
plt.tick_params(labelsize=7)
plt.title(str(title_r), size=12)
plt.grid(axis='both', alpha=.3)
plt.savefig("hv_tb_w_015_001_m_g_001.png", bbox_inches='tight')
plt.close('all')
plt.close()
plt.cla()
plt.clf()
del df1




### 016 policy rate vs govt debt     <a id="title_page"></a>


#### policy vs Debt to gdp
#### policy vs Debt to gdp
#### policy vs Debt to gdp
#hv_tb_w_016_001_n_g_001



w_s_tickers = ["n193rtar", "n156rtar", "n023rtar", "n196rtar", "n142rtar", 
               "n144rtar", "n146rtar", "n112rtar", "n111rtar"]
print("getting from api")
hv_tb_w_016_001_m = Haver.data(w_s_tickers, "G10", dates=True)
print(hv_tb_w_016_001_m)
print(hv_tb_w_016_001_m.columns)
hv_tb_w_016_001_m.rename(columns={"n193rtar": "Australia Policy Rate"}, inplace=True)
hv_tb_w_016_001_m.rename(columns={"n156rtar": "Canada Policy Rate"}, inplace=True)
hv_tb_w_016_001_m.rename(columns={"n023rtar": "EA Policy Rate"}, inplace=True)
hv_tb_w_016_001_m.rename(columns={"n196rtar": "New Zealand Policy Rate"}, inplace=True)
hv_tb_w_016_001_m.rename(columns={"n142rtar": "Norway Policy Rate"}, inplace=True)
hv_tb_w_016_001_m.rename(columns={"n144rtar": "Sweden Policy Rate"}, inplace=True)
hv_tb_w_016_001_m.rename(columns={"n146rtar": "Switzerland Policy Rate"}, inplace=True)
hv_tb_w_016_001_m.rename(columns={"n112rtar": "UK Policy Rate"}, inplace=True)
hv_tb_w_016_001_m.rename(columns={"n111rtar": "USA Policy Rate"}, inplace=True)
#w_m_tickers = ["n193fdm", "n156fdm", "n025fdm", "n196fdm", "n142fdm", "n144fdm", "n112fdm", "n111fdm"]
w_m_tickers = ["n193fdm", "n156fdm", "n025fdm",  "n142fdm", "n144fdm", "n112fdm", "n111fdm"]
#print("getting from api")
hv_tb_w_016_002_m = Haver.data(w_m_tickers, "G10", dates=True)
#print(hv_tb_w_016_002_m)
#print(hv_tb_w_016_002_m.columns)
hv_tb_w_016_002_m.rename(columns={"n193fdm": "Australia General Govt Debt Moving GDP"}, inplace=True)
hv_tb_w_016_002_m.rename(columns={"n156fdm": "Canada General Govt Debt Moving GDP"}, inplace=True)
hv_tb_w_016_002_m.rename(columns={"n025fdm": "EA General Govt Debt Moving GDP"}, inplace=True)
#hv_tb_w_016_002_m.rename(columns={"n196fdm": "New Zealand General Govt Debt Moving GDP"}, inplace=True)
hv_tb_w_016_002_m.rename(columns={"n142fdm": "Norway General Govt Debt Moving GDP"}, inplace=True)
hv_tb_w_016_002_m.rename(columns={"n144fdm": "Sweden General Govt Debt Moving GDP"}, inplace=True)
hv_tb_w_016_002_m.rename(columns={"n112fdm": "UK General Govt Debt Moving GDP"}, inplace=True)
hv_tb_w_016_002_m.rename(columns={"n111fdm": "USA General Govt Debt Moving GDP"}, inplace=True)
hv_tb_w_016_001_m = pd.concat([hv_tb_w_016_001_m, hv_tb_w_016_002_m], axis=1, join="outer")
# w_m_tickers = w_m_tickers + e_m_tickers
hv_tb_w_016_001_m = hv_tb_w_016_001_m.fillna(method="ffill")
hv_tb_w_016_001_m = hv_tb_w_016_001_m.tail(32)
hv_tb_w_016_001_m_g_001 = hv_tb_w_016_001_m.copy()
hv_tb_w_016_001_m_t = hv_tb_w_016_001_m.transpose()
hv_tb_w_016_001_m_t.index.names = ["Variable"]
#table_w_016_001_m.csv
#print(path_display)
#hv_tb_w_016_001_m_t.to_csv (path_display, index =True, header=True)
#print(hv_tb_w_016_001_m)
#print("step2")

df1=hv_tb_w_016_001_m_g_001.copy()
df1_list=df1.columns.tolist()
df1.index= df1.index.date
g1=df1.copy()
fig, ax = plt.subplots(figsize=(7, 7))
title_r="Policy Rate vs General Govt Debt Moving GDP"
#x 91["Canada Policy Rate EOP"]
#yg1["Canada UR SA"]
#t= 91["Canada Policy Rate EOP"]
y_label="General Govt Debt Moving GDP"
x_label="Policy Rate"
plt.scatter(g1["Australia Policy Rate"], g1["Australia General Govt Debt Moving GDP"], cmap="brg", zorder=2)
plt.scatter(g1["Canada Policy Rate"], g1["Canada General Govt Debt Moving GDP"], cmap="brg", zorder=2)
plt.scatter(g1["EA Policy Rate"], g1["EA General Govt Debt Moving GDP"], cmap="brg", zorder=2)
plt.scatter(g1["Norway Policy Rate"], g1["Norway General Govt Debt Moving GDP"], cmap="brg", zorder=2)
plt.scatter(g1["Sweden Policy Rate"], g1["Sweden General Govt Debt Moving GDP"], cmap="brg", zorder=2)
plt.scatter(g1["UK Policy Rate"], g1["UK General Govt Debt Moving GDP"], cmap="brg", zorder=2)
plt.scatter(g1[ "USA Policy Rate"], g1[ "USA General Govt Debt Moving GDP"], cmap="brg", zorder=2)
plt.annotate(f"Australia", xy=(g1["Australia Policy Rate"][-1], g1["Australia General Govt Debt Moving GDP"][-1]),
             xytext=(-25, 15), size=15, textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle="->"))
plt.annotate(f"Canada", xy=(g1["Canada Policy Rate"][-1], g1["Canada General Govt Debt Moving GDP"][-1]),
             xytext=(-25, 15), size=15, textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle="->"))
plt.annotate(f"EA", xy=(g1["EA Policy Rate"][-1], g1["EA General Govt Debt Moving GDP"][-1]),
             xytext=(-25, 15), size=15, textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle="->"))
plt.annotate(f"Norway", xy=(g1["Norway Policy Rate"][-1], g1["Norway General Govt Debt Moving GDP"][-1]),
             xytext=(-25, 15), size=15, textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle="->"))
plt.annotate(f"Sweden", xy=(g1["Sweden Policy Rate"][-1], g1["Sweden General Govt Debt Moving GDP"][-1]),
             xytext=(-25, 15), size=15, textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle="->"))
plt.annotate(f"UK", xy=(g1["UK Policy Rate"][-1], g1["UK General Govt Debt Moving GDP"][-1]),
             xytext=(-25, 15), size=15, textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle="->"))
plt.annotate(f"USA", xy=(g1["USA Policy Rate"][-1], g1["USA General Govt Debt Moving GDP"][-1]),
             xytext=(-25, 15), size=15, textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle="->"))
plt.legend()
plt.style.use("default")
plt.ylabel(str(y_label), size=12)
plt.xlabel(str(x_label), size=12)
plt.tick_params(labelsize=7)
plt.title(str(title_r), size=12)
plt.grid(axis="both", alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_016_001_m_g_001.png", bbox_inches="tight")
plt.savefig("hv_tb_w_016_001_m_g_001.jpg", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del df1

print("CXompelte")

### 017 policy rate     <a id="title_page"></a>


# Scatterplots
# Scatterplots
# Scatterplots



###table_w_016_001_m
w_m_tickers = ['n193rtar', 'n156rtar', 'n023rtar',
               'n196rtar', 'n142rtar', 'n144rtar',
               'n146rtar', 'n112rtar', 'n111rtar']

print("getting from api")
hv_tb_w_016_001_m = Haver.data(w_m_tickers, "G10", dates=True)

print(hv_tb_w_016_001_m)
print(hv_tb_w_016_001_m.columns)
hv_tb_w_016_001_m.rename(columns={"n193rtar": "Australia Policy Rate"}, inplace=True)
hv_tb_w_016_001_m.rename(columns={"n156rtar": "Canada Policy Rate"}, inplace=True)
hv_tb_w_016_001_m.rename(columns={"n023rtar": "EA Policy Rate"}, inplace=True)
hv_tb_w_016_001_m.rename(columns={"n196rtar": "New Zealand Policy Rate"}, inplace=True)
hv_tb_w_016_001_m.rename(columns={"n142rtar": "Norway Policy Rate"}, inplace=True)
hv_tb_w_016_001_m.rename(columns={"n144rtar": "Sweden Policy Rate"}, inplace=True)
hv_tb_w_016_001_m.rename(columns={"n146rtar": "Switzerland Policy Rate"}, inplace=True)
hv_tb_w_016_001_m.rename(columns={"n112rtar": "UK Policy Rate"}, inplace=True)
hv_tb_w_016_001_m.rename(columns={"n111rtar": "USA Policy Rate"}, inplace=True)

w_m_tickers = ['n193fdm', 'n156fdm', 'n025fdm',
               'n142fdm', 'n144fdm',
               'n112fdm', 'n111fdm']
print("getting from api")
hv_tb_w_016_002_m = Haver.data(w_m_tickers, "G10", dates=True)
print(hv_tb_w_016_002_m)
print(hv_tb_w_016_002_m.columns)
hv_tb_w_016_002_m.rename(columns={"n193fdm": "Australia General Govt Debt Moving GDP"}, inplace=True)
hv_tb_w_016_002_m.rename(columns={"n156fdm": "Canada General Govt Debt Moving GDP"}, inplace=True)
hv_tb_w_016_002_m.rename(columns={"n825fdm": "EA General Govt Debt Moving GDP"}, inplace=True)
# hv_tb_w_016_002_m.rename(columns={"n196fdm": "New Zealand General Govt Debt Moving GDP"}, inplace=True)
hv_tb_w_016_002_m.rename(columns={"n142fdm": "Norway General Govt Debt Moving GDP"}, inplace=True)
hv_tb_w_016_002_m.rename(columns={"n144fdm": "Sweden General Govt Debt Moving GDP"}, inplace=True)
# hv_tb_w_016_002_m.rename(columns={"n146fdm": "Switzerland General Govt Debt Moving GDP"}, inplace=True)
hv_tb_w_016_002_m.rename(columns={"n112fdm": "UK General Govt Debt Moving GDP"}, inplace=True)
hv_tb_w_016_002_m.rename(columns={"n111fdm": "USA General Govt Debt Moving GDP"}, inplace=True)
hv_tb_w_016_001_m = pd.concat([hv_tb_w_016_001_m, hv_tb_w_016_002_m], axis=1, join="outer")
# w_m_tickers = w_m_tickers + w_m_tickers
hv_tb_w_016_001_m = hv_tb_w_016_001_m.fillna(method='ffill')
hv_tb_w_016_001_m = hv_tb_w_016_001_m.tail(32)
hv_tb_w_016_001_m_g_001 = hv_tb_w_016_001_m.copy()
hv_tb_w_016_001_m_t = hv_tb_w_016_001_m.transpose()
hv_tb_w_016_001_m_t.index.names = ["Variable"]



#hv_tb_w_017_001_001
#hv_tb_w_017_001_001
#plt.plot(gi["Australia Policy Rate"], gi["Australia General Govt Debt Moving GDP"], zorder=1)


import matplotlib.pyplot as plt
# Assuming 'gi' is a dictionary containing the data
# Plot the data for each country
plt.plot(g1["Australia Policy Rate"], g1["Australia General Govt Debt Moving GDP"], zorder=1)
plt.plot(g1["Canada Policy Rate"], g1["Canada General Govt Debt Moving GDP"], zorder=1)
plt.plot(g1["EA Policy Rate"], g1["EA General Govt Debt Moving GDP"], zorder=1)
plt.plot(g1["Norway Policy Rate"], g1["Norway General Govt Debt Moving GDP"], zorder=1)
plt.plot(g1["Sweden Policy Rate"], g1["Sweden General Govt Debt Moving GDP"], zorder=1)
plt.plot(g1["UK Policy Rate"], g1["UK General Govt Debt Moving GDP"], zorder=1)
plt.plot(g1["USA Policy Rate"], g1["USA General Govt Debt Moving GDP"], zorder=1)
# Add annotations for the current values
plt.annotate(f'{"Australia now"}', xy=(g1["Australia Policy Rate"][-1], g1["Australia General Govt Debt Moving GDP"][-1]),
             xytext=(-25, 15), size=12, textcoords='offset points', arrowprops=dict(facecolor="black", arrowstyle="->"))
plt.annotate(f'{"Canada now"}', xy=(g1["Canada Policy Rate"][-1], g1["Canada General Govt Debt Moving GDP"][-1]),
             xytext=(-25, 15), size=12, textcoords='offset points', arrowprops=dict(facecolor="black", arrowstyle="->"))

plt.annotate(f'{"EA now"}', xy=(g1["EA Policy Rate"][-1], g1["EA General Govt Debt Moving GDP"][-1]),
             xytext=(-25, 15), size=12, textcoords='offset points', arrowprops=dict(facecolor="black", arrowstyle="->"))
plt.annotate(f'{"Norway now"}', xy=(g1["Norway Policy Rate"][-1], g1["Norway General Govt Debt Moving GDP"][-1]),
             xytext=(-25, 15), size=12, textcoords='offset points', arrowprops=dict(facecolor="black", arrowstyle="->"))
plt.annotate(f'{"Sweden now"}', xy=(g1["Sweden Policy Rate"][-1], g1["Sweden General Govt Debt Moving GDP"][-1]),
             xytext=(-25, 15), size=12, textcoords='offset points', arrowprops=dict(facecolor="black", arrowstyle="->"))



plt.annotate(f'{"UK now"}', xy=(g1["UK Policy Rate"][-1], g1["UK General Govt Debt Moving GDP"][-1]),
             xytext=(-25, 15), size=12, textcoords='offset points', arrowprops=dict(facecolor="black", arrowstyle="->"))
plt.annotate(f'{"USA now"}', xy=(g1["USA Policy Rate"][-1], g1["USA General Govt Debt Moving GDP"][-1]),
             xytext=(-25, 15), size=12, textcoords='offset points', arrowprops=dict(facecolor="black", arrowstyle="->"))



# Add legend, labels, and title
plt.legend()
plt.style.use('default')
plt.ylabel(str(y_label), size=12)
plt.xlabel(str(x_label), size=12)
plt.tick_params(labelsize=7)
plt.title(str(title_r), size=12)
plt.grid(axis="both", alpha=.3)
# Add secondary y-axis
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
# Save the plot
plt.savefig("hv_tb_w_017_001_m_g_001.png", bbox_inches='tight')
# Close the plot
plt.close()
plt.close("all")
plt.clf()
plt.cla()


print("CXompelte")

#####TD
#####TD
#####TD
#####TD
#####TD
print("Complete")
w_m_tickers = ['h228ndtc', 's233ndtc', 's944ndtc',
               'h542ndtc', 's273ndtc', 'h293ndtc',
               'h566ndtc', 's964ndtc', 's199ndtc']
print("getting from api")
hv_tb_w_017_001_m = Haver.data(w_m_tickers, "EMERGE", dates=True)
print(hv_tb_w_017_001_m)


hv_tb_w_017_001_m_a = hv_tb_w_017_001_m.copy()
for x in range(len(w_m_tickers)):
    variable = str(w_m_tickers[x])
    hv_tb_w_017_001_m[(str(variable))] = hv_tb_w_017_001_m[variable].pct_change(periods=1, 
                                                                                fill_method='bfill').multiply(100).round(3)

hv_tb_w_017_001_m.rename(columns={"h228ndtc": "Chile TD"}, inplace=True)
hv_tb_w_017_001_m.rename(columns={"s233ndtc": "Colombia TD"}, inplace=True)
hv_tb_w_017_001_m.rename(columns={"s944ndtc": "Hungary TD"}, inplace=True)
hv_tb_w_017_001_m.rename(columns={"h542ndtc": "Southkorea TD"}, inplace=True)
hv_tb_w_017_001_m.rename(columns={"s273ndtc": "Mexico TD"}, inplace=True)
hv_tb_w_017_001_m.rename(columns={"h293ndtc": "Peru TD"}, inplace=True)
hv_tb_w_017_001_m.rename(columns={"h566ndtc": "Philippines TD"}, inplace=True)
hv_tb_w_017_001_m.rename(columns={"s964ndtc": "Poland TD"}, inplace=True)
hv_tb_w_017_001_m.rename(columns={"s199ndtc": "Southafrica TD"}, inplace=True)
hv_tb_w_017_001_m = hv_tb_w_017_001_m.tail(4)
# Identify columns where the last value is NaN
columns_with_last_nan = hv_tb_w_017_001_m.columns[hv_tb_w_017_001_m.isna().iloc[-1]]
# For each of these columns, shift all the row values up by 1 row
for column in columns_with_last_nan:
    hv_tb_w_017_001_m[column] = hv_tb_w_017_001_m[column].shift(1)

hv_tb_w_017_001_m = hv_tb_w_017_001_m.tail(2)
hv_tb_w_017_001_m = hv_tb_w_017_001_m.transpose()
print(hv_tb_w_017_001_m)

w_m_tickers = ['s111ndtc', 's112ndtc', 's146ndtc', 'h144ndtc', 
               's142ndtc', 's196ndtc', 's134ndtc', 's025ndtc', 
               's997ndtc', 's193ndfc', 's156ndfc']
print("getting from api")
hv_tb_w_017_002_m = Haver.data(w_m_tickers, "G10", dates=True)
#print(hvtb_w_017_002_m)
#print(hv_tb_w_017_002_m.columns)
for x in range(len(w_m_tickers)):
    # print(x)
    variable = str(w_m_tickers[x])
    # print(variable)
    hv_tb_w_017_002_m[(str(variable))] = hv_tb_w_017_002_m[variable].pct_change(periods=1,
                                                                                fill_method="bfill").multiply(100).round(3)

hv_tb_w_017_002_m.rename(columns={"s111ndtc": "USA TD"}, inplace=True)
hv_tb_w_017_002_m.rename(columns={"s112ndtc": "UK TD"}, inplace=True)
hv_tb_w_017_002_m.rename(columns={"s146ndtc": "Switzerland TD"}, inplace=True)
hv_tb_w_017_002_m.rename(columns={"h144ndtc": "Sweden TD"}, inplace=True)
hv_tb_w_017_002_m.rename(columns={"s142ndtc": "Norway TD"}, inplace=True)
hv_tb_w_017_002_m.rename(columns={"s196ndtc": "Newzealand TD"}, inplace=True)
hv_tb_w_017_002_m.rename(columns={"s134ndtc": "Germany TD"}, inplace=True)
hv_tb_w_017_002_m.rename(columns={"s025ndtc": "EA20 TD"}, inplace=True)
hv_tb_w_017_002_m.rename(columns={"s997ndtc": "EU27 TD"}, inplace=True)
hv_tb_w_017_002_m.rename(columns={"s193ndfc": "Australia TD"}, inplace=True)
hv_tb_w_017_002_m.rename(columns={"s156ndfc": "Canada TD"}, inplace=True)
hv_tb_w_017_002_m = hv_tb_w_017_002_m.tail(4)
# Identify columns where the Last value is NaN
columns_with_last_nan = hv_tb_w_017_002_m.columns[hv_tb_w_017_002_m.isna().iloc[-1]]
# For each of these columns, shift all the row values up by 1 row
for column in columns_with_last_nan:
    hv_tb_w_017_002_m[column] = hv_tb_w_017_002_m[column].shift(1)
hv_tb_w_017_002_m = hv_tb_w_017_002_m.tail(2)
hv_tb_w_017_002_m = hv_tb_w_017_002_m.transpose()
# hv_tb_w_017_002_m.reset.index.names = ['Variable']
#print(hv_tb_w_017_002_m)

hv_tb_w_017_003_m = pd.concat([hv_tb_w_017_001_m, 
                               hv_tb_w_017_002_m], axis=0)
print(hv_tb_w_017_003_m)
hv_tb_w_017_003_m.columns = ["Previous", "Recent"]
print(hv_tb_w_017_003_m)
scatter_df = hv_tb_w_017_003_m[["Recent", "Previous"]]
# Generating the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(scatter_df['Recent'], 
            scatter_df['Previous'],
            color='blue')
# Adding annotations for each data point with the index name
for idx, point in scatter_df.iterrows():
    plt.text(point['Recent'], 
             point['Previous'], 
             idx, fontsize=8)
# Adding a vertical line at 0
plt.axvline(x=0, color="grey", linestyle='--')
# Adding a horizontal line at 0
plt.axhline(y=0, color="grey", linestyle='--')
plt.title('Scatter Plot Total Domestic Demand momentum')
plt.xlabel('Recent')
plt.ylabel('Previous')
#plt.grid(True)
plt.savefig("hv_tb_w_018_001_m_g_001.png", bbox_inches='tight')
# Displaying the plot
#plt.show()
plt.close()
plt.close('all')
plt.clf()
plt.cla()

### 019 output gap    <a id="title_page"></a>

#plt.savefig("hv_tb_w_019_001_m_g_001.png", bbox_inches='tight')
w_tickers = ["n193ngap", 
             "n156ngap", 
             "n158ngap",
             "n196ngap", 
             "n146ngap", 
             "n111ngap",
             "n112ngap"]
print("getting from api")
hv_tb_w_019_001_m = Haver.data(w_tickers, "G10", dates=True)
print(hv_tb_w_019_001_m)
#print(hv_tb_w_019_001_m.columns)
hv_tb_w_019_001_m.rename(columns={"n193ngap": "Australia output gap hp filter"}, inplace=True)
hv_tb_w_019_001_m.rename(columns={"n156ngap": "Canada output gap integrated framework"}, inplace=True)
hv_tb_w_019_001_m.rename(columns={"n158ngap": "Japan output gap haver"}, inplace=True)
hv_tb_w_019_001_m.rename(columns={"n196ngap": "NewZealand output gap haver"}, inplace=True)
hv_tb_w_019_001_m.rename(columns={"n146ngap": "Switzerland output gap production function"}, inplace=True)
hv_tb_w_019_001_m.rename(columns={"n111ngap": "US output gap budget office"}, inplace=True)
hv_tb_w_019_001_m.rename(columns={"n112ngap": "UK output gap hp filter"}, inplace=True)
#print(hv_tb_w_019_001_m)


def find_last_valid_index(column_name, df):
  return df[column_name].last_valid_index()

last_valid_index = find_last_valid_index("Australia output gap hp filter", hv_tb_w_019_001_m)
print(last_valid_index)


# Finding the index of the target date
target_index = hv_tb_w_019_001_m.index.get_loc(last_valid_index)
# Creating a list of indices: 2 before the target and 4 after
index_range = range(max(0, target_index - 13), min(len(hv_tb_w_019_001_m), target_index + 2))
# Extracting the actual index values based on the range
selected_indices = hv_tb_w_019_001_m.index[index_range]
selected_indices = selected_indices.tolist()
print(selected_indices)
# print(hv_tb_w_019_001_m.tail(28))
filtered_df = hv_tb_w_019_001_m.loc[selected_indices]
# hv_tb_w_019_001_m = hv_tb_w_019_001_m.tail(84)



title="Output Gap"
y_label="Index %"
x_label=title_r
df1=filtered_df.copy()
df1_list=df1.columns.tolist()
g1=df1.copy()
df1.index=pd.to_datetime(df1.index)
fig,ax=plt.subplots(figsize=(parameter_size1, parameter_size2))

g1.plot(kind="line", ax=ax, y=(df1_list[0]), color="orange", linewidth=(l1+3), linestyle="-",
        marker="P", markersize=s2)
g1.plot(kind='line',ax=ax, y=(df1_list[1]), color="red", linewidth=(l1+2), linestyle="-",
        marker="D", markersize=s2)
g1.plot(kind='line', ax=ax,y=(df1_list[2]), color="navy", linewidth=(l1+2), linestyle="-",
        marker="s", markersize=s2)
g1.plot(kind="line", ax=ax, y=(df1_list[3]), color="black", linewidth=(l1+2), linestyle="-",
        marker="o", markersize=s2)
g1.plot(kind='line', ax=ax, y=(df1_list[4]), color="green", linewidth=(l1+2), linestyle="-",
        marker="^", markersize=s2)

for series_name in df1_list[0:5]:
    #Find the Last non-NA value in the series
    last_valid_index = g1[series_name].last_valid_index()
    last_valid_value = g1.loc[last_valid_index, series_name]

    #Annotate using the Last non-NA value
    plt.annotate(series_name.split()[0],
                 xy=(last_valid_index, last_valid_value),
                 xytext=(50, 18), textcoords="offset points",
                 arrowprops=dict(facecolor='black', arrowstyle='->'),)

plt.axhline(0, color='black', lw=1, linestyle= "dashed", alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis="both", alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_019_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del fig
del ax

df1 = df1.copy()
fig, ax = plt.subplots(figsize=(parameter_size1, parameter_size2))
g1.plot(kind='line', ax=ax, y=(df1_list[5]), color='gray', linewidth=(11+2), linestyle='-', marker='o', markersize=s2)
g1.plot(kind='line', ax=ax, y=(df1_list[6]), color='purple', linewidth=(11+2), linestyle='-', marker='o', markersize=s2)


for series_name in df1_list[5:7]:
    # Find the last non-NA value in the series
    last_valid_index = g1[series_name].last_valid_index()
    last_valid_value = g1.loc[last_valid_index, series_name]

    # Annotate using the last non-NA value
    plt.annotate(series_name.split()[0],
                 xy=(last_valid_index, last_valid_value),
                 xytext=(50, 10), textcoords="offset points",
                 arrowprops=dict(facecolor='black', arrowstyle="->"))

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=0.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_019_001_m_g_002.png", bbox_inches="tight")
plt.close()


#date = '2024-12-31'
#prevf = 'F 202301'
#lastf = 'F 202401'
#l#astfe = 'F 202304'
w_m_tickers = ['pcxmd231', 'pcemd231', 'gdpm0231',
               'pcxmd234', 'pcemd234', 'gdpmd234']
print("getting from api")
#hv_tb_w_020_001_m = Haver.data(w_m_tickers, "surveys", dates=True)
#print(hv_tb_w_020_001_m)
#print(hv_tb_w_020_001_m.columns)
#hv_tb_w_020_001_m.rename(columns={'pcxmd231': 'US FED CPCE ' + str(prevf)}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'pcemd231': 'US FED PCE ' + str(prevf)}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'gdpm0231': 'US FED GDP ' + str(prevf)}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'pcxmd234': 'US FED CPCE ' + str(lastf)}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'pcemd234': 'US FED PCE ' + str(lastf)}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'gdpmd234': 'US FED GDP ' + str(lastf)}, inplace=True)
#hv_tb_w_020_001_m['US FED GDP d ' + str(date)] = hv_tb_w_020_001_m['US FED GDP ' + str(prevf)] - hv_tb_w_020_001_m['US FED GDP ' + str(lastf)]
#hv_tb_w_020_001_m['US FED CPCE d ' + str(date)] = hv_tb_w_020_001_m['US FED CPCE ' + str(prevf)] - hv_tb_w_020_001_m['US FED CPCE ' + str(lastf)]
#hv_tb_w_020_001_m['US FED PCE d ' + str(date)] = hv_tb_w_020_001_m['US FED PCE ' + str(prevf)] - hv_tb_w_020_001_m['US FED PCE ' + str(lastf)]
#hv_tb_w_020_001_m.columns = ['GDP d ' + str(date), 'CPI d ' + str(date)]
#hv_tb_w_020_001_m = hv_tb_w_020_001_m[hv_tb_w_020_001_m.index == date]
#print(hv_tb_w_020_001_m)
#hv_tb_w_020_001_m.index = [US]
#print(hv_tb_w_020_001_m)
#hv_tb_w_020_001_mf = hv_tb_w_020_001_m.copy()


#Japan - JPANA
w_m_tickers = ["jpgm231", "jpgm241", "jpxm231", "jpxm241"]
#print("getting from api")
#hv_tb_w_020_001_m=Haver.data(w_m_tickers, "japan", dates=True)
#print(hv_tb_w_020_001_m)
#print(hv_tb_w_020_001_m.columns)
#hv_tb_w_020_001_m.rename(columns={"jpgm231":"Japan BOJ GDP "+str(prevf)}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"jpgm241":"Japan BOJ GDP "+str(lastf)}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"jpxm231":"Japan BOJ CPI "+str(prevf)}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"jpxm241":"Japan BOJ CPI "+str(lastf)}, inplace=True)
#hv_tb_w_020_001_m["Japan BOJ GDP d "+str(date)]=hv_tb_w_020_001_m["Japan BOJ GDP "+str(prevf)]-hv_tb_w_020_001_m["Japan BOJ GDP "+str(lastf)]
#hv_tb_w_020_001_m["Japan BOJ CPI d "+str(date)]=hv_tb_w_020_001_m["Japan BOJ CPI "+str(prevf)]-hv_tb_w_020_001_m["Japan BOJ CPI "+str(lastf)]
#hv_tb_w_020_001_m = hv_tb_w_020_001_m[["Japan BOJ GDP d "+str(date), "Japan BOJ CPI d "+str(date)]]
#hv_tb_w_020_001_m.columns=["GDP d "+str(date), "CPI d "+str(date)]
#hv_tb_w_020_001_m = hv_tb_w_020_001_m[hv_tb_w_020_001_m.index==date]
#print(hv_tb_w_020_001_m)
##hv_tb_w_020_001_m.index=["Japan"]
#print(hv_tb_w_020_001_m)
#hv_tb_w_020_001_m_f = pd.concat([hv_tb_w_020_001_m_f, hv_tb_w_020_001_m], axis=0)

#Australia - ANZ
w_m_tickers = ["augp241", "augp231", "aupc241", "aupc231"]
#print("getting from api")
#hv_tb_w_020_001_m=Haver.data(w_m_tickers, "anz", dates=True)
#print(hv_tb_w_020_001_m)
#print(hv_tb_w_020_001_m.columns)
#hv_tb_w_020_001_m.rename(columns={"augp241":"Australia RBA GDP "+str(lastf)}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"augp231":"Australia RBA GDP "+str(prevf)}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"aupc241":"Australia RBA CPI "+str(lastf)}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"aupc231":"Australia RBA CPI "+str(prevf)}, inplace=True)
#hv_tb_w_020_001_m["Australia RBA GDP d "+str(date)]=hv_tb_w_020_001_m["Australia RBA GDP "+str(prevf)]-hv_tb_w_020_001_m["Australia RBA GDP "+str(lastf)]
#hv_tb_w_020_001_m["Australia RBA CPI d "+str(date)]=hv_tb_w_020_001_m["Australia RBA CPI "+str(prevf)]-hv_tb_w_020_001_m["Australia RBA CPI "+str(lastf)]
#hv_tb_w_020_001_m = hv_tb_w_020_001_m[["Australia RBA GDP d "+str(date), "Australia RBA CPI d "+str(date)]]
#hv_tb_w_020_001_m.columns=["GDP d "+str(date), "CPI d "+str(date)]
#hv_tb_w_020_001_m = hv_tb_w_020_001_m[hv_tb_w_020_001_m.index==date]
#print(hv_tb_w_020_001_m)
#hv_tb_w_020_001_m.index=["Australia"]
#print(hv_tb_w_020_001_m)
#print(hv_tb_w_020_001_m)
#hv_tb_w_020_001_m_f = pd.concat([hv_tb_w_020_001_m_f, hv_tb_w_020_001_m], axis=0)


#New Zealand RENZ anz
#w_m_tickers = ["nzgp241", "nzgp231", "nzpcy241", "nzpcy231"]#
#print("getting from api")
#hv_tb_w_020_001_m = Haver.data(w_m_tickers, "anz", dates=True)
#print(hv_tb_w_020_001_m)
#print(hv_tb_w_020_001_m.columns)
#hv_th_w_020_001_m.rename(columns={"nzgp241": "New Zealand RBNZ GDP " + str(lastf)}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"nzgp231": "New Zealand RBNZ GDP " + str(prevf)}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"nzpcy241": "New Zealand RBNZ CPI " + str(lastf)}, inplace=True)
#hv_tb_k_020_001_m.rename(columns={"nzpcy231": "New Zealand RBNZ CPI " + str(prevf)}, inplace=True)
#hv_tb_w_020_001_m["New Zealand RBNZ GDP d " + str(date)] = hv_tb_w_020_001_m["New Zealand RBNZ GDP " + str(prevf)] - hv_tb_w_020_001_m["New Zealand RBNZ GDP " + str(lastf)]
#hv_tb_w_020_001_m["New Zealand RBNZ CPI d " + str(date)] = hv_tb_w_020_001_m["New Zealand RBNZ CPI " + str(prevf)] - hv_tb_w_020_001_m["New Zealand RBNZ CPI " + str(lastf)]
#hv_th_w_020_001_m = hv_tb_w_020_001_m[["New Zealand RBNZ GDP " + str(date), "New Zealand RBNZ CPI d " + str(date)]]
#hv_tb_w_020_001_m.columns = ["GDP d " + str(date), "CPI d " + str(date)]
#hv_tb_w_020_001_m.index = date#
#print(hv_th_w_020_001_a)

#hv_tb_w_020_001_m.index = ["New Zealand"]
#print(hv_th_w_020_001_m)
#hv_tb_w_020_001_m_fpd.concat([hv_tb_w_020_001_m_f,
#                              hv_tb_w_020_001_m], axis=0,)

# Canada - CANADA
#w_n_tickers = ["caqgx241", "caqgx231", "caqpc241", "caqpc231"]
#print("getting from api")
#hv_tb_w_020_001_m = Haver.data(w_m_tickers, 
#                               "canada", dates=True)
#print(hv_tb_w_020_001_m)
#print(hv_tb_w_020_001_m.columns)
#hv_tb_w_020_001_m.rename(columns={"caqgx241": "Canada BOC GDP " + str(lastf)}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"caqgx231": "Canada BOC GDP " + str(prevf)}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"caqpc241": "Canada BOC CPI " + str(lastf)}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"caqpc231": "Canada BOC CPI " + str(prevf)}, inplace=True)
#hv_th_w_020_001_m["Canada BOC GDP d " + str(date)] = hv_tb_w_020_001_m["Canada BOC GDP " + str(prevf)] - hv_tb_w_020_001_m["Canada BOC GDP " + str(lastf)]
#hv_tb_w_020_001_m["Canada BOC CPI d " + str(date)] = hv_tb_w_020_001_m["Canada BOC CPI " + str(prevf)] - hv_tb_w_020_001_m["Canada BOC CPI " + str(lastf)]
#hv_tb_w_020_001_m = hv_tb_w_020_001_m[["Canada BOC GDP d " + str(date), "Canada BOC CPI d " + str(date)]]
#hv_tb_w_020_001_m.columns = ["GDP d " + str(date), "CPI d " + str(date)]
#hv_tb_w_020_001_m.index = date
#print(hv_tb_w_020_001_m)
#hv_th_w_020_001_m.index = ["Canada"]
#print(hv_th_w_020_001_m)
#hv_tb_w_020_001_m_fpd.concat([hv_tb_w_020_001_m_f,
#                              hv_tb_w_020_001_m], 
#                             axis=0,)

#print(hv_th_w_020_001_)
#hv_th_w_020_001_m_f pd.concat([hv_tb_w_020_001_m_f, hv_tb_w_020_001_m), axis=0,)
##segg1234 segg1231
#Sweden -NORDIC
#M__tickers=['segg1234", "seggi231","sepf234", "sepF231']
#print("getting from api")
#hv_tb_w_020_001_n=Haver.data(w_a_tickers, 
#                            "nordic", dates True)
#print(hv_th_w_020_001_)
#print(hv_th_w_020_001_m.columns)
##hv_th__828 eel_m.rename(columns("segg1234": "Sweden Riksbank GDP "+str(Lastfe)), inplace=True)
##hv_tb_w_020_001_.rename(columns("segg1231": "Sweden Riksbank GDP "+str(prevf)), inplace=True)
##hv_th_w_020_001_m.rename(columns("sepf234": "Sweden Riksbank CPI "+str(lastf)), inplace=True)
##print(hv_tb_w_020_001_m.tail(10))                                                                                                                         020 001 m. rename(columns("sepf231":"Sweden Riksbank CPI "+str(prevf)), inplace=True)#
#
##hv_to_w_020_001_["Sweden Riksbank GOP d "+str(date)]+hv_tb_w_020_001_["Sweden Riksbank GOP "+str(prevf)]-hν το_w_020_001 / "Sweden Riksbank GDP "str
#whv_to_828_01_["Sweden Riksbank CPI d "+str(date)]+hv tb_w_020_001_["Sweden Riksbank CPI "+
#str(prevf)]-hv to w_828_001_m["Sweden Rikshank CPI "+str
#001 hv_th_w_828_001_[["Sweden Riksbank GDP d "+str(date), "Sweden Riksbank CPI d "+str(date)]]
##hv_tb_w_020_001_hv_th_w_020_001_m.Loc[date]

##norway-nordic
#w_m_tickers= [nogpq234", "nogpq231, nocp1234", "поср1231"]###
##print("getting from api")
#hv_tb_w_020_001_Haver.data(w_m_tickers, "nordic", dates=True)
#print(hv_tb_w_020_001_m)
#print(hv_th_w_020_001_m.columns)
#hv_tb_w_020_001_n.rename(columns("nogpq234": "Norway Norges GDP "+str(lastfe)), inplace=True)
#hv_th_w_020_001_m.rename(columns={"nagpq231": "Norway Norges GDP "+str(prevf)}, inplace=True)
#hv_th_w_020_001_m.rename(columns={"nocp1234": "Norway Norges CPI "+str(lastf)}, inplace=True)
#hv_th_w_020_001_m.rename(columns={"nocp1231": "Norway Norges CPI "+str(prevf)}, inplace=True)
#print(hv_th_w_020_001_m.columns)
#h#v_th_w_020_001_m["Norway Norges GDP d "+str(date)]=hv_th_w_020_001_m["Norway Norges GDP "+str(prevf)]-hv_th_w_020_001_m["Norway Norges GDP "+str(lastf)]
#h#v_th_w_020_001_m["Norway Norges CPI d "+str(date)]=hv_th_w_020_001_m["Norway Norges CPI "+str(prevf)]-hv_th_w_020_001_m["Norway Norges CPI "+str(lastf)]
#hv_th_w_020_001_m=hv_th_w_020_001_m[["Norway Norges GDP d "+str(date),"Norway Norges CPI d "+str(date)]]
#hv_th_w_020_001_m.columns=["GDP d "+str(date), "CPI d "+str(date)]#
#hv_th_w_020_001_m=hv_th_w_020_001_m.T
#hv_th_w_020_001_m.index=["Norway"]
#print(hv_th_w_020_001_m)
#hv_th_w_020_001_m_f=pd.concat((hv_th_w_020_001_m_f, hv_th_w_020_001_m), axis=1)


#France
#Germany
#Spain
#Italy
#Japan
#UK
#UK
#w_tickers = ["unpa241", "unga241", "unpa231", "unga231"]
#print("getting from api")
#hv_th_w_020_001_m=Haver.data(w_m_tickers, "uk", dates=True)
#print(hv_th_w_020_001_m)
#print(hv_th_w_020_001_m.columns)
#hv_th_w_020_001_m.rename(columns={"unpa241": "UK BOE CPI "+str(lastf)}, inplace=True)
#hv_th_w_020_001_m.rename(columns={"unga241": "UK BOE GDP "+str(lastf)}, inplace=True)
#hv_th_w_020_001_m.rename(columns={"unpa231": "UK BOE CPI "+str(prevf)}, inplace=True)
#hv_th_w_020_001_m.rename(columns={"unga231": "UK BOE GDP "+str(prevf)}, inplace=True)
#hv_th_w_020_001_m["UK BOE GDP d "+str(date)]=hv_th_w_020_001_m["UK BOE GDP "+str(prevf)]-hv_th_w_020_001_m["UK BOE GDP "+str(lastf)]
#hv_th_w_020_001_m["UK BOE CPI d "+str(date)]=hv_th_w_020_001_m["UK BOE CPI "+str(prevf)]-hv_th_w_020_001_m["UK BOE CPI "+str(lastf)]
#hv_th_w_020_001_m=hv_th_w_020_001_m[["UK BOE GDP d "+str(date),"UK BOE CPI d "+str(date)]]
#hv_th_w_020_001_m.columns=["GDP d "+str(date), "CPI d "+str(date)]
#hv_th_w_020_001_m=hv_th_w_020_001_m.T
#hv_th_w_020_001_m.index=["UK"]
#print(hv_th_w_020_001_m)
#hv_th_w_020_001_m_f=pd.concat((hv_th_w_020_001_m_f, hv_th_w_020_001_m), axis=1)
##Brazil
#China
#Russia
#Mexico
#India



# Creating a scatter plot
#plt.figure(figsize=(10, 6))
#plt.scatter(scatter_df['GDP d ' + str(date)], scatter_df['CPI d ' + str(date)], color='blue')
## Adding annotations for each data point with the index name
#for idx, point in scatter_df.iterrows():
#    plt.text(point['GDP d ' + str(date)], point['CPI d ' + str(date)], idx, fontsize=8)
## Adding a vertical line at x=e
#plt.axvline(x=e, color='grey', linestyle='--')
## Adding a horizontal line at y=e
#plt.axhline(y=e, color='grey', linestyle='--')
#plt.title('Central bank changes in Forecasts from ' + str(prev_f) + ' to ' + str(last_f))
#plt.xlabel('GDP d ' + str(date))
#plt.ylabel('CPI d ' + str(date))
## Adding watermarks / text annotations
#plt.text(0.05, 0.05, 'Negative Demand Shock in Lower Growth Lower Inflation', transform=plt.gca().transAxes,
#         fontsize=12, color='grey', alpha=0.5, ha='left', va='top')##
#
#plt.text(0.05, 0.95, 'Negative Supply Shock in Lower Growth Higher Inflation', transform=plt.gca().transAxes,
#         fontsize=12, color='grey', alpha=0.5, ha='left', va='top')#
#plt.text(0.95, 0.05, 'Positive Supply Shock in Higher Growth Lower Inflation', transform=plt.gca().transAxes,
#         fontsize=12, color='grey', alpha=0.5, ha='right', va='bottom')
#
## Placeholder for the fourth watermark
#plt.text(0.95, 0.95, 'Positive Demand Shock in Higher Growth Higher Inflation', transform=plt.gca().transAxes,
#         fontsize=12, color='grey', alpha=0.5, ha='right', va='bottom')#
#
# plt.grid(True)#
#plt.savefig('hv_tb_w_020_001_n_g_001.png', bbox_inches='tight')#
## Displaying the plot
#lt.show()
# Closing the plot
#plt.close()
#plt.close('all')
#plt.clf()
#plt.cla()

print("CXompelte")

### 022 supply shoick inflation   <a id="title_page"></a>

date = 2024-12-31
#'time_r = report most recent jan 2024
w_m_tickers = ['c163gpcp', 'c132gpcp', 'c134gpcp', 'c136gpcp', 'c184gpcp', 'c158gpcp', 
               'c112gpcp', 'c111gpcp', 'c193gpcp', 'c924gpcp', 'c534gpcp', 'c273gpcp',
               'c223gpcp', 'c922gpcp', 'c156gpcp', 'c110gpcp', 'c280gpcp']

print("getting from api")

#hv_tb_w_020_001_m=Haver.data(w_m_tickers, "imfweo", dates=True)

#print(hv_tb_w_020_001_m.columns)
#hv_tb_w_020_001_m.rename(columns={"c163gpcp": "EuroArea"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"c132gpcp": "France"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"c134gpcp": "Germany"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"c136gpcp": "Italy"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"c184gpcp": "Spain"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"c158gpcp":"Japan"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"c112gpcp":"UK"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"c111gpcp": "US"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"c193gpcp": "Australia"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"c924gpcp":"China"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"c534gpcp": "India"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"c273gpcp":"Mexico"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"c223gpcp": "Brazil"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"c922gpcp": "Russia"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"c156gpcp": "Canada"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"c110gpcp":"AdvancedEco"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"c200gpcp": "EmergingEco"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"c469gpcp":"Egypt"}, inplace=True)#
#hv_tb_w_020_001_m[hv_tb_w_020_001_m.index==date]
#hv_tb_w_020_001_m hv_tb_w_020_001_m.T
#v_tb_w_020_001_m.columns=["GDP "+str(time_r)]
#print(hv_tb_w_020_001_m)
#World Economic Outook (WED)
#h#v_tb_w_020_001_m1=hv_tb_w_020_001_m.copy()

#FULL Report 6 Months Ago
#By Concept

#time_r= report 6m ago

w_m_tickers = ['j163gpcp', 'j132gpcp', 'j134gpcp', 'j136gpcp', 'j184gpcp',
               'j158gpcp', 'j112gpcp', 'j111gpcp', 'j193gpcp', 'j924gpcp',
               'j534gpcp', 'j273gpcp', 'j223gpcp', 'j922gpcp', 'j156gpcp', 
               'j110gpcp', 'j200gpcp']

print("getting from api")

#j163gpcp, j132gpcp, j134gpcp, j136gpcp, j184gpcp, j158gpcp, j112gpcp
#, j111gpcp, j193gpcp, j924gpcp, j534gpcp, j273gpcp, j223gpcp, j922gpcp, j156gpcp, j110gpcp, j200gpcp



#By Concept
#time_r= report 6m ago

w_m_tickers=['j163gpcp', 'j132gpcp', 'j134gpcp', 'j136gpcp',
'j184gpcp', 'j158gpcp', 'j112gpcp', 'j111gpcp',
'j193gpcp', 'j924gpcp', 'j534gpcp', 'j273gpcp',
'j223gpcp', 'j922gpcp', 'j156gpcp', 'j118gpcp', 'j200gpcp']

print("getting from api")
#hv_tb_w_020_001_m=Haver.data(w_m_tickers, "imfweo", dates=True)

#print(hv_tb_w_020_001_m.columns)
#hv_tb_w_020_001_m.rename(columns={"j163gpcp": "EuroArea"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"j132gpcp": "France"}, inplace=True)
#
#hv_tb_w_020_001_m.rename(columns={"j134gpcp": "Germany"}, inplace=True)#
#hv_tb_w_020_001_m.rename(columns={"j136gpcp": "Italy"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"j184gpcp": "Spain"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"j158gpcp": "Japan"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"j112gpcp": "UK"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"j111gpcp": "US"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"j193gpcp": "Australia"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"j924gpcp": "China"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"j534gpcp": "India"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"j273gpcp": "Mexico"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"j223gpcp": "Brazil"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"j922gpcp": "Russia"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"j156gpcp": "Canada"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"j118gpcp": "AdvancedEco"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"j200gpcp": "EmergingEco"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"j469gpcp": "Egypt"}, inplace=True)##
#hv_tb_w_020_001_m.index = pd.to_datetime(hv_tb_w_020_001_m.index)
#hv_tb_w_020_001_m = hv_tb_w_020_001_m.T
#print(hv_tb_w_020_001_m)
#hv_tb_w_020_001_m1 = pd.concat([hv_tb_w_020_001_m1, hv_tb_w_020_001_m], axis=1)
#print(hv_tb_w_020_001_m1)
#hv_tb_w_020_001_m1["Difference GDP"] = hv_tb_w_020_001_m1.iloc[:, 0] - hv_tb_w_020_001_m1.iloc[:, -1]
#hv_tb_w_020_001_m1_gdp = hv_tb_w_020_001_m1["Difference GDP"]
#print(hv_tb_w_020_001_m1)

print("CXompelte")

#time_r = "report most recent oct2023"

w_m_tickers = ['a163pcip', 'a132pcip', 'a134pcip', 'a136pcip',
               'a184pcip', 'a158pcip', 'a112pcip', 'a111pcip',
               'a193pcip', 'a924pcip', 'a534pcip', 'a273pcip',
               'a223pcip', 'a922pcip', 'a156pcip', 'a11@pcip', 'a200pcip']

#print("getting from api")
#hv_tb_w_020_001_m = Haver.data(w_m_tickers, "infweo", dates=True)#
#print(hv_tb_w_020_001_m)

#hv_tb_w_020_001_m.rename(columns={"a163pcip": "EuroArea"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"a132pcip": "France"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"a134pcip": "Germany"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"a136pcip": "Italy"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"a184pcip": "Spain"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"a158pcip": "Japan"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"a112pcip": "UK"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"a111pcip": "US"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"a193pcip": "Australia"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"a924pcip": "China"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"a534pcip": "India"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"a273pcip": "Mexico"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"a223pcip": "Brazil"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"a922pcip": "Russia"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"a156pcip": "Canada"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"a11@pcip": "AdvancedEco"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"a200pcip": "EmergingEco"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"a469pcip": "Egypt"}, inplace=True)
#hv_tb_w_020_001_m = hv_tb_w_020_001_m[hv_tb_w_020_001_m.index == date]
#hv_tb_w_020_001_m = hv_tb_w_020_001_m.T
#hv_tb_w_020_001_m.columns = ["CPI " + str(time_r)]
#print(hv_tb_w_020_001_m)#
# World Economic OutLook (WED)
#hv_tb_w_020_001_m1 = hv_tb_w_020_001_m.copy()



#File Edit View Run Kernel Settings Help
#Code JupyterLab Python 3 (ipykernel)
#time_report 6m ago

w_tickers = ['1183pcip', 'j132pcip', 'j334pcip', 'j136pcip',
             '1184pcip', 'j156pcip', '1112pcip', 'j114pcip',
             '1193pcip', '1924pcip', '1554pcip', '3273pcip',
             '1223pcip', '1922pcip', '1156pcip', '1110pcip', '1200pcip',
             '1469pcip', '1273pcip', '1923pcip', '1534pcip', '1924pcip']

#print("getting from api")

#hv_tb_w_020_001_m = Haver.data(w_tickers, "infweo", dates=True)
#print(hv_tb_w_020_001_m.columns)
#hv_tb_w_020_001_m.rename(columns={'1183pcip': 'EuroArea'}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'j132pcip': 'France'}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'1114pcip': 'Germany'}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'j116pcip': 'Italy'}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'j184pcip': 'Spain'}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'j358pcip': 'Japan'}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'j112pcip': 'UK'}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'j111pcip': 'US'}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'j193pcip': 'Australia'}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'j924pcip': 'China'}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'1534pcip': 'India'}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'1273pcip': 'Mexico'}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'j223pcip': 'Brazil'}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'1922pcip': 'Russia'}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'1156pcip': 'Canada'}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'1110pcip': 'AdvancedEco'}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'1200pcip': 'EmergingEco'}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={'1469pcip': 'Egypt'}, inplace=True)

#hv_tb_w_020_001_m = hv_tb_w_020_001_m[hv_tb_w_020_001_m.index.isna() == False]
#hv_tb_w_020_001_m = hv_tb_w_020_001_m.T
#hv_tb_w_020_001_m.columns = ['CPI ' + str(timer)]
#print(hv_tb_w_020_001_m)
#hv_tb_w_020_001_m1 = pd.concat([hv_tb_w_020_001_m1, hv_tb_w_020_001_m], axis=1)
#print(hv_tb_w_020_001_m1)
#hv_tb_w_020_001_m1['Difference CPI'] = hv_tb_w_020_001_m1.iloc[:, -1] - hv_tb_w_020_001_m1.iloc[:, -2]
#hv_tb_w_020_001_m1_cpi = hv_tb_w_020_001_m1[['Difference CPI']]
#print(hv_tb_w_020_001_m1_cpi)
#hv_tb_w_020_001_m1_weo = pd.concat([hv_tb_w_020_001_m1_cpi, hv_tb_w_020_001_m1_gdp], axis=1)





# Generating the scatter plot
#plt.figure(figsize=(10, 6))
#plt.scatter(scatter_df["Difference GDP"], scatter_df["Difference CPI"], color='blue')
## Adding annotations for each data point with the index name
#for idx, point in scatter_df.iterrows():
#    plt.text(point["Difference GDP"], point["Difference CPI"], idx, fontsize=8)##
## Adding a vertical line at x=0
#plt.axvline(x=0, color="grey", linestyle="--")
## Adding a horizontal line at y=0
#plt.axhline(y=0, color="grey", linestyle="--")
#plt.title("Central bank changes in Forecast str(date)+ (Most recent WEO report vs 6 months ago)")
#plt.xlabel("GDP Forecast change")
#plt.ylabel("CPI Forecast change")
## Adding watermarks / text annotations
#plt.text(0.03, 0.03, str(owner) transform=plt.gca().transAxes, fontsize=12, color="grey", alpha=0.5, ha='center', va="center", rotation=30)
#plt.text(0.07, 0.07, 'Negative Demand Shock in Lower exp Growth Lower exp Inflation', 
#         transform=plt.gca().transAxes, fontsize=12, color="grey", alpha=0.5, ha='left', va='top')
#plt.text(0.05, 0.95, 'Negative Supply Shock in Lower exp Growth Higher exp Inflation',
#         transform=plt.gca().transAxes, fontsize=12, color="grey", alpha=0.5, ha='left', va='top')
#plt.text(0.95, 0.05, 'Positive Supply Shock in Higher exp Growth Lower exp Inflation', 
#         transform=plt.gca().transAxes, fontsize=12, color="grey", alpha=0.5, ha='right', va='bottom')
## Placeholder for the fourth watermark
#plt.text(0.90, 0.98, 'Positive Demand Shock in Higher exp Growth Higher exp Inflation', 
#         transform=plt.gca().transAxes, fontsize=12, color="grey", alpha=0.5, ha='right', va="bottom")#
# plt.grid(True#)
#plt.savefig("hv_tb_w_021_001_m_g_001.png", bbox_inches="tight")
# Displaying the plot
# plt.show()

print("CXompelte")

#hv_tb_w_022_001_m_g_001
w_m_tickers = ["s997elpi", "s025elpi",
               "s132elpi", "s134elpi", "s146elpi",
               "s142elpi", "s144elpi", "s158elpi",
               "s112elpi", "s116elpi", "s193elpi", "s156elpi"]

#hv_tb_w_020_001_m = Haver.data(w_m_tickers, "gdp", dates=True)
#print(hv_tb_w_020_001_m)
#hv_tb_w_020_001_m.rename(columns={"s997elpi": "eu27 productivity"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"s025elpi": "eaze productivity"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"s132elpi": "france productivity"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"s134elpi": "germany productivity"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"s146elpi": "swtizerland productivity"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"s142elpi": "norway productivity"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"s144elpi": "sweden productivity"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"s158elpi": "japan productivity"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"s112elpi": "uk productivity"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"s116elpi": "usa productivity"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"s193elpi": "australia productivity"}, inplace=True)
#hv_tb_w_020_001_m.rename(columns={"s156elpi": "canada productivity"}, inplace=True)

#title_r = "Productivity: TOTAL ECONOMY PRODUCTIVITY (OUTPUT PER EMPLOYED PERSON)"
#y_label = "Index"
#x_label = title_r
#df1 = hv_tb_w_020_001_m.copy()
#df1_list = df1.columns.tolist()
#df1 = df1.tail(18)
#g1 = df1.copy()
#df1.index = pd.to_datetime(df1.index)
#fig, ax = plt.subplots(figsize=(parameter_size1, parameter_size2))
#g1.plot(kind='line', ax=ax, y=(df1_list[0]), color="orange", linewidth=(11+3), linestyle='',
#         marker="P", markersize=s2)
#g1.plot(kind='line', ax=ax, y=(df1_list[1]), color="red", linewidth=(11+2), linestyle='',
#         marker="D", markersize=s2)
#g1.plot(kind='line', ax=ax, y=(df1_list[2]), color="navy", linewidth=(11+2), linestyle='',
#         marker="s", markersize=s2)
#g1.plot(kind='line', ax=ax, y=(df1_list[3]), color="black", linewidth=(11+2), linestyle='',
#         marker="o", markersize=s2)
#g1.plot(kind='line', ax=ax, y=(df1_list[4]), color="green", linewidth=(11+2), linestyle='',
#         marker="^", markersize=s2)
#g1.plot(kind='line', ax=ax, y=(df1_list[5]), color="gray", linewidth=(11+2), linestyle='',
#         marker="v", markersize=s2)
#g1.plot(kind='line', ax=ax, y=(df1_list[6]), color="purple", linewidth=(11+2), linestyle='',
#         marker="*", markersize=s2)
#for series_name in df1_list[0:7]:
#    #Find the last non-NA value in the series
#    last_valid_index = df1[series_name].last_valid_index()
#    last_valid_value = df1.loc[last_valid_index, series_name]###
#    #Annotate using the Last non-NA value
#    plt.annotate(series_name.split()[0],
#                 f"({series_name}): {last_valid_value}",
#                 xy=(last_valid_index, last_valid_value),
#                 xytext=(50, 18), textcoords="offset points",
#                 arrowprops=dict(facecolor='black', arrowstyle='->'))#
##plt.axhline(B, color='black', Lw=1, linestyle='dashed', alpha=0.75)
#plt.style.use('default')
#plt.ylabel(str(y_label), size=parameter3)
#plt.xlabel(str(x_label), size=parameter3)
#plt.tick_params(labelsize=parameter4)
#plt.title(str(title_r), size=parameter5)
#plt.grid(axis='both', alpha=.3)#
#ax2 = ax.twinx(#)
#ax2.set_ylim(ax.get_ylim())
#plt.savefig("hv_tb_w_022_001_m_g_001.png", bbox_inches='tight')
#plt.close()
#plt.close('all')
#plt.clf()
#plt.cla()
#del g1
#del fig
#del a#x





#title_r="Productivity: TOTAL ECONOMY PRODUCTIVITY (OUTPUT PER EMPLOYED PERSON)"
#y_label="Index"
#x_label=title_
#df1=hv_tb_w_020_001_m.copy()
#df1_list=df1.columns.tolist()
#df1=df1.tail(28)
#1df1.copy()
#df1.index pd.to_datetime(df1.index)
#fig,ax plt.subplots(figsize=(parameter_sizel, parameter_size2))
#g1.plot(kinds="line", ax=ax, y=(df1_list[7]), color="orange", linewidth =(l1+2), linestyles="-",
#        marker ="P", markersize=s2)
#gl.plot(kind='line', axxax, y=(df1_list[8]), color="red", linewidth= (l1+2), linestyle="-",
#        marker='D', markersize= s2)
#g1.plot(kind="line", ax=xax, y=(df1_list[9]), colore="navy", linewidth= (l1+2), linestyles="-",                                                        
#        marker='s', markersize=s2)
#gl.plot(kinds ="line", ax=ax, y=(dfl_list[10]), color="black", linewidth (l1+2), linestyle="-",
#        marker="o", markersize= s2)
#g1.plot(kind="line", ax=ax, y=(df1_list[11]), color="green", linewidth (l1+2), linestyle="-",
#        marker="o", markersize=s2)
#for series_name in dfi_list[7:12):
#                             Find the Last non-NA volue in the series
#                             last valid_index
#                             gi[series_name].last_valid_index()
#last_valid_value gi.loc[last_valid_index, series_name]
#plt.annotate(series_name.split()[0],
#             #f' (series_name): (Last_valid_value)",
#             xy=(last_valid_index, last valid_value),
#             xytext=(58, 10), textcoord="offset points".
#             arrowprops dict(facecolor="black", arrowstyle="->"),)
##pit.ashline(, color="black", L1, Linestyle 'dashed', alpha-0.75)
#plt.style.use('default')
#plt.ylabel(str(y_label), size parameter3)
#plt.xlabel(str(x_label), size parameter3)
#plt.tick parans (labelsize-parameter4)
#plt.title(str(title_r), sizexparameters)
#plt.grid(axis='both', alpha=.3)
#ax2 =ax.twinx()
#ax2.set ylim(ax.get_ylim())
#plt.savefig("hv_tb_k_022_001__g_002.png", bbox_inches="tight")
#plt.close()
#plt.close('all")
#plt.clf()

print("CXompelte")

### 023 10 y vs citi  <a id="title_page"></a>

#https://haverproducts.com/charts-of-the-week/

w_tickers = ['fcm10',]
print("getting from api")
hv_tb_w_023_001_m = Haver.data(w_tickers, "daily", dates=True)
print(hv_tb_w_023_001_m)
w_tickers = ['v001csi',]
hv_tb_w_023_002_m = Haver.data(w_tickers, "intdaily", dates=True)
hv_tb_w_023_001_m = pd.concat([hv_tb_w_023_001_m, hv_tb_w_023_002_m], axis=1)

hv_tb_w_023_001_m.rename(columns={'fcm10': '10-Year Treasury Note Yield at Constant Maturity (% p.a.)'}, inplace=True)
hv_tb_w_023_001_m.rename(columns={'v001csi': 'Citigroup Economic Surprise Index: Based on Global Currencies (%)'}, inplace=True)
print(hv_tb_w_023_001_m.columns.tolist())


#Series 1: FCM10@DAILY 
#  FCM10@DAILY   [10-Year Treasury Note Yield at Constant Maturity (% p.a.)]
#Series 2: V001CSI@INTDAILY 
#  V001CSI@INTDAILY   [Citigroup Economic Surprise Index: Based on Global Currencies (%)]



title_r="10y Treasury vs Economic Surprise"
y_label="Index %"
x_label=title_r
df1=hv_tb_w_023_001_m.copy()
df1=df1.tail(500)
g1=df1.copy()
list_c=g1.columns.tolist()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
# Plot the first variable on the primary y-axis
# Plot the first variable on the primary y-axis
line1, = ax.plot(df1.index, df1.iloc[:, 0], color="darkred", linewidth=l1, linestyle='-', label=df1.columns[0])
ax.set_ylabel(list_c[0], size=6, color="black")
ax.tick_params(axis='y', labelsize=parameter4, colors="darkred")

# Plot the second variable on the secondary y-axis
ax2 = ax.twinx()
line2, = ax2.plot(df1.index, df1.iloc[:, 1], color="darkorange", linewidth=l1, linestyle='-', label=df1.columns[1])
ax2.set_ylabel(list_c[1], size=6, color="black")
ax2.tick_params(axis='y', labelsize=parameter4, colors="darkorange")

# Set x-axis label and title
ax.set_xlabel(x_label, size=parameter3)
ax.set_title(title_r, size=parameter5)

# Apply grid and styling
plt.style.use('default')
ax.grid(axis='both', alpha=0.3)

# Combine legends from both axes
lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper left', fontsize=7, title="Legend")
plt.savefig("hv_tb_w_023_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax

w_tickers = ['fcm10',]
print("getting from api")
hv_tb_w_023_001_m = Haver.data(w_tickers, "daily", dates=True)
print(hv_tb_w_023_001_m)
w_tickers = ['v111csi',]
hv_tb_w_023_002_m = Haver.data(w_tickers, "intdaily", dates=True)
hv_tb_w_023_001_m = pd.concat([hv_tb_w_023_001_m, hv_tb_w_023_002_m], axis=1)

hv_tb_w_023_001_m.rename(columns={'fcm10': '10-Year Treasury Note Yield at Constant Maturity (% p.a.)'}, inplace=True)
hv_tb_w_023_001_m.rename(columns={'v001csi': 'Citigroup Economic Surprise Index: Based on USD'}, inplace=True)
print(hv_tb_w_023_001_m.columns.tolist())


#Series 1: FCM10@DAILY 
#  FCM10@DAILY   [10-Year Treasury Note Yield at Constant Maturity (% p.a.)]
#Series 2: V001CSI@INTDAILY 
#  V001CSI@INTDAILY   [Citigroup Economic Surprise Index: Based on Global Currencies (%)]



title_r="10y Treasury vs Economic Surprise"
y_label="Index %"
x_label=title_r
df1=hv_tb_w_023_001_m.copy()
df1=df1.tail(500)
g1=df1.copy()
list_c=g1.columns.tolist()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
# Plot the first variable on the primary y-axis
# Plot the first variable on the primary y-axis
line1, = ax.plot(df1.index, df1.iloc[:, 0], color="darkred", linewidth=l1, linestyle='-', label=df1.columns[0])
ax.set_ylabel(list_c[0], size=6, color="black")
ax.tick_params(axis='y', labelsize=parameter4, colors="darkred")

# Plot the second variable on the secondary y-axis
ax2 = ax.twinx()
line2, = ax2.plot(df1.index, df1.iloc[:, 1], color="darkorange", linewidth=l1, linestyle='-', label=df1.columns[1])
ax2.set_ylabel(list_c[1], size=6, color="black")
ax2.tick_params(axis='y', labelsize=parameter4, colors="darkorange")

# Set x-axis label and title
ax.set_xlabel(x_label, size=parameter3)
ax.set_title(title_r, size=parameter5)

# Apply grid and styling
plt.style.use('default')
ax.grid(axis='both', alpha=0.3)

# Combine legends from both axes
lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper left', fontsize=7, title="Legend")
plt.savefig("hv_tb_w_023_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax

w_tickers = ['fcm2',]
print("getting from api")
hv_tb_w_023_001_m = Haver.data(w_tickers, "daily", dates=True)
print(hv_tb_w_023_001_m)
w_tickers = ['v001csi',]
hv_tb_w_023_002_m = Haver.data(w_tickers, "intdaily", dates=True)
hv_tb_w_023_001_m = pd.concat([hv_tb_w_023_001_m, hv_tb_w_023_002_m], axis=1)

hv_tb_w_023_001_m.rename(columns={'fcm2': '2-Year Treasury Note Yield at Constant Maturity (% p.a.)'}, inplace=True)
hv_tb_w_023_001_m.rename(columns={'v001csi': 'Citigroup Economic Surprise Index: Based on Global Currencies (%)'}, inplace=True)
print(hv_tb_w_023_001_m.columns.tolist())


#Series 1: FCM10@DAILY 
#  FCM10@DAILY   [10-Year Treasury Note Yield at Constant Maturity (% p.a.)]
#Series 2: V001CSI@INTDAILY 
#  V001CSI@INTDAILY   [Citigroup Economic Surprise Index: Based on Global Currencies (%)]



title_r="2y Treasury vs Economic Surprise"
y_label="Index %"
x_label=title_r
df1=hv_tb_w_023_001_m.copy()
df1=df1.tail(500)
g1=df1.copy()
list_c=g1.columns.tolist()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
# Plot the first variable on the primary y-axis
# Plot the first variable on the primary y-axis
line1, = ax.plot(df1.index, df1.iloc[:, 0], color="darkred", linewidth=l1, linestyle='-', label=df1.columns[0])
ax.set_ylabel(list_c[0], size=6, color="black")
ax.tick_params(axis='y', labelsize=parameter4, colors="darkred")

# Plot the second variable on the secondary y-axis
ax2 = ax.twinx()
line2, = ax2.plot(df1.index, df1.iloc[:, 1], color="darkorange", linewidth=l1, linestyle='-', label=df1.columns[1])
ax2.set_ylabel(list_c[1], size=6, color="black")
ax2.tick_params(axis='y', labelsize=parameter4, colors="darkorange")

# Set x-axis label and title
ax.set_xlabel(x_label, size=parameter3)
ax.set_title(title_r, size=parameter5)

# Apply grid and styling
plt.style.use('default')
ax.grid(axis='both', alpha=0.3)

# Combine legends from both axes
lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper left', fontsize=7, title="Legend")
plt.savefig("hv_tb_w_023_001_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax

#### Dow Jones Global Indx vs Citi group growht surprse


#Series 1: diff(S001DJW@INTDAILY,90) 
#  S001DJW@INTDAILY   [Dow Jones Global Index: World (Avg, Dec-31-91=100)]
#'90days changes
#Series 2: (V110CSI@INTDAILY - V110CIS@INTDAILY) 
#  V110CSI@INTDAILY   [Citigroup Economic Surprise Index: Based on G10 Currencies (%)]
#  V110CIS@INTDAILY   [Citigroup Inflation Surprise Index: Based on G10 Currencies (%)]



w_tickers = ['S001DJW',]
w_tickers = [element.lower() for element in w_tickers]
print("getting from api")
hv_tb_w_023_001_m = Haver.data(w_tickers, "intdaily", dates=True)
#print(hv_tb_w_023_001_m)
w_tickers = ['V110CSI','V110CIS']
w_tickers = [element.lower() for element in w_tickers]
hv_tb_w_023_002_m = Haver.data(w_tickers, "intdaily", dates=True)
hv_tb_w_023_001_m = pd.concat([hv_tb_w_023_001_m, hv_tb_w_023_002_m], axis=1)

hv_tb_w_023_001_m.rename(columns={'s001djw': 'Dow Jones Global Index: World'}, inplace=True)
hv_tb_w_023_001_m.rename(columns={'v110csi': 'Citigroup Economic Surprise Index'}, inplace=True)
hv_tb_w_023_001_m.rename(columns={'v110cis': 'Citigroup Inflation Surprise Index'}, inplace=True)
hv_tb_w_023_001_m['Diff Economic Surprise  - Inflation Surprise']=hv_tb_w_023_001_m['Citigroup Economic Surprise Index']-hv_tb_w_023_001_m['Citigroup Inflation Surprise Index']
hv_tb_w_023_001_m['Dow Jones Global Index: World']= hv_tb_w_023_001_m['Dow Jones Global Index: World'].pct_change(90).multiply(100).round(3)


print(hv_tb_w_023_001_m.columns.tolist())

title_r = "Dow Jones 90d change vs Citi growth less inflation surprise"
y_label = "Index"
x_label = title_r
df1 = hv_tb_w_023_001_m.copy()
df1_list = df1.columns.tolist()
df1 = df1.tail(200)
g1 = df1.copy()
df1.index = pd.to_datetime(df1.index)
fig, ax = plt.subplots(figsize=(parameter_size1, parameter_size2))
g1.plot(kind='line', ax=ax, y=(df1_list[3]), color="orange", linewidth=(l1+2), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[0]), color="red", linewidth=(l1), linestyle='-',)
#plt.axhline(B, color='black', Lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_023_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del fig



print("CXompelte")

### 024  policy ucnertainty <a id="title_page"></a>


#Series 1: N111FOA@G10 
#  N111FOA@G10   [U.S.: Assets at all Federal Reserve Banks (EOP, NSA, Mil.$)]
#Series 2: N001VIUC@G10 
#  N001VIUC@G10   [Global Economic Policy Uncertainty Index [Current Price GDP Weights] (Mean=100)]



w_tickers = ['n111foa',]
hv_tb_w_024_001_m = Haver.data(w_tickers, "g10", dates=True)
w_tickers = ['n001viuc',]
hv_tb_w_024_002_m = Haver.data(w_tickers, "g10", dates=True)
hv_tb_w_024_001_m = pd.concat([hv_tb_w_024_001_m, hv_tb_w_024_002_m], axis=1)

hv_tb_w_024_001_m.rename(columns={'n111foa': 'U.S.: Assets at all Federal Reserve Banks (EOP, NSA, Mil.$)'}, inplace=True)
hv_tb_w_024_001_m.rename(columns={'n001viuc': 'Global Economic Policy Uncertainty Index [Current Price GDP Weights] (Mean=100)'}, inplace=True)
print(hv_tb_w_024_001_m.columns.tolist())



title_r="US FED Assets vs Global Economic Policy Uncertainty"
y_label="Index %"
x_label=title_r
df1=hv_tb_w_024_001_m.copy()
df1=df1.tail(250)
g1=df1.copy()
list_c=g1.columns.tolist()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
# Plot the first variable on the primary y-axis
# Plot the first variable on the primary y-axis
line1, = ax.plot(df1.index, df1.iloc[:, 0], color="darkred", linewidth=l1, linestyle='-', label=df1.columns[0])
ax.set_ylabel(list_c[0], size=6, color="black")
ax.tick_params(axis='y', labelsize=parameter4, colors="darkred")

# Plot the second variable on the secondary y-axis
ax2 = ax.twinx()
line2, = ax2.plot(df1.index, df1.iloc[:, 1], color="darkorange", linewidth=l1, linestyle='-', label=df1.columns[1])
ax2.set_ylabel(list_c[1], size=6, color="black")
ax2.tick_params(axis='y', labelsize=parameter4, colors="darkorange")

# Set x-axis label and title
ax.set_xlabel(x_label, size=parameter3)
ax.set_title(title_r, size=parameter5)

# Apply grid and styling
plt.style.use('default')
ax.grid(axis='both', alpha=0.3)

# Combine legends from both axes
lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper left', fontsize=7, title="Legend")
plt.savefig("hv_tb_w_024_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax





#Series 1: diff((((N023FAPG@G10 + N158FAPG@G10) + N111FAPG@G10) / 3),4) 
#  N023FAPG@G10   [Euro Area: Central Bank Assets as a % of GDP (NSA, %)]
#  N158FAPG@G10   [Japan: Central Bank Assets as a % of GDP (NSA, %)]
#  N111FAPG@G10   [U.S.: Central Bank Assets as a % of GDP (NSA, %)]
#  3
#Series 2: FII10@DAILY 
#  FII10@DAILY   [10-Year Treasury Inflation Indexed Note Yield at Constant Maturity (% p.a.)]


w_tickers = ['n023fapg','n158fapg','n111fapg']
hv_tb_w_024_001_m = Haver.data(w_tickers, "g10", dates=True)
hv_tb_w_024_001_m["central_bank_assets_gdp_unweighted"]=(hv_tb_w_024_001_m['n023fapg']+hv_tb_w_024_001_m['n158fapg']+hv_tb_w_024_001_m['n111fapg'])/3
hv_tb_w_024_001_m["central_bank_assets_gdp_unweighted"]=hv_tb_w_024_001_m["central_bank_assets_gdp_unweighted"].diff(4)
hv_tb_w_024_001_m=hv_tb_w_024_001_m[['central_bank_assets_gdp_unweighted']]
hv_tb_w_024_001_m=hv_tb_w_024_001_m.tail(60)

w_tickers = ['fii10',]
hv_tb_w_024_002_m = Haver.data(w_tickers, "daily", dates=True)
hv_tb_w_024_002_m.rename(columns={'fii10': '10-Year Treasury Inflation Indexed Note Yield at Constant Maturity (% p.a.)'}, inplace=True)
hv_tb_w_024_001_m = pd.concat( [hv_tb_w_024_001_m, hv_tb_w_024_002_m.reindex(hv_tb_w_024_001_m.index)],  axis=1)

print(hv_tb_w_024_001_m.columns.tolist())



title_r="US FED Assets vs Global Economic Policy Uncertainty"
y_label="Index %"
x_label=title_r
df1=hv_tb_w_024_001_m.copy()
#df1=df1.tail(250)
g1=df1.copy()
list_c=g1.columns.tolist()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
# Plot the first variable on the primary y-axis
# Plot the first variable on the primary y-axis
line1, = ax.plot(df1.index, df1.iloc[:, 0], color="darkred", linewidth=l1, linestyle='-', label=df1.columns[0])
ax.set_ylabel(list_c[0], size=6, color="black")
ax.tick_params(axis='y', labelsize=parameter4, colors="darkred")

# Plot the second variable on the secondary y-axis
ax2 = ax.twinx()
line2, = ax2.plot(df1.index, df1.iloc[:, 1], color="darkorange", linewidth=l1, linestyle='-', label=df1.columns[1])
ax2.set_ylabel(list_c[1], size=6, color="black")
ax2.tick_params(axis='y', labelsize=parameter4, colors="darkorange")

# Set x-axis label and title
ax.set_xlabel(x_label, size=parameter3)
ax.set_title(title_r, size=parameter5)

# Apply grid and styling
plt.style.use('default')
ax.grid(axis='both', alpha=0.3)

# Combine legends from both axes
lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper left', fontsize=7, title="Legend")
plt.savefig("hv_tb_w_024_001_m_g_002.png", bbox_inches='tight')

#hv_tb_w_024_001_m_g_001
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax

hv_tb_w_024_001_m.to_clipboard()



### 025_policy uncertainty  <a id="025_policy"></a>

##### Oolicy uncertainty
horizon_f=500                                             
w_m_tickers = ['n134viuc',
                'n132viuc',
               'n112viuc','n111viuc',
                'n158viuc',
               ]
hv_tb_w_025_001_m=Haver.data(w_m_tickers, "G10", dates=True)

#print(hv_tb_w_025_001_m)
hv_tb_w_025_001_m.rename(columns={"n134viuc": "Germany News-Based Economic Policy Uncertainty Index"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"n132viuc": "France News-Based Economic Policy Uncertainty Index"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"n112viuc": "UK News-Based Economic Policy Uncertainty Index"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"n111viuc": "US News-Based Economic Policy Uncertainty Index"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"n158viuc": "Japan News-Based Economic Policy Uncertainty Index"}, inplace=True)
print(hv_tb_w_025_001_m.index.min())
print(hv_tb_w_025_001_m.index.max())
#hv_tb_w_025_001_m.rename(columns={"m170eqty": "Emerging Europe: Est Nonres Portfolio Eqty Inflows to Emerging Europe (Bil.US$)"}, inplace=True)
#hv_tb_w_025_001_m_g_001=hv_tb_w_025_001_m.copy()

column_means = hv_tb_w_025_001_m.mean()
print(column_means)
# Divide each row value by the mean of its respective column
hv_tb_w_025_001_m = hv_tb_w_025_001_m / column_means

title_r = "News-Based Economic Policy Uncertainty Index"
y_label = "Index"
x_label = title_r
df1 = hv_tb_w_025_001_m.copy()
df1_list = df1.columns.tolist()
df1 = df1.tail(200)
g1 = df1.copy()
df1.index = pd.to_datetime(df1.index)
fig, ax = plt.subplots(figsize=(parameter_size1, parameter_size2))
g1.plot(kind='line', ax=ax, y=(df1_list[0]), color="orange", linewidth=(l1+2), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[1]), color="red", linewidth=(l1), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[2]), color="navy", linewidth=(l1), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[3]), color="black", linewidth=(l1), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[4]), color="green", linewidth=(l1), linestyle='-',)
#plt.axhline(B, color='black', Lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_025_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del fig

#Domestic demand volume index

horizon_f=500                                             
w_m_tickers = ['s111ndtc',
                's025ndtc',
               's112ndtc',
                's158ndtc',
               ]
hv_tb_w_025_001_m=Haver.data(w_m_tickers, "G10", dates=True)

#print(hv_tb_w_025_001_m)
hv_tb_w_025_001_m.rename(columns={"s111ndtc": "U.S.: Gross Domestic Purchases (SA, Bil.Chn.2017$)"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"s025ndtc": "EA 20: GDP: Total Domestic Demand (SWDA, Mil.Chn.2020.EUR)"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"s112ndtc": "UK: GDP: Total Domestic Demand (SA, Mil.Chained.2022.Pounds)"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"s158ndtc": "Japan: GDP: Total Domestic Demand (SA, Bil.Chn.2015.Yen)"}, inplace=True)
#hv_tb_w_025_001_m.rename(columns={"m170eqty": "Emerging Europe: Est Nonres Portfolio Eqty Inflows to Emerging Europe (Bil.US$)"}, inplace=True)
#hv_tb_w_025_001_m_g_001=hv_tb_w_025_001_m.copy()

base_date = "2009-12-31"
hv_tb_w_025_001_m = hv_tb_w_025_001_m.div(hv_tb_w_025_001_m.loc[base_date]).mul(100)
#print(hv_tb_w_025_001_m)


#Series 1: index(S111NDTC@G10,2010=100) [I]
#  S111NDTC@G10   [U.S.: Gross Domestic Purchases (SA, Bil.Chn.2017$)]
#Series 2: index(S025NDTC@G10,2010=100) [I]
#  S025NDTC@G10   [EA 20: GDP: Total Domestic Demand (SWDA, Mil.Chn.2020.EUR)]
#Series 3: index(S112NDTC@G10,2010=100) [I]
#  S112NDTC@G10   [UK: GDP: Total Domestic Demand (SA, Mil.Chained.2022.Pounds)]
#Series 4: index(S158NDTC@G10,2010=100) [I]
#  S158NDTC@G10   [Japan: GDP: Total Domestic Demand (SA, Bil.Chn.2015.Yen)]


title_r = "Domestic demand volume index"
y_label = "Index"
x_label = title_r
df1 = hv_tb_w_025_001_m.copy()
df1_list = df1.columns.tolist()
df1 = df1.tail(75)
g1 = df1.copy()
df1.index = pd.to_datetime(df1.index)
fig, ax = plt.subplots(figsize=(parameter_size1, parameter_size2))
g1.plot(kind='line', ax=ax, y=(df1_list[0]), color="orange", linewidth=(l1), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[1]), color="red", linewidth=(l1), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[2]), color="navy", linewidth=(l1), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[3]), color="black", linewidth=(l1), linestyle='-',)
#plt.axhline(B, color='black', Lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_025_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del fig

#### Industrial produciton exlcusidn construction 

w_m_tickers = ['s111d','s134d',
                's025d',
               's112d',
                's158d','s110dpm',
               ]
hv_tb_w_025_001_m=Haver.data(w_m_tickers, "G10", dates=True)

#print(hv_tb_w_025_001_m)
hv_tb_w_025_001_m.rename(columns={"s111d": "U.S IP ex Construction sa"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"s134d": "Germany ex Construction sa"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"s025d": "EA 20 IP ex Construction sa"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"s112d": "UK: IP ex Construction sa"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"s158d": "Japan IP ex Construction sa"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"s110dpm": "Advanced economies IP ex Construction sa"}, inplace=True)
#hv_tb_w_025_001_m.rename(columns={"m170eqty": "Emerging Europe: Est Nonres Portfolio Eqty Inflows to Emerging Europe (Bil.US$)"}, inplace=True)
#hv_tb_w_025_001_m_g_001=hv_tb_w_025_001_m.copy()

base_date = "2009-12-31"
hv_tb_w_025_001_m = hv_tb_w_025_001_m.div(hv_tb_w_025_001_m.loc[base_date]).mul(100)
#print(hv_tb_w_025_001_m)


#Series 1: index(S111NDTC@G10,2010=100) [I]
#  S111NDTC@G10   [U.S.: Gross Domestic Purchases (SA, Bil.Chn.2017$)]
#Series 2: index(S025NDTC@G10,2010=100) [I]
#  S025NDTC@G10   [EA 20: GDP: Total Domestic Demand (SWDA, Mil.Chn.2020.EUR)]
#Series 3: index(S112NDTC@G10,2010=100) [I]
#  S112NDTC@G10   [UK: GDP: Total Domestic Demand (SA, Mil.Chained.2022.Pounds)]
#Series 4: index(S158NDTC@G10,2010=100) [I]
#  S158NDTC@G10   [Japan: GDP: Total Domestic Demand (SA, Bil.Chn.2015.Yen)]


title_r = "IP ex Construction"
y_label = "Index"
x_label = title_r
df1 = hv_tb_w_025_001_m.copy()
df1_list = df1.columns.tolist()
df1 = df1.tail(150)
g1 = df1.copy()
df1.index = pd.to_datetime(df1.index)
fig, ax = plt.subplots(figsize=(parameter_size1, parameter_size2))
g1.plot(kind='line', ax=ax, y=(df1_list[0]), color="orange", linewidth=(l1+1), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[1]), color="red", linewidth=(l1+1), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[2]), color="navy", linewidth=(l1+1), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[3]), color="black", linewidth=(l1+1), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[4]), color="blue", linewidth=(l1+1), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[5]), color="brown", linewidth=(l1+1), linestyle='-',)
#g1.plot(kind='line', ax=ax, y=(df1_list[3]), color="black", linewidth=(l1), linestyle='-',)
#plt.axhline(B, color='black', Lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_025_003_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del fig

#### IP manufacturing
w_m_tickers = ['s111dm','s134dm',
                's025dm',
               's112dm',
                's158dm',
               ]
hv_tb_w_025_001_m=Haver.data(w_m_tickers, "G10", dates=True)

#print(hv_tb_w_025_001_m)
hv_tb_w_025_001_m.rename(columns={"s111dm": "U.S IP manufacturing sa"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"s134dm": "Germany manufacturing sa"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"s025dm": "EA 20 IP manufacturing sa"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"s112dm": "UK: IP manufacturing sa"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"s158dm": "Japan IP manufacturing sa"}, inplace=True)
#hv_tb_w_025_001_m.rename(columns={"s110dpm": "Advanced economies IP manufacturing sa"}, inplace=True)
#hv_tb_w_025_001_m.rename(columns={"m170eqty": "Emerging Europe: Est Nonres Portfolio Eqty Inflows to Emerging Europe (Bil.US$)"}, inplace=True)
#hv_tb_w_025_001_m_g_001=hv_tb_w_025_001_m.copy()

base_date = "2009-12-31"
hv_tb_w_025_001_m = hv_tb_w_025_001_m.div(hv_tb_w_025_001_m.loc[base_date]).mul(100)
#print(hv_tb_w_025_001_m)


#Series 1: index(S111NDTC@G10,2010=100) [I]
#  S111NDTC@G10   [U.S.: Gross Domestic Purchases (SA, Bil.Chn.2017$)]
#Series 2: index(S025NDTC@G10,2010=100) [I]
#  S025NDTC@G10   [EA 20: GDP: Total Domestic Demand (SWDA, Mil.Chn.2020.EUR)]
#Series 3: index(S112NDTC@G10,2010=100) [I]
#  S112NDTC@G10   [UK: GDP: Total Domestic Demand (SA, Mil.Chained.2022.Pounds)]
#Series 4: index(S158NDTC@G10,2010=100) [I]
#  S158NDTC@G10   [Japan: GDP: Total Domestic Demand (SA, Bil.Chn.2015.Yen)]


title_r = "IP manufacturing"
y_label = "Index"
x_label = title_r
df1 = hv_tb_w_025_001_m.copy()
df1_list = df1.columns.tolist()
df1 = df1.tail(150)
g1 = df1.copy()
df1.index = pd.to_datetime(df1.index)
fig, ax = plt.subplots(figsize=(parameter_size1, parameter_size2))
g1.plot(kind='line', ax=ax, y=(df1_list[0]), color="orange", linewidth=(l1+1), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[1]), color="red", linewidth=(l1+1), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[2]), color="navy", linewidth=(l1+1), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[3]), color="black", linewidth=(l1+1), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[4]), color="blue", linewidth=(l1+1), linestyle='-',)
#g1.plot(kind='line', ax=ax, y=(df1_list[5]), color="brown", linewidth=(l1), linestyle='-',)
#g1.plot(kind='line', ax=ax, y=(df1_list[3]), color="black", linewidth=(l1), linestyle='-',)
#plt.axhline(B, color='black', Lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_025_004_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del fig


### 026_inflation expectations 

#hv_tb_w_026_001_m_g_001

horizon_f=500                                             
w_m_tickers = ['fyiei5e','cinf5'
               ]
hv_tb_w_026_001_m=Haver.data(w_m_tickers, "usecon", dates=True)

print(hv_tb_w_026_001_m)
hv_tb_w_026_001_m.rename(columns={"fyiei5e": "Inflation Compensation - Continuously Compounded Instantaneous 5Y Forward Rates (%)"}, inplace=True)
hv_tb_w_026_001_m.rename(columns={"cinf5": "Michigan Expected inflation rate, next 5 years (%)"}, inplace=True)



title_r="Inflation expectations 5y"
y_label="Index %"
x_label=title_r
df1=hv_tb_w_026_001_m.copy()
df1=df1.tail(250)
g1=df1.copy()
list_c=g1.columns.tolist()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
# Plot the first variable on the primary y-axis
# Plot the first variable on the primary y-axis
line1, = ax.plot(df1.index, df1.iloc[:, 0], color="black", linewidth=l1+1, linestyle='-', label=df1.columns[0])
ax.set_ylabel(list_c[0], size=6, color="black")
ax.tick_params(axis='y', labelsize=parameter4, colors="black")

# Plot the second variable on the secondary y-axis
ax2 = ax.twinx()
line2, = ax2.plot(df1.index, df1.iloc[:, 1], color="blue", linewidth=l1+1, linestyle='-', label=df1.columns[1])
ax2.set_ylabel(list_c[1], size=6, color="blue")
ax2.tick_params(axis='y', labelsize=parameter4, colors="blue")

# Set x-axis label and title
ax.set_xlabel(x_label, size=parameter3)
ax.set_title(title_r, size=parameter5)

# Apply grid and styling
plt.style.use('default')
ax.grid(axis='both', alpha=0.3)

# Combine legends from both axes
lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper left', fontsize=7, title="Legend")
plt.savefig("hv_tb_w_026_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax


horizon_f=500                                             
w_m_tickers = ['r112inf','r156fbv']
hv_tb_w_026_001_m=Haver.data(w_m_tickers, "intdaily", dates=True)

print(hv_tb_w_026_001_m)
hv_tb_w_026_001_m.rename(columns={"r112inf": "UK Implied 5-year forward inflation rate "}, inplace=True)
hv_tb_w_026_001_m.rename(columns={"r156fbv": "Canada Spread between conventional and real return (breakeven ifnlation)"}, inplace=True)



title_r="Inflation expectations 5y"
y_label="Index %"
x_label=title_r
df1=hv_tb_w_026_001_m.copy()
df1 = df1[df1.index.is_month_end]
df1=df1.tail(200)
g1=df1.copy()
list_c=g1.columns.tolist()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
# Plot the first variable on the primary y-axis
# Plot the first variable on the primary y-axis
line1, = ax.plot(df1.index, df1.iloc[:, 0], color="black", linewidth=l1+1, linestyle='-', label=df1.columns[0])
ax.set_ylabel(list_c[0], size=6, color="black")
ax.tick_params(axis='y', labelsize=parameter4, colors="black")

# Plot the second variable on the secondary y-axis
ax2 = ax.twinx()
line2, = ax2.plot(df1.index, df1.iloc[:, 1], color="blue", linewidth=l1+1, linestyle='-', label=df1.columns[1])
ax2.set_ylabel(list_c[1], size=6, color="blue")
ax2.tick_params(axis='y', labelsize=parameter4, colors="blue")

# Set x-axis label and title
ax.set_xlabel(x_label, size=parameter3)
ax.set_title(title_r, size=parameter5)

# Apply grid and styling
plt.style.use('default')
ax.grid(axis='both', alpha=0.3)

# Combine legends from both axes
lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper left', fontsize=7, title="Legend")
plt.savefig("hv_tb_w_026_002_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax

##################################################
### rest o the world 

horizon_f=500                                             
w_m_tickers = ['r132f5v','r134f5v']
hv_tb_w_026_001_m=Haver.data(w_m_tickers, "intdaily", dates=True)

print(hv_tb_w_026_001_m)
hv_tb_w_026_001_m.rename(columns={"r132f5v": "France 5 year breakeven Inflation rate"}, inplace=True)
hv_tb_w_026_001_m.rename(columns={"r134f5v": "Germany 5 year breakeven Inflation rate"}, inplace=True)


title_r="Inflation expectations 5y"
y_label="Index %"
x_label=title_r
df1=hv_tb_w_026_001_m.copy()
df1 = df1[df1.index.is_month_end]
df1=df1.tail(200)
g1=df1.copy()
list_c=g1.columns.tolist()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
# Plot the first variable on the primary y-axis
# Plot the first variable on the primary y-axis
line1, = ax.plot(df1.index, df1.iloc[:, 0], color="black", linewidth=l1+1, linestyle='-', label=df1.columns[0])
ax.set_ylabel(list_c[0], size=6, color="black")
ax.tick_params(axis='y', labelsize=parameter4, colors="black")

# Plot the second variable on the secondary y-axis
ax2 = ax.twinx()
line2, = ax2.plot(df1.index, df1.iloc[:, 1], color="blue", linewidth=l1+1, linestyle='-', label=df1.columns[1])
ax2.set_ylabel(list_c[1], size=6, color="blue")
ax2.tick_params(axis='y', labelsize=parameter4, colors="blue")

# Set x-axis label and title
ax.set_xlabel(x_label, size=parameter3)
ax.set_title(title_r, size=parameter5)

# Apply grid and styling
plt.style.use('default')
ax.grid(axis='both', alpha=0.3)

# Combine legends from both axes
lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper left', fontsize=7, title="Legend")
plt.savefig("hv_tb_w_026_003_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax

##########################
horizon_f=500                                             
w_m_tickers = ['r158f5v',]
hv_tb_w_026_001_m=Haver.data(w_m_tickers, "intdaily", dates=True)

print(hv_tb_w_026_001_m)
hv_tb_w_026_001_m.rename(columns={"r158f5v": "Japan 5 year breakeven Inflation rate"}, inplace=True)

title_r = "Japan 5 year breakeven Inflation rate"
y_label = "Index"
x_label = title_r
df1 = hv_tb_w_026_001_m.copy()
df1_list = df1.columns.tolist()
#df1 = df1.tail(200)
g1 = df1.copy()
df1.index = pd.to_datetime(df1.index)
fig, ax = plt.subplots(figsize=(parameter_size1, parameter_size2))
g1.plot(kind='line', ax=ax, y=(df1_list[0]), color="orange", linewidth=(l1), linestyle='-',)
#plt.axhline(B, color='black', Lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_026_004_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del fig

### 027_recession  <a id="027_recession"></a>


w_tickers = ['sahmurdv',]
hv_tb_w_024_001_m = Haver.data(w_tickers, "usecon", dates=True)
print()
w_tickers = ['ismc',]
hv_tb_w_024_002_m = Haver.data(w_tickers, "usecon", dates=True)
hv_tb_w_024_001_m = pd.concat([hv_tb_w_024_001_m, hv_tb_w_024_002_m], axis=1)

hv_tb_w_024_001_m.rename(columns={'sahmurdv': 'Sahm rule'}, inplace=True)
hv_tb_w_024_001_m.rename(columns={'ismc': 'ISM Composite index'}, inplace=True)
print(hv_tb_w_024_001_m.columns.tolist())



title_r="Sahm rule"
y_label="Index %"
x_label=title_r
df1=hv_tb_w_024_001_m.copy()
df1=df1.tail(250)
g1=df1.copy()
list_c=g1.columns.tolist()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
# Plot the first variable on the primary y-axis
# Plot the first variable on the primary y-axis
line1, = ax.plot(df1.index, df1.iloc[:, 0], color="darkred", linewidth=l1+1, linestyle='-', label=df1.columns[0])
ax.set_ylabel(list_c[0], size=6, color="black")
ax.tick_params(axis='y', labelsize=parameter4, colors="darkred")

# Plot the second variable on the secondary y-axis
ax2 = ax.twinx()
line2, = ax2.plot(df1.index, df1.iloc[:, 1], color="darkorange", linewidth=l1+1, linestyle='-', label=df1.columns[1])
#line3, = ax2.plot(50,linestyle='-', )
ax2.axhline(50, color='black', lw=2, linestyle ='dashed', alpha=0.75)
ax2.set_ylabel(list_c[1], size=6, color="black")
ax2.tick_params(axis='y', labelsize=parameter4, colors="darkorange")

# Set x-axis label and title
ax.set_xlabel(x_label, size=parameter3)
ax.set_title(title_r, size=parameter5)

# Apply grid and styling
plt.style.use('default')
ax.grid(axis='both', alpha=0.3)

# Combine legends from both axes
lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper left', fontsize=7, title="Legend")
plt.savefig("hv_tb_w_027_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax

### 028_commodities  <a id="028_commodities"></a>

horizon_f=500                                             
w_m_tickers = ['pzall','pzmt',
                'pztf',
               'pzraw','pzfds',
                'pzfo','pzlp'
               ]
hv_tb_w_025_001_m=Haver.data(w_m_tickers, "usecon", dates=True)

#print(hv_tb_w_025_001_m)
hv_tb_w_025_001_m.rename(columns={"pzall": "CRB Commodity spot index avg"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"pzmt": "CRB Metals subindex avg"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"pztf": "CRB Textiles subindex avg"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"pzraw": "CRB raw industrials subindex avg"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"pzfds": "CRB foodstuffs subindex avg"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"pzfo": "CRB fats subindex avg"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"pzlp": "CRB livestock subindex avg"}, inplace=True)



print(hv_tb_w_025_001_m.index.min())
print(hv_tb_w_025_001_m.index.max())
#hv_tb_w_025_001_m.rename(columns={"m170eqty": "Emerging Europe: Est Nonres Portfolio Eqty Inflows to Emerging Europe (Bil.US$)"}, inplace=True)
#hv_tb_w_025_001_m_g_001=hv_tb_w_025_001_m.copy()



title_r = "CRB Commodity"
y_label = "Index"
x_label = title_r
df1 = hv_tb_w_025_001_m.copy()
df1_list = df1.columns.tolist()
df1 = df1.tail(75)
g1 = df1.copy()
df1.index = pd.to_datetime(df1.index)
fig, ax = plt.subplots(figsize=(parameter_size1, parameter_size2))
g1.plot(kind='line', ax=ax, y=(df1_list[0]), color="orange", linewidth=(l1+1), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[1]), color="red", linewidth=(l1+1), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[2]), color="navy", linewidth=(l1+1), linestyle='-',)
#g1.plot(kind='line', ax=ax, y=(df1_list[3]), color="black", linewidth=(l1+1), linestyle='-',)
#g1.plot(kind='line', ax=ax, y=(df1_list[4]), color="blue", linewidth=(l1+1), linestyle='-',)
#g1.plot(kind='line', ax=ax, y=(df1_list[5]), color="brown", linewidth=(l1), linestyle='-',)
#g1.plot(kind='line', ax=ax, y=(df1_list[3]), color="black", linewidth=(l1), linestyle='-',)
#plt.axhline(B, color='black', Lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_028_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del fig



title_r = "CRB Commodity"
y_label = "Index"
x_label = title_r
df1 = hv_tb_w_025_001_m.copy()
df1_list = df1.columns.tolist()
df1 = df1.tail(75)
g1 = df1.copy()
df1.index = pd.to_datetime(df1.index)
fig, ax = plt.subplots(figsize=(parameter_size1, parameter_size2))
g1.plot(kind='line', ax=ax, y=(df1_list[0]), color="orange", linewidth=(l1+1), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[3]), color="red", linewidth=(l1+1), linestyle='-',)
g1.plot(kind='line', ax=ax, y=(df1_list[4]), color="navy", linewidth=(l1+1), linestyle='-',)
#g1.plot(kind='line', ax=ax, y=(df1_list[3]), color="black", linewidth=(l1+1), linestyle='-',)
#g1.plot(kind='line', ax=ax, y=(df1_list[4]), color="blue", linewidth=(l1+1), linestyle='-',)
#g1.plot(kind='line', ax=ax, y=(df1_list[5]), color="brown", linewidth=(l1), linestyle='-',)
#g1.plot(kind='line', ax=ax, y=(df1_list[3]), color="black", linewidth=(l1), linestyle='-',)
#plt.axhline(B, color='black', Lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
plt.savefig("hv_tb_w_028_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del fig

### 029 supply chain pressure citi surprise idnex  <a id="028_commodities"></a>

#Series 1: W1NGSCPI@TRANSPRT [-3] 
#  W1NGSCPI@TRANSPRT   [Global Supply Chain Pressure Index (Std Dev Pts)]
#Series 2: V110CIS@INTDAILY 
#  V110CIS@INTDAILY   [Citigroup Inflation Surprise Index: Based on G10 Currencies (%)]


horizon_f=500                                             
w_m_tickers = ['W1NGSCPI',]
w_m_tickers = [element.lower() for element in w_m_tickers]
hv_tb_w_025_001_m=Haver.data(w_m_tickers, "TRANSPRT", dates=True)
#print(hv_tb_w_025_001_m)
hv_tb_w_025_001_m.rename(columns={"w1ngscpi": "[Global Supply Chain Pressure Index (Std Dev Pts)]"}, inplace=True)


w_m_tickers = ['V110CIS',]
w_m_tickers = [element.lower() for element in w_m_tickers]
hv_tb_w_025_002_m=Haver.data(w_m_tickers, "INTDAILY", dates=True)
#print(hv_tb_w_025_001_m)
hv_tb_w_025_002_m.rename(columns={"v110cis": "Citigroup Inflation Surprise Index: Based on G10 Currencies (%"}, inplace=True)
hv_tb_w_025_001_m = pd.concat([hv_tb_w_025_001_m, hv_tb_w_025_002_m], axis=1)


title_r="Supply chain pressure vs citi inflation surprise"
y_label="Index %"
x_label=title_r
df1=hv_tb_w_024_001_m.copy()
df1=df1.tail(250)
g1=df1.copy()
list_c=g1.columns.tolist()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
# Plot the first variable on the primary y-axis
# Plot the first variable on the primary y-axis
line1, = ax.plot(df1.index, df1.iloc[:, 0], color="darkred", linewidth=l1+1, linestyle='-', label=df1.columns[0])
ax.set_ylabel(list_c[0], size=6, color="black")
ax.tick_params(axis='y', labelsize=parameter4, colors="darkred")

# Plot the second variable on the secondary y-axis
ax2 = ax.twinx()
line2, = ax2.plot(df1.index, df1.iloc[:, 1], color="darkorange", linewidth=l1+1, linestyle='-', label=df1.columns[1])
#line3, = ax2.plot(50,linestyle='-', )
ax2.axhline(50, color='black', lw=2, linestyle ='dashed', alpha=0.75)
ax2.set_ylabel(list_c[1], size=6, color="black")
ax2.tick_params(axis='y', labelsize=parameter4, colors="darkorange")

# Set x-axis label and title
ax.set_xlabel(x_label, size=parameter3)
ax.set_title(title_r, size=parameter5)

# Apply grid and styling
plt.style.use('default')
ax.grid(axis='both', alpha=0.3)

# Combine legends from both axes
lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper left', fontsize=7, title="Legend")
plt.savefig("hv_tb_w_029_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax

### 030 NATURAL GAS ISM

#Series 1: SETNA(PENGAS@DAILY,20240112:20240112) 
#  PENGAS@DAILY   [Natural Gas Price, Henry Hub, LA [EIA] ($/mmbtu)]
#Series 2: NMFPIA@USECON 
#  NMFPIA@USECON   [ISM Services: Prices Index (SA, 50+ = Economy Expanding)]





horizon_f=500                                             
w_m_tickers = ['PENGAS',]
w_m_tickers = [element.lower() for element in w_m_tickers]
hv_tb_w_025_001_m=Haver.data(w_m_tickers, "DAILY", dates=True)
#print(hv_tb_w_025_001_m)
hv_tb_w_025_001_m.rename(columns={"pengas": " [Natural Gas Price, Henry Hub, LA [EIA] ($/mmbtu)]"}, inplace=True)


w_m_tickers = ['NMFPIA',]
w_m_tickers = [element.lower() for element in w_m_tickers]
hv_tb_w_025_002_m=Haver.data(w_m_tickers, "USECON", dates=True)
#print(hv_tb_w_025_001_m)
hv_tb_w_025_002_m.rename(columns={"nmfpia": "[ISM Services: Prices Index (SA, 50+ = Economy Expanding)]"}, inplace=True)
hv_tb_w_025_001_m = pd.concat([hv_tb_w_025_001_m, hv_tb_w_025_002_m], axis=1)

print(hv_tb_w_025_001_m)

### 031 supply chain pressures citi ifnaltion 

title_r="Supply chain pressure vs citi inflation surprise"
y_label="Index %"
x_label=title_r
df1=hv_tb_w_025_001_m.copy()
df1=df1.tail(1250)
g1=df1.copy()
list_c=g1.columns.tolist()
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
# Plot the first variable on the primary y-axis
# Plot the first variable on the primary y-axis
line1, = ax.plot(df1.index, df1.iloc[:, 0], color="darkred", linewidth=l1+1, linestyle='-', label=df1.columns[0])
ax.set_ylabel(list_c[0], size=6, color="black")
ax.tick_params(axis='y', labelsize=parameter4, colors="darkred")

# Plot the second variable on the secondary y-axis
ax2 = ax.twinx()
line2, = ax2.plot(df1.index, df1.iloc[:, 1], color="darkorange", linewidth=l1+1, linestyle='-', label=df1.columns[1])
#line3, = ax2.plot(50,linestyle='-', )
#ax2.axhline(50, color='black', lw=2, linestyle ='dashed', alpha=0.75)
ax2.set_ylabel(list_c[1], size=6, color="black")
ax2.tick_params(axis='y', labelsize=parameter4, colors="darkorange")

# Set x-axis label and title
ax.set_xlabel(x_label, size=parameter3)
ax.set_title(title_r, size=parameter5)

# Apply grid and styling
plt.style.use('default')
ax.grid(axis='both', alpha=0.3)

# Combine legends from both axes
lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper left', fontsize=7, title="Legend")
plt.savefig("hv_tb_w_030_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
del df1
#del list_c
del fig
del ax

### 032 foreign holdings 

#Series 1: FH001TB@USINT 
#  FH001TB@USINT   [Foreign Holdings of US Treasury Securities (EOP, Bil.$)]
#Series 2: (((FH001TB@USINT - FH158TB@USINT) - FH170TB@USINT) - FH924TB@USINT) 
#  FH001TB@USINT   [Foreign Holdings of US Treasury Securities (EOP, Bil.$)]
#  FH158TB@USINT   [Japan: Holdings of US Treasury Securities (EOP, Bil.$)]
#  FH170TB@USINT   [Europe: Holdings of US Treasury Securities (EOP, Bil.$)]
#  FH924TB@USINT   [China: Holdings of US Treasury Securities (EOP, Bil.$)]
#Series 3: FH158TB@USINT 
#  FH158TB@USINT   [Japan: Holdings of US Treasury Securities (EOP, Bil.$)]
#Series 4: FH924TB@USINT 
#  FH924TB@USINT   [China: Holdings of US Treasury Securities (EOP, Bil.$)]
#Series 5: FH170TB@USINT 
#  FH170TB@USINT   [Europe: Holdings of US Treasury Securities (EOP, Bil.$)]

horizon_f=500                                             
w_m_tickers = ['fh001tb','fh158tb','fh170tb','fh924tb',]
hv_tb_w_025_001_m=Haver.data(w_m_tickers, "USINT", dates=True)
print(hv_tb_w_025_001_m)

#Series 2: (((FH001TB@USINT - FH158TB@USINT) - FH170TB@USINT) - FH924TB@USINT) 
hv_tb_w_025_001_m["Rest of the world"]=(((hv_tb_w_025_001_m["fh001tb"]-hv_tb_w_025_001_m["fh158tb"])-hv_tb_w_025_001_m["fh170tb"])-hv_tb_w_025_001_m["fh924tb"])
hv_tb_w_025_001_m=hv_tb_w_025_001_m[['fh158tb','fh170tb','fh924tb','Rest of the world']]
hv_tb_w_025_001_m.rename(columns={"fh001tb": "Foreign Holdings of US Treasury Securities (EOP, Bil.$)"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"fh158tb": "Japan: Holdings of US Treasury Securities (EOP, Bil.$)"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"fh170tb": "Europe: Holdings of US Treasury Securities (EOP, Bil.$)"}, inplace=True)
hv_tb_w_025_001_m.rename(columns={"fh924tb": "China: Holdings of US Treasury Securities (EOP, Bil.$)"}, inplace=True)
print(hv_tb_w_025_001_m.columns.tolist())


df=hv_tb_w_025_001_m.copy()
df=df.tail(120)
# Plotting

colors = ['green',
          'magenta', 
          'orange', 
          'navy', 
           'salmon',]

# Plotting
fig, ax1 = plt.subplots(figsize=(15, 8))

# Define the bar width
bar_width = 20
bottom = np.zeros(len(df))

for i, col in enumerate(df.columns):
    plt.bar(df.index, df[col], width=bar_width, bottom=bottom, color=colors[i], label=col)
    bottom += df[col].values

plt.xlabel("Date")
plt.ylabel("Value")
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), ncol=1)
plt.title("Stacked Bar Chart of Monthly Time Series Data")
# Format x-axis to show monthly dates
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.xticks(rotation=45,ha='right')
plt.tight_layout()
plt.savefig("hv_tb_w_032_001_m_g_001.png", bbox_inches='tight')
plt.savefig("hv_tb_w_032_001_m_g_001.png", bbox_inches='tight')
plt.show()
plt.close()




####Equity portolio inflows

horizon_f=500                                             
w_m_tickers = ['m200eqty',
                'm405eqty',
               'm205eqty',
                'm505eqty',
                'm170eqty',
               ]
hv_tb_w_025_001_m=Haver.data(w_m_tickers, "IIFDATA", dates=True)
#print(hv_tb_w_025_001_m)
#hv_tb_w_025_001_m.rename(columns={"m200eqty": "Emerging Mrkts: Est Nonres Portfolio Eqty Inflows to Emerging Mrkts(Bil.US$)"}, inplace=True)
#hv_tb_w_025_001_m.rename(columns={"m405eqty": "Africa/Middle East: Est Nonres Portfolio Eqty Infl to Africa/Mid East (Bil.US$)"}, inplace=True)
#hv_tb_w_025_001_m.rename(columns={"m205eqty": "Latin America: Est Non-Res Portfolio Eqty Inflows to Latin America (Bil.US$)"}, inplace=True)
#hv_tb_w_025_001_m.rename(columns={"m505eqty": "Emerging Asia: Est Nonres Portfolio Eqty Inflows to Emerging Asia (Bil.US$)"}, inplace=True)
#hv_tb_w_025_001_m.rename(columns={"m170eqty": "Emerging Europe: Est Nonres Portfolio Eqty Inflows to Emerging Europe (Bil.US$)"}, inplace=True)
#hv_tb_w_025_001_m_g_001=hv_tb_w_025_001_m.copy()


#Series 1: M200EQTY@IIFDATA 
#  M200EQTY@IIFDATA   [Emerging Mrkts: Est Nonres Portfolio Eqty Inflows to Emerging Mrkts(Bil.US$)]
#Series 2: M405EQTY@IIFDATA 
#  M405EQTY@IIFDATA   [Africa/Middle East: Est Nonres Portfolio Eqty Infl to Africa/Mid East (Bil.US$)]
#Series 3: M205EQTY@IIFDATA 
#  M205EQTY@IIFDATA   [Latin America: Est Non-Res Portfolio Eqty Inflows to Latin America (Bil.US$)]
#Series 4: M505EQTY@IIFDATA 
#  M505EQTY@IIFDATA   [Emerging Asia: Est Nonres Portfolio Eqty Inflows to Emerging Asia (Bil.US$)]
#Series 5: M170EQTY@IIFDATA 
#  M170EQTY@IIFDATA   [Emerging Europe: Est Nonres Portfolio Eqty Inflows to Emerging Europe (Bil.US$)]



horizon_f=500                                             
w_m_tickers = ['aayw',]
hv_tb_w_025_001_m=Haver.data(w_m_tickers, "BLUECFIN", dates=True)
print(hv_tb_w_025_001_m)
#no acccess???


#Series 1: (AAYW@BLUECFIN - N158RTAR@G10) 
#  AAYW@BLUECFIN   [BCFF: Japan: Policy-Rate Balance Rate 12-Mo Forecast: Consensus (%)]
#  N158RTAR@G10   [Japan: Bank of Japan Policy Rate (EOP, %)]
#Series 2: (AAZI@BLUECFIN - N193RTAR@G10) 
#  AAZI@BLUECFIN   [BCFF: Australia: Official Cash Rate 12-Mo Forecast: Consensus (%)]
#  N193RTAR@G10   [Australia: Official Cash Rate (EOP, %)]
#Series 3: (AAZF@BLUECFIN - N156RTAR@G10) 
#  AAZF@BLUECFIN   [BCFF: Canada: O/N Money Mkt Financing Rate 12-Mo Forecast: Consensus (%)]
#  N156RTAR@G10   [Canada: Overnight Money Market Financing Rate [Target] (EOP, %)]
#Series 4: (AAYQ@BLUECFIN - N111RTAR@G10) 
#  AAYQ@BLUECFIN   [BCFF: US: Fed Funds Target Rate 12-Mo Forecast: Consensus (%)]
#  N111RTAR@G10   [U.S.: Federal Open Market Committee: Fed Funds Target Rate (EOP, %)]
#Series 5: (AAYZ@BLUECFIN - N112RTAR@G10) 
#  AAYZ@BLUECFIN   [BCFF: UK: Official Bank Rate 12-Mo Forecast: Consensus (%)]
#  N112RTAR@G10   [U.K.: Official Bank Rate (EOP, %)]
#Series 6: (AAZL@BLUECFIN - N023RTA2@G10) 
#  AAZL@BLUECFIN   [BCFF: Euro area: Main Refinancing Rate 12-Mo Forecast: Consensus (%)]
#  N023RTA2@G10   [Euro Area 11-20: Main Refinancing Rate (EOP, %)]









### cleaning 

import gc
import sys

def cleanup_environment():
    # List all variables in the global scope
    globals_copy = globals().copy()
    
    # Delete DataFrames specifically (and optionally other variables)
    for var_name, var_value in globals_copy.items():
        if isinstance(var_value, pd.DataFrame):  # Checks if it's a DataFrame
            print(f"Deleting DataFrame: {var_name}")
            del globals()[var_name]
    
    # Trigger garbage collection
    gc.collect()
    print("Environment cleaned!")

# Call the cleanup function
cleanup_environment()





### bottom <a id="bottom"></a>
- [Top](#table_contents)
