# %% [markdown]
# ### 001_top <a id="title_page"></a

# %% [markdown]
# ### 001_packages <a id="title_page"></a

# %%
owner=""
###econiomics DASHBOARD
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display, HTML
import Haver
Haver.path(Haver.direct(1))    
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import os
def clear():
    os.system('cls')
# then you can clear the window with:
from matplotlib.dates import date2num
import os
os.chdir('C:/database/dashboard')
#C:\database\dashboard
print(os.getcwd())

import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import matplotlib.ticker as plticker
import matplotlib.dates as mdates
from matplotlib.ticker import MultipleLocator

import seaborn as sns

from matplotlib.colors import LinearSegmentedColormap

import matplotlib.pyplot as pit
from PIL import Image
import time
import seaborn as sns
import plotly.graph_objects as go
parameter1_s=9
parameter2_s=6
parameter3_s=11
parameter4_s=7
parameter5_s=20
parameter3=15
parameter4=15
parameter5=20
s0=1
s1=5
s2=6
s3=7
s4=12
s5=14
s6=15
l0=1.0
l1=1.0
l2=1.5
tail_y=12
tail_0=24
tail_1=60
tail_2=72
tail_4=36
parameter_size1=8
parameter_size2=6

million = 1000000
horizon_120 = 120
horizon_tb = 24
#DAA0236BLUECHIP

def zscore(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  o = arr.rolling(window = window).std()
  return (x-u)/o

def zscore_avg(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  return (x-u)

# %% [markdown]
# ### 001_ sweden cpi yy

# %%
country_database="NORDIC"
chf_m_tickers = ['senph', 'senphct', 'senpc', 'senpcsh', 'senpcctx',
                'senpcif', 'senpcxf', 'senpcct', 'senpcfct', 'senpcxi',
                'senpchim', 'senpck', 'senpcx4',
                'senmifxr', 'senmi85r', 'senmi1r', 'senmi24r', 'senmipvr', 'senmipcr']
hv_tb_no_001_001_m = Haver.data(chf_m_tickers, country_database, dates=True)
print(hv_tb_no_001_001_m)
#print(hv_tb_ch_001_001_m)
#print(chf_m_tickers.columns)
for x in range(len(chf_m_tickers)):
#    print(x)
    variable = str(chf_m_tickers[x])
#    print(variable)
    hv_tb_no_001_001_m[variable] = hv_tb_no_001_001_m[variable].pct_change(12).multiply(100).round(1)
    #print(chf_m_tickers[variable])
hv_tb_no_001_001_m.rename(columns={"senph": "Sweden Harmonized CPI YY NSA"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"senphct": "Sweden HICP at constant tax YY NSA"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"senpc": "Sweden CPI Headline YY NSA"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"senpcsh": "Sweden CPI Headline Shadow revised YY NSA"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"senpcctx": "Sweden CPI-CT Headline at constant tax YY NSA"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"senpcif": "Sweden CPI fixed interest rate YY NSA"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"senpcxf": "Sweden CPI fixed interest rate ex energy YY NSA"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"senpcct": "Sweden CPI-CT constant tax YY NSA"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"senpcfct": "Sweden CPIF fixed rate constant taxes YY NSA"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"senpcxi": "Sweden CPI ex interest rate capital stock YY NSA"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"senpchim": "Sweden Mortgage Interest YY NSA"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"senpck": "Sweden Capital Stock YY NSA"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"senpcx4": "Sweden ex package holidays YY NSA"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"senmifxr": "Riksbank CPIF ex energy food YY NSA"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"senmi85r": "Riksbank underlying inflation trim 85 yy nsa"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"senmilr": "Riksbank underlying inflation trim 1 yy nsa"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"senmi24r": "Riksbank underlying inflation und 24 yy nsa"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"senmipvr": "Riksbank underlying inflation kpifpv yy nsa"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"senmipcr": "Riksbank underlying inflation kpifpc yy nsa"}, inplace=True)


hv_tb_no_001_001_m_g = hv_tb_no_001_001_m.copy()
hv_tb_no_001_001_m_g_001 = hv_tb_no_001_001_m.copy()

hv_tb_no_001_001_m.index=hv_tb_no_001_001_m.index.date
hv_tb_no_001_001_m = hv_tb_no_001_001_m.tail(horizon_tb)
hv_tb_no_001_001_t1=hv_tb_no_001_001_m.tail(horizon_tb)

hv_tb_no_001_001_m_t = hv_tb_no_001_001_m.transpose()
hv_tb_no_001_001_m_t.index.names = ['Variable']

hv_tb_no_001_001_t1_t = hv_tb_no_001_001_t1.transpose()
hv_tb_no_001_001_t1_t.index.names = ['Variable']

# %% [markdown]
# ### 001_ sweden cpi yy table

# %%
#hv_tb_no_001_001_m_g = hv_tb_no_001_001_m.copy()
#hv_tb_no_001_001_m = hv_tb_no_001_001_m.transpose()
#hv_tb_no_001_001_m.index.names = ['Variable']
##dashboard.to_clipboard()
#print(hv_tb_no_001_001_m)
#dashboard.to_clipboard()

#print(path_display)
#hv_tb_ch_001_001_m.to_csv (path_display, index True, header=True)
#print(hv_tb_au_006_001_m)
#print("step2")

# %%
############################################################
######Table 1

#####here*******
title_table="swe_inflation_yy_table"
df =hv_tb_no_001_001_t1.copy()
df_transposed = hv_tb_no_001_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_swe_001_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_no_001_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_swe_001_001_m_t_002.png')

# %% [markdown]
# ### 001_ sweden cpi graph

# %%
df1=hv_tb_no_001_001_m_g.copy()
df1=df1.tail(48)
for i in range(19):    
    ai=f"{i:02}"
    print(ai)
    g1=df1.copy()
    list_c=g1.columns.tolist()
    title_r=str(list_c[i])
    y_label="Growth %"
    x_label=title_r
    fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
    g1.plot(kind='line', ax=ax, y=list_c[i], color="darkred", linewidth= l1, linestyle='-',
            marker='D', markersize=(s3-1))

    for x,y in zip(g1.index,g1[list_c[i]]):
        label = "{:.1f}".format(y)
        plt.annotate(label,  # this is the text
                     (x,y),  # these are the coordinates to position the label
                     textcoords="offset points",  # how to position the text
                     xytext=(0,15),  # distance from text to points (x,y)
                     size=7,
                     ha='center',
                     weight="bold")
    
    for series_name in list_c[1:(i+1)]:
        last_y_value = g1[series_name][-1]
        #print(last_y_value)
        plt.annotate(f"({series_name}) \n ({last_y_value})",
                     xy=(g1.index.max(), last_y_value),
                     xytext=(20, -25),
                     textcoords="offset points", arrowprops=dict(facecolor='black', arrowstyle='->'))
    
    plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
    plt.style.use('default')
    plt.ylabel(str(y_label), size=parameter3)
    plt.xlabel(str(x_label), size=parameter3)
    plt.tick_params(labelsize=parameter4)
    plt.title(str(title_r), size=parameter5)
    plt.grid(axis='both', alpha=0.3)
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    x_position = 0.5  # Adjust this value
    y_position = 8.5  # Adjust this value to place the text inside the plot
    
    plt.text(0.05, 0.5, "[Sweden]",
             fontsize=12, transform=plt.gca().transAxes,
             bbox=dict(facecolor="white", alpha=0.5)) # Adding the text box
    
    #plt.text(8.5, 8.5, "Riksbank",
    #         fontsize=40,
    #         color="gray",
    #         alpha=0.5,
    #         ha="center",
    #         va="center",
    #         rotation=30,
    #         transform=plt.gca().transAxes)
    
    plt.savefig(str("hv_tb_swe_001_001_m_g_0" + str(ai) + ".png"), bbox_inches="tight")
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    #del gl
    #del df1
    del list_c
    del fig
    del ax

# %% [markdown]
# ### 001_ sweden riksbnak forecast  <a id="title_page"></a

# %%
sweden_m_tickers = ['sepfc', 'sepxc', 'seggi', 'segap', 
                    'seghr', 'segur', 'serpc', 'serpr', 
                    'sergy', 'sekix', 'segnl']

# List_c=g_i.columns.toList()
# title_r=str(list_c[0])
# y_Label="Growth"
# x_Label=title_r

for i in range(len(sweden_m_tickers)):
    print(i)
    ai = f"{i:02}"
#    print(ai)
    sweden_m_ticker = str(sweden_m_tickers[i])
    time.sleep(1)
    hv_tb_swe_001_001_m = Haver.data(sweden_m_ticker, country_database, dates=True)
    time.sleep(1)
    hv_tb_swe_001_001_m.rename(columns={'sepfc': 'Riksbank forecast cpif yy na monthly'}, inplace=True)
    hv_tb_swe_001_001_m.rename(columns={'sepxc': 'Riksbank forecast cpif xe yy na monthly'}, inplace=True)
    hv_tb_swe_001_001_m.rename(columns={'seggi': 'Riksbank forecast gdp sa'}, inplace=True)
    hv_tb_swe_001_001_m.rename(columns={'segap': 'Riksbank forecast gdp gap sa'}, inplace=True)
    hv_tb_swe_001_001_m.rename(columns={'seghr': 'Riksbank forecast hours gap sa'}, inplace=True)
    hv_tb_swe_001_001_m.rename(columns={'segur': 'Riksbank forecast unemployment rate sa'}, inplace=True)
    hv_tb_swe_001_001_m.rename(columns={'serpc': 'Riksbank forecast policy rate quarterly average'}, inplace=True)
    # annual
    #rename
    hv_tb_swe_001_001_m.rename(columns={"segap": "Riksbank forecast gdo gap sa"}, inplace=True)
    hv_tb_swe_001_001_m.rename(columns={"seghr": "Riksbank forecast hours gap sa"}, inplace=True)
    hv_tb_swe_001_001_m.rename(columns={"segur": "Riksbank forecast unemployment rate sa"}, inplace=True)
    hv_tb_swe_001_001_m.rename(columns={"serpc": "Riksbank forecast policy rate quarterly average"}, inplace=True)
    #Rannval
    hv_tb_swe_001_001_m.rename(columns={"serpr": "Riksbank forecast policy rate annual average"}, inplace=True)
    hv_tb_swe_001_001_m.rename(columns={"sergy": "Riksbank forecast 10y rate annual average"}, inplace=True)
    hv_tb_swe_001_001_m.rename(columns={"sekix": "Riksbank forecast kix exchange rate average"}, inplace=True)
    hv_tb_swe_001_001_m.rename(columns={"segni": "Riksbank forecast general govt net lending average"}, inplace=True)
    time.sleep(1)
    df1= hv_tb_swe_001_001_m.copy()
    g1=df1.copy()
    list_c=g1.columns.tolist()
    title_r=str(list_c[0])
    y_label="Growth"
    x_label=title_r
    fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
    g1.plot(kind='line', ax=ax, y=list_c[0], color="darkred", linewidth=11, linestyle='-',
                                                   marker="o", markersize=s2)
    #g1.plot(kind='line', ax=ax, y=list_c[1], color="darkgreen", linewidth=11, linestyle='-',marker="P", markersize=s2)
    #g1.plot(kind='line', ax=ax, y=list_c[2], color="darkblue", linewidth=11, linestyle='-',marker="o", markersize=s2)
    for x,y in zip(g1.index,g1[list_c[0]]):
        label=f"{x.date()}\n{y:.2f}"
        label=f'(label)%: \n [{y}]'
        plt.annotate(label,  # this is the text
        (x,y),  # these are the coordinates to position the label
        textcoords="offset points",  # how to position the text
        xytext=(0,15),  # distance from text to points (x,y)
        size=5,
        ha="center",
        rotation=0,
        weight='bold'
        )
    #plt.axhline(8, color="black", lw=1, linestyle="dashed", alpha=0.75)
    plt.style.use('default')
    plt.ylabel(str(y_label), size=parameter3)
    plt.xlabel(str(x_label), size=parameter3)
    plt.tick_params(labelsize=7)
    plt.title(str(title_r), size=parameter5)
    plt.grid(axis='both', alpha=.3)
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    x_position = 0.5  # Adjust this value
    y_position = 8.5  # Adjust this value to place the text inside the plot
    plt.text(0.05, 0.5, 
             "[Sweden]",
             fontsize=12, transform=plt.gca().transAxes,
             bbox=dict(facecolor="white",
                       alpha=0.5))  # Adding the text box
    
    plt.text(0.5, 8.5, '',  fontsize=40,
             color='gray',
             alpha=0.5,
             ha='center',
             va='center',
             rotation=30,
             transform=plt.gca().transAxes)
    plt.savefig(str("hv_tb_swe_001_002_m_g_0" + str(ai) + ".png"), bbox_inches='tight')
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    # dei gi
    # dei df1
    del list_c
    del fig
    del ax
    del ax2

# %% [markdown]
# ### 001_ sweden riksbnak forecast  <a id="title_page"></a

# %%
import matplotlib.pyplot as plt
from PIL import Image

country_database = "NORDIC"
horizon_00=120
print("monthly")
no_m_tickers1 = ['sepcc', 'sepfc', 'sepxc',]
hv_tb_swe_001_001_m = Haver.data(no_m_tickers1, "NORDIC", dates=True)
print(hv_tb_swe_001_001_m)
print("qyarterly")
no_m_tickers2 = ["seggi", "segap", "segur", "serpc",]
hv_tb_swe_001_002_m = Haver.data(no_m_tickers2, "NORDIC", dates=True)
print(hv_tb_swe_001_002_m)
print("annual")
no_m_tickers3 = ["seghr", "serpr", "sergy", "sekix", "segnl"]
hv_tb_swe_001_003_m = Haver.data(no_m_tickers3, "NORDIC", dates=True)
print(hv_tb_swe_001_003_m)
hv_tb_swe_001_001_m = pd.concat([hv_tb_swe_001_001_m, hv_tb_swe_001_002_m], axis=1, join="outer")
hv_tb_swe_001_001_m = pd.concat([hv_tb_swe_001_001_m, hv_tb_swe_001_003_m], axis=1, join="outer")
# hv_tb_swe_001_001_m = hv_tb_swe_001_001_m.fillna(method="bfill")
# no_m_tickers = no_m_tickers1 + no_m_tickers2
hv_tb_swe_001_001_m.rename(columns={"sepcc": "Riksbank forecast cpi yy nsa monthly"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"sepfc": "Riksbank forecast cpif yy nsa monthly"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"sepxc": "Riksbank forecast cpif xe yy nsa monthly"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"seggi": "Riksbank forecast gdp sa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"segap": "Riksbank forecast gdp gap sa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"segur": "Riksbank forecast unemployment rate sa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"serpc": "Riksbank forecast policy rate quarterly average"}, inplace=True)
# annual
hv_tb_swe_001_001_m.rename(columns={"seghr": "Riksbank forecast hours gap sa annual"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"serpr": "Riksbank forecast policy rate annual average"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"sergy": "Riksbank forecast 10y rate annual average"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"sekix": "Riksbank forecast kix exchange rate average"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"segnl": "Riksbank forecast general govt net lending average"}, inplace=True)


hv_tb_swe_001_001_m = hv_tb_swe_001_001_m.tail(60)
hv_tb_swe_001_001_m.index = hv_tb_swe_001_001_m.index.date

print(hv_tb_swe_001_001_m.shape[1])

# hv_tb_swe_001_001_m.to_clipboard()
list_c=["Riksbank forecast cpi yy nsa monthly","Riksbank forecast cpif yy nsa monthly",
        "Riksbank forecast cpif xe yy nsa monthly","Riksbank forecast gdp sa",
        "Riksbank forecast gdp gap sa","Riksbank forecast unemployment rate sa",
        "Riksbank forecast policy rate quarterly average",
        "Riksbank forecast policy rate annual average",
        "Riksbank forecast 10y rate annual average",
        "Riksbank forecast kix exchange rate average",
        "Riksbank forecast general govt net lending average",
        "Riksbank forecast hours gap sa annual",]

#print(hv_tb_swe_001_001_m.columns.tolist())
hv_tb_swe_001_001_m=hv_tb_swe_001_001_m[list_c]
hv_tb_swe_001_001_m_c=hv_tb_swe_001_001_m.copy()
#hv_tb_swe_001_001_m_c=hv_tb_swe_001_001_m_c.tail(120)
#h#v_tb_swe_001_001_m=hv_tb_swe_001_001_m.tail(60)
#"['Financial: International International eop nsa',
#Financial: Nok improte weighted index avg',
#Cycle: Norway Consumer Confidence next year Quarterly SA']

n_time=45
#size figure
#wide
size1=30
#height
size2=12
##heatmaps inside
font_size_h=12
number_vbs=12
#x size Label axis
x_sizel=17
#axis 2 Label
x2_sizel=x_sizel-5
xlabel_size=20
### axes-1 lael sie dates
axes_1label=12
title_s=32

df1=hv_tb_swe_001_001_m.copy()
#df1=df1.toil(n_time)
df1=df1.transpose()
df1.index.names = ['Variable']

num_rows = df1.shape[0]
for x in range(num_rows):
    locals()[str(str("data_r")+str(x))] = pd.DataFrame([df1.iloc[x]])
    #print("end Loop")

for x in range(num_rows):
    locals() [str(str("vmin_")+str(x))] = hv_tb_swe_001_001_m.iloc[:,x].min()
    locals() [str(str("vmax_")+str(x))] = hv_tb_swe_001_001_m.iloc[:,x].max()
    #print("end Loop")

print(vmin_0)
print(vmax_0)
#data = np.random.random((10,12))
#df=pd.DataFrame(data)
red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue=sns.color_palette("coolwarm")
reversed_red_to_blue=list(reversed(reversed_red_to_blue))
print(vmin_0)
print(vmax_0)
#data = np.random.random((10,12))
#df = pd.DataFrame(data)
red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")
reversed_red_to_blue = list(reversed(reversed_red_to_blue))
#sns.color_palette("coolwarm", as_cmap=True)
fig, axes = plt.subplots(number_vbs, 1,
                         figsize=(size1, size2),
                         sharex=True,)
sns.heatmap(data_r0, cmap=red_to_blue, annot=True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": 'Red to blue'})
sns.heatmap(data_r1, cmap=red_to_blue, annot=True, ax=axes[1], cbar=False, vmin=vmin_1, vmax=vmax_1, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": 'Red to blue'})
sns.heatmap(data_r2, cmap=red_to_blue, annot=True, ax=axes[2], cbar=False, vmin=vmin_2, vmax=vmax_2, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": 'Red to blue'})
sns.heatmap(data_r3, cmap=red_to_blue, annot=True, ax=axes[3], cbar=False, vmin=vmin_3, vmax=vmax_3, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": 'Red to blue'})
sns.heatmap(data_r4, cmap=red_to_blue, annot=True, ax=axes[4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": 'Red to blue'})
sns.heatmap(data_r5, cmap=red_to_blue, annot=True, ax=axes[5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": 'Red to blue'})
sns.heatmap(data_r6, cmap=red_to_blue, annot=True, ax=axes[6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": 'Red to blue'})
sns.heatmap(data_r7, cmap=red_to_blue, annot=True, ax=axes[7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": 'Red to blue'})
sns.heatmap(data_r8, cmap=red_to_blue, annot=True, ax=axes[8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": 'Red to blue'})
sns.heatmap(data_r9, cmap=red_to_blue, annot=True, ax=axes[9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": 'Red to blue'})
sns.heatmap(data_r10, cmap=red_to_blue, annot=True, ax=axes[10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": 'Red to blue'})
sns.heatmap(data_r11, cmap=red_to_blue, annot=True, ax=axes[11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g',
            annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": 'Red to blue'})

n=0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_sizel, rotation=0)
    locals()[str(str("axes_t")+str(n))]= ax.twinx()
    locals()[str(str("axes_t")+str(n))].set_yticklabels(ax.get_yticklabels(), fontsize=x2_sizel, rotation=0, va="center")
    #ax.set_xticklabels(ax.get_xticklabels(), rotation=-90)
    n=(n+1)
axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=15, size=0)
#axes[-1].set_xticklabels(axis="x", which="both", length=0, labelrotation=45)
#.set_xticks([])
fig.suptitle("SWEDEN Riksbank forecast Dashboard ", fontsize=title_s)
plt.figtext(0.5,0.01, "SWEDEN Riksbank forecast Dashboard", fontsize=title_s, ha="center")
plt.subplots_adjust(hspace=-.1)
plt.tight_layout(rect=[0,0.03,1,0.97])
plt.savefig('sweden_forecast_heatmap_001.png', bbox_inches="tight", dpi=300)
plt.show()
plt.close()

# %% [markdown]
# ### 001_ sweden riksbnak forecast  <a id="title_page"></a

# %%
import seaborn as sns
import plotly.graph_objects as go

list_c = ["Riksbank forecast cpi yy nsa monthly",
          "Riksbank forecast cpif yy nsa monthly",
          "Riksbank forecast cpif xe yy nsa monthly",
          "Riksbank forecast unemployment rate sa",
          "Riksbank forecast policy rate quarterly average"]

hv_tb_swe_001_001_m_c.rename(columns={"Riksbank forecast cpi yy nsa monthly": "cpi yy nsa"}, inplace=True)
hv_tb_swe_001_001_m_c.rename(columns={"Riksbank forecast cpif yy nsa monthly": "cpif yy nsa"}, inplace=True)
hv_tb_swe_001_001_m_c.rename(columns={"Riksbank forecast cpif xe yy nsa monthly": "cpif xe yy"}, inplace=True)
hv_tb_swe_001_001_m_c.rename(columns={"Riksbank forecast unemployment rate sa": "unemployment"}, inplace=True)
hv_tb_swe_001_001_m_c.rename(columns={"Riksbank forecast policy rate quarterly average": "policy rate q"}, inplace=True)
#hv_tb_swe_001_001_m_c["Riksbank forecast cpi yy nsa monthly"]= hv_tb_swe_001_001_m_c["Riksbank forecast cpi yy nsa monthly"].round(1)
#hv_tb_swe_001_001_m_c["Riksbank forecast cpif yy nsa monthly"]= hv_tb_swe_001_001_m_c["Riksbank forecast cpif yy nsa monthly"].round(1)
#hv_tb_swe_001_001_m_c["Riksbank forecast cpif xe yy nsa monthly"]= hv_tb_swe_001_001_m_c["Riksbank forecast cpif xe yy nsa monthly"].round(1)
#hv_tb_swe_001_001_m_c.index = hv_tb_swe_001_001_m_c.index.date
print(hv_tb_swe_001_001_m_c.shape[1])
print(hv_tb_swe_001_001_m_c.shape[0])
df = hv_tb_swe_001_001_m_c.copy()
df.index =pd.to_datetime(df.index)
df.index = df.index.strftime('%Y-%m')
df["Index"] = df.index
df["Index_"] = df.index
column_to_move = "Index"
#Reorder columns
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
#df = df.transpose()
#df.reset_index(inplace=True)
df.fillna('', inplace=True)
modified_column_names = [f'{col}<br>' for col in df.columns]
fig=go.Figure(data=[go.Table(
    header=dict(
        values=modified_column_names,
        font=dict(size=9), # Increase header font size here
        fill_color='paleturquoise',
        align='center',
        height=40),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=12),
        align='center' # Increase cell font size here
                         ),# Specify column widths here, adjust values as needed
)])               
fig.update_layout(autosize=False, 
                  width=800, height=1200, 
                  title="Sweden Riksbank Inflation Forecast") # Add title here)
fig.write_image('hv_tb_sweden_forecast_cpi.png')

# %%
# ['nordic:senrmle', 'nordic:senrmse'

# %% [markdown]
# ### 001_ sweden heatmpa table  <a id="title_page"></a

# %%
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt
from PIL import Image
country_database="NORDIC"
horizon_00=120
print("monthly")
no_m_tickers1 = ['setib', 'sesgvi', 'sesdb', 'sesdc', 'sesdd', 'sesdq', 'sestc47', 
                 'sessxgjc', 'seschmc', 'senespvt', 'senewpvt', 'seneksb', 'senun', 
                 'seselur', 'seneey', 'seneezy', 'seneeyd', 'seneeyc', 'sesem', 'senelep', 
                 'senele', 'senph', 'senphct', 'senpc', 'senpcsh', 'senpcctx', 'senpcif', 
                 'senpcxf', 'senpcct', 'senpcfct', 'senpcxi', 'senpchim', 'senpck', 
                 'senpcx4', 'senmifxr', 'senmi85r', 'senmi1r', 'senmi24r', 'senmipvr',
                 'senmipcr', 'senpp', 'senj1ia', 'senj2ia', 'senj5ia', 'senj1fa', 'senj2fa',
                 'senj5fa', 'sesvx', 'sesvbodm', 'senpcx4', 'senpp', 'senvhpe', 'senrrep', 
                 'senrgb2e', 'senrgb5e', 'senrgb7e', 'senrgb1e', 'senrm2e', 'senrm5e',
                 'senxeue', 'senxuse', 'senxkixv', 'senfm3y']
hv_tb_swe_001_001_m = Haver.data(no_m_tickers1, "NORDIC", dates=True)
print(hv_tb_swe_001_001_m)
print("qyarterly")
no_m_tickers2 = ["senhc", "senhs", "sesngcp", "sewngcy", "senngcy", "sesncpc", 
                 "sesncvc", "sesnic", "sesnxc", "sesnmc","seszlhdi", "seszdhp",
                 "sennypc"]
#                   ]"senпурс", 
hv_tb_swe_001_002_m = Haver.data(no_m_tickers2, "NORDIC", dates=True)
print(hv_tb_swe_001_002_m)
hv_tb_swe_001_001_m = pd.concat([hv_tb_swe_001_001_m, hv_tb_swe_001_002_m], axis=1, join="outer")
hv_tb_swe_001_001_m = hv_tb_swe_001_001_m.fillna(method="bfill")
no_m_tickers = no_m_tickers1 + no_m_tickers2
yy_m_tickers = ['senpp', 'senph', 'senphct', 'senpc', 'senpcsh', 'senpcctx',
                'senpcif', 'senpcxf', 'senpcct', 'senpcfct', 'senpcxi',
                'senpchim', 'senpck', 'senpcx4',
                'senmifxr', 'senmi85r', 'senmi1r', 'senmi24r', 'senmipvr', 'senmipcr',
                'sesncpc', 'sesncvc', 'sesnic', 'sesnxc', 'sesnmc', 'sennypc', 'senhc', 'senhs']

for x in range(len(yy_m_tickers)):
    # print(x)
    variable = str(yy_m_tickers[x])
    # print(variable)
    hv_tb_swe_001_001_m[variable] = hv_tb_swe_001_001_m[variable].pct_change(12).multiply(100).round(1)
    # print(chf_m_tickers[variable])
# divided

d_m_tickers = ["setib", "senun"]
for x in range(len(d_m_tickers)):
    # print(x)
    variable = str(d_m_tickers[x])
    # print(variable)
    hv_tb_swe_001_001_m[variable] = hv_tb_swe_001_001_m[variable].multiply(0.001)
    # print(chf__tickers[variable])

df_m_tickers = ["sesem", "senelep", "senele"]
for x in range(len(df_m_tickers)):
    variable = str(df_m_tickers[x])
    hv_tb_swe_001_001_m[variable] = hv_tb_swe_001_001_m[variable].diff()

r_m_tickers = ["senxkixv", "sesvx"]
for x in range(len(df_m_tickers)):
    variable = str(df_m_tickers[x])
    hv_tb_swe_001_001_m[variable] = hv_tb_swe_001_001_m[variable].round(0)

r_m_tickers = ["sesvx", "senj1ia", "senj2ia", "senj5ia", "senj1fa", "senj2fa", "senj5fa"]
for x in range(len(r_m_tickers)):
    variable = str(r_m_tickers[x])
    hv_tb_swe_001_001_m[variable] = hv_tb_swe_001_001_m[variable].round(0)


#sesngcp, sewngcy, senngcy,
#Q
hv_tb_swe_001_001_m.rename(columns={"sesngcp": "Real: Sweden Flash GDP QQ SA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"sewngcy": "Real: Sweden Flash GDP YY WDA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senngcy": "Real: Sweden Flash GDP YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"seszlhdi": "Real: Domestic economy outstanding debt sa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"seszdhp": "Real: household outstanding debt sa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"seszlhdi": "Real: hh deot to disposable income sa"}, inplace=True)
#Pyy//
hv_tb_swe_001_001_m.rename(columns={"sesncpc": "Real: GDP general goverment YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"sesncvc": "Real: GDP households YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"sesnic": "Real: GDP gross fixed investment YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"sesnxc": "Real: GDP exports YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"sesnmc": "Real: GDP imports YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"sennypc": "Real: HH Disposable Income YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senhc": "Real: Housing completions YY"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senhs": "Real: Housing starts YY"}, inplace= True)
#myy**
hv_tb_swe_001_001_m.rename(columns={"sesgvi": "Real: Economic Activity index YY SA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"sesdb": "Real: IP mining quarrying YY swda"}, inplace= True)
hv_tb_swe_001_001_m.rename(columns={"sesdc": "Real: IP manufacturing YY swda"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"sesdd": "Real: IP energy YY swda"}, inplace =True)

hv_tb_swe_001_001_m.rename(columns={"sesdq": "Real: PVI production value inde yy swda"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"sestc47": "Real: retail sales yy sa"}, inplace= True)
hv_tb_swe_001_001_m.rename(columns={"sessxgjc": "Real: Services index yy swda"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"seschmc":"Real: household consumption indicator yy swda"}, inplace=True)

hv_tb_swe_001_001_m.rename(columns={"senespvt":"Employment: LCI salaried private sector yy nsa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senewpvt":"Employment: LCI wage earners private sector yy nsa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"seneksb": "Employment: average hours worked per week yy nsa"}, inplace=True)

#                        Level /1000
hv_tb_swe_001_001_m.rename(columns={"setib": "Real: trade balance next exports"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senun": "Employment: layoffs"}, inplace=True)

#Level
hv_tb_swe_001_001_m.rename(columns={"seselur": "Employment: eu harm unemployment rate"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"seneey": "Employment: wage growth total yy nsa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senee2y": "Employment: wage growth private yy nsa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"seneeyd": "Employment: definitive wage growth yy nsa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"seneeyc": "Employment: agreement wage growth yy nsa"}, inplace=True)

#diff
hv_tb_swe_001_001_m.rename(columns={"sesem": "Employment: eu harm change employment"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senelep": "Employment: private sector change employment nsa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senele": "Employment: domestic employment nsa"}, inplace=True)

hv_tb_swe_001_001_m.rename(columns={"senvhpe": "Real: seb housing price indicator"}, inplace=True)

# inflation expectation
hv_tb_swe_001_001_m.rename(columns={"senj1ia": "Prices: tns expected inflation 1y mean nsa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senj2ia": "Prices: tns expected inflation 2y mean nsa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senj5ia": "Prices: tns expected inflation 5y mean nsa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senj1fa": "Prices: tns expected cpif 1y mean nsa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senj2fa": "Prices: tns expected cpif 2y mean nsa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senj5fa": "Prices: tns expected cpif 5y mean nsa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"sesvx": "Cycle: confidence indicator total industry"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"sesvbodm": "Cycle: confidence indicator demand"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senph":"Prices: Harmonized CPI YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senphct":"Prices: HICP at constant tax YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senpc":"Prices: CPI Headline YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senpcsh":"Prices: CPI Headline Shadow revised YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senpcctx":"CPI-CT Headline at constant tax YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senpcif": "Prices: CPI fixed interest rate YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senpcxf": "Prices: CPI fixed interest rate ex energy YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senpcct": "Prices: CPI-CT constant tax YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senpcfct": "Prices: CPIF fixed rate constant taxes YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senpcxi": "Prices: CPI ex interest rate capital stock YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senpchim": "Prices: Mortgage Interest YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senpck": "Prices: Capital Stock YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senpcx4": "Prices: CPI ex package holidays YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senmifxr": "Prices: CPIF ex energy food YY NSA"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senmi85r": "Prices: Riksbank underlying inflation trim 85 yy nsa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senmi1r": "Prices: Riksbank underlying inflation trim 1 yy nsa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senmi24r": "Prices: Riksbank underlying inflation und 24 yy nsa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senmipvr": "Prices: Riksbank underlying inflation kpifpv yy nsa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senmipcr": "Prices: Riksbank underlying inflation kpifpc yy nsa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senpp": "Prices: ppi producer price index yy nsa"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senrrep": "Financial: Sweden Policy Rate eop"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senrgb2e": "Financial: Swedish govt bond 2y eop"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senrgb5e": "Financial: Swedish govt bond 5y eop"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senrgb7e": "Financial: Swedish govt bond 7y eop"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senrgb1e": "Financial: Swedish govt bond 10y eop"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senrm2e": "Financial: mortgage bond 2y eop"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senrm5e": "Financial: mortgage bond 5y eop"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senxeue": "Financial: SEK/EUR eop"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senxuse": "Financial: SEK/USD eop"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senxkixv": "Financial: KIX effective exchange rate eop"}, inplace=True)
hv_tb_swe_001_001_m.rename(columns={"senfm3y": "Financial: money supply m3 yy nsa"}, inplace=True)

hv_tb_swe_001_001_m=hv_tb_swe_001_001_m.tail(60) 
hv_tb_swe_001_001_m.index=hv_tb_swe_001_001_m.index.date



list_c=[
    "Real: Sweden Flash GDP QQ SA",
    "Real: Sweden Flash GDP YY WDA",
    "Real: Sweden Flash GDP YY NSA",
    "Real: seb housing price indicator",
    "Real: GDP general goverment YY NSA",
    "Real: GDP households YY NSA",
    "Real: GDP gross fixed investment YY NSA",
    "Real: GDP exports YY NSA",
    "Real: GDP imports YY NSA",
    "Real: HH Disposable Income YY NSA",
    "Employment: layoffs",
    "Employment: domestic employment nsa",
    "Employment: private sector change employment nsa",
    "Employment: eu harm change employment",
    "Employment: agreement wage growth yy nsa",
    "Employment: wage growth total yy nsa",
    "Employment: eu harm unemployment rate",
    "Prices: Harmonized CPI YY NSA",
    "Prices: HICP at constant tax YY NSA",
    "Prices: CPI Headline YY NSA",
    "Prices: CPI Headline Shadow revised YY NSA",
    "CPI-CT Headline at constant tax YY NSA",
    "Prices: CPI fixed interest rate YY NSA",
    "Prices: CPI fixed interest rate ex energy YY NSA",
    "Prices: CPI-CT constant tax YY NSA",
    "Prices: CPIF fixed rate constant taxes YY NSA",
    "Prices: CPI ex interest rate capital stock YY NSA",
    "Prices: Mortgage Interest YY NSA",
    "Prices: Capital Stock YY NSA",
    "Prices: CPI ex package holidays YY NSA",
    "Prices: CPIF ex energy food YY NSA",
    "Prices: Riksbank underlying inflation trim 85 yy nsa",
    "Prices: Riksbank underlying inflation trim 1 yy nsa",
    "Prices: Riksbank underlying inflation und 24 yy nsa",
    "Prices: Riksbank underlying inflation kpifpv yy nsa",
    "Prices: Riksbank underlying inflation kpifpc yy nsa",
    "Prices: ppi producer price index yy nsa",
    "Prices: tns expected inflation 2y mean nsa",
    "Prices: tns expected inflation 1y mean nsa",
    "Prices: tns expected inflation 5y mean nsa",
    "Prices: tns expected cpif 1y mean nsa",
    "Prices: tns expected cpif 2y mean nsa",
    "Prices: tns expected cpif 5y mean nsa",
    "Financial: Sweden Policy Rate eop",
    "Financial: Swedish govt bond 2y eop",
    "Financial: Swedish govt bond 5y eop",
    "Financial: Swedish govt bond 7y eop",
    "Financial: Swedish govt bond 10y eop",
    "Financial: mortgage bond 2y eop",
    "Financial: mortgage bond 5y eop",
    "Financial: SEK/EUR eop",
    "Financial: SEK/USD eop",
    "Financial: KIX effective exchange rate eop",
    "Cycle: confidence indicator demand",
    "Cycle: confidence indicator total industry",]


print(hv_tb_swe_001_001_m.columns.tolist())
hv_tb_swe_001_001_m=hv_tb_swe_001_001_m[list_c]

hv_tb_swe_001_001_m_c=hv_tb_swe_001_001_m.copy()
hv_tb_swe_001_001_m_c=hv_tb_swe_001_001_m_c.tail(120)

hv_tb_swe_001_001_m=hv_tb_swe_001_001_m.tail(60)

#['Financial: International International eop nsa',
#Financial: Nok improte weighted index avg',

#Cycle: Norway Consumer Confidence next year Quarterly SA']

# %%
n_time=45
#size figure
#wide
size1=32
#height
size2-size1/1.1
##heatmaps inside
font_size_h=10
number_vbs=54
#x size Label axis
x_size1=17
#axis 2 Label
x2_sizel=x_sizel-5
xlabel_size=20
### axes-1 Lael sie dates
axes_1label=12
title_s=32
df1=hv_tb_swe_001_001_m.copy()
df1=df1.tail(n_time)
df1 = df1.transpose()
df1.index.names= ['Variable']
num_rows = df1.shape[0]
for x in range(num_rows):
    locals()[str(str("data_r")+str(x))] = pd. DataFrame([df1.iloc[x]])

for x in range(num_rows):
    locals() [str(str("vmin_")+str(x))] = hv_tb_swe_001_001_m.iloc[:,x].min()
    locals() [str(str("vmax_")+str(x))] = hv_tb_swe_001_001_m.iloc[:,x].max()

print(vmin_0)
print(vmax_0)


#data = np.random.random((10,12))
#df=pd.DataFrame(data)
red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")
reversed_red_to_blue = list(reversed(reversed_red_to_blue))

#sns.color_palette("coolwarm", as_cmap=True)

fig, axes = plt.subplots(number_vbs, 1,
                         figsize=(size1,
                                  size2),
                         sharex=True,)
sns.heatmap(data_r0, cmap=red_to_blue, annot=True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r1, cmap=red_to_blue, annot=True, ax=axes[1], cbar=False, vmin=vmin_1, vmax=vmax_1, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r2, cmap=red_to_blue, annot=True, ax=axes[2], cbar=False, vmin=vmin_2, vmax=vmax_2, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r3, cmap=red_to_blue, annot=True, ax=axes[3], cbar=False, vmin=vmin_3, vmax=vmax_3, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r4, cmap=red_to_blue, annot=True, ax=axes[4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r5, cmap=red_to_blue, annot=True, ax=axes[5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r6, cmap=red_to_blue, annot=True, ax=axes[6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r7, cmap=red_to_blue, annot=True, ax=axes[7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r8, cmap=red_to_blue, annot=True, ax=axes[8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r9, cmap=red_to_blue, annot=True, ax=axes[9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r10, cmap=red_to_blue, annot=True, ax=axes[10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r11, cmap=red_to_blue, annot=True, ax=axes[11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r12, cmap=red_to_blue, annot=True, ax=axes[12], cbar=False, vmin=vmin_12, vmax=vmax_12, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r13, cmap=red_to_blue, annot=True, ax=axes[13], cbar=False, vmin=vmin_13, vmax=vmax_13, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r14, cmap=red_to_blue, annot=True, ax=axes[14], cbar=False, vmin=vmin_14, vmax=vmax_14, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r15, cmap=red_to_blue, annot=True, ax=axes[15], cbar=False, vmin=vmin_15, vmax=vmax_15, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r16, cmap=red_to_blue, annot=True, ax=axes[16], cbar=False, vmin=vmin_16, vmax=vmax_16, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r17, cmap=red_to_blue, annot=True, ax=axes[17], cbar=False, vmin=vmin_17, vmax=vmax_17, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r18, cmap=red_to_blue, annot=True, ax=axes[18], cbar=False, vmin=vmin_18, vmax=vmax_18, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r19, cmap=red_to_blue, annot=True, ax=axes[19], cbar=False, vmin=vmin_19, vmax=vmax_19, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r20, cmap=red_to_blue, annot=True, ax=axes[20], cbar=False, vmin=vmin_20, vmax=vmax_20, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r21, cmap=red_to_blue, annot=True, ax=axes[21], cbar=False, vmin=vmin_21, vmax=vmax_21, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r22, cmap=red_to_blue, annot=True, ax=axes[22], cbar=False, vmin=vmin_22, vmax=vmax_22, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r23, cmap=red_to_blue, annot=True, ax=axes[23], cbar=False, vmin=vmin_23, vmax=vmax_23, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r24, cmap=red_to_blue, annot=True, ax=axes[24], cbar=False, vmin=vmin_24, vmax=vmax_24, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r25, cmap=red_to_blue, annot=True, ax=axes[25], cbar=False, vmin=vmin_25, vmax=vmax_25, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r26, cmap=red_to_blue, annot=True, ax=axes[26], cbar=False, vmin=vmin_26, vmax=vmax_26, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r27, cmap=red_to_blue, annot=True, ax=axes[27], cbar=False, vmin=vmin_27, vmax=vmax_27, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r28, cmap=red_to_blue, annot=True, ax=axes[28], cbar=False, vmin=vmin_28, vmax=vmax_28, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r29, cmap=red_to_blue, annot=True, ax=axes[29], cbar=False, vmin=vmin_29, vmax=vmax_29, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r30, cmap=red_to_blue, annot=True, ax=axes[30], cbar=False, vmin=vmin_30, vmax=vmax_30, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r31, cmap=red_to_blue, annot=True, ax=axes[31], cbar=False, vmin=vmin_31, vmax=vmax_31, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r32, cmap=red_to_blue, annot=True, ax=axes[32], cbar=False, vmin=vmin_32, vmax=vmax_32, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r33, cmap=red_to_blue, annot=True, ax=axes[33], cbar=False, vmin=vmin_33, vmax=vmax_33, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r34, cmap=red_to_blue, annot=True, ax=axes[34], cbar=False, vmin=vmin_34, vmax=vmax_34, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r35, cmap=red_to_blue, annot=True, ax=axes[35], cbar=False, vmin=vmin_35, vmax=vmax_35, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r36, cmap=red_to_blue, annot=True, ax=axes[36], cbar=False, vmin=vmin_36, vmax=vmax_36, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r37, cmap=red_to_blue, annot=True, ax=axes[37], cbar=False, vmin=vmin_37, vmax=vmax_37, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r38, cmap=red_to_blue, annot=True, ax=axes[38], cbar=False, vmin=vmin_38, vmax=vmax_38, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r39, cmap=red_to_blue, annot=True, ax=axes[39], cbar=False, vmin=vmin_39, vmax=vmax_39, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r40, cmap=red_to_blue, annot=True, ax=axes[40], cbar=False, vmin=vmin_40, vmax=vmax_40, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r41, cmap=red_to_blue, annot=True, ax=axes[41], cbar=False, vmin=vmin_41, vmax=vmax_41, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r42, cmap=red_to_blue, annot=True, ax=axes[42], cbar=False, vmin=vmin_42, vmax=vmax_42, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r43, cmap=red_to_blue, annot=True, ax=axes[43], cbar=False, vmin=vmin_43, vmax=vmax_43, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r44, cmap=red_to_blue, annot=True, ax=axes[44], cbar=False, vmin=vmin_44, vmax=vmax_44, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r45, cmap=red_to_blue, annot=True, ax=axes[45], cbar=False, vmin=vmin_45, vmax=vmax_45, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r46, cmap=red_to_blue, annot=True, ax=axes[46], cbar=False, vmin=vmin_46, vmax=vmax_46, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r47, cmap=red_to_blue, annot=True, ax=axes[47], cbar=False, vmin=vmin_47, vmax=vmax_47, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r48, cmap=red_to_blue, annot=True, ax=axes[48], cbar=False, vmin=vmin_48, vmax=vmax_48, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r49, cmap=red_to_blue, annot=True, ax=axes[49], cbar=False, vmin=vmin_49, vmax=vmax_49, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r50, cmap=red_to_blue, annot=True, ax=axes[50], cbar=False, vmin=vmin_50, vmax=vmax_50, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r51, cmap=red_to_blue, annot=True, ax=axes[51], cbar=False, vmin=vmin_51, vmax=vmax_51, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r52, cmap=red_to_blue, annot=True, ax=axes[52], cbar=False, vmin=vmin_52, vmax=vmax_52, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r53, cmap=red_to_blue, annot=True, ax=axes[53], cbar=False, vmin=vmin_53, vmax=vmax_53, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
#sns.heatmap(data_r54, cmap=red_to_blue, annot=True, ax=axes[54], cbar=False, vmin=vmin_54, vmax=vmax_54, fmt='g',
#            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})

n=0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_sizel, rotation=0)
    locals()[str(str("axes_t")+str(n))]= ax.twinx()
    locals()[str(str("axes_t")+str(n))].set_yticklabels(ax.get_yticklabels(), fontsize=x2_sizel, rotation=0, va="center")
    #ax.set_xticklabels (ax.get_xticklabels(), rotation=90)
    n=(n+1)

#axes[0].set_xticks([])
#axes[1].set_xticks([])
#xes[1].set_xticks([])
axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=15, size=0)
#axes[-1].set_xticklabels(axis="x", which="both", Length=0, labelrotation=45)
#.set_xticks([])
fig.suptitle("SWEDEN Economic Dashboard ", fontsize=title_s)
plt.figtext(0.5,0.01, "SWEDEN Economic Dashboard ", fontsize=title_s, ha="center")
plt.subplots_adjust(hspace=-.1)
plt.tight_layout (rect=[0,0.03,1,0.97])
plt.savefig('sweden_heatmap_001.png', bbox_inches='tight',dpi=300)
plt.show()
plt.close()

# %% [markdown]
# ### 001_ sweden riksbnak heatmap birdeye t  <a id="title_page"></a

# %%
hv_tb_swe_001_001_m_g=hv_tb_swe_001_001_m.copy()
print("start right here")
parameter1_0=6
parameter2_0=4
tail_n=102
tail_n2=48
linew=2
mks=0.5

list_c=["Real: Sweden Flash GDP QQ SA",
        "Real: Sweden Flash GDP YY WDA",
        "Real: Sweden Flash GDP YY NSA",
        "Real: seb housing price indicator",
        "Real: GDP general goverment YY NSA",
        "Real: GDP households YY NSA",
        "Real: GDP gross fixed investment YY NSA",
        "Real: GDP exports YY NSA",
        "Real: GDP imports YY NSA",
        "Real: HH Disposable Income YY NSA",
        "Employment: layoffs",
        "Employment: domestic employment nsa",
        "Employment: private sector change employment nsa",
        "Employment: eu harm change employment",
        "Employment: agreement wage growth yy nsa",
        "Employment: wage growth total yy nsa",
        "Employment: eu harm unemployment rate",
        "Prices: Harmonized CPI YY NSA",
        "Prices: HICP at constant tax YY NSA",
        "Prices: CPI Headline YY NSA",
        "Prices: CPI Headline Shadow revised YY NSA",
        "CPI-CT Headline at constant tax YY NSA",
        "Prices: CPI fixed interest rate YY NSA",
        "Prices: CPI fixed interest rate ex energy YY NSA",
        "Prices: CPI-CT constant tax YY NSA",
        "Prices: CPIF fixed rate constant taxes YY NSA",
        "Prices: CPI ex interest rate capital stock YY NSA",
        "Prices: Mortgage Interest YY NSA",
        "Prices: Capital Stock YY NSA",
        "Prices: CPI ex package holidays YY NSA",
        "Prices: CPIF ex energy food YY NSA",
        "Prices: Riksbank underlying inflation trim 85 yy nsa",
        "Prices: Riksbank underlying inflation trim 1 yy nsa",
        "Prices: Riksbank underlying inflation und 24 yy nsa",
        "Prices: Riksbank underlying inflation kpifpv yy nsa",
        "Prices: Riksbank underlying inflation kpifpc yy nsa",   
        "Prices: ppi producer price index yy nsa",
        "Prices: tns expected inflation 1y mean nsa",
        "Prices: tns expected inflation 2y mean nsa",
        "Prices: tns expected inflation 5y mean nsa",
        "Prices: tns expected cpif 1y mean nsa",
        "Prices: tns expected cpif 2y mean nsa",
        "Prices: tns expected cpif 5y mean nsa",
        "Financial: Sweden Policy Rate eop",
        "Financial: Swedish govt bond 2y eop",
#        "Financial: Swedish govt bond 5y eop",
        "Financial: Swedish govt bond 7y eop",
        "Financial: Swedish govt bond 10y eop",
        "Financial: mortgage bond 2y eop",
        "Financial: mortgage bond 5y eop",
        "Financial: SEK/EUR eop",
        "Financial: SEK/USD eop",
        "Financial: KIX effective exchange rate eop",
        "Cycle: confidence indicator demand",
        "Cycle: confidence indicator total industry"]

# %%
print("ojo ave, ojo ave,ojo ave, ojo ave, ojo aveojo ave, ojo ave,,ojo aveojo ave ")
n=1
for y in list_c:
    print(y)
    #print("filtering time horizon")
    df1=hv_tb_swe_001_001_m_g.copy()
    df1=pd.DataFrame(df1[str(y)])
    #List_c=df1.columns.tolist()
    df1=df1.tail(90)
    g1=df1.copy()
    fig,ax = plt.subplots(figsize=((parameter1_0-1), (parameter2_0)))
    g1.plot(kind='line', ax=ax,y=str(y),
            color="orange",
            linewidth= (linew+1),
            linestyle='-',
            marker="o",
            markersize=mks)
    x_last = g1.index[-1] # Assuming the DataFrame index is date or sequential
    y_last = g1[str(y)].iloc[-1]
    # Annotate the last value on the right of the plot line
    ax.annotate(f' (y_last:.2f)',
                xy=(x_last, y_last),
                xytext=(10, 0),
                textcoords="offset points",
                ha='left',
                va="center",
                color="orange",
                size=17,
                weight="bold")

    plt.style.use('default')
    plt.tick_params(labelsize=parameter4)
    plt.title(str(df1.columns.tolist()[0]), size=(parameter5-2))
    plt.grid(axis='both', alpha=.3)
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    plt.savefig(str("hv_tb_swe_ov"+str(n)+".png"), bbox_inches='tight')
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    

    del df1
    del fig
    del ax
    del ax2
    n=n+1

# %% [markdown]
# ###

# %% [markdown]
# ### cleanign

# %%
import gc
import sys

def cleanup_environment():
    # List all variables in the global scope
    globals_copy = globals().copy()
    
    # Delete DataFrames specifically (and optionally other variables)
    for var_name, var_value in globals_copy.items():
        if isinstance(var_value, pd.DataFrame):  # Checks if it's a DataFrame
            print(f"Deleting DataFrame: {var_name}")
            del globals()[var_name]
    
    # Trigger garbage collection
    gc.collect()
    print("Environment cleaned!")

# Call the cleanup function
cleanup_environment()

# %% [markdown]
# ### 001_ bottom  <a id="title_page"></a
