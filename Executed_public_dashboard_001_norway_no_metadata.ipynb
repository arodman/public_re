# %% [markdown]
# ### 000 TOP <a id="title_page"></a

# %% [markdown]
# ### 000 packages <a id="title_page"></a

# %%
owner=""
###econiomics DASHBOARD
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display, HTML
import Haver
Haver.path(Haver.direct(1))    
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import os
def clear():
    os.system('cls')
# then you can clear the window with:
from matplotlib.dates import date2num
import os
os.chdir('C:/database/dashboard')
#C:\database\dashboard
print(os.getcwd())

import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import matplotlib.ticker as plticker
import matplotlib.dates as mdates
from matplotlib.ticker import MultipleLocator
# Import warnings
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns

from matplotlib.colors import LinearSegmentedColormap

import matplotlib.pyplot as pit
from PIL import Image
import time
import seaborn as sns
import plotly.graph_objects as go
parameter1_s=9
parameter2_s=6
parameter3_s=11
parameter4_s=7
parameter5_s=20
parameter3=15
parameter4=15
parameter5=20
s0=1
s1=5
s2=6
s3=7
s4=12
s5=14
s6=15
l0=1.0
l1=1.0
l2=1.5
tail_y=12
tail_0=24
tail_1=60
tail_2=72
tail_4=36
parameter_size1=8
parameter_size2=6

million = 1000000
horizon_120 = 120
horizon_tb = 24
#DAA0236BLUECHIP

def zscore(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  o = arr.rolling(window = window).std()
  return (x-u)/o

def zscore_avg(arr, window):
  x = arr.rolling(window = 1).mean()
  u = arr.rolling(window = window).mean()
  return (x-u)
# Out:
# Haver path not set.
# C:\database\dashboard

# %% [markdown]
# ### 001 norway cpi <a id="title_page"></a

# %%
country_database="NORDIC"
chf_m_tickers = ['nonpcy', 'nonpcxe1', 'nonpcyte', 'nonpc20', 'nonpcmw']
hv_tb_no_001_001_m = Haver.data(chf_m_tickers, country_database, dates=True)
print(hv_tb_no_001_001_m)
#rint(chf_m_tickers.columns)
#for x in range(len(chf_m_tickers)):
#    print(x)
#    variable = str(chf_m_tickers[x])
#    print(variable)
#    # hv_tb_no_001_001_m[variable] = hu_tb_no_001_001_m[variable].pct_change(12).multiply(100).round(1)
#    # print(chf_m_tickers[variable])

hv_tb_no_001_001_m.rename(columns={'nonpcy': 'Norway CPI nsa YY'}, inplace=True)
hv_tb_no_001_001_m.rename(columns={'nonpcxel': 'Norway CPI ATE nsa YY'}, inplace=True)
hv_tb_no_001_001_m.rename(columns={'nonpcyte': 'Norway CPIXE nsa YY'}, inplace=True)
hv_tb_no_001_001_m.rename(columns={'nonpc20': 'Norway CPI-AT trimmed mean nsa YY'}, inplace=True)
hv_tb_no_001_001_m.rename(columns={'nonpcmw': 'Norway CPI-AT weighted mean nsa YY'}, inplace=True)

#hv_tb_no_001_001_m_g = hv_tb_no_001_001_m.copy()
#hv_tb_no_001_001_m = hv_tb_no_001_001_m.transpose()
#hv_tb_no_001_001_m.index.names = ['Variable']
# dashboard.to_clipboard()
#rint(hv_tb_no_001_001_m)
# dashboard.to_clipboard()


hv_tb_no_001_001_m_g = hv_tb_no_001_001_m.copy()
hv_tb_no_001_001_m_g_001 = hv_tb_no_001_001_m.copy()

#hv_tb_no_001_001_m.index=hv_tb_no_001_001_m.index.date
hv_tb_no_001_001_m = hv_tb_no_001_001_m.tail(horizon_tb)
hv_tb_no_001_001_t1=hv_tb_no_001_001_m.tail(horizon_tb)

hv_tb_no_001_001_m_t = hv_tb_no_001_001_m.transpose()
hv_tb_no_001_001_m_t.index.names = ['Variable']

hv_tb_no_001_001_t1_t = hv_tb_no_001_001_t1.transpose()
hv_tb_no_001_001_t1_t.index.names = ['Variable']
# Out:
#             nonpcy  nonpcxe1  nonpcyte  nonpc20  nonpcmw
# 2002-01-31     NaN       2.8       NaN      NaN      NaN
# 2002-02-28     NaN       2.5       NaN      NaN      NaN
# 2002-03-31     NaN       2.9       NaN      NaN      NaN
# 2002-04-30     NaN       2.7       NaN      NaN      NaN
# 2002-05-31     NaN       2.9       NaN      NaN      NaN
# ...            ...       ...       ...      ...      ...
# 2024-10-31     2.6       2.5       2.7      2.6      3.5
# 2024-11-30     2.4       2.7       3.0      2.8      4.2
# 2024-12-31     2.2       2.5       2.7      3.2      4.3
# 2025-01-31     2.3       2.5       2.8      2.9      4.0
# 2025-02-28     3.6       3.1       3.4      3.7      4.3
#
# [278 rows x 5 columns]

# %% [markdown]
# ### 001 norway cpi table

# %%
############################################################
######Table 1

#####here*******
title_table="no_cpi_yy_table"
df =hv_tb_no_001_001_t1.copy()
df_transposed = hv_tb_no_001_001_t1_t.copy()


fig, ax = plt.subplots(figsize=(16, 8))  # Increase figure width for more space
sns.heatmap(df_transposed, annot=True, fmt=".0f", cmap="coolwarm", cbar=False, 
            linewidths=0.5, linecolor='black', ax=ax, annot_kws={"fontsize": 10})

xtick_labels = [date.strftime('%Y-%m') for date in df.index]  # Convert to 'YYYY-MM'
ax.set_xticks(np.arange(len(df.index)) + 0.5)  # Align ticks at the center of cells
ax.set_xticklabels(xtick_labels, rotation=35, ha='center', fontweight="bold")
ax.xaxis.set_tick_params(labeltop=True, labelbottom=True)

ax.set_xlim(-0.5, len(df.index) - 0.5)  # Center the x-ticks properly
ax.tick_params(axis="y", labelleft=True, labelright=False, right=False, labelsize=12)

# Adjust font size of left y-axis tick labels
for tick in ax.get_yticklabels(which='both', minor=False):
    if tick.get_position()[0] == 0:  # Left y-axis ticks
        tick.set_fontsize(12)  # Increase font size for left y-axis labels

ax.set_title(title_table, fontsize=16, fontweight='bold', pad=20)

# Adjust layout and margins to ensure the last column is fully visible
plt.subplots_adjust(right=0.92, left=0.05, bottom=0.12, top=0.93)  # Adjusting margins
plt.tight_layout(pad=3.0)  # Adjust padding for better fit

plt.savefig("hv_tb_no_001_001_m_t_001.png", dpi=300, bbox_inches="tight")
plt.close()




#########################################################################
###table 2
#####here*******

df = hv_tb_no_001_001_t1.copy()


df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df = df.transpose()
df.index.names = ['Variable']
df["Index"] = df.index
column_to_move = "Index"
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
df.fillna(" ", inplace=True)
df["Variables "] = df.index


fig = go.Figure(data=[go.Table(
    header=dict(
        values=new_columns,
        font=dict(size=12),  # Increase header font size here
        fill_color='paleturquoise',
        align='right',
        height=45,  # Increased height of the header row
  #      textangle=35  # Set the rotation angle to 35 degrees
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ), columnwidth=[400] + [80] * (len(new_columns) - 1) + [400]  # Set first and last columns to 400
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=True,
                  width=1500,
                  height=700,
                  title=title_table)  # Add title here
fig.write_image('hv_tb_no_001_001_m_t_002.png')

# %% [markdown]
# ### 001 norway cpi graphs

# %%
df1 = hv_tb_no_001_001_m_g.copy()
df1 = df1.tail(48)
g1 = df1.copy()
list_c = g1.columns.tolist()
title_r = str(list_c[0])
y_label = "Growth %"
x_label = title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[0], color="black", linewidth=l1, linestyle="-",
        marker="D", markersize=s3-1)
for x, y in zip(g1.index, g1[list_c[0]]):
    label = "{:.1f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x, y)
                 size=8,
                 ha='center')
for series_name in list_c[0:1]:
    last_y_value = g1[series_name][-1]
    plt.annotate(f"{series_name} {last_y_value}", xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())

x_position = 0.5  # Adjust this value
y_position = 0.5  # Adjust this value to place the text inside the plot
plt.text(0.1, 0.5, '[Norway]', fontsize=12, transform=plt.gca().transAxes,
         bbox=dict(facecolor='white', alpha=0.5))  # Adding the text box
plt.text(0.5, 0.5, 'Norges', fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_no_001_001_m_g_001.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
# del gl
# del df1
del list_c
del fig
del ax
del ax2

# %%
g1 = df1.copy()
list_c = g1.columns.tolist()
title_r = str(list_c[0])
y_label = "Growth %"
x_label = title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[1], color="black", linewidth=l1, linestyle="-", marker="D", markersize=s1)
for x, y in zip(g1.index, g1[list_c[1]]):
    label = "{:.1f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0, 18), # distance from text to points (x,y)
                 size=8,
                 ha="center")
for series_name in list_c[1:2]:
    last_y_value = g1[series_name][-1]
    plt.annotate(f"{series_name} ({last_y_value})", xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle="->"))
plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
x_position = 0.5  # Adjust this value
y_position = 0.5  # Adjust this value to place the text inside the plot
plt.text(0.1, 0.5, 'Norway', fontsize=12, transform=plt.gca().transAxes,
         bbox=dict(facecolor="white", alpha=0.5)) # Adding the text box
plt.text(0.5, 0.5, 'Norges', fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_no_001_001_m_g_002.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
#del gi
#del dfl
del list_c
del fig
del ax
del ax2

# %%
g1=df1.copy()
list_c=g1.columns.tolist()
title_r=str(list_c[2])
y_label="Growth %"
x_label=title_r
fig,ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax,y=list_c[2], color="black", linewidth=l1, linestyle="-", marker="D", markersize=s1)
for x,y in zip(g1.index,g1[list_c[2]]):
    label = "{:.1f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0, 18), # distance from text to points (x,y)
                 size=8,
                 ha="center")
for series_name in list_c[2:3]:
    last_y_value = g1[series_name][-1]
    plt.annotate(f'({series_name}: {last_y_value})', xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords='offset points', arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
x_position = 0.5  # Adjust this value
y_position = 0.5  # Adjust this value to place the text inside the plot
plt.text(0.1, 0.5, 'Norway', fontsize=12, transform=plt.gca().transAxes,
         bbox=dict(facecolor='white', alpha=0.5))  # Adding the text box
plt.text(0.5, 0.5, 'Norges', fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_no_001_001_m_g_003.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
#det gi
#del afl
del list_c
del fig
del ax
del ax2

# %%
g1=df1.copy()
list_c=g1.columns.tolist()
title_r=str(list_c[2])
y_label="Growth %"
x_label=title_r
fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))
g1.plot(kind='line', ax=ax, y=list_c[3], color="black", linewidth=l1, linestyle="-", marker="D", markersize=s1)

for x, y in zip(g1.index, g1[list_c[3]]):
    label = "{:.1f}".format(y)
    plt.annotate(label,  # this is the text
                 (x, y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 18),  # distance from text to points (x, y)
                 size=8,
                 ha='center')

for series_name in list_c[3:4]:
    last_y_value = g1[series_name][-1]
    # print(last_y_value)
    plt.annotate(f"({series_name}): ({last_y_value})", xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=0.3)
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
x_position = 0.5  # Adjust this value
y_position = 0.5  # Adjust this value to place the text inside the plot
plt.text(0.1, 0.5, 'Norway', fontsize=12, transform=plt.gca().transAxes,
         bbox=dict(facecolor='white', alpha=0.5))  # Adding the text box
plt.text(0.5, 0.5, 'Norges', fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_no_001_001_m_g_004.png", bbox_inches='tight')
plt.close()
plt.close('all')
plt.clf()
plt.cla()
del g1
#del dfi
del list_c
del fig
del ax
del ax2

# %%
g1=df1.copy()
list_c=g1.columns.tolist()
title_r=str(list_c[4])
y_label="Growth %"
x_label=title_r
fig,ax=plt.subplots(figsize=(parameter1_s,parameter2_s))
g1.plot(kind="line", ax=ax, y=list_c[4], color="black", linewidth=l1, linestyle="-", marker="D", markersize=s1)
for x,y in zip(g1.index,g1[list_c[4]]):
    label="{:.1f}".format(y)
    plt.annotate(label,  # this is the text
                 (x,y),  # these are the coordinates to position the label
                 textcoords="offset points",  # how to position the text
                 xytext=(0,18),  # distance from text to points (x,y)
                 size=8,
                 ha='center')
for series_name in list_c[4:5]:
    last_y_value = g1[series_name][-1]
    #print(last_y_value)
    plt.annotate(f"{series_name} ({last_y_value})", xy=(g1.index.max(), last_y_value),
                 xytext=(30, 15), textcoords="offset points", arrowprops=dict(facecolor="black", arrowstyle='->'))

plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
plt.style.use('default')
plt.ylabel(str(y_label), size=parameter3)
plt.xlabel(str(x_label), size=parameter3)
plt.tick_params(labelsize=parameter4)
plt.title(str(title_r), size=parameter5)
plt.grid(axis='both', alpha=0.3)
ax2=ax.twinx()
ax2.set_ylim(ax.get_ylim())
x_position = 0.5  # Adjust this value
y_position = 0.5  # Adjust this value to place the text inside the plot
plt.text(0.1, 0.5, 'Norway', fontsize=12, transform=plt.gca().transAxes,
         bbox=dict(facecolor='white', alpha=0.5))  # Adding the text box
plt.text(0.5, 0.5, 'Norges', fontsize=40, color='gray', alpha=0.5,
         ha='center', va='center', rotation=30, transform=plt.gca().transAxes)
plt.savefig("hv_tb_no_001_001_m_g_005.png", bbox_inches="tight")
plt.close()
plt.close('all')
plt.clf()
plt.cla()
# del gi
# del df1
del list_c
del fig
del ax
del ax2

# %% [markdown]
# ### 001_norges projections <a id="title_page"></a

# %%
# Annual
nok_m_tickers = ['noawg']
hv_tb_no_001_001_m = Haver.data(nok_m_tickers, country_database, dates=True)
hv_tb_no_001_001_m.rename(columns={"noawg": "Norges projected wage growth annual"}, inplace=True)
hv_tb_no_001_001_g1 = hv_tb_no_001_001_m.copy()
print(hv_tb_no_001_001_g1.tail(5))
# Quarterly
nok_m_tickers = ['nofsbc', 'nogpq',
                 'noxni', 'nopoi',
                 'nophi', 'nof3m', 
                 'nonmg', 'nondg', 
                 'nocpi', 'nopca']
hv_tb_no_001_001_m = Haver.data(nok_m_tickers, country_database, dates=True)
hv_tb_no_001_001_m.rename(columns={"nofsbc": "Norges projected key policy rate baseline quarterly"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nogpq": "Norges projected gdp mainland quarterly"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"noxni": "Norges projected imported weighted exchange rate quarterly"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nopoi": "Norges projected oil price quarterly"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nophi": "Norges projected house prices quarterly"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nof3m": "Norges projected money market premium quarterly"}, inplace=True)
# hv_tb_no_001_001_m.rename(columns={"noduz": "Norges projected capacity utilization quarterly"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nonmg": "Norges projected cpi ate imported goods quarterly"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nondg": "Norges projected cpi ate domestic goods services quarterly"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nocpi": "Norges projected cpi baseline quarterly"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nopca": "Norges projected cpi ate baseline quarterly"}, inplace=True)
hv_tb_no_001_001_g2 = hv_tb_no_001_001_m.copy()
# Monthly
nok_m_tickers = ['nogpm', 'nounr', 'nopcm', 'nopcm']
hv_tb_no_001_001_m = Haver.data(nok_m_tickers, country_database, dates=True)
hv_tb_no_001_001_m.rename(columns={'nogpm': 'Norges projected gdp mainland monthly'}, inplace=True)
hv_tb_no_001_001_m.rename(columns={'nounr': 'Norges projected registered unemployment rate'}, inplace=True)
hv_tb_no_001_001_m.rename(columns={'nocpm': 'Norges projected cpi baseline monthly'}, inplace=True)
hv_tb_no_001_001_m.rename(columns={'nopcm': 'Norges projected cpi ate baseline monthly'}, inplace=True)


hv_tb_no_001_001_g3 = hv_tb_no_001_001_m.copy()
hv_tb_no_001_001_g4 = pd.concat([hv_tb_no_001_001_g1, hv_tb_no_001_001_g2], axis=1, join='outer')
hv_tb_no_001_001_g4 = pd.concat([hv_tb_no_001_001_g4, hv_tb_no_001_001_g3], axis=1, join='outer')

nok_m_tickers = ['noawg', 'nofsbc', 'nogpq', 'noxni', 
                 'nopoi', 'nophi', 'nof3m', 'nonmg',
                 'nondg', 'nogpm', 'nounr', 'nocpm', 'nopcm']
df1 = hv_tb_no_001_001_g4.copy()
g1 = df1.copy()
list_c = g1.columns.tolist()
title_r = str(list_c[0])
for i in range(len(nok_m_tickers)):
    print(i)
    ai = f"{i:02}"
    print(ai)
    nok_m_tickers_str = str(nok_m_tickers[i])
    hv_tb_no_001_001_m = Haver.data(nok_m_tickers_str, country_database, dates=True)
    hv_tb_no_001_001_m.rename(columns={"noawg": "Norges projected wage growth annual"}, inplace=True)
    hv_tb_no_001_001_m.rename(columns={"nofsbc": "Norges projected key policy rate baseline quarterly"}, inplace=True)
    hv_tb_no_001_001_m.rename(columns={"nogpq": "Norges projected gdp mainland quarterly"}, inplace=True)
    hv_tb_no_001_001_m.rename(columns={"noxni": "Norges projected imported weighted exchange rate quarterly"}, inplace=True)
    hv_tb_no_001_001_m.rename(columns={"nopoi": "Norges projected oil price quarterly"}, inplace=True)
    hv_tb_no_001_001_m.rename(columns={"nophi": "Norges projected house prices quarterly"}, inplace=True)
    hv_tb_no_001_001_m.rename(columns={"nof3m": "Norges projected money market premium quarterly"}, inplace=True)
    hv_tb_no_001_001_m.rename(columns={"noduz": "Norges projected capacity utilization quarterly"}, inplace=True)
    hv_tb_no_001_001_m.rename(columns={"nonmg": "Norges projected cpi ate imported goods quarterly"}, inplace=True)
    hv_tb_no_001_001_m.rename(columns={"nondg": "Norges projected cpi ate domestic goods services quarterly"}, inplace=True)
    hv_tb_no_001_001_m.rename(columns={"nocpi": "Norges projected cpi baseline quarterly"}, inplace=True)
    hv_tb_no_001_001_m.rename(columns={"nopca": "Norges projected cpi ate baseline quarterly"}, inplace=True)
    hv_tb_no_001_001_m.rename(columns={"nogpm": "Norges projected gdp mainland monthly"}, inplace=True)
    hv_tb_no_001_001_m.rename(columns={"nounr": "Norges projected registered unemployment rate"}, inplace=True)
    hv_tb_no_001_001_m.rename(columns={"nocpm": "Norges projected cpi baseline monthly"}, inplace=True)
    hv_tb_no_001_001_m.rename(columns={"nopcm": "Norges projected cpi ate baseline monthly"}, inplace=True)

    g1 = df1.copy()
    list_c = g1.columns.tolist()
    title_r = str(list_c[i])
    y_label = "Growth %"
    x_label = title_r
   
    fig, ax = plt.subplots(figsize=(parameter1_s, parameter2_s))  
    g1.plot(kind='line', ax=ax, y=list_c[i], color="darkred", 
            linewidth=l1, linestyle='-', marker='D', markersize=(s3-3))
    for x, y in zip(g1.index, g1[list_c[i]]):
        label = "{:.2f}".format(y)
        x = x.date()
        label = f"{label}%\n[{x}]"
        plt.annotate(label,  # this is the text
                     (x, y),  # these are the coordinates to position the label
                     textcoords="offset points",  # how to position the text
                     xytext=(0, 10),  # distance from text to points (x, y)
                     size=6,
                     ha='left',
                     rotation=30,
                     weight='bold')
    
    # plt.axhline(0, color="black", lw=1, linestyle='dashed', alpha=0.75)
    plt.style.use("default") 
    plt.ylabel(str(y_label), size=parameter3)
    plt.xlabel(str(x_label), size=parameter3)
    plt.tick_params(labelsize=7)
    plt.title(str(title_r), size=parameter5)
    plt.grid(axis='both', alpha=.3)
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    x_position = 0.5  # Adjust this value
    y_position = 0.5  # Adjust this value to place the text inside the plot
    plt.text(0.05, 0.5, 
             "[Norway]",
             fontsize=12, transform=plt.gca().transAxes,
             bbox=dict(facecolor='white',
                       alpha=0.5))  # Adding the text box
    plt.text(0.5, 0.5, "", 
             fontsize=40,
             color="gray",
             alpha=0.5,
             ha="center",
             va="center",
             rotation=30,
             transform=plt.gca().transAxes)
    plt.savefig(str("hv_tb_no_001_005_m_g_0" + str(ai) + ".png"), bbox_inches="tight")
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    #del gi
    #del df1
    del list_c
    del fig
    del ax
    del ax2
# Out:
#             Norges projected wage growth annual
# 2024-12-31                                  5.2
# 2025-12-31                                  4.2
# 0
# 00
# 1
# 01
# 2
# 02
# 3
# 03
# 4
# 04
# 5
# 05
# 6
# 06
# 7
# 07
# 8
# 08
# 9
# 09
# 10
# 10
# 11
# 11
# 12
# 12

# %%
print("Complete")
# Out:
# Complete

# %% [markdown]
# ### 001_norges projections <a id="title_page"></a

# %%
no_m_tickers1 = ['nocpi','nopca','nondg','nonmg',
                'noxni','nopoi','nofsbc','nogpq']
hv_tb_no_000_001_m = Haver.data(no_m_tickers1, "NORDIC", dates=True)
#hv_tb_no_000_001_m.to_clipboard()
no_m_tickers2 =['nocpm','nopcm','nogpm','nounr']
hv_tb_no_000_002_m = Haver.data(no_m_tickers2, "NORDIC", dates=True)
hv_tb_no_001_001_m = pd.concat([hv_tb_no_000_001_m, hv_tb_no_000_002_m], axis=1, join="outer")
nok_m_tickers = ['nocpm', 'nopcm', 'nocpi',
                 'nopca', 'nondg', 'nonmg',
                 'nogpm', 'nogpq', 'nounr',
                 'noxni', 'nopoi', 'nofsbc']
hv_tb_no_001_001_m = hv_tb_no_001_001_m[nok_m_tickers]


hv_tb_no_001_001_m.rename(columns={"nofsbc": "policy rate baseline"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nogpq":"gdp quarterly"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"noxni":"exchange rate"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nopoi": "oil"}, inplace=True)
#hv_tb_no_001_001_m.rename(columns=("nophi": "Norges projected house prices quarterly"), inplace=True)
#hv_tb_no_001_001_m.rename(columns=("nof3m": "Norges projected money market premium quarterly"), inplace=True)
#hv_tb_no_001_001_m.rename(columns=["noduz": "Norges projected capacity utilization quarterly"), inplace=True)
hv_tb_no_001_001_m.rename(columns={"nonmg": "cpi ate imported"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nondg":"cpi ate domestic"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nocpi": "cpi q"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nopca": "cpi ate q"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nogpm":"gdp monthly"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nounr": "unemployment"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nocpm":"cpi monthly"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nopcm": "cpi ate monthly"}, inplace=True)


import seaborn as sns
import plotly.graph_objects as go

#hv_tb_swe_001_001_m_c=hv_tb_swe_001_001_m_c[list_c]
#hv_tb_swe_001_001_m_c.rename(columns={"Riksbank forecast cpi yy nsa monthly": "cpi yy nsa"), inplace=True)

#hv_tb_swe_001_001_m_c.rename(columns=["Riksbank forecast cpif yy nsa monthly": "cpif yy nso"), inplace=True)
#hv_tb_swe_001_001_m_c.rename(columns={"Riksbank forecast cpif xe yy nsa monthly": "cpif xe yy"), inplace=True)

#hv_tb_swe_001_001_m_c.rename(columns="Riksbank forecast unemployment rate sa": "unemployment"}, inplace=True)
#hv_tb_swe_001_001_m_c.rename(columns={"Riksbank forecast policy rate quarterly average": "policy rate q"), inplace=True)

#hv_tb_swe_001_001_m_c["Riksbank forecast cpi yy nsa monthly"]= hv_tb_swe_001_001_m_c["Riksbank forecast cpi yy nsa monthly"].round(1)
#hv_tb_swe_001_001_m_c["Riksbank forecast cpif yy nsa monthly"]= hv_tb_swe_001_001_m_c["Riksbank forecast cpif yy nsa monthly"].round(1)

#hv_tb_swe_001_001_m_c["Riksbank forecast cpif xe yy nsa monthly"]= hv_tb_swe_001_001_m_c["Riksbank forecast cpif xe yy nsa monthly"].round(1)

# Move to save 001_001_m_c.index to 001_001_m_c.index.date
#hv_tb_001_001_m_c.index = hv_tb_001_001_m_c.index.date
#print(hv_tb_001_001_m_c.shape[1])

df = hv_tb_no_001_001_m.copy()
df.index = pd.to_datetime(df.index)
df.index = df.index.strftime("%Y-%m")
df["Index"] = df.index
df["Index"] = df.index
column_to_move = "Index"
# Reorder columns
new_columns = [column_to_move] + [col for col in df.columns if col != column_to_move]
df = df[new_columns]
# df = df.transpose()
# df.reset_index(inplace=True)
df.fillna(" ", inplace=True)
modified_column_names = [f'{col}<br>' for col in df.columns]
#modified_column_names = [f"<span style='writing-mode: tb-rl; transform: rotate(-180deg);'>{col}</span>" for col in df.columns]
fig = go.Figure(data=[go.Table(
    header=dict(
        values=modified_column_names,
        font=dict(size=9),  # Increase header font size here
        fill_color='paleturquoise',
        align='center',
        height=40  # Increased height of the header row
    ),
    cells=dict(
        values=df.transpose().values.tolist(),
        font=dict(size=13),  # Increase cell font size here
        align='center'
    ),
    # Specify column widths here, adjust values as needed
    # columnwidth=[900, 100, 100, 100, 100]
)])

fig.update_layout(autosize=False,
                  width=1400,
                  height=600,
                  title="Norway Norges Inflation Forecast")  # Add title here
fig.write_image('hv_tb_norway_forecast_cpi.png')

# %%
hv_tb_no_001_001_m=hv_tb_no_001_001_m.tail(60)
n_time=45
#size figure
#wide
size1=32
size2=16
font_size_h=13
number_vbs=12
x_sizel=17
x2_sizel=x_sizel-5
xlabel_size=20
### axes-1 Lael sie dates
axes_1label=12
title_s=32
df1=hv_tb_no_001_001_m.copy()
df1=df1.tail(n_time)
df1=df1.transpose()
df1.index.names = ["Variable"]
num_rows = df1.shape[0]
for x in range(num_rows):
    # print(x)
    locals()[str(str("data_r") + str(x))] = pd.DataFrame([df1.iloc[x]])
    # print("end Loop")
for x in range(num_rows):
    # print(x)
    locals()[str(str("vmin_") + str(x))] = hv_tb_no_001_001_m.iloc[:, x].min()
    locals()[str(str("vmax_") + str(x))] = hv_tb_no_001_001_m.iloc[:, x].max()
    # print("end Loop")
print(vmin_0)
print(vmax_0)
red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")
reversed_red_to_blue = list(reversed(reversed_red_to_blue))

fig, axes = plt.subplots(number_vbs, 1, figsize=(size1, size2), sharex=True)

sns.heatmap(data_r0, cmap=red_to_blue, annot=True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to Blue'})
sns.heatmap(data_r1, cmap=red_to_blue, annot=True, ax=axes[1], cbar=False, vmin=vmin_1, vmax=vmax_1, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to Blue'})
sns.heatmap(data_r2, cmap=red_to_blue, annot=True, ax=axes[2], cbar=False, vmin=vmin_2, vmax=vmax_2, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to Blue'})
sns.heatmap(data_r3, cmap=red_to_blue, annot=True, ax=axes[3], cbar=False, vmin=vmin_3, vmax=vmax_3, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to Blue'})
sns.heatmap(data_r4, cmap=red_to_blue, annot=True, ax=axes[4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to Blue'})
sns.heatmap(data_r5, cmap=red_to_blue, annot=True, ax=axes[5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to Blue'})
sns.heatmap(data_r6, cmap=red_to_blue, annot=True, ax=axes[6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to Blue'})
sns.heatmap(data_r7, cmap=red_to_blue, annot=True, ax=axes[7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to Blue'})
sns.heatmap(data_r8, cmap=red_to_blue, annot=True, ax=axes[8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to Blue'})
sns.heatmap(data_r9, cmap=red_to_blue, annot=True, ax=axes[9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to Blue'})
sns.heatmap(data_r10, cmap=red_to_blue, annot=True, ax=axes[10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to Blue'})
sns.heatmap(data_r11, cmap=red_to_blue, annot=True, ax=axes[11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g',
            annot_kws={'size': font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to Blue'})


n=0
for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_sizel, rotation=0)
    locals()[str(str("axes_t") + str(n))] = ax.twinx()
    locals()[str(str("axes_t") + str(n))].set_yticklabels(ax.get_yticklabels(), fontsize=x2_sizel, rotation=0, va="center")
    # ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    n = (n + 1)

axes[11].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=15, size=0)
# axes[-1].set_xticklabels(axis="x", which="both", length=0, Labelrotation=45)
# .set_xticks([])

fig.suptitle("Norway Economic Dashboard [ARM]", fontsize=title_s)
plt.figtext(0.5, 0.01, "Norway Economic Dashboard [ARM]", fontsize=title_s, ha="center")

plt.subplots_adjust(hspace=-.1)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])

plt.savefig('norway_forecast_heatmap_001.png', bbox_inches='tight', dpi=300)
plt.show()

plt.close()
# Out:
# 2.3
# 2.8

# %% [markdown]
# ### 001_norges heatmap <a id="title_page"></a

# %%
##### heatmaps

import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt
from PIL import Image
horizon_00=120

print("monthly")
#nostr47

no_m_tickers1 = ["nohngpc", "nosch", "nosd06", "nosdbc", "nonhja",
                 "nonpcmw", "nospc", "nonpcy", "nonpcxe", "nonpcxl",
                 "nonpcxe1", "nonpcyte","nonpc20","nonpcmw",
                 "nostr47c", "nontr47", "nosele", "noselsr",
                 "noselcr", "nosdb", "nosdc", "nonejn",
                 "nonrdl", "nonron", "noneiv",
                 "nonefv", "nonrdmhe", "nonlfrg"]
hv_tb_no_000_001_m=Haver.data(no_m_tickers1, "NORDIC", dates=True)
print(hv_tb_no_000_001_m)
no_m_tickers2 = ["nonemi", "nosvz", "nongdpcy", "nonncpcy", "nonnchcy",
                "nonncgcy", "nonnfbcy", "nonnxcy", "nonnmcy", "nonnutcy", "nonndtcy", "nosv4qau", "nonelpw"]
hv_tb_no_000_002_m = Haver.data(no_m_tickers2, "NORDIC", dates=True)
print(hv_tb_no_000_002_m)
hv_tb_no_001_001_m = pd.concat([hv_tb_no_000_001_m, hv_tb_no_000_002_m], axis=1, join="outer")
hv_tb_no_001_001_m = hv_tb_no_001_001_m.fillna(method='bfill')
no_m_tickers = no_m_tickers1 + no_m_tickers2
# Out:
# monthly
#              nohngpc  nosch  nosd06  nosdbc  nonhja  nonpcmw  nospc  nonpcy  \
# 1975-01-31       NaN    NaN     NaN     NaN     NaN      NaN    NaN     NaN
# 1975-02-28       NaN    NaN     NaN     NaN     NaN      NaN    NaN     NaN
# 1975-03-31       NaN    NaN     NaN     NaN     NaN      NaN    NaN     NaN
# 1975-04-30       NaN    NaN     NaN     NaN     NaN      NaN    NaN     NaN
# 1975-05-31       NaN    NaN     NaN     NaN     NaN      NaN    NaN     NaN
# ...              ...    ...     ...     ...     ...      ...    ...     ...
# 2024-10-31  484538.0  142.7   103.7   100.6  53.962      3.5  134.5     2.6
# 2024-11-30  484138.0  143.8   103.4   101.9  51.447      4.2  134.9     2.4
# 2024-12-31  483454.0  142.2   102.7   105.5  51.142      4.3  135.2     2.2
# 2025-01-31       NaN  144.3   100.3   103.4  52.183      4.0  135.9     2.3
# 2025-02-28       NaN    NaN     NaN     NaN  52.520      4.3  137.5     3.6
#
# ...

# %%
# Calculations
hv_tb_no_001_001_m['nospc'] = hv_tb_no_001_001_m['nospc'].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_no_001_001_m.rename(columns={"nospc": "Prices: Norway CPI yy sa"}, inplace=True)
hv_tb_no_001_001_m['nonpcxe'] = hv_tb_no_001_001_m['nonpcxe'].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_no_001_001_m.rename(columns={"nonpcxe": "Prices: Norway CPI excluding energy yy sa"}, inplace=True)
hv_tb_no_001_001_m['nonpcxl'] = hv_tb_no_001_001_m['nonpcxl'].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_no_001_001_m.rename(columns={"nonpcxl": "Prices: Norway CPI excluding electricity yy sa"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nonpcy": "Prices: Norway CPI nsa"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nonpcxe1": "Prices: Norway CPI ATE nsa"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nonpcyte": "Prices: Norway CPIXE nsa"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nonpc20": "Prices: Norway CPI-AT trimmed mean nsa"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nonpcmw": "Prices: Norway CPI-AT weighted mean nsa"}, inplace=True)
hv_tb_no_001_001_m['nonhja'] = hv_tb_no_001_001_m['nonhja'].pct_change(periods=12, fill_method='bfill').multiply(100).round(1)
hv_tb_no_001_001_m.rename(columns={"nonhja": "Real: Norway House Price per Sq meter NSA"}, inplace=True)
hv_tb_no_001_001_m['nosdbc'] = hv_tb_no_001_001_m['nosdbc'].round()
hv_tb_no_001_001_m.rename(columns={"nosdbc": "Real: Industrial Production Mining Manufacturing swda"}, inplace=True)
hv_tb_no_001_001_m['nosd06'] = hv_tb_no_001_001_m['nosd06'].round(8)
hv_tb_no_001_001_m.rename(columns={"nosd06": "Real: Extraction Services swda"}, inplace=True)
hv_tb_no_001_001_m['nosdb'] = hv_tb_no_001_001_m['nosdb'].round(0)
hv_tb_no_001_001_m.rename(columns={"nosdb": "Real: Mining quarrying swda"}, inplace=True)
hv_tb_no_001_001_m['nosdc'] = hv_tb_no_001_001_m['nosdc'].round(8)
hv_tb_no_001_001_m.rename(columns={"nosdc": "Real: Manufacturing swda"}, inplace=True)
hv_tb_no_001_001_m['nosv4qau'] = hv_tb_no_001_001_m['nosv4qau'].round(0)
hv_tb_no_001_001_m.rename(columns={"nosv4qau": "Real: Capacity Utilization sa"}, inplace=True)
hv_tb_no_001_001_m['nontr47'] = hv_tb_no_001_001_m['nontr47'].pct_change(periods=12,
                                                                         fill_method="bfill").multiply(100).round(1)
hv_tb_no_001_001_m.rename(columns={"nontr47": "Real: Retail Sales Value sa"}, inplace=True)
hv_tb_no_001_001_m['nostr47c'] = hv_tb_no_001_001_m['nostr47c'].pct_change(periods=12,
                                                                           fill_method="bfill").multiply(100).round(1)
hv_tb_no_001_001_m.rename(columns={"nostr47c": "Real: Retail Sales Volume sa"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"noselcr": "Employment: Unemployment Rate SA"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"noselsr": "Employment: Unemployment and jobseekers Rate SA"}, inplace=True)
hv_tb_no_001_001_m['nosele'] = hv_tb_no_001_001_m['nosele'].diff()
hv_tb_no_001_001_m.rename(columns={"nosele": "Employment: Employed and jobseekers Rate SA"}, inplace=True)
hv_tb_no_001_001_m['nonejn'] = hv_tb_no_001_001_m['nonejn'].pct_change(periods=12,
                                                                       fill_method='bfill').multiply(100).round(1)
hv_tb_no_001_001_m.rename(columns={"nonejn": "Employment: job vacancies eop"}, inplace=True)
hv_tb_no_001_001_m['nonemi'] = hv_tb_no_001_001_m['nonemi'].pct_change(periods=12,
                                                                       fill_method="bfill").multiply(100).round(1)
hv_tb_no_001_001_m.rename(columns={"nonemi": "Employment: Compensation of employees"}, inplace=True)
hv_tb_no_001_001_m['nonelpw'] = hv_tb_no_001_001_m['nonelpw'].pct_change(periods=12,
                                                                         fill_method="bfill").multiply(100).round(1)
hv_tb_no_001_001_m.rename(columns={"nonelpw": "Employment: population"}, inplace=True)
hv_tb_no_001_001_m['nonlfrg'] = hv_tb_no_001_001_m['nonlfrg'].pct_change(periods=12,
                                                                         fill_method='bfill').multiply(100).round(1)

hv_tb_no_001_001_m.rename(columns={"nonlfrg": "Financial: International Reserves eop nsa"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nonrdmhe": "Financial: Sight deposit rate"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nonrdl": "Financial: overnight lending rate eop"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nonron": "Financial: NOWA eop"}, inplace=True)
hv_tb_no_001_001_m["noneiv"] = hv_tb_no_001_001_m["noneiv"].round(0)
hv_tb_no_001_001_m.rename(columns={"noneiv": "Financial: Nok imported weighted index avg"}, inplace=True)
hv_tb_no_001_001_m["nonefv"] = hv_tb_no_001_001_m["nonefv"].round(0)
hv_tb_no_001_001_m.rename(columns={"nonefv": "Financial: Nok trade weighted index avg"}, inplace=True)
hv_tb_no_001_001_m["nosvz"] = hv_tb_no_001_001_m["nosvz"].round(0)
hv_tb_no_001_001_m.rename(columns={"nosvz": "Cycle: Norway Consumer Confidence Quarterly SA"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nosvze": "Cycle: Norway Consumer Confidence next year Quarterly SA"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nongdpcy": "Real: Gdp real growth rate nsa"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nonncpcy": "Real: Gdp private consumption expenditure yy nsa"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nonnchcy": "Real: Gdp household consumption expenditure yy nsa"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nonncgcy": "Real: Gdp government consumption expenditure yy nsa"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nonnfbcy": "Real: Gdp gross capital formation Quarterly yy nsa"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nonnxcy": "Real: Gdp exports goods services Quarterly yy nsa"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nonnmcy": "Real: Gdp import goods services Quarterly yy nsa"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nonnutcy": "Real: Gdp total demand Quarterly yy nsa"}, inplace=True)
hv_tb_no_001_001_m.rename(columns={"nonndtcy": "Real: Gdp total domestic demand Quarterly yy nsa"}, inplace=True)

hv_tb_no_001_001_m["nosch"] = hv_tb_no_001_001_m["nosch"].pct_change(periods=12, fill_method="bfill").multiply(100).round(1)
hv_tb_no_001_001_m.rename(columns={"nosch": "Real: Index HH consumption all goods yy nsa"}, inplace=True)
hv_tb_no_001_001_m["nohngpc"] = hv_tb_no_001_001_m["nohngpc"].pct_change(periods=12, fill_method="bfill").multiply(100).round(1)
hv_tb_no_001_001_m.rename(columns={"nohngpc": "Real: Norway GDP monthly yy sa"}, inplace=True)
hv_tb_no_001_001_m = hv_tb_no_001_001_m.tail(60)
hv_tb_no_001_001_m.index = hv_tb_no_001_001_m.index.date

list_c = [
    "Real: Gdp real growth rate nsa",
    "Real: Gdp private consumption expenditure yy nsa",
    "Real: Gdp household consumption expenditure yy nsa",
    "Real: Gdp government consumption expenditure yy nsa",
    "Real: Gdp gross capital formation Quarterly yy nsa",
    "Real: Gdp exports goods services Quarterly yy nsa",
    "Real: Gdp import goods services Quarterly yy nsa",
    "Real: Gdp total demand Quarterly yy nsa",
    "Real: Gdp total domestic demand Quarterly yy nsa",
    "Real: Index HH consumption all goods yy nsa",
    "Real: Norway GDP monthly yy sa",
    "Real: Norway House Price per Sq meter NSA",
    "Real: Industrial Production Mining Manufacturing swda",
    "Real: Extraction Services swda",
    "Real: Mining quarrying swda",
    "Real: Manufacturing swda",
    "Real: Capacity Utilization sa",
    "Real: Retail Sales Value sa",
    "Real: Retail Sales Volume sa",
    "Prices: Norway CPI yy sa",
    "Prices: Norway CPI excluding energy yy sa",
    "Prices: Norway CPI excluding electricity yy sa",
    "Prices: Norway CPI nsa",
    "Prices: Norway CPI ATE nsa",
    "Prices: Norway CPIXE nsa",
    "Prices: Norway CPI-AT trimmed mean nsa",
    "Prices: Norway CPI-AT weighted mean nsa",
    "Employment: Unemployment Rate SA",
    "Employment: Unemployment and jobseekers Rate SA",
    "Employment: Employed and jobseekers Rate SA",
    "Employment: job vacancies eop",
    "Employment: Compensation of employees",
    "Employment: population",
    "Financial: International Reserves eop nsa",
    "Financial: Sight deposit rate",
    "Financial: overnight lending rate eop",
    "Financial: NOWA eop",
    "Financial: Nok imported weighted index avg",
    "Financial: Nok trade weighted index avg",
    "Cycle: Norway Consumer Confidence Quarterly SA"
]
hv_tb_no_001_001_m=hv_tb_no_001_001_m[list_c]
hv_tb_no_001_001_m_c=hv_tb_no_001_001_m.copy()
hv_tb_no_001_001_m_c=hv_tb_no_001_001_m_c.tail(120)
hv_tb_no_001_001_m=hv_tb_no_001_001_m.tail(60)

# %%
#Financial: International International eop nsa
#Financial: Non improte weighted index avg
#Cycle: Norway Consumer Confidence next year Quarterly SA
n_time=45
#size figure
#wide
size1=32
#height
size2=size1/1.1
#heatmaps inside
font_size_h=10
number_vbs=40
#x size Label, axis
x_sizel=17
#axis 2 Label
x2_sizel=x_sizel-5
xlabel_size=20
#axes-1 Lael sie dates
axes_1label=12
title_s=32
df1=hv_tb_no_001_001_m.copy()
df1=df1.tail(n_time)
df1=df1.transpose()
df1.index.names=['Variable']


num_rows = df1.shape[0]
for x in range(num_rows):
    #print(x)
    locals()[str(str("data_r")+str(x))] = pd.DataFrame([df1.iloc[x]])

    #print("end Loop")

for x in range(num_rows):
    #print(x)

    locals()[str(str("vmin_")+str(x))] = hv_tb_no_001_001_m.iloc[:,x].min()
    locals()[str(str("vmax_")+str(x))] = hv_tb_no_001_001_m.iloc[:,x].max()

    #print("end Loop")

print(vmin_0)
print(vmax_0)

#data = np.random.random((10,12))
#df1 = pd.DataFrame(data)

red_to_blue = sns.color_palette("coolwarm", as_cmap=True)
reversed_red_to_blue = sns.color_palette("coolwarm")
reversed_red_to_blue = list(reversed(reversed_red_to_blue))
#sns.color_palette("coolwarm", as_cmap=True)

fig, axes = plt.subplots(number_vbs, 1, figsize=(size1, size2), sharex=True)


sns.heatmap(data_r0, cmap=red_to_blue, annot=True, ax=axes[0], cbar=False, vmin=vmin_0, vmax=vmax_0, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r1, cmap=red_to_blue, annot=True, ax=axes[1], cbar=False, vmin=vmin_1, vmax=vmax_1, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r2, cmap=red_to_blue, annot=True, ax=axes[2], cbar=False, vmin=vmin_2, vmax=vmax_2, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r3, cmap=red_to_blue, annot=True, ax=axes[3], cbar=False, vmin=vmin_3, vmax=vmax_3, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r4, cmap=red_to_blue, annot=True, ax=axes[4], cbar=False, vmin=vmin_4, vmax=vmax_4, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r5, cmap=red_to_blue, annot=True, ax=axes[5], cbar=False, vmin=vmin_5, vmax=vmax_5, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r6, cmap=red_to_blue, annot=True, ax=axes[6], cbar=False, vmin=vmin_6, vmax=vmax_6, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r7, cmap=red_to_blue, annot=True, ax=axes[7], cbar=False, vmin=vmin_7, vmax=vmax_7, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r8, cmap=red_to_blue, annot=True, ax=axes[8], cbar=False, vmin=vmin_8, vmax=vmax_8, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r9, cmap=red_to_blue, annot=True, ax=axes[9], cbar=False, vmin=vmin_9, vmax=vmax_9, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r10, cmap=red_to_blue, annot=True, ax=axes[10], cbar=False, vmin=vmin_10, vmax=vmax_10, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r11, cmap=red_to_blue, annot=True, ax=axes[11], cbar=False, vmin=vmin_11, vmax=vmax_11, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r12, cmap=red_to_blue, annot=True, ax=axes[12], cbar=False, vmin=vmin_12, vmax=vmax_12, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r13, cmap=red_to_blue, annot=True, ax=axes[13], cbar=False, vmin=vmin_13, vmax=vmax_13, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r14, cmap=red_to_blue, annot=True, ax=axes[14], cbar=False, vmin=vmin_14, vmax=vmax_14, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r15, cmap=red_to_blue, annot=True, ax=axes[15], cbar=False, vmin=vmin_15, vmax=vmax_15, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r16, cmap=red_to_blue, annot=True, ax=axes[16], cbar=False, vmin=vmin_16, vmax=vmax_16, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r17, cmap=red_to_blue, annot=True, ax=axes[17], cbar=False, vmin=vmin_17, vmax=vmax_17, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r18, cmap=red_to_blue, annot=True, ax=axes[18], cbar=False, vmin=vmin_18, vmax=vmax_18, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r19, cmap=red_to_blue, annot=True, ax=axes[19], cbar=False, vmin=vmin_19, vmax=vmax_19, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r20, cmap=red_to_blue, annot=True, ax=axes[20], cbar=False, vmin=vmin_20, vmax=vmax_20, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})
sns.heatmap(data_r21, cmap=red_to_blue, annot=True, ax=axes[21], cbar=False, vmin=vmin_21, vmax=vmax_21, fmt='g', annot_kws={"size": font_size_h, "weight": "bold"}, cbar_kws={"label": "Red to blue"})

sns.heatmap(data_r22, cmap=red_to_blue, annot=True, ax=axes[22], cbar=False, vmin=vmin_22, vmax=vmax_22, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r23, cmap=red_to_blue, annot=True, ax=axes[23], cbar=False, vmin=vmin_23, vmax=vmax_23, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r24, cmap=red_to_blue, annot=True, ax=axes[24], cbar=False, vmin=vmin_24, vmax=vmax_24, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r25, cmap=red_to_blue, annot=True, ax=axes[25], cbar=False, vmin=vmin_25, vmax=vmax_25, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r26, cmap=red_to_blue, annot=True, ax=axes[26], cbar=False, vmin=vmin_26, vmax=vmax_26, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r27, cmap=red_to_blue, annot=True, ax=axes[27], cbar=False, vmin=vmin_27, vmax=vmax_27, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r28, cmap=red_to_blue, annot=True, ax=axes[28], cbar=False, vmin=vmin_28, vmax=vmax_28, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r29, cmap=red_to_blue, annot=True, ax=axes[29], cbar=False, vmin=vmin_29, vmax=vmax_29, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r30, cmap=red_to_blue, annot=True, ax=axes[30], cbar=False, vmin=vmin_30, vmax=vmax_30, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r31, cmap=red_to_blue, annot=True, ax=axes[31], cbar=False, vmin=vmin_31, vmax=vmax_31, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r32, cmap=red_to_blue, annot=True, ax=axes[32], cbar=False, vmin=vmin_32, vmax=vmax_32, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r33, cmap=red_to_blue, annot=True, ax=axes[33], cbar=False, vmin=vmin_33, vmax=vmax_33, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r34, cmap=red_to_blue, annot=True, ax=axes[34], cbar=False, vmin=vmin_34, vmax=vmax_34, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r35, cmap=red_to_blue, annot=True, ax=axes[35], cbar=False, vmin=vmin_35, vmax=vmax_35, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r36, cmap=red_to_blue, annot=True, ax=axes[36], cbar=False, vmin=vmin_36, vmax=vmax_36, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r37, cmap=red_to_blue, annot=True, ax=axes[37], cbar=False, vmin=vmin_37, vmax=vmax_37, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r38, cmap=red_to_blue, annot=True, ax=axes[38], cbar=False, vmin=vmin_38, vmax=vmax_38, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})
sns.heatmap(data_r39, cmap=red_to_blue, annot=True, ax=axes[39], cbar=False, vmin=vmin_39, vmax=vmax_39, fmt='g',
            annot_kws={"size": font_size_h, 'weight': 'bold'}, cbar_kws={'label': 'Red to blue'})

for ax in axes:
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=x_sizel, rotation=2)
    locals()[str(str("axes_t") + str(n))] = ax.twinx()
    locals()[str(str("axes_t") + str(n))].set_yticklabels(ax.get_yticklabels(), 
                                                          fontsize=x2_sizel,
                                                          rotation=0,
                                                          va="center")
    n = n + 1
    
axes[-1].tick_params(axis="x", which="both", length=0, labelrotation=45, labelsize=15, size=0)
fig.suptitle("Norway Economic Dashboard [ARM]", fontsize=title_s)
plt.figtext(0.5, 0.01, "Norway Economic Dashboard [ARM]", fontsize=title_s, ha="center")
plt.subplots_adjust(hspace=-.1)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig('norway_heatmap_001.png', bbox_inches='tight', dpi=300)
plt.show()
plt.close()
# Out:
# -4.1
# 5.8

# %%
print(hv_tb_no_001_001_m.columns.to_list())
# Out:
# ['Real: Gdp real growth rate nsa', 'Real: Gdp private consumption expenditure yy nsa', 'Real: Gdp household consumption expenditure yy nsa', 'Real: Gdp government consumption expenditure yy nsa', 'Real: Gdp gross capital formation Quarterly yy nsa', 'Real: Gdp exports goods services Quarterly yy nsa', 'Real: Gdp import goods services Quarterly yy nsa', 'Real: Gdp total demand Quarterly yy nsa', 'Real: Gdp total domestic demand Quarterly yy nsa', 'Real: Index HH consumption all goods yy nsa', 'Real: Norway GDP monthly yy sa', 'Real: Norway House Price per Sq meter NSA', 'Real: Industrial Production Mining Manufacturing swda', 'Real: Extraction Services swda', 'Real: Mining quarrying swda', 'Real: Manufacturing swda', 'Real: Capacity Utilization sa', 'Real: Retail Sales Value sa', 'Real: Retail Sales Volume sa', 'Prices: Norway CPI yy sa', 'Prices: Norway CPI excluding energy yy sa', 'Prices: Norway CPI excluding electricity yy sa', 'Prices: Norway CPI nsa', 'Prices: Norway CPI ATE nsa
# ...

# %% [markdown]
# ### 001_norges heatmap birdeye <a id="title_page"></a

# %%
hv_tb_no_001_001_m_g=hv_tb_no_001_001_m.copy()
print("start right here")
parameter1_o=6
parameter2_o=4
tail_n=102
tail_n2=48
linew=2
mks=0.5
list_c=["Real: Gdp real growth rate nsa",
        "Real: Gdp private consumption expenditure yy nsa",
        "Real: Gdp household consumption expenditure yy nsa",
        "Real: Gdp government consumption expenditure yy nsa",
        "Real: Gdp gross capital formation Quarterly yy nsa",
        "Real: Gdp exports goods services Quarterly yy nsa",
        "Real: Gdp import goods services Quarterly yy nsa",
        "Real: Gdp total demand Quarterly yy nsa",
        "Real: Gdp total domestic demand Quarterly yy nsa",
        "Real: Index HH consumption all goods yy nsa",
        "Real: Norway GDP monthly yy sa",
        "Real: Norway House Price per Sq meter NSA",
        "Real: Industrial Production Mining Manufacturing swda",
        "Real: Extraction Services swda",
        "Real: Mining quarrying swda",
        "Real: Manufacturing swda",
        "Real: Capacity Utilization sa",
        "Real: Retail Sales Value sa",
        "Real: Retail Sales Volume sa",
        "Prices: Norway CPI yy sa",
        "Prices: Norway CPI excluding energy yy sa",
        "Prices: Norway CPI excluding electricity yy sa",
        "Prices: Norway CPI nsa",
        "Prices: Norway CPI ATE nsa",
        "Prices: Norway CPIXE nsa",
        "Prices: Norway CPI-AT trimmed mean nsa",
        "Prices: Norway CPI-AT weighted mean nsa",
        "Employment: Unemployment Rate SA",
        "Employment: Unemployment and jobseekers Rate SA",
        "Employment: Employed and jobseekers Rate SA",
        "Employment: job vacancies eop",
        "Employment: Compensation of employees",
        "Employment: population",
        "Financial: International Reserves eop nsa",
        "Financial: Sight deposit rate",
        "Financial: overnight lending rate eop",
        "Financial: NOWA eop",
        "Financial: Nok imported weighted index avg",
        "Financial: Nok trade weighted index avg",
        "Cycle: Norway Consumer Confidence Quarterly SA"]



print("ojo ave, ojo ave, ojo ave, ojo ave, ojo ave, ojo ave, ojo ave, ojo ave, ojo ave, ojo ave")
n=1
for y in list_c:
    #print("filtering time horizon")
    df1 = hv_tb_no_001_001_m_g.copy()
    df1 = pd.DataFrame(df1[str(y)])
    # List_c = df1.columns.tolist()
    df1 = df1.tail(90)
    g1 = df1.copy()
    fig, ax = plt.subplots(figsize=((parameter1_o - 1), (parameter2_o)))
    g1.plot(kind='line', ax=ax, y=str(y), color="orange", linewidth=(linew + 1), linestyle='-',
            marker='o', markersize=mks)
    x_last = g1.index[-1]  # Assuming the DataFrame index is date or sequential
    y_last = g1[str(y)].iloc[-1]

    # Annotate the Last value on the right of the plot Line
    ax.annotate(f'(y_last:.2f)', xy=(x_last, y_last), xytext=(10, 0),
                textcoords="offset points",
                ha='left', va="center",
                color="orange", size=17,
                weight="bold")

    for line, name in zip(ax.lines, str(y)):
        yy = line.get_ydata()[-1]
        ax.annotate(yy, xy=(1, yy), xytext=(6, 6), color=line.get_color(), xycoords=ax.get_yaxis_transform(),
                    textcoords="offset points", size=15, va="center")

    # plt.axhline(0, color='black', lw=1, linestyle='dashed', alpha=0.75)
    plt.style.use('default')
    plt.tick_params(labelsize=parameter4)
    plt.title(str(df1.columns.tolist()[0]), size=(parameter5-2))
    plt.grid(axis='both', alpha=.3)
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim())
    plt.savefig(str("hv_tb_no_ov"+str(n)+".png"), bbox_inches='tight')
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
    del fig
    del ax
    del ax2
    n=n+1
# Out:
# start right here
# ojo ave, ojo ave, ojo ave, ojo ave, ojo ave, ojo ave, ojo ave, ojo ave, ojo ave, ojo ave
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# ...

# %%
import warnings
# Ignore all warning messages
warnings.filterwarnings("ignore")

# Variable: projected rate path = cpi, gap, oil, fx, ur
# Norges Bank Norges Projected Key Policy Rate

nok_m_tickers = ['nofsb241', 'nofsb234', 'nofsb233', 'nofsb231',
                'nofsb224', 'nofsb223', 'nofsb222', 'nofsb221',
                'nofsb214', 'nofsb213', 'nofsb212', 'nofsb211',
                'nofsb204', 'nofsb203', 'nofsb202', 'nofsb201',
                'nofsb194', 'nofsb193', 'nofsb192', 'nofsb191',
                'nofsb184', 'nofsb183', 'nofsb182', 'nofsb181',
                'nofsb174', 'nofsb173', 'nofsb172', 'nofsb171',
                'nofsb164', 'nofsb163', 'nofsb162', 'nofsb161']

hv_tb_nok_001_001_h = Haver.data(nok_m_tickers, "NORDIC", dates=True)

# %%
###### Norges Monthlh GDP
nok_m_tickers=['nogpm241',
'nogpm234', 'nogpm233',
'nogpm224', 'nogpm223', 'nogpm222', 'nogpm221',
'nogpm214', 'nogpm213', 'nogpm212', 'nogpm211',
'nogpm204', 'nogpm203', 'nogpm202',]

hv_tb_nok_001_001_h=Haver.data(nok_m_tickers, "NORDIC", dates=True)

# %%
#forecast_df_gdp_mm-data001.copy()
#forecast_df_gdp_mm.to_clipboard()



###Norges OIL PATH
nok_m_tickers=['nono1244', 'nono1243', 'nono1242', 'nono1241',
              'nono1234', 'nono1233', 'nono1232', 'nono1231',
              'nono1224', 'nono1223', 'nono1222', 'nono1221',
              'nono1214', 'nono1213', 'nono1212', 'nono1211',
              'nono1204', 'nono1203', 'nono1202', 'nono1201',
              'nono1194', 'nono1193', 'nono1192', 'nono1191',
              'nono1184', 'nono1183', 'nono1182', 'nono1181',
              'nono1174', 'nono1173', 'nono1172', 'nono1171',
              'nono1164', 'nono1163', 'nono1162', 'nono1161']

hv_tb_nok_001_001_h = Haver.data(nok_m_tickers, "NORDIC", dates=True)

# %%
# Norges weighted exchange rate

nok_m_tickers = ['noxn1241', 'noxn1234', 'noxn1233', 'noxn1231',
                 'noxn1224', 'noxn1223', 'noxn1222', 'noxn1221',
                 'noxn1214', 'noxn1213', 'noxn1212', 'noxn1211',
                 'noxn1204', 'noxn1203', 'noxn1202', 'noxn1201',
                 'noxn1194', 'noxn1193', 'noxn1192', 'noxn1191',
                 'noxn1184', 'noxn1183', 'noxn1182', 'noxn1181',
                 'noxn1174', 'noxn1173', 'noxn1172', 'noxn1171',
                 'noxn1164', 'noxn1163', 'noxn1162', 'noxn1161']

hv_tb_nok_001_001_h0 = Haver.data(nok_m_tickers, "NORDIC", dates=True)

# %%
# Norges unemployment registers
nok_m_tickers = ['nounr241',
                 'nounr234', 'nounr233', 'nounr232', 'nounr231',
                 'nounr224', 'nounr223', 'nounr222', 'nounr221',
                 'nounr214', 'nounr213', 'nounr212', 'nounr211',
                 'nounr204', 'nounr203', 'nounr202', 'nounr201',
                 'nounr194', 'nounr193', 'nounr192', 'nounr191',
                 'nounr184', 'nounr183', 'nounr182', 'nounr181']

hv_tb_nok_001_001_h = Haver.data(nok_m_tickers, "NORDIC", dates=True)

# %%
################################################################################
# Norges CPI PROJECTED
nok_m_tickers = ['nocpm241',
                 'nocpm234', 'nocpm233', 'nocpm232', 'nocpm231',
                 'nocpm224', 'nocpm223', 'nocpm222', 'nocpm221',
                 'nocpm214', 'nocpm213', 'nocpm212', 'nocpm211',
                 'nocpm204', 'nocpm203', 'nocpm202', 'nocpm201',
                 'nocpm194', 'nocpm193', 'nocpm192', 'nocpm191',
                 'nocpm184', 'nocpm183', 'nocpm182', 'nocpm181']

# %%
###########Norges CPI ATE PROJECTED

nok_m_tickers = ["nopcm241", "nopcm234", "nopcm233", "nopcm232", "nopcm231", 
                 "nopcm224", "nopcm223", "nopcm222", "nopcm221", "nopcm214", 
                 "nopcm213", "nopcm212", "nopcm211", "nopcm204", "nopcm203",
                 "nopcm202", "nopcm201", "nopcm194", "nopcm193", "nopcm192", 
                 "nopcm191", "nopcm184", "nopcm183", "nopcm182"]

# %%
import warnings
warnings.filterwarnings("ignore")

#cpi, cpi ate, gdp monthly, oil, weighted fx
print("monthly real data")

no_m_tickers1 = ["nonrdl", "nospc", "nonpcxe", "nonpcy", "nonpcxel",
                "noselcr", "noselsr",
                "noneiv", "nonefv",
                "nohngpc"]
# Out:
# monthly real data

# %%
nok_m_tickers = [
    "nofsb241", "nofsb234", "nofsb233", "nofsb231",
    "nofsb224", "nofsb223", "nofsb222", "nofsb221",
    "nofsb214", "nofsb213", "nofsb212", "nofsb211",
    "nofsb204", "nofsb203", "nofsb202", "nofsb201",
    "nofsb194", "nofsb193", "nofsb192", "nofsb191",
    "nofsb184", "nofsb183", "nofsb182", "nofsb181",
    "nofsb174", "nofsb173", "nofsb172", "nofsb171",
    "nofsb164", "nofsb163", "nofsb162", "nofsb161",
]

# %%
# "nofsb184", "nofsb183", "nofsb182", "nofsb181",
# "nofsb174", "nofsb173", "nofsb172", "nofsb171",
# "nofsb164", "nofsb163", "nofsb162", "nofsb161",
# "nofsb234", "nofsb233", "nofsb232", "nofsb231",
# "nofsb224", "nofsb223", "nofsb222", "nofsb221",
# "nofsb214", "nofsb213", "nofsb212", "nofsb211",
# "nofsb204", "nofsb203"

nok_m_tickers = ['nofsb234', 'nofsb233', 'nofsb232', 'nofsb231',
                'nofsb224', 'nofsb223', 'nofsb222', 'nofsb221',
                'nofsb214', 'nofsb213', 'nofsb212', 'nofsb211',
                'nofsb204', 'nofsb203']

# %%
nok_m_tickers=['nofsb241',
               'nofsb234', 'nofsb233', 'nofsb231',
               'nofsb224', 'nofsb223', 'nofsb222', 'nofsb221',
               'nofsb214', 'nofsb213', 'nofsb212', 'nofsb211',
               'nofsb204', 'nofsb203', 'nofsb202', 'nofsb201',
               'nofsb194', 'nofsb193', 'nofsb192', 'nofsb191',
               'nofsb184', 'nofsb183', 'nofsb182', 'nofsb181',
               'nofsb174', 'nofsb173', 'nofsb172', 'nofsb171',
               'nofsb164', 'nofsb163', 'nofsb162', 'nofsb161']

# %% [markdown]
# ### clean

# %%
import gc
import sys

def cleanup_environment():
    # List all variables in the global scope
    globals_copy = globals().copy()
    
    # Delete DataFrames specifically (and optionally other variables)
    for var_name, var_value in globals_copy.items():
        if isinstance(var_value, pd.DataFrame):  # Checks if it's a DataFrame
            print(f"Deleting DataFrame: {var_name}")
            del globals()[var_name]
    
    # Trigger garbage collection
    gc.collect()
    print("Environment cleaned!")

# Call the cleanup function
cleanup_environment()
# Out:
# Deleting DataFrame: hv_tb_no_001_001_m
# Deleting DataFrame: hv_tb_no_001_001_m_g
# Deleting DataFrame: hv_tb_no_001_001_m_g_001
# Deleting DataFrame: hv_tb_no_001_001_t1
# Deleting DataFrame: hv_tb_no_001_001_m_t
# Deleting DataFrame: hv_tb_no_001_001_t1_t
# Deleting DataFrame: df
# Deleting DataFrame: df_transposed
# Deleting DataFrame: df1
# Deleting DataFrame: g1
# Deleting DataFrame: hv_tb_no_001_001_g1
# Deleting DataFrame: hv_tb_no_001_001_g2
# Deleting DataFrame: hv_tb_no_001_001_g3
# Deleting DataFrame: hv_tb_no_001_001_g4
# Deleting DataFrame: hv_tb_no_000_001_m
# Deleting DataFrame: hv_tb_no_000_002_m
# Deleting DataFrame: data_r0
# Deleting DataFrame: data_r1
# Deleting DataFrame: data_r2
# Deleting DataFrame: data_r3
# Deleting DataFrame: data_r4
# Deleting DataFrame: data_r5
# Deleting DataFrame: data_r6
# Deleting DataFrame: data_r7
# Deleting DataFrame: data_r8
# Deleting DataFrame: data_r9
# Deleting DataFrame: data_r10
# Deleting DataFrame: data_r11
# ...

# %% [markdown]
# ### 001_bottom <a id="title_page"></a
